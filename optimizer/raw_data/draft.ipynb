# %%
import pandas as pd

# Replace with your actual file path
df = pd.read_csv("LoanApp.csv.gz", compression='gzip')

# Print column names
print(df.columns)
# Out:
# Index(['case_id', 'resource', 'activity', 'start_time', 'end_time'], dtype='object')

# %%
list_of_all_end_activities = []
for case_id in range(0,200):
    # print(case_id, simulated[simulated['case_id'] == case_id].tail(1)['activity_name'].values[0])
    list_of_all_end_activities.append(df[df['case_id'] == case_id].tail(1)['activity'].values[0])
list_of_all_end_activities = list(set(list_of_all_end_activities))

# %%
list_of_all_end_activities
# Out:
# ['Cancel application', 'Reject application', 'Approve application']

# %%
for i in range(0,1000):
    case_rows = df[df['case_id'] == i]
    if len(case_rows)==16:
        print(case_rows)
        print("----")

# %% [markdown]
# Get Strict Pre-requisites

# %%
from collections import defaultdict

# %%
def discover_strict_prerequisites_from_log(df, activity_col='activity', case_col='case_id', order_by='end_timestamp'):
    # Step 1: Collect all activities that appear before each activity in each case
    activity_to_preceding_sets = defaultdict(list)

    for case_id, group in df.groupby(case_col):
        sorted_activities = group.sort_values(by=order_by)[activity_col].tolist()
        seen = set()
        for i, act in enumerate(sorted_activities):
            activity_to_preceding_sets[act].append(seen.copy())
            seen.add(act)

    # Step 2: Intersect the "seen-before" sets across all cases
    raw_prerequisites = {}
    for act, preceding_sets in activity_to_preceding_sets.items():
        if preceding_sets:
            raw_prerequisites[act] = set.intersection(*preceding_sets)
        else:
            raw_prerequisites[act] = set()

    # Step 3: Remove transitive dependencies
    # If A → B and B → C, remove A from prerequisites of C
    def remove_transitive(prereq_dict):
        cleaned = {}
        for act in prereq_dict:
            direct_prereqs = prereq_dict[act].copy()
            # Remove any indirect dependencies
            for p in direct_prereqs.copy():
                indirects = prereq_dict.get(p, set())
                direct_prereqs -= indirects
            cleaned[act] = list(direct_prereqs)
        return cleaned

    strict_prerequisites = remove_transitive(raw_prerequisites)
    return strict_prerequisites

# %%
# load logs


strict_prereqs = discover_strict_prerequisites_from_log(df)
for act, pre in strict_prereqs.items():
    print(f"{act}: {pre}")

# %% [markdown]
# Test: get pre-requisites and paths from raw logs

# %%
df['activity'].unique()
# Out:
# array(['Check application form completeness', 'Check credit history',
#        'Appraise property', 'AML check', 'Assess loan risk',
#        'Design loan offer', 'Approve loan offer', 'Cancel application',
#        'Approve application', 'Reject application',
#        'Return application back to applicant', 'Applicant completes form'],
#       dtype=object)

# %%
list_of_all_end_activities = []
first_activities = []
for case_id in range(0,200):
    first_activity = df[df['case_id'] == case_id].iloc[0]['activity']
    first_activities.append(first_activity)
first_activities = list(set(first_activities))

# %%
first_activities 
# no pre-requisites for 'Check application form completeness'
# Out:
# ['Check application form completeness']

# %%
list_of_all_end_activities = []
second_activities = []
for case_id in range(0,200):
    second_activity = df[df['case_id'] == case_id].iloc[1]['activity']
    second_activities.append(second_activity)
second_activities = list(set(second_activities))

# %%
second_activities #  pre-requisite only 'Check application form completeness'
# Out:
# ['Check credit history',
#  'Appraise property',
#  'Return application back to applicant',
#  'AML check']

# %%
list_of_all_end_activities = []
third_activities = []
potential_prerequisites = []
for case_id in range(0,200):
    third_activity = df[df['case_id'] == case_id].iloc[2]['activity']
    if third_activity == 'Applicant completes form':
        potential_prerequisites.append(df[df['case_id'] == case_id].iloc[1:2]['activity'].values[0])
    third_activities.append(third_activity)
third_activities = list(set(third_activities))
print(third_activities)
potential_prerequisites = list(set(potential_prerequisites))
print(potential_prerequisites)  # only pre-requisite for 'Applicant completes form' is 'Return application back to applicant'
# Out:
# ['AML check', 'Appraise property', 'Applicant completes form', 'Check credit history']
# ['Return application back to applicant']

# %%
list_of_all_end_activities = []
fifth_activities = []
potential_prerequisites = []
for case_id in range(0,200):
    fifth_activity = df[df['case_id'] == case_id].iloc[4]['activity']
    fifth_activities.append(fifth_activity)
    if fifth_activity == 'Assess loan risk':
        # print(df[df['case_id'] == case_id].iloc[1:3]['activity'].values)
        potential_prerequisites.append(df[df['case_id'] == case_id].iloc[1:4]['activity'].values.tolist())
fifth_activities = list(set(fifth_activities))
print(fifth_activities)
# potential_prerequisites = list(set(potential_prerequisites))
potential_prerequisites = {tuple(sorted(pair)) for pair in potential_prerequisites}

print(potential_prerequisites)
# prerequisites of 'Assess loan risk': ('AML check', 'Appraise property', 'Check credit history')
# Out:
# ['AML check', 'Assess loan risk', 'Check credit history', 'Appraise property', 'Return application back to applicant']
# {('AML check', 'Appraise property', 'Check credit history')}

# %%
list_of_all_end_activities = []
sixth_activities = []
potential_prerequisites_design = []
potential_prerequisites_reject = []
for case_id in range(0,200):
    sixth_activity = df[df['case_id'] == case_id].iloc[5]['activity']
    sixth_activities.append(sixth_activity)
    if sixth_activity == 'Design loan offer':
        potential_prerequisites_design.append(df[df['case_id'] == case_id].iloc[1:5]['activity'].values.tolist())
    if sixth_activity == 'Reject application':
        potential_prerequisites_reject.append(df[df['case_id'] == case_id].iloc[1:5]['activity'].values.tolist())
sixth_activities = list(set(sixth_activities))
print(sixth_activities)

potential_prerequisites_design = {tuple(sorted(triple)) for triple in potential_prerequisites_design}
potential_prerequisites_design = [list(triple) for triple in potential_prerequisites_design]
potential_prerequisites_reject = {tuple(sorted(triple)) for triple in potential_prerequisites_reject}
potential_prerequisites_reject = [list(triple) for triple in potential_prerequisites_reject]
print(potential_prerequisites_design)
# prerequisites of 'Design loan offer' and 'Reject application': Assess loan risk
# Out:
# ['AML check', 'Design loan offer', 'Reject application', 'Check credit history', 'Appraise property', 'Applicant completes form']
# [['AML check', 'Appraise property', 'Assess loan risk', 'Check credit history']]

# %%
df[df['case_id'] == 0]
# Out:
#     case_id                 resource                             activity  \
# 0         0             Clerk-000001  Check application form completeness
# 2         0             Clerk-000002                 Check credit history
# 7         0  AML Investigator-000001                            AML check
# 8         0         Appraiser-000001                    Appraise property
# 12        0      Loan Officer-000001                     Assess loan risk
# 13        0      Loan Officer-000002                    Design loan offer
# 15        0    Senior Officer-000001                   Approve loan offer
# 16        0             Clerk-000003                   Cancel application
#
#                  start_time                 end_time
# 0   2023-02-09T08:00:00.000  2023-02-09T08:28:27.808
# 2   2023-02-09T08:28:27.808  2023-02-09T09:00:01.030
# 7   2023-02-09T08:28:27.808  2023-02-09T09:25:12.258
# 8   2023-02-09T08:28:27.808  2023-02-09T09:35:08.311
# 12  2023-02-09T09:35:08.311  2023-02-09T09:55:08.311
# 13  2023-02-09T09:55:08.311  2023-02-09T10:01:45.244
# 15  2023-02-09T10:01:45.244  2023-02-09T10:21:45.244
# 16  2023-02-09T10:21:45.244  2023-02-09T10:26:45.244

# %%
list_of_all_end_activities = []
seventh_activities = []
potential_prerequisites = []
for case_id in range(0,200):
    if len(df[df['case_id'] == case_id])>6:
        seventh_activity = df[df['case_id'] == case_id].iloc[6]['activity']
        seventh_activities.append(seventh_activity)
        if seventh_activity == 'Approve loan offer':
            potential_prerequisites.append(df[df['case_id'] == case_id].iloc[1:6]['activity'].values.tolist())
            # if df[df['case_id'] == case_id].iloc[1:5]['activity'].values.tolist()[-1] != 'Assess loan risk':
            #     print(df[df['case_id'] == case_id].iloc[1:5]['activity'].values.tolist()[-1])
       
seventh_activities = list(set(seventh_activities))
# print(seventh_activities)
potential_prerequisites = {tuple(sorted(triple)) for triple in potential_prerequisites}
potential_prerequisites = [list(triple) for triple in potential_prerequisites]
print(potential_prerequisites)

# prerequisites of 'Approve loan offer': Design loan offer
# Out:
# [['AML check', 'Appraise property', 'Assess loan risk', 'Check credit history', 'Design loan offer']]

# %%
list_of_all_end_activities = []
eight_activities = []
potential_prerequisites = []
for case_id in range(0,200):
    if len(df[df['case_id'] == case_id])>7:
        eight_activity = df[df['case_id'] == case_id].iloc[7]['activity']
        eight_activities.append(eight_activity)
        if eight_activity == 'Cancel application':
            potential_prerequisites.append(df[df['case_id'] == case_id].iloc[1:7]['activity'].values.tolist())
            # if df[df['case_id'] == case_id].iloc[1:5]['activity'].values.tolist()[-1] != 'Assess loan risk':
            #     print(df[df['case_id'] == case_id].iloc[1:5]['activity'].values.tolist()[-1])
       
eight_activities = list(set(eight_activities))
print(eight_activities)
potential_prerequisites = {tuple(sorted(triple)) for triple in potential_prerequisites}
potential_prerequisites = [list(triple) for triple in potential_prerequisites]
print(potential_prerequisites)
# prerequisites of 'Cancel application': 'Approve loan offer'
# Out:
# ['Assess loan risk', 'Check credit history', 'Cancel application', 'Appraise property', 'Approve application']
# [['AML check', 'Appraise property', 'Approve loan offer', 'Assess loan risk', 'Check credit history', 'Design loan offer']]

# %%
potential_prerequisites = []
for case_id in range(0,200):
    if not df.loc[(df['case_id'] == case_id) & (df['activity'] == 'Return application back to applicant')].empty:
        print(df.loc[(df['case_id'] == case_id)])

# prerequisites of 'Return application back to applicant': ['Check application form completeness']
# Out:
#      case_id                 resource                              activity  \
# 103       13             Clerk-000007   Check application form completeness
# 104       13             Clerk-000005  Return application back to applicant
# 116       13         Applicant-000001              Applicant completes form
# 118       13             Clerk-000007   Check application form completeness
# 120       13             Clerk-000004                  Check credit history
# 126       13  AML Investigator-000002                             AML check
# 128       13         Appraiser-000002                     Appraise property
# 135       13      Loan Officer-000004                      Assess loan risk
# 136       13      Loan Officer-000001                     Design loan offer
# 142       13    Senior Officer-000002                    Approve loan offer
# 144       13             Clerk-000003                   Approve application
#
#                   start_time                 end_time
# 103  2023-02-09T14:30:00.000  2023-02-10T07:42:33.186
# 104  2023-02-10T07:42:33.186  2023-02-10T07:47:33.186
# 116  2023-02-10T07:47:33.186  2023-02-10T08:47:33.186
# 118  2023-02-10T08:47:33.186  2023-02-10T09:07:57.007
# 120  2023-02-10T09:07:57.007  2023-02-10T09:16:48.261
# 126  2023-02-10T09:07:57.007  2023-02-10T09:47:01.830
# 128  2023-02-10T09:07:57.007  2023-02-10T09:59:18.744
# 135  2023-02-10T09:59:18.744  2023-02-10T10:19:18.744
# 136  2023-02-10T10:19:18.744  2023-02-10T10:22:26.346
# 142  2023-02-10T10:22:26.346  2023-02-10T10:42:26.346
# 144  2023-02-10T10:42:26.346  2023-02-10T10:47:26.346
#      case_id                 resource                              activity  \
# 315       45             Clerk-000006   Check application form completeness
# 317       45             Clerk-000007  Return application back to applicant
# 328       45         Applicant-000001              Applicant completes form
# 330       45             Clerk-000003   Check application form completeness
# 334       45         Appraiser-000001                     Appraise property
# 344       45             Clerk-000006                  Check credit history
# 360       45  AML Investigator-000002                             AML check
# 367       45      Loan Officer-000001                      Assess loan risk
# 373       45             Clerk-000008                    Reject application
#
#                   start_time                 end_time
# 315  2023-02-13T14:30:00.000  2023-02-13T14:40:54.861
# 317  2023-02-13T14:40:54.861  2023-02-13T14:45:54.861
# 328  2023-02-13T14:45:54.861  2023-02-14T07:45:54.861
# 330  2023-02-14T07:45:54.861  2023-02-14T07:48:49.314
# 334  2023-02-14T07:48:49.314  2023-02-14T08:00:23.166
# 344  2023-02-14T07:48:49.314  2023-02-14T08:54:07.313
# 360  2023-02-14T07:48:49.314  2023-02-14T09:37:06.932
# 367  2023-02-14T09:37:06.932  2023-02-14T09:57:06.932
# 373  2023-02-14T09:57:06.932  2023-02-14T10:07:06.932
#      case_id                 resource                              activity  \
# 331       46             Clerk-000002   Check application form completeness
# 332       46             Clerk-000007  Return application back to applicant
# 345       46         Applicant-000001              Applicant completes form
# 347       46             Clerk-000008   Check application form completeness
# 350       46         Appraiser-000002                     Appraise property
# 354       46  AML Investigator-000001                             AML check
# 355       46             Clerk-000005                  Check credit history
# 365       46      Loan Officer-000002                      Assess loan risk
# 369       46             Clerk-000006                    Reject application
#
#                   start_time                 end_time
# 331  2023-02-13T15:00:00.000  2023-02-14T07:52:57.955
# 332  2023-02-14T07:52:57.955  2023-02-14T07:57:57.955
# 345  2023-02-14T07:57:57.955  2023-02-14T08:57:57.955
# 347  2023-02-14T08:57:57.955  2023-02-14T09:10:12.097
# 350  2023-02-14T09:10:12.097  2023-02-14T09:16:43.139
# 354  2023-02-14T09:16:20.512  2023-02-14T09:27:45.449
# 355  2023-02-14T09:10:12.097  2023-02-14T09:28:23.879
# 365  2023-02-14T09:28:23.879  2023-02-14T09:48:23.879
# 369  2023-02-14T09:48:23.879  2023-02-14T09:58:23.879
#      case_id                 resource                              activity  \
# 434       59             Clerk-000003   Check application form completeness
# 435       59             Clerk-000004  Return application back to applicant
# 451       59         Applicant-000001              Applicant completes form
# 455       59             Clerk-000006   Check application form completeness
# 461       59         Appraiser-000002                     Appraise property
# 465       59  AML Investigator-000001                             AML check
# 477       59             Clerk-000001                  Check credit history
# 484       59      Loan Officer-000001                      Assess loan risk
# 485       59      Loan Officer-000004                     Design loan offer
# 489       59    Senior Officer-000002                    Approve loan offer
# 490       59             Clerk-000005                   Approve application
#
#                   start_time                 end_time
# 434  2023-02-14T13:30:00.000  2023-02-14T14:38:37.285
# 435  2023-02-14T14:38:37.285  2023-02-14T14:43:37.285
# 451  2023-02-14T14:43:37.285  2023-02-15T07:43:37.285
# 455  2023-02-15T07:43:37.285  2023-02-15T08:02:10.430
# 461  2023-02-15T08:02:10.430  2023-02-15T08:12:49.013
# 465  2023-02-15T08:02:10.430  2023-02-15T08:34:47.232
# 477  2023-02-15T08:02:10.430  2023-02-15T09:10:44.030
# 484  2023-02-15T09:10:44.030  2023-02-15T09:30:44.030
# 485  2023-02-15T09:30:44.030  2023-02-15T09:32:02.920
# 489  2023-02-15T09:32:02.920  2023-02-15T09:52:02.920
# 490  2023-02-15T09:52:02.920  2023-02-15T09:57:02.920
#      case_id                 resource                              activity  \
# 442       62             Clerk-000007   Check application form completeness
# 445       62             Clerk-000002  Return application back to applicant
# 469       62         Applicant-000001              Applicant completes form
# 471       62             Clerk-000006   Check application form completeness
# 475       62             Clerk-000005                  Check credit history
# 478       62  AML Investigator-000002                             AML check
# 479       62         Appraiser-000002                     Appraise property
# 486       62      Loan Officer-000002                      Assess loan risk
# 488       62             Clerk-000008                    Reject application
#
#                   start_time                 end_time
# 442  2023-02-14T15:00:00.000  2023-02-15T07:22:17.865
# 445  2023-02-15T07:22:17.865  2023-02-15T07:27:17.865
# 469  2023-02-15T07:43:37.285  2023-02-15T08:43:37.285
# 471  2023-02-15T08:43:37.285  2023-02-15T08:44:01.203
# 475  2023-02-15T08:44:01.203  2023-02-15T08:57:51.330
# 478  2023-02-15T08:55:07.344  2023-02-15T09:12:07.396
# 479  2023-02-15T08:44:01.203  2023-02-15T09:13:21.323
# 486  2023-02-15T09:13:21.323  2023-02-15T09:33:21.323
# 488  2023-02-15T09:33:21.323  2023-02-15T09:43:21.323
#      case_id                 resource                              activity  \
# 505       70             Clerk-000005   Check application form completeness
# 507       70             Clerk-000006  Return application back to applicant
# 528       70         Applicant-000001              Applicant completes form
# 530       70             Clerk-000002   Check application form completeness
# 533       70             Clerk-000007                  Check credit history
# 538       70  AML Investigator-000001                             AML check
# 539       70         Appraiser-000001                     Appraise property
# 544       70      Loan Officer-000004                      Assess loan risk
# 548       70             Clerk-000007                    Reject application
#
#                   start_time                 end_time
# 505  2023-02-15T11:00:00.000  2023-02-15T11:16:22.772
# 507  2023-02-15T11:16:22.772  2023-02-15T11:21:22.772
# 528  2023-02-15T11:21:22.772  2023-02-15T12:21:22.772
# 530  2023-02-15T12:21:22.772  2023-02-15T12:24:13.524
# 533  2023-02-15T12:24:13.524  2023-02-15T12:30:05.228
# 538  2023-02-15T12:24:13.524  2023-02-15T12:51:16.832
# 539  2023-02-15T12:24:13.524  2023-02-15T12:52:49.704
# 544  2023-02-15T12:52:49.704  2023-02-15T13:12:49.704
# 548  2023-02-15T13:12:49.704  2023-02-15T13:22:49.704
#      case_id                 resource                              activity  \
# 578       79             Clerk-000004   Check application form completeness
# 579       79             Clerk-000002  Return application back to applicant
# 588       79         Applicant-000001              Applicant completes form
# 590       79             Clerk-000002   Check application form completeness
# 592       79             Clerk-000007  Return application back to applicant
# 613       79         Applicant-000001              Applicant completes form
# 629       79             Clerk-000003   Check application form completeness
# 630       79         Appraiser-000001                     Appraise property
# 633       79             Clerk-000002                  Check credit history
# 644       79  AML Investigator-000002                             AML check
# 648       79      Loan Officer-000003                      Assess loan risk
# 650       79             Clerk-000005                    Reject application
#
#                   start_time                 end_time
# 578  2023-02-16T07:30:00.000  2023-02-16T07:35:51.401
# 579  2023-02-16T07:35:51.401  2023-02-16T07:40:51.401
# 588  2023-02-16T07:40:51.401  2023-02-16T08:40:51.401
# 590  2023-02-16T08:40:51.401  2023-02-16T08:45:27.334
# 592  2023-02-16T08:45:27.334  2023-02-16T08:50:27.334
# 613  2023-02-16T09:40:51.401  2023-02-16T10:40:51.401
# 629  2023-02-16T10:40:51.401  2023-02-16T11:35:44.938
# 630  2023-02-16T11:35:44.938  2023-02-16T11:36:18.769
# 633  2023-02-16T11:35:44.938  2023-02-16T11:39:33.888
# 644  2023-02-16T11:35:44.938  2023-02-16T12:48:55.465
# 648  2023-02-16T12:48:55.465  2023-02-16T13:08:55.465
# 650  2023-02-16T13:08:55.465  2023-02-16T13:18:55.465
#      case_id                 resource                              activity  \
# 583       80             Clerk-000006   Check application form completeness
# 584       80             Clerk-000003  Return application back to applicant
# 596       80         Applicant-000001              Applicant completes form
# 597       80             Clerk-000008   Check application form completeness
# 598       80             Clerk-000004                  Check credit history
# 601       80         Appraiser-000002                     Appraise property
# 603       80  AML Investigator-000002                             AML check
# 610       80      Loan Officer-000002                      Assess loan risk
# 611       80      Loan Officer-000004                     Design loan offer
# 617       80    Senior Officer-000001                    Approve loan offer
# 619       80             Clerk-000006                    Cancel application
#
#                   start_time                 end_time
# 583  2023-02-16T08:00:00.000  2023-02-16T08:04:12.110
# 584  2023-02-16T08:04:12.110  2023-02-16T08:09:12.110
# 596  2023-02-16T08:40:51.401  2023-02-16T09:40:51.401
# 597  2023-02-16T09:40:51.401  2023-02-16T09:45:12.924
# 598  2023-02-16T09:45:12.924  2023-02-16T09:48:27.315
# 601  2023-02-16T09:45:12.924  2023-02-16T10:11:51.242
# 603  2023-02-16T09:45:12.924  2023-02-16T10:18:38.379
# 610  2023-02-16T10:18:38.379  2023-02-16T10:38:38.379
# 611  2023-02-16T10:38:38.379  2023-02-16T10:39:22.529
# 617  2023-02-16T10:39:22.529  2023-02-16T10:59:22.529
# 619  2023-02-16T10:59:22.529  2023-02-16T11:04:22.529
#      case_id                 resource                              activity  \
# 587       81             Clerk-000008   Check application form completeness
# 589       81             Clerk-000004  Return application back to applicant
# 635       81         Applicant-000001              Applicant completes form
# 636       81             Clerk-000007   Check application form completeness
# 639       81         Appraiser-000001                     Appraise property
# 643       81             Clerk-000003                  Check credit history
# 660       81  AML Investigator-000002                             AML check
# 665       81      Loan Officer-000004                      Assess loan risk
# 673       81      Loan Officer-000002                     Design loan offer
# 681       81    Senior Officer-000002                    Approve loan offer
# 685       81             Clerk-000001                    Cancel application
#
#                   start_time                 end_time
# 587  2023-02-16T08:30:00.000  2023-02-16T08:36:49.217
# 589  2023-02-16T08:36:49.217  2023-02-16T08:41:49.217
# 635  2023-02-16T10:40:51.401  2023-02-16T11:40:51.401
# 636  2023-02-16T11:40:51.401  2023-02-16T11:42:41.596
# 639  2023-02-16T11:42:41.596  2023-02-16T11:51:34.951
# 643  2023-02-16T11:42:41.596  2023-02-16T12:16:14.562
# 660  2023-02-16T12:48:55.465  2023-02-16T13:52:41.445
# 665  2023-02-16T13:52:41.445  2023-02-16T14:12:41.445
# 673  2023-02-16T14:17:38.773  2023-02-16T14:33:54.453
# 681  2023-02-16T14:33:54.453  2023-02-16T14:53:54.453
# 685  2023-02-16T14:53:54.453  2023-02-16T14:58:54.453
#      case_id                 resource                              activity  \
# 641       88             Clerk-000001   Check application form completeness
# 642       88             Clerk-000008  Return application back to applicant
# 649       88         Applicant-000001              Applicant completes form
# 655       88             Clerk-000001   Check application form completeness
# 659       88             Clerk-000002                  Check credit history
# 671       88         Appraiser-000002                     Appraise property
# 675       88  AML Investigator-000001                             AML check
# 682       88      Loan Officer-000002                      Assess loan risk
# 687       88             Clerk-000004                    Reject application
#
#                   start_time                 end_time
# 641  2023-02-16T12:00:00.000  2023-02-16T12:11:02.123
# 642  2023-02-16T12:11:02.123  2023-02-16T12:16:02.123
# 649  2023-02-16T12:16:02.123  2023-02-16T13:16:02.123
# 655  2023-02-16T13:16:02.123  2023-02-16T13:42:06.566
# 659  2023-02-16T13:42:06.566  2023-02-16T13:48:53.812
# 671  2023-02-16T13:42:06.566  2023-02-16T14:26:20.065
# 675  2023-02-16T13:47:58.451  2023-02-16T14:34:31.149
# 682  2023-02-16T14:34:31.149  2023-02-16T14:54:31.149
# 687  2023-02-16T14:54:31.149  2023-02-17T07:04:31.149
#      case_id                 resource                              activity  \
# 689       94             Clerk-000008   Check application form completeness
# 691       94             Clerk-000005  Return application back to applicant
# 707       94         Applicant-000001              Applicant completes form
# 709       94             Clerk-000001   Check application form completeness
# 710       94         Appraiser-000001                     Appraise property
# 712       94  AML Investigator-000002                             AML check
# 733       94             Clerk-000007                  Check credit history
# 738       94      Loan Officer-000003                      Assess loan risk
# 741       94             Clerk-000005                    Reject application
#
#                   start_time                 end_time
# 689  2023-02-16T15:00:00.000  2023-02-17T07:11:31.486
# 691  2023-02-17T07:11:31.486  2023-02-17T07:16:31.486
# 707  2023-02-17T07:16:31.486  2023-02-17T08:16:31.486
# 709  2023-02-17T08:16:31.486  2023-02-17T08:21:21.772
# 710  2023-02-17T08:21:21.772  2023-02-17T08:24:26.642
# 712  2023-02-17T08:21:21.772  2023-02-17T08:30:49.699
# 733  2023-02-17T08:21:21.772  2023-02-17T09:33:54.938
# 738  2023-02-17T09:33:54.938  2023-02-17T09:53:54.938
# 741  2023-02-17T09:53:54.938  2023-02-17T10:03:54.938
#      case_id                 resource                              activity  \
# 714       97             Clerk-000002   Check application form completeness
# 717       97             Clerk-000004  Return application back to applicant
# 736       97         Applicant-000001              Applicant completes form
# 745       97             Clerk-000008   Check application form completeness
# 746       97             Clerk-000006  Return application back to applicant
# 755       97         Applicant-000001              Applicant completes form
# 756       97             Clerk-000006   Check application form completeness
# 760       97             Clerk-000007                  Check credit history
# 762       97  AML Investigator-000001                             AML check
# 783       97         Appraiser-000002                     Appraise property
# 789       97      Loan Officer-000004                      Assess loan risk
# 796       97             Clerk-000003                    Reject application
#
#                   start_time                 end_time
# 714  2023-02-17T08:30:00.000  2023-02-17T08:35:45.201
# 717  2023-02-17T08:35:45.201  2023-02-17T08:40:45.201
# 736  2023-02-17T08:40:45.201  2023-02-17T09:40:45.201
# 745  2023-02-17T09:40:45.201  2023-02-17T10:19:55.149
# 746  2023-02-17T10:19:55.149  2023-02-17T10:24:55.149
# 755  2023-02-17T10:24:55.149  2023-02-17T11:24:55.149
# 756  2023-02-17T11:24:55.149  2023-02-17T11:26:11.210
# 760  2023-02-17T11:26:11.210  2023-02-17T11:42:43.645
# 762  2023-02-17T11:26:11.210  2023-02-17T11:54:40.418
# 783  2023-02-17T11:26:11.210  2023-02-17T13:35:07.432
# 789  2023-02-17T13:35:07.432  2023-02-17T13:55:07.432
# 796  2023-02-17T13:55:07.432  2023-02-17T14:05:07.432
#      case_id                 resource                              activity  \
# 748      101             Clerk-000003   Check application form completeness
# 749      101             Clerk-000005  Return application back to applicant
# 769      101         Applicant-000001              Applicant completes form
# 803      101             Clerk-000006   Check application form completeness
# 804      101  AML Investigator-000001                             AML check
# 808      101         Appraiser-000002                     Appraise property
# 812      101             Clerk-000001                  Check credit history
# 819      101      Loan Officer-000001                      Assess loan risk
# 823      101             Clerk-000002                    Reject application
#
#                   start_time                 end_time
# 748  2023-02-17T10:30:00.000  2023-02-17T10:43:51.296
# 749  2023-02-17T10:43:51.296  2023-02-17T10:48:51.296
# 769  2023-02-17T11:24:55.149  2023-02-17T12:24:55.149
# 803  2023-02-17T12:24:55.149  2023-02-17T14:21:05.001
# 804  2023-02-17T14:21:05.001  2023-02-17T14:21:31.452
# 808  2023-02-17T14:21:05.001  2023-02-17T14:26:46.256
# 812  2023-02-17T14:21:05.001  2023-02-17T14:32:57.490
# 819  2023-02-17T14:32:57.490  2023-02-17T14:52:57.490
# 823  2023-02-17T14:52:57.490  2023-02-20T07:02:57.490
#      case_id                 resource                              activity  \
# 846      114             Clerk-000007   Check application form completeness
# 847      114             Clerk-000003  Return application back to applicant
# 861      114         Applicant-000001              Applicant completes form
# 862      114             Clerk-000003   Check application form completeness
# 865      114             Clerk-000005                  Check credit history
# 868      114         Appraiser-000002                     Appraise property
# 884      114  AML Investigator-000001                             AML check
# 892      114      Loan Officer-000004                      Assess loan risk
# 894      114             Clerk-000005                    Reject application
#
#                   start_time                 end_time
# 846  2023-02-20T09:00:00.000  2023-02-20T09:00:49.983
# 847  2023-02-20T09:00:49.983  2023-02-20T09:05:49.983
# 861  2023-02-20T09:05:49.983  2023-02-20T10:05:49.983
# 862  2023-02-20T10:05:49.983  2023-02-20T10:08:20.041
# 865  2023-02-20T10:08:20.041  2023-02-20T10:14:52.216
# 868  2023-02-20T10:08:20.041  2023-02-20T10:27:08.714
# 884  2023-02-20T10:08:20.041  2023-02-20T12:03:54.399
# 892  2023-02-20T12:03:54.399  2023-02-20T12:23:54.399
# 894  2023-02-20T12:23:54.399  2023-02-20T12:33:54.399
#      case_id                 resource                              activity  \
# 863      116             Clerk-000007   Check application form completeness
# 864      116             Clerk-000002  Return application back to applicant
# 875      116         Applicant-000001              Applicant completes form
# 876      116             Clerk-000007   Check application form completeness
# 880      116             Clerk-000002                  Check credit history
# 882      116  AML Investigator-000002                             AML check
# 883      116         Appraiser-000001                     Appraise property
# 885      116      Loan Officer-000002                      Assess loan risk
# 890      116             Clerk-000003                    Reject application
#
#                   start_time                 end_time
# 863  2023-02-20T10:00:00.000  2023-02-20T10:08:47.187
# 864  2023-02-20T10:08:47.187  2023-02-20T10:13:47.187
# 875  2023-02-20T10:13:47.187  2023-02-20T11:13:47.187
# 876  2023-02-20T11:13:47.187  2023-02-20T11:21:48.557
# 880  2023-02-20T11:21:48.557  2023-02-20T11:36:31.668
# 882  2023-02-20T11:21:48.557  2023-02-20T11:39:56.530
# 883  2023-02-20T11:21:48.557  2023-02-20T11:49:30.933
# 885  2023-02-20T11:49:30.933  2023-02-20T12:09:30.933
# 890  2023-02-20T12:09:30.933  2023-02-20T12:19:30.933
#      case_id                 resource                              activity  \
# 873      117             Clerk-000004   Check application form completeness
# 874      117             Clerk-000003  Return application back to applicant
# 887      117         Applicant-000001              Applicant completes form
# 895      117             Clerk-000007   Check application form completeness
# 896      117             Clerk-000008                  Check credit history
# 900      117         Appraiser-000001                     Appraise property
# 902      117  AML Investigator-000001                             AML check
# 908      117      Loan Officer-000002                      Assess loan risk
# 910      117      Loan Officer-000003                     Design loan offer
# 917      117    Senior Officer-000002                    Approve loan offer
# 919      117             Clerk-000006                   Approve application
#
#                   start_time                 end_time
# 873  2023-02-20T10:30:00.000  2023-02-20T11:00:27.038
# 874  2023-02-20T11:00:27.038  2023-02-20T11:05:27.038
# 887  2023-02-20T11:13:47.187  2023-02-20T12:13:47.187
# 895  2023-02-20T12:13:47.187  2023-02-20T12:35:28.763
# 896  2023-02-20T12:35:28.763  2023-02-20T12:36:04.102
# 900  2023-02-20T12:35:28.763  2023-02-20T12:39:54.387
# 902  2023-02-20T12:35:28.763  2023-02-20T12:48:48.912
# 908  2023-02-20T12:48:48.912  2023-02-20T13:08:48.912
# 910  2023-02-20T13:08:48.912  2023-02-20T13:21:56.332
# 917  2023-02-20T13:21:56.332  2023-02-20T13:41:56.332
# 919  2023-02-20T13:41:56.332  2023-02-20T13:46:56.332
#      case_id                 resource                              activity  \
# 915      123             Clerk-000001   Check application form completeness
# 916      123             Clerk-000002  Return application back to applicant
# 927      123         Applicant-000001              Applicant completes form
# 929      123             Clerk-000002   Check application form completeness
# 932      123             Clerk-000006                  Check credit history
# 936      123  AML Investigator-000002                             AML check
# 942      123         Appraiser-000002                     Appraise property
# 946      123      Loan Officer-000002                      Assess loan risk
# 949      123             Clerk-000006                    Reject application
#
#                   start_time                 end_time
# 915  2023-02-20T13:30:00.000  2023-02-20T13:32:42.133
# 916  2023-02-20T13:32:42.133  2023-02-20T13:37:42.133
# 927  2023-02-20T13:37:42.133  2023-02-20T14:37:42.133
# 929  2023-02-20T14:37:42.133  2023-02-20T14:52:08.958
# 932  2023-02-20T14:52:08.958  2023-02-20T14:57:21.607
# 936  2023-02-20T14:56:16.403  2023-02-21T07:02:55.445
# 942  2023-02-20T14:52:08.958  2023-02-21T07:24:01.069
# 946  2023-02-21T07:24:01.069  2023-02-21T07:44:01.069
# 949  2023-02-21T07:44:01.069  2023-02-21T07:54:01.069
#      case_id                 resource                              activity  \
# 950      128             Clerk-000004   Check application form completeness
# 951      128             Clerk-000005  Return application back to applicant
# 965      128         Applicant-000001              Applicant completes form
# 967      128             Clerk-000003   Check application form completeness
# 970      128         Appraiser-000002                     Appraise property
# 974      128             Clerk-000004                  Check credit history
# 978      128  AML Investigator-000001                             AML check
# 982      128      Loan Officer-000001                      Assess loan risk
# 984      128             Clerk-000001                    Reject application
#
#                   start_time                 end_time
# 950  2023-02-21T08:00:00.000  2023-02-21T08:00:20.457
# 951  2023-02-21T08:00:20.457  2023-02-21T08:05:20.457
# 965  2023-02-21T08:05:20.457  2023-02-21T09:05:20.457
# 967  2023-02-21T09:05:20.457  2023-02-21T09:11:52.192
# 970  2023-02-21T09:11:52.192  2023-02-21T09:18:17.336
# 974  2023-02-21T09:11:52.192  2023-02-21T09:25:12.168
# 978  2023-02-21T09:11:52.192  2023-02-21T09:44:17.333
# 982  2023-02-21T09:44:17.333  2023-02-21T10:04:17.333
# 984  2023-02-21T10:04:17.333  2023-02-21T10:14:17.333
#       case_id                 resource                              activity  \
# 1077      145             Clerk-000005   Check application form completeness
# 1079      145             Clerk-000007  Return application back to applicant
# 1093      145         Applicant-000001              Applicant completes form
# 1095      145             Clerk-000003   Check application form completeness
# 1098      145  AML Investigator-000001                             AML check
# 1099      145         Appraiser-000001                     Appraise property
# 1105      145             Clerk-000008                  Check credit history
# 1112      145      Loan Officer-000001                      Assess loan risk
# 1114      145      Loan Officer-000002                     Design loan offer
# 1119      145    Senior Officer-000001                    Approve loan offer
# 1122      145             Clerk-000006                    Cancel application
#
#                    start_time                 end_time
# 1077  2023-02-22T08:30:00.000  2023-02-22T08:42:38.186
# 1079  2023-02-22T08:42:38.186  2023-02-22T08:47:38.186
# 1093  2023-02-22T08:47:38.186  2023-02-22T09:47:38.186
# 1095  2023-02-22T09:47:38.186  2023-02-22T09:49:14.647
# 1098  2023-02-22T09:49:14.647  2023-02-22T10:00:49.831
# 1099  2023-02-22T09:49:14.647  2023-02-22T10:02:29.944
# 1105  2023-02-22T09:49:14.647  2023-02-22T10:31:07.468
# 1112  2023-02-22T10:31:07.468  2023-02-22T10:51:07.468
# 1114  2023-02-22T10:51:07.468  2023-02-22T10:54:04.824
# 1119  2023-02-22T10:54:04.824  2023-02-22T11:14:04.824
# 1122  2023-02-22T11:14:04.824  2023-02-22T11:19:04.824
#       case_id                 resource                              activity  \
# 1201      162             Clerk-000008   Check application form completeness
# 1202      162             Clerk-000001  Return application back to applicant
# 1213      162         Applicant-000001              Applicant completes form
# 1219      162             Clerk-000008   Check application form completeness
# 1222      162         Appraiser-000002                     Appraise property
# 1225      162  AML Investigator-000001                             AML check
# 1226      162             Clerk-000002                  Check credit history
# 1231      162      Loan Officer-000001                      Assess loan risk
# 1237      162             Clerk-000008                    Reject application
#
#                    start_time                 end_time
# 1201  2023-02-23T09:00:00.000  2023-02-23T09:12:47.952
# 1202  2023-02-23T09:12:47.952  2023-02-23T09:17:47.952
# 1213  2023-02-23T09:17:47.952  2023-02-23T10:17:47.952
# 1219  2023-02-23T10:17:47.952  2023-02-23T10:37:34.411
# 1222  2023-02-23T10:42:00.147  2023-02-23T10:52:02.642
# 1225  2023-02-23T10:37:34.411  2023-02-23T11:06:57.293
# 1226  2023-02-23T10:37:34.411  2023-02-23T11:11:10.564
# 1231  2023-02-23T11:11:10.564  2023-02-23T11:31:10.564
# 1237  2023-02-23T11:31:10.564  2023-02-23T11:41:10.564
#       case_id                 resource                              activity  \
# 1299      175             Clerk-000001   Check application form completeness
# 1300      175             Clerk-000006  Return application back to applicant
# 1311      175         Applicant-000001              Applicant completes form
# 1315      175             Clerk-000001   Check application form completeness
# 1322      175             Clerk-000007                  Check credit history
# 1328      175         Appraiser-000002                     Appraise property
# 1334      175  AML Investigator-000001                             AML check
# 1337      175      Loan Officer-000003                      Assess loan risk
# 1346      175             Clerk-000003                    Reject application
#
#                    start_time                 end_time
# 1299  2023-02-24T07:30:00.000  2023-02-24T07:53:48.727
# 1300  2023-02-24T07:53:48.727  2023-02-24T07:58:48.727
# 1311  2023-02-24T07:58:48.727  2023-02-24T08:58:48.727
# 1315  2023-02-24T08:58:48.727  2023-02-24T09:13:50.944
# 1322  2023-02-24T09:13:50.944  2023-02-24T09:49:32.764
# 1328  2023-02-24T09:13:50.944  2023-02-24T10:10:01.141
# 1334  2023-02-24T09:13:50.944  2023-02-24T10:46:31.076
# 1337  2023-02-24T10:46:31.076  2023-02-24T11:06:31.076
# 1346  2023-02-24T11:06:31.076  2023-02-24T11:16:31.076
#       case_id                 resource                              activity  \
# 1325      180             Clerk-000001   Check application form completeness
# 1327      180             Clerk-000006  Return application back to applicant
# 1336      180         Applicant-000001              Applicant completes form
# 1338      180             Clerk-000001   Check application form completeness
# 1340      180  AML Investigator-000002                             AML check
# 1347      180             Clerk-000006                  Check credit history
# 1351      180         Appraiser-000002                     Appraise property
# 1358      180      Loan Officer-000001                      Assess loan risk
# 1361      180             Clerk-000003                    Reject application
#
#                    start_time                 end_time
# 1325  2023-02-24T10:00:00.000  2023-02-24T10:00:32.407
# 1327  2023-02-24T10:00:32.407  2023-02-24T10:05:32.407
# 1336  2023-02-24T10:05:32.407  2023-02-24T11:05:32.407
# 1338  2023-02-24T11:05:32.407  2023-02-24T11:07:59.101
# 1340  2023-02-24T11:08:07.302  2023-02-24T11:08:34.980
# 1347  2023-02-24T11:07:59.101  2023-02-24T11:17:54.662
# 1351  2023-02-24T11:07:59.101  2023-02-24T11:44:43.924
# 1358  2023-02-24T11:44:43.924  2023-02-24T12:04:43.924
# 1361  2023-02-24T12:04:43.924  2023-02-24T12:14:43.924

# %% [markdown]
# Generated log checking

# %%
simulated = pd.read_csv("../simulated_data/LoanApp.csv/autonomous/simulated_log_0.csv")

# %%
list_of_all_end_activities = []
for case_id in range(0,200):
    # print(case_id, simulated[simulated['case_id'] == case_id].tail(1)['activity_name'].values[0])
    list_of_all_end_activities.append(simulated[simulated['case_id'] == case_id].tail(1)['activity_name'].values[0])
list_of_all_end_activities = list(set(list_of_all_end_activities))

# %%
list_of_all_end_activities
# Out:
# ['AML check',
#  'Check application form completeness',
#  'Approve loan offer',
#  'Reject application',
#  'Design loan offer',
#  'Assess loan risk',
#  'Check credit history',
#  'Cancel application',
#  'Appraise property',
#  'Return application back to applicant',
#  'Approve application',
#  'Applicant completes form']

# %%
l
# Out:
# [874    Cancel application
#  Name: activity_name, dtype: object,
#  874    Cancel application
#  Name: activity_name, dtype: object,
#  array(['Cancel application'], dtype=object),
#  'Cancel application']

# %%
simulated[simulated['case_id'] == 0]
# Out:
#      case_id  agent                         activity_name  \
# 0          0      0   Check application form completeness
# 1          0      9  Return application back to applicant
# 2          0      1                    Reject application
# 4          0      5  Return application back to applicant
# 5          0      3                     Appraise property
# 7          0     10  Return application back to applicant
# 10         0     14                    Approve loan offer
# 22         0      4                   Approve application
# 28         0     11                      Assess loan risk
# 36         0      9                   Approve application
# 44         0      1                   Approve application
# 51         0      8                   Approve application
# 58         0      8                    Cancel application
# 68         0      4                    Reject application
# 78         0      1                  Check credit history
# 87         0     10   Check application form completeness
# 98         0     12                    Reject application
# 109        0      8                    Reject application
# 131        0      5                    Cancel application
# 144        0     13                      Assess loan risk
# 157        0      0                    Cancel application
# 171        0      4   Check application form completeness
# 184        0      9                    Cancel application
# 211        0      1                   Approve application
# 244        0      9   Check application form completeness
# 260        0     11                     Design loan offer
# 278        0     12                    Cancel application
# 296        0     10                    Cancel application
# 314        0      2                             AML check
# 331        0      0                    Cancel application
# 349        0     12                    Cancel application
# 364        0      5                   Approve application
# 394        0      5                    Cancel application
# 411        0     12                   Approve application
# 447        0      9                    Cancel application
# 462        0     10                    Cancel application
# 478        0     10   Check application form completeness
# 497        0      9                  Check credit history
# 515        0      9                    Reject application
# 551        0     17                    Approve loan offer
# 567        0      5                    Cancel application
# 598        0     17                    Approve loan offer
# 614        0     10                    Cancel application
# 632        0      4                    Cancel application
# 650        0      9                    Cancel application
# 669        0     11                     Design loan offer
# 685        0     17                    Approve loan offer
# 705        0      1                    Cancel application
# 723        0     12   Check application form completeness
# 740        0     10                    Cancel application
# 797        0      1                    Cancel application
# 816        0     10                    Reject application
# 837        0      0                   Approve application
# 858        0     13                      Assess loan risk
# 874        0      0                    Cancel application
#
#                          start_timestamp                        end_timestamp  \
# 0              2023-04-20 08:00:00+00:00  2023-04-20 08:16:26.305513912+00:00
# 1    2023-04-20 08:16:26.305513912+00:00  2023-04-20 08:21:26.305513912+00:00
# 2    2023-04-20 08:21:26.305513912+00:00  2023-04-20 08:31:26.305513912+00:00
# 4    2023-04-20 08:31:26.305513912+00:00  2023-04-20 08:36:26.305513912+00:00
# 5    2023-04-20 08:36:26.305513912+00:00  2023-04-20 08:50:30.639385526+00:00
# 7    2023-04-20 08:50:30.639385526+00:00  2023-04-20 08:55:30.639385526+00:00
# 10   2023-04-20 08:55:30.639385526+00:00  2023-04-20 09:15:30.639385526+00:00
# 22   2023-04-20 10:44:47.228181439+00:00  2023-04-20 10:49:47.228181439+00:00
# 28   2023-04-20 10:49:47.228181439+00:00  2023-04-20 11:09:47.228181439+00:00
# 36   2023-04-20 11:09:47.228181439+00:00  2023-04-20 11:14:47.228181439+00:00
# 44   2023-04-20 11:14:47.228181439+00:00  2023-04-20 11:19:47.228181439+00:00
# 51   2023-04-20 11:19:47.228181439+00:00  2023-04-20 11:24:47.228181439+00:00
# 58   2023-04-20 11:24:47.228181439+00:00  2023-04-20 11:29:47.228181439+00:00
# 68   2023-04-20 11:29:47.228181439+00:00  2023-04-20 11:39:47.228181439+00:00
# 78   2023-04-20 11:39:47.228181439+00:00  2023-04-20 11:51:47.941921586+00:00
# 87   2023-04-20 11:51:47.941921586+00:00  2023-04-20 12:26:16.792334202+00:00
# 98   2023-04-20 12:26:16.792334202+00:00  2023-04-20 12:36:16.792334202+00:00
# 109  2023-04-20 12:36:16.792334202+00:00  2023-04-20 12:46:16.792334202+00:00
# 131  2023-04-20 13:08:43.444916226+00:00  2023-04-20 13:13:43.444916226+00:00
# 144  2023-04-20 13:13:43.444916226+00:00  2023-04-20 13:33:43.444916226+00:00
# 157  2023-04-20 13:33:43.444916226+00:00  2023-04-20 13:38:43.444916226+00:00
# 171  2023-04-20 13:38:43.444916226+00:00  2023-04-20 13:53:10.592143675+00:00
# 184  2023-04-20 13:53:10.592143675+00:00  2023-04-20 13:58:10.592143675+00:00
# 211  2023-04-20 14:31:04.124100090+00:00  2023-04-20 14:36:04.124100090+00:00
# 244  2023-04-21 08:00:00.000000025+00:00  2023-04-21 08:02:40.965164256+00:00
# 260  2023-04-21 08:02:40.965164256+00:00  2023-04-21 08:07:23.422392420+00:00
# 278  2023-04-21 08:07:23.422392420+00:00  2023-04-21 08:12:23.422392420+00:00
# 296  2023-04-21 08:12:23.422392420+00:00  2023-04-21 08:17:23.422392420+00:00
# 314  2023-04-21 08:17:23.422392420+00:00  2023-04-21 08:52:07.198886515+00:00
# 331  2023-04-21 08:52:07.198886515+00:00  2023-04-21 08:57:07.198886515+00:00
# 349  2023-04-21 08:57:07.198886515+00:00  2023-04-21 09:02:07.198886515+00:00
# 364  2023-04-21 09:02:07.198886515+00:00  2023-04-21 09:07:07.198886515+00:00
# 394  2023-04-21 10:10:00.000000025+00:00  2023-04-21 10:15:00.000000025+00:00
# 411  2023-04-21 10:15:00.000000025+00:00  2023-04-21 10:20:00.000000025+00:00
# 447  2023-04-21 11:56:35.657627405+00:00  2023-04-21 12:01:35.657627405+00:00
# 462  2023-04-21 12:01:35.657627405+00:00  2023-04-21 12:06:35.657627405+00:00
# 478  2023-04-21 12:06:35.657627405+00:00  2023-04-21 12:10:46.954319767+00:00
# 497  2023-04-21 12:10:46.954319767+00:00  2023-04-21 12:11:43.681386035+00:00
# 515  2023-04-21 12:11:43.681386035+00:00  2023-04-21 12:21:43.681386035+00:00
# 551  2023-04-21 13:45:35.286480560+00:00  2023-04-21 14:05:35.286480560+00:00
# 567  2023-04-21 14:05:35.286480560+00:00  2023-04-21 14:10:35.286480560+00:00
# 598  2023-04-21 14:45:35.286480560+00:00  2023-04-24 07:05:35.286480560+00:00
# 614  2023-04-24 07:05:35.286480560+00:00  2023-04-24 07:10:35.286480560+00:00
# 632  2023-04-24 07:10:35.286480560+00:00  2023-04-24 07:15:35.286480560+00:00
# 650  2023-04-24 07:15:35.286480560+00:00  2023-04-24 07:20:35.286480560+00:00
# 669  2023-04-24 07:20:35.286480560+00:00  2023-04-24 07:22:04.298491893+00:00
# 685  2023-04-24 07:22:04.298491893+00:00  2023-04-24 07:42:04.298491893+00:00
# 705  2023-04-24 07:42:04.298491893+00:00  2023-04-24 07:47:04.298491893+00:00
# 723  2023-04-24 07:47:04.298491893+00:00  2023-04-24 08:14:57.644787211+00:00
# 740  2023-04-24 08:14:57.644787211+00:00  2023-04-24 08:19:57.644787211+00:00
# 797  2023-04-24 09:00:00.000000215+00:00  2023-04-24 09:05:00.000000215+00:00
# 816  2023-04-24 09:05:00.000000215+00:00  2023-04-24 09:15:00.000000215+00:00
# 837  2023-04-24 09:15:00.000000215+00:00  2023-04-24 09:20:00.000000215+00:00
# 858  2023-04-24 09:20:00.000000215+00:00  2023-04-24 09:40:00.000000215+00:00
# 874  2023-04-24 09:40:00.000000215+00:00  2023-04-24 09:45:00.000000215+00:00
#
#      TimeStep                 resource
# 0           0             Clerk-000001
# 1           1             Clerk-000006
# 2           2             Clerk-000002
# 4           4             Clerk-000004
# 5           5         Appraiser-000001
# 7           7             Clerk-000007
# 10         10    Senior Officer-000001
# 22         23             Clerk-000003
# 28         29      Loan Officer-000001
# 36         37             Clerk-000006
# 44         45             Clerk-000002
# 51         52             Clerk-000005
# 58         60             Clerk-000005
# 68         70             Clerk-000003
# 78         80             Clerk-000002
# 87         90             Clerk-000007
# 98        103             Clerk-000008
# 109       114             Clerk-000005
# 131       138             Clerk-000004
# 144       151      Loan Officer-000002
# 157       165             Clerk-000001
# 171       179             Clerk-000003
# 184       195             Clerk-000006
# 211       227             Clerk-000002
# 244       263             Clerk-000006
# 260       281      Loan Officer-000001
# 278       300             Clerk-000008
# 296       320             Clerk-000007
# 314       339  AML Investigator-000001
# 331       358             Clerk-000001
# 349       378             Clerk-000008
# 364       395             Clerk-000004
# 394       433             Clerk-000004
# 411       452             Clerk-000008
# 447       492             Clerk-000006
# 462       511             Clerk-000007
# 478       529             Clerk-000007
# 497       549             Clerk-000006
# 515       570             Clerk-000006
# 551       608    Senior Officer-000002
# 567       625             Clerk-000004
# 598       660    Senior Officer-000002
# 614       680             Clerk-000007
# 632       698             Clerk-000003
# 650       718             Clerk-000006
# 669       738      Loan Officer-000001
# 685       757    Senior Officer-000002
# 705       778             Clerk-000002
# 723       798             Clerk-000008
# 740       816             Clerk-000007
# 797       882             Clerk-000002
# 816       902             Clerk-000007
# 837       926             Clerk-000001
# 858       950      Loan Officer-000002
# 874       971             Clerk-000001
