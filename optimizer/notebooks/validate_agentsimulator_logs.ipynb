# %%
import pandas as pd
import os
import numpy as np

# %%
def calculate_average_cycle_time(file_path):
    """
    Reads a simulation log and calculates the average cycle time per case.
    """
    try:
        df = pd.read_csv(file_path)
    except FileNotFoundError:
        print(f"Warning: File not found at {file_path}")
        return None

    if df.empty:
        print(f"Warning: File is empty at {file_path}")
        return None

    # Ensure timestamp columns are in datetime format
    df['start_timestamp'] = pd.to_datetime(df['start_timestamp'], format='ISO8601', errors='coerce')
    df['end_timestamp'] = pd.to_datetime(df['end_timestamp'], format='ISO8601', errors='coerce')

    # Group by case_id to find the start of the first activity and end of the last
    case_times = df.groupby('case_id').agg(
        case_start=('start_timestamp', 'min'),
        case_end=('end_timestamp', 'max')
    )

    # Calculate cycle time for each case
    case_times['cycle_time'] = case_times['case_end'] - case_times['case_start']
    
    # Return the average cycle time for the entire log
    return case_times['cycle_time'].mean()

def calculate_case_cycle_times(df):
    """Returns a dictionary of {case_id: cycle_time} from the log."""
    df['start_timestamp'] = pd.to_datetime(df['start_timestamp'], format='ISO8601', errors='coerce')
    df['end_timestamp'] = pd.to_datetime(df['end_timestamp'], format='ISO8601', errors='coerce')

    case_times = {}
    for case_id, group in df.groupby('case_id'):
        start = group['start_timestamp'].min()
        end = group['end_timestamp'].max()
        if pd.notna(start) and pd.notna(end):
            case_times[case_id] = (end - start).total_seconds()
    return case_times

# %%
def comparison_across_logs():
    """
    Compares cycle times between baseline and optimized simulation logs.
    Returns overall improvements and a dict of case-level improvements.
    """
    log_name = 'LoanApp.csv' 
    
    base_path = os.path.join('..', '..', 'simulated_data', log_name)
    baseline_dir = os.path.join(base_path, 'baseline')
    optimized_dir = os.path.join(base_path, 'autonomous')

    if not os.path.exists(baseline_dir) or not os.path.exists(optimized_dir):
        print(f"Error: Make sure both '{baseline_dir}' and '{optimized_dir}' exist.")
        return

    try:
        num_simulations = len([f for f in os.listdir(baseline_dir) if f.startswith('simulated_log_')])
    except FileNotFoundError:
        print(f"Error: Baseline directory not found at {baseline_dir}")
        return
        
    print(f"Comparing {num_simulations} simulation logs from '{log_name}'...\n")

    all_improvements = []
    case_improvements = {}

    for i in range(num_simulations):
        baseline_file = os.path.join(baseline_dir, f'simulated_log_{i}.csv')
        optimized_file = os.path.join(optimized_dir, f'simulated_log_{i}.csv')

        if not os.path.exists(baseline_file) or not os.path.exists(optimized_file):
            print(f"--- Log {i} ---\n  Could not compare due to missing file(s).\n")
            continue

        try:
            df_base = pd.read_csv(baseline_file)
            df_opt = pd.read_csv(optimized_file)
        except Exception as e:
            print(f"--- Log {i} ---\n  Error reading files: {e}\n")
            continue

        baseline_cases = calculate_case_cycle_times(df_base)
        optimized_cases = calculate_case_cycle_times(df_opt)

        per_log_improvements = []
        for case_id in baseline_cases:
            if case_id in optimized_cases and baseline_cases[case_id] > 0:
                improvement = ((baseline_cases[case_id] - optimized_cases[case_id]) / baseline_cases[case_id]) * 100
                per_log_improvements.append(improvement)
                case_improvements[(i, case_id)] = improvement  # (log_number, case_id) => improvement

        if per_log_improvements:
            avg_baseline_time = np.mean(list(baseline_cases.values()))
            avg_optimized_time = np.mean(list(optimized_cases.values()))
            improvement_percent = ((avg_baseline_time - avg_optimized_time) / avg_baseline_time) * 100
            all_improvements.append(improvement_percent)

            print(f"--- Log {i} ---")
            print(f"  Baseline Avg. Cycle Time:  {avg_baseline_time}")
            print(f"  Optimized Avg. Cycle Time: {avg_optimized_time}")
            print(f"  Improvement: {improvement_percent:.2f}%\n")
        else:
            print(f"--- Log {i} ---\n  No valid case matches found.\n")

    if all_improvements:
        overall_avg_improvement = np.mean(all_improvements)
        print("="*40)
        print(f"Overall Average Improvement: {overall_avg_improvement:.2f}%")
        print("="*40)

    return all_improvements, case_improvements

# %%
def compararison_across_cases():
    """
    Aggregates and compares mean and median cycle times per case_id across all logs.
    Prints per-case statistics and overall average/median improvement.
    """
    log_name = 'LoanApp.csv'

    base_path = os.path.join('..', '..', 'simulated_data', log_name)
    baseline_dir = os.path.join(base_path, 'baseline')
    optimized_dir = os.path.join(base_path, 'autonomous')

    if not os.path.exists(baseline_dir) or not os.path.exists(optimized_dir):
        print(f"Error: Make sure both '{baseline_dir}' and '{optimized_dir}' exist.")
        return

    try:
        num_simulations = len([f for f in os.listdir(baseline_dir) if f.startswith('simulated_log_')])
    except FileNotFoundError:
        print(f"Error: Baseline directory not found at {baseline_dir}")
        return

    # Collect case times across all logs
    all_baseline = {}
    all_optimized = {}

    for i in range(num_simulations):
        baseline_file = os.path.join(baseline_dir, f'simulated_log_{i}.csv')
        optimized_file = os.path.join(optimized_dir, f'simulated_log_{i}.csv')

        if not os.path.exists(baseline_file) or not os.path.exists(optimized_file):
            continue

        try:
            df_base = pd.read_csv(baseline_file)
            df_opt = pd.read_csv(optimized_file)
        except:
            continue

        baseline_cases = calculate_case_cycle_times(df_base)
        optimized_cases = calculate_case_cycle_times(df_opt)

        for case_id, time in baseline_cases.items():
            all_baseline.setdefault(case_id, []).append(time)

        for case_id, time in optimized_cases.items():
            all_optimized.setdefault(case_id, []).append(time)

    # Now compare
    common_cases = set(all_baseline.keys()) & set(all_optimized.keys())

    print("Case-by-case aggregated stats:\n")

    mean_improvements = []
    median_improvements = []

    for case_id in sorted(common_cases):
        baseline_times = all_baseline[case_id]
        optimized_times = all_optimized[case_id]

        if not baseline_times or not optimized_times:
            continue

        mean_base = np.mean(baseline_times)
        mean_opt = np.mean(optimized_times)
        median_base = np.median(baseline_times)
        median_opt = np.median(optimized_times)

        if mean_base > 0:
            mean_improvement = ((mean_base - mean_opt) / mean_base) * 100
            mean_improvements.append(mean_improvement)
        else:
            mean_improvement = 0

        if median_base > 0:
            median_improvement = ((median_base - median_opt) / median_base) * 100
            median_improvements.append(median_improvement)
        else:
            median_improvement = 0

        print(f"Case ID: {case_id}")
        print(f"  Mean Baseline:  {mean_base:.2f}")
        print(f"  Mean Optimized: {mean_opt:.2f}")
        print(f"  Mean Improvement: {mean_improvement:.2f}%")
        print(f"  Median Baseline:  {median_base:.2f}")
        print(f"  Median Optimized: {median_opt:.2f}")
        print(f"  Median Improvement: {median_improvement:.2f}%\n")

    # Print overall stats
    if mean_improvements:
        overall_mean_improvement = np.mean(mean_improvements)
        overall_median_improvement = np.median(median_improvements)

        print("="*40)
        print(f"Overall Mean Improvement:   {overall_mean_improvement:.2f}%")
        print(f"Overall Median Improvement: {overall_median_improvement:.2f}%")
        print("="*40)

# %%
# --- CONFIGURATION ---
# Define the cost per hour for each resource.
# The script will assign a cost of 0 to any resource not listed here.
AGENT_COSTS = {
    "Clerk-000006": 90,
    "Clerk-000001": 30,
    "Applicant-000001": 0,
    "Clerk-000007": 30,
    "Clerk-000004": 90,
    "Clerk-000003": 60,
    "Clerk-000008": 30,
    "Senior Officer-000002": 150,
    "Appraiser-000002": 90,
    "AML Investigator-000002": 110,
    "Appraiser-000001": 90,
    "Loan Officer-000002": 95,
    "AML Investigator-000001": 110,
    "Loan Officer-000001": 95,
    "Loan Officer-000004": 105,
    "Clerk-000002": 30,
    "Loan Officer-000003": 105,
    "Senior Officer-000001": 150,
    "Clerk-000005": 90
    }


def calculate_case_costs(df: pd.DataFrame, agent_costs: dict) -> dict:
    """
    Reads a simulation log DataFrame and calculates the total agent cost for each case.
    
    Args:
        df: The log DataFrame.
        agent_costs: A dictionary mapping resource names to their cost per hour.

    Returns:
        A dictionary mapping each case_id to its total cost.
    """
    if df.empty:
        return {}
    
    # Ensure timestamp columns are in datetime format
    df['start_timestamp'] = pd.to_datetime(df['start_timestamp'], format='ISO8601', errors='coerce')
    df['end_timestamp'] = pd.to_datetime(df['end_timestamp'], format='ISO8601', errors='coerce')

    # Calculate the duration of each task in seconds
    df['duration_seconds'] = (df['end_timestamp'] - df['start_timestamp']).dt.total_seconds()

    # Map the cost per hour to each event, defaulting to 0 if not found
    df['cost_per_hour'] = df['resource'].map(agent_costs).fillna(0)

    # Calculate the cost for each individual task
    df['task_cost'] = (df['duration_seconds'] / 3600) * df['cost_per_hour']

    # Group by case_id and sum the costs to get the total cost per case
    case_total_costs = df.groupby('case_id')['task_cost'].sum()

    return case_total_costs.to_dict()


def compare_costs_across_logs():
    """
    Compares total agent costs between baseline and optimized simulation logs on a per-log basis.
    """
    log_name = 'LoanApp.csv' 
    
    # Adjust this path to match your project structure
    base_path = os.path.join('..', '..', 'simulated_data', log_name)
    baseline_dir = os.path.join(base_path, 'baseline')
    optimized_dir = os.path.join(base_path, 'autonomous') # Updated to point to your optimized logs

    if not os.path.exists(baseline_dir) or not os.path.exists(optimized_dir):
        print(f"Error: Make sure both '{baseline_dir}' and '{optimized_dir}' exist.")
        return

    try:
        num_simulations = len([f for f in os.listdir(baseline_dir) if f.startswith('simulated_log_')])
    except FileNotFoundError:
        print(f"Error: Baseline directory not found at {baseline_dir}")
        return
        
    print(f"Comparing costs for {num_simulations} simulation logs from '{log_name}'...\n")

    all_improvements = []

    for i in range(num_simulations):
        baseline_file = os.path.join(baseline_dir, f'simulated_log_{i}.csv')
        optimized_file = os.path.join(optimized_dir, f'simulated_log_{i}.csv')

        if not os.path.exists(baseline_file) or not os.path.exists(optimized_file):
            print(f"--- Log {i} ---\n  Could not compare due to missing file(s).\n")
            continue

        try:
            df_base = pd.read_csv(baseline_file)
            df_opt = pd.read_csv(optimized_file)
        except Exception as e:
            print(f"--- Log {i} ---\n  Error reading files: {e}\n")
            continue

        baseline_costs = calculate_case_costs(df_base, AGENT_COSTS)
        optimized_costs = calculate_case_costs(df_opt, AGENT_COSTS)
        
        # Filter for cases present in both logs
        common_case_ids = set(baseline_costs.keys()) & set(optimized_costs.keys())
        
        if not common_case_ids:
            print(f"--- Log {i} ---\n  No common cases found to compare.\n")
            continue

        avg_baseline_cost = np.mean([baseline_costs[cid] for cid in common_case_ids])
        avg_optimized_cost = np.mean([optimized_costs[cid] for cid in common_case_ids])
        
        if avg_baseline_cost > 0:
            improvement_percent = ((avg_baseline_cost - avg_optimized_cost) / avg_baseline_cost) * 100
            all_improvements.append(improvement_percent)

            print(f"--- Log {i} ---")
            print(f"  Baseline Avg. Case Cost:  ${avg_baseline_cost:.2f}")
            print(f"  Optimized Avg. Case Cost: ${avg_optimized_cost:.2f}")
            print(f"  Cost Reduction: {improvement_percent:.2f}%\n")
        else:
            print(f"--- Log {i} ---\n  Baseline cost is zero, cannot calculate improvement.\n")

    if all_improvements:
        overall_avg_improvement = np.mean(all_improvements)
        print("="*40)
        print(f"Overall Average Cost Reduction: {overall_avg_improvement:.2f}%")
        print("="*40)


def compare_costs_across_cases():
    """
    Aggregates and compares mean and median costs per case_id across all logs.
    """
    log_name = 'LoanApp.csv'

    base_path = os.path.join('..', '..', 'simulated_data', log_name)
    baseline_dir = os.path.join(base_path, 'baseline')
    optimized_dir = os.path.join(base_path, 'autonomous') # Updated path

    if not os.path.exists(baseline_dir) or not os.path.exists(optimized_dir):
        print(f"Error: Make sure both '{baseline_dir}' and '{optimized_dir}' exist.")
        return

    try:
        num_simulations = len([f for f in os.listdir(baseline_dir) if f.startswith('simulated_log_')])
    except FileNotFoundError:
        print(f"Error: Baseline directory not found at {baseline_dir}")
        return

    # Collect case costs across all logs
    all_baseline_costs = {}
    all_optimized_costs = {}

    for i in range(num_simulations):
        baseline_file = os.path.join(baseline_dir, f'simulated_log_{i}.csv')
        optimized_file = os.path.join(optimized_dir, f'simulated_log_{i}.csv')

        if not os.path.exists(baseline_file) or not os.path.exists(optimized_file): continue
        try:
            df_base = pd.read_csv(baseline_file)
            df_opt = pd.read_csv(optimized_file)
        except: continue

        baseline_cases = calculate_case_costs(df_base, AGENT_COSTS)
        optimized_cases = calculate_case_costs(df_opt, AGENT_COSTS)

        for case_id, cost in baseline_cases.items(): all_baseline_costs.setdefault(case_id, []).append(cost)
        for case_id, cost in optimized_cases.items(): all_optimized_costs.setdefault(case_id, []).append(cost)

    common_cases = set(all_baseline_costs.keys()) & set(all_optimized_costs.keys())
    print("Case-by-case aggregated cost stats:\n")

    mean_improvements = []
    median_improvements = []

    for case_id in sorted(common_cases):
        baseline_costs = all_baseline_costs[case_id]
        optimized_costs = all_optimized_costs[case_id]

        if not baseline_costs or not optimized_costs: continue

        mean_base = np.mean(baseline_costs)
        mean_opt = np.mean(optimized_costs)
        median_base = np.median(baseline_costs)
        median_opt = np.median(optimized_costs)

        mean_improvement = ((mean_base - mean_opt) / mean_base) * 100 if mean_base > 0 else 0
        median_improvement = ((median_base - median_opt) / median_base) * 100 if median_base > 0 else 0
        mean_improvements.append(mean_improvement)
        median_improvements.append(median_improvement)

        print(f"Case ID: {case_id}")
        print(f"  Mean Baseline Cost:  ${mean_base:.2f}")
        print(f"  Mean Optimized Cost: ${mean_opt:.2f}")
        print(f"  Mean Reduction: {mean_improvement:.2f}%")
        print(f"  Median Baseline Cost:  ${median_base:.2f}")
        print(f"  Median Optimized Cost: ${median_opt:.2f}")
        print(f"  Median Reduction: {median_improvement:.2f}%\n")

    if mean_improvements:
        overall_mean_improvement = np.mean(mean_improvements)
        overall_median_improvement = np.median(median_improvements)

        print("="*40)
        print(f"Overall Mean Cost Reduction:   {overall_mean_improvement:.2f}%")
        print(f"Overall Median Cost Reduction: {overall_median_improvement:.2f}%")
        print("="*40)

# %%
def add_activity_cost_column(logs_df: pd.DataFrame, agent_costs: dict) -> pd.DataFrame:
    """
    Enriches a log DataFrame with activity-level cost information.

    This function calculates the cost of each individual activity based on its
    duration and the hourly rate of the resource who performed it.

    Args:
        logs_df (pd.DataFrame): 
            The input DataFrame of simulation logs. It must contain the columns:
            'start_timestamp', 'end_timestamp', and 'resource'.
        
        agent_costs (dict): 
            A dictionary mapping resource names (str) to their cost per hour (float/int).

    Returns:
        pd.DataFrame: 
            A new DataFrame containing all original columns plus a new 
            'activity_cost' column. Returns an empty DataFrame if the input is empty.
    """
    if logs_df.empty:
        return logs_df.copy()

    # Create a copy to avoid modifying the original DataFrame in place
    df = logs_df.copy()

    # 1. Ensure timestamp columns are proper datetime objects
    df['start_timestamp'] = pd.to_datetime(df['start_timestamp'], format='ISO8601')
    df['end_timestamp'] = pd.to_datetime(df['end_timestamp'], format='ISO8601')

    # 2. Calculate the duration of each task in seconds
    df['duration_seconds'] = (df['end_timestamp'] - df['start_timestamp']).dt.total_seconds()

    # 3. Map the agent's cost per hour to each event row.
    #    .map() is a highly efficient way to do this.
    #    .fillna(0) ensures that any resource not in our agent_costs dict gets a cost of 0.
    df['cost_per_hour'] = df['resource'].map(agent_costs).fillna(0)

    # 4. Calculate the final cost for each activity
    #    (Duration in seconds / 3600 seconds per hour) * cost per hour
    df['activity_cost'] = (df['duration_seconds'] / 3600) * df['cost_per_hour']
    
    # Optional: You can drop the intermediate columns if you want a cleaner output
    # df = df.drop(columns=['duration_seconds', 'cost_per_hour'])

    return df

# %%
log_improvements, case_improvements = comparison_across_logs()
# Out:
# Comparing 10 simulation logs from 'LoanApp.csv'...
#
# --- Log 0 ---
#   Baseline Avg. Cycle Time:  50275.163768165
#   Optimized Avg. Cycle Time: 43461.497169015
#   Improvement: 13.55%
#
# --- Log 1 ---
#   Baseline Avg. Cycle Time:  56348.631561815
#   Optimized Avg. Cycle Time: 45204.58302051001
#   Improvement: 19.78%
#
# --- Log 2 ---
#   Baseline Avg. Cycle Time:  54611.17538516499
#   Optimized Avg. Cycle Time: 52252.299407725
#   Improvement: 4.32%
#
# --- Log 3 ---
#   Baseline Avg. Cycle Time:  52161.806842785
#   Optimized Avg. Cycle Time: 47716.723373835
#   Improvement: 8.52%
#
# --- Log 4 ---
#   Baseline Avg. Cycle Time:  47820.89159405001
#   Optimized Avg. Cycle Time: 49535.708788134994
#   Improvement: -3.59%
#
# --- Log 5 ---
#   Baseline Avg. Cycle Time:  47887.91980021
#   Optimized Avg. Cycle Time: 59425.925722969994
#   Improvement: -24.09%
#
# --- Log 6 ---
#   Baseline Avg. Cycle Time:  52402.908601805
#   Optimized Avg. Cycle Time: 45991.507329604996
#   Improvement: 12.23%
#
# --- Log 7 ---
#   Baseline Avg. Cycle Time:  55972.741497740004
#   Optimized Avg. Cycle Time: 45158.642363980005
#   Improvement: 19.32%
#
# --- Log 8 ---
#   Baseline Avg. Cycle Time:  53739.924323885
#   Optimized Avg. Cycle Time: 46999.00448438
#   Improvement: 12.54%
#
# --- Log 9 ---
#   Baseline Avg. Cycle Time:  47826.745340024994
#   Optimized Avg. Cycle Time: 46819.900271965
#   Improvement: 2.11%
#
# ========================================
# Overall Average Improvement: 6.47%
# ========================================

# %%
compararison_across_cases()
# Out:
# Case-by-case aggregated stats:
#
# Case ID: 0
#   Mean Baseline:  9998.62
#   Mean Optimized: 10201.42
#   Mean Improvement: -2.03%
#   Median Baseline:  10295.61
#   Median Optimized: 9025.61
#   Median Improvement: 12.34%
#
# Case ID: 1
#   Mean Baseline:  10671.63
#   Mean Optimized: 8128.81
#   Mean Improvement: 23.83%
#   Median Baseline:  10751.04
#   Median Optimized: 7358.01
#   Median Improvement: 31.56%
#
# Case ID: 2
#   Mean Baseline:  16381.52
#   Mean Optimized: 7739.25
#   Mean Improvement: 52.76%
#   Median Baseline:  9643.76
#   Median Optimized: 7330.25
#   Median Improvement: 23.99%
#
# Case ID: 3
#   Mean Baseline:  7699.71
#   Mean Optimized: 11752.98
#   Mean Improvement: -52.64%
#   Median Baseline:  7950.31
#   Median Optimized: 10415.51
#   Median Improvement: -31.01%
#
# Case ID: 4
#   Mean Baseline:  16440.36
#   Mean Optimized: 10292.38
#   Mean Improvement: 37.40%
#   Median Baseline:  9095.94
#   Median Optimized: 9168.23
#   Median Improvement: -0.79%
#
# Case ID: 5
#   Mean Baseline:  17603.60
#   Mean Optimized: 23614.99
#   Mean Improvement: -34.15%
#   Median Baseline:  11132.85
#   Median Optimized: 11957.16
#   Median Improvement: -7.40%
#
# Case ID: 6
#   Mean Baseline:  9059.38
#   Mean Optimized: 16847.08
#   Mean Improvement: -85.96%
#   Median Baseline:  9497.48
#   Median Optimized: 10805.74
#   Median Improvement: -13.77%
#
# Case ID: 7
#   Mean Baseline:  14456.38
#   Mean Optimized: 27364.08
#   Mean Improvement: -89.29%
#   Median Baseline:  7701.82
#   Median Optimized: 9183.56
#   Median Improvement: -19.24%
#
# Case ID: 8
#   Mean Baseline:  33949.35
#   Mean Optimized: 27017.11
#   Mean Improvement: 20.42%
#   Median Baseline:  10995.64
#   Median Optimized: 8925.15
#   Median Improvement: 18.83%
#
# Case ID: 9
#   Mean Baseline:  39220.14
#   Mean Optimized: 44792.24
#   Mean Improvement: -14.21%
#   Median Baseline:  38219.92
#   Median Optimized: 68225.10
#   Median Improvement: -78.51%
#
# Case ID: 10
#   Mean Baseline:  57864.71
#   Mean Optimized: 64564.95
#   Mean Improvement: -11.58%
#   Median Baseline:  69587.06
#   Median Optimized: 68792.64
#   Median Improvement: 1.14%
#
# Case ID: 11
#   Mean Baseline:  70400.43
#   Mean Optimized: 68433.00
#   Mean Improvement: 2.79%
#   Median Baseline:  70552.02
#   Median Optimized: 66190.40
#   Median Improvement: 6.18%
#
# Case ID: 12
#   Mean Baseline:  72315.85
#   Mean Optimized: 68012.65
#   Mean Improvement: 5.95%
#   Median Baseline:  72424.09
#   Median Optimized: 66937.65
#   Median Improvement: 7.58%
#
# Case ID: 13
#   Mean Baseline:  67510.08
#   Mean Optimized: 66975.60
#   Mean Improvement: 0.79%
#   Median Baseline:  67285.97
#   Median Optimized: 66276.08
#   Median Improvement: 1.50%
#
# Case ID: 14
#   Mean Baseline:  68432.22
#   Mean Optimized: 69840.07
#   Mean Improvement: -2.06%
#   Median Baseline:  68231.58
#   Median Optimized: 68082.68
#   Median Improvement: 0.22%
#
# Case ID: 15
#   Mean Baseline:  12935.46
#   Mean Optimized: 35349.05
#   Mean Improvement: -173.27%
#   Median Baseline:  13001.73
#   Median Optimized: 10250.77
#   Median Improvement: 21.16%
#
# Case ID: 16
#   Mean Baseline:  10785.92
#   Mean Optimized: 9627.83
#   Mean Improvement: 10.74%
#   Median Baseline:  10809.25
#   Median Optimized: 9015.12
#   Median Improvement: 16.60%
#
# Case ID: 17
#   Mean Baseline:  11906.67
#   Mean Optimized: 9672.85
#   Mean Improvement: 18.76%
#   Median Baseline:  11912.29
#   Median Optimized: 9305.94
#   Median Improvement: 21.88%
#
# Case ID: 18
#   Mean Baseline:  36148.76
#   Mean Optimized: 9050.81
#   Mean Improvement: 74.96%
#   Median Baseline:  12565.74
#   Median Optimized: 8638.18
#   Median Improvement: 31.26%
#
# Case ID: 19
#   Mean Baseline:  9651.06
#   Mean Optimized: 8495.79
#   Mean Improvement: 11.97%
#   Median Baseline:  8035.20
#   Median Optimized: 8241.36
#   Median Improvement: -2.57%
#
# Case ID: 20
#   Mean Baseline:  35211.63
#   Mean Optimized: 33118.83
#   Mean Improvement: 5.94%
#   Median Baseline:  12254.58
#   Median Optimized: 9075.82
#   Median Improvement: 25.94%
#
# Case ID: 21
#   Mean Baseline:  57230.03
#   Mean Optimized: 32866.06
#   Mean Improvement: 42.57%
#   Median Baseline:  10249.65
#   Median Optimized: 8473.72
#   Median Improvement: 17.33%
#
# Case ID: 22
#   Mean Baseline:  32927.77
#   Mean Optimized: 34600.96
#   Mean Improvement: -5.08%
#   Median Baseline:  9150.34
#   Median Optimized: 10665.76
#   Median Improvement: -16.56%
#
# Case ID: 23
#   Mean Baseline:  79583.02
#   Mean Optimized: 79729.98
#   Mean Improvement: -0.18%
#   Median Baseline:  10031.52
#   Median Optimized: 10918.03
#   Median Improvement: -8.84%
#
# Case ID: 24
#   Mean Baseline:  104571.30
#   Mean Optimized: 102871.93
#   Mean Improvement: 1.63%
#   Median Baseline:  10114.67
#   Median Optimized: 10189.26
#   Median Improvement: -0.74%
#
# Case ID: 25
#   Mean Baseline:  148667.51
#   Mean Optimized: 149919.61
#   Mean Improvement: -0.84%
#   Median Baseline:  240767.42
#   Median Optimized: 240470.88
#   Median Improvement: 0.12%
#
# Case ID: 26
#   Mean Baseline:  148004.79
#   Mean Optimized: 193067.70
#   Mean Improvement: -30.45%
#   Median Baseline:  238711.60
#   Median Optimized: 239040.09
#   Median Improvement: -0.14%
#
# Case ID: 27
#   Mean Baseline:  241258.48
#   Mean Optimized: 239148.98
#   Mean Improvement: 0.87%
#   Median Baseline:  240683.71
#   Median Optimized: 238539.36
#   Median Improvement: 0.89%
#
# Case ID: 28
#   Mean Baseline:  240892.81
#   Mean Optimized: 241533.81
#   Mean Improvement: -0.27%
#   Median Baseline:  240052.19
#   Median Optimized: 241062.59
#   Median Improvement: -0.42%
#
# Case ID: 29
#   Mean Baseline:  239391.45
#   Mean Optimized: 238529.35
#   Mean Improvement: 0.36%
#   Median Baseline:  238999.02
#   Median Optimized: 237848.49
#   Median Improvement: 0.48%
#
# Case ID: 30
#   Mean Baseline:  237069.05
#   Mean Optimized: 237961.85
#   Mean Improvement: -0.38%
#   Median Baseline:  237445.17
#   Median Optimized: 236799.04
#   Median Improvement: 0.27%
#
# Case ID: 31
#   Mean Baseline:  11709.99
#   Mean Optimized: 8341.42
#   Mean Improvement: 28.77%
#   Median Baseline:  10906.64
#   Median Optimized: 8055.87
#   Median Improvement: 26.14%
#
# Case ID: 32
#   Mean Baseline:  12390.13
#   Mean Optimized: 9201.69
#   Mean Improvement: 25.73%
#   Median Baseline:  13222.57
#   Median Optimized: 9460.03
#   Median Improvement: 28.46%
#
# Case ID: 33
#   Mean Baseline:  10385.24
#   Mean Optimized: 10591.37
#   Mean Improvement: -1.98%
#   Median Baseline:  9246.84
#   Median Optimized: 10183.81
#   Median Improvement: -10.13%
#
# Case ID: 34
#   Mean Baseline:  12125.74
#   Mean Optimized: 8600.58
#   Mean Improvement: 29.07%
#   Median Baseline:  13770.14
#   Median Optimized: 7781.58
#   Median Improvement: 43.49%
#
# Case ID: 35
#   Mean Baseline:  10250.95
#   Mean Optimized: 8152.86
#   Mean Improvement: 20.47%
#   Median Baseline:  10299.78
#   Median Optimized: 7762.06
#   Median Improvement: 24.64%
#
# Case ID: 36
#   Mean Baseline:  18327.12
#   Mean Optimized: 15730.07
#   Mean Improvement: 14.17%
#   Median Baseline:  12365.49
#   Median Optimized: 9558.83
#   Median Improvement: 22.70%
#
# Case ID: 37
#   Mean Baseline:  16927.54
#   Mean Optimized: 8968.92
#   Mean Improvement: 47.02%
#   Median Baseline:  10569.06
#   Median Optimized: 8488.95
#   Median Improvement: 19.68%
#
# Case ID: 38
#   Mean Baseline:  22277.61
#   Mean Optimized: 15910.80
#   Mean Improvement: 28.58%
#   Median Baseline:  10075.51
#   Median Optimized: 8027.58
#   Median Improvement: 20.33%
#
# Case ID: 39
#   Mean Baseline:  33794.81
#   Mean Optimized: 10050.88
#   Mean Improvement: 70.26%
#   Median Baseline:  11883.22
#   Median Optimized: 10711.42
#   Median Improvement: 9.86%
#
# Case ID: 40
#   Mean Baseline:  27719.60
#   Mean Optimized: 40716.07
#   Mean Improvement: -46.89%
#   Median Baseline:  10196.55
#   Median Optimized: 39899.06
#   Median Improvement: -291.30%
#
# Case ID: 41
#   Mean Baseline:  58971.98
#   Mean Optimized: 52503.00
#   Mean Improvement: 10.97%
#   Median Baseline:  68346.97
#   Median Optimized: 70227.56
#   Median Improvement: -2.75%
#
# Case ID: 42
#   Mean Baseline:  55941.52
#   Mean Optimized: 44711.91
#   Mean Improvement: 20.07%
#   Median Baseline:  66637.27
#   Median Optimized: 65503.14
#   Median Improvement: 1.70%
#
# Case ID: 43
#   Mean Baseline:  77513.77
#   Mean Optimized: 68903.64
#   Mean Improvement: 11.11%
#   Median Baseline:  67439.10
#   Median Optimized: 69365.81
#   Median Improvement: -2.86%
#
# Case ID: 44
#   Mean Baseline:  61524.38
#   Mean Optimized: 67906.50
#   Mean Improvement: -10.37%
#   Median Baseline:  65055.71
#   Median Optimized: 68715.10
#   Median Improvement: -5.63%
#
# Case ID: 45
#   Mean Baseline:  66687.94
#   Mean Optimized: 67182.13
#   Mean Improvement: -0.74%
#   Median Baseline:  66560.22
#   Median Optimized: 66933.64
#   Median Improvement: -0.56%
#
# Case ID: 46
#   Mean Baseline:  77448.53
#   Mean Optimized: 75082.94
#   Mean Improvement: 3.05%
#   Median Baseline:  67638.54
#   Median Optimized: 67586.78
#   Median Improvement: 0.08%
#
# Case ID: 47
#   Mean Baseline:  10087.03
#   Mean Optimized: 10033.57
#   Mean Improvement: 0.53%
#   Median Baseline:  9901.01
#   Median Optimized: 9550.99
#   Median Improvement: 3.54%
#
# Case ID: 48
#   Mean Baseline:  16611.92
#   Mean Optimized: 10423.94
#   Mean Improvement: 37.25%
#   Median Baseline:  9309.39
#   Median Optimized: 10428.80
#   Median Improvement: -12.02%
#
# Case ID: 49
#   Mean Baseline:  19868.55
#   Mean Optimized: 10068.25
#   Mean Improvement: 49.33%
#   Median Baseline:  11726.64
#   Median Optimized: 8390.88
#   Median Improvement: 28.45%
#
# Case ID: 50
#   Mean Baseline:  11096.05
#   Mean Optimized: 9943.63
#   Mean Improvement: 10.39%
#   Median Baseline:  10033.81
#   Median Optimized: 9749.70
#   Median Improvement: 2.83%
#
# Case ID: 51
#   Mean Baseline:  11441.79
#   Mean Optimized: 10893.40
#   Mean Improvement: 4.79%
#   Median Baseline:  10652.49
#   Median Optimized: 11939.67
#   Median Improvement: -12.08%
#
# Case ID: 52
#   Mean Baseline:  33240.39
#   Mean Optimized: 9962.92
#   Mean Improvement: 70.03%
#   Median Baseline:  11667.70
#   Median Optimized: 9611.95
#   Median Improvement: 17.62%
#
# Case ID: 53
#   Mean Baseline:  30009.18
#   Mean Optimized: 21896.73
#   Mean Improvement: 27.03%
#   Median Baseline:  13581.15
#   Median Optimized: 8684.50
#   Median Improvement: 36.05%
#
# Case ID: 54
#   Mean Baseline:  23671.48
#   Mean Optimized: 9092.85
#   Mean Improvement: 61.59%
#   Median Baseline:  11290.21
#   Median Optimized: 9087.36
#   Median Improvement: 19.51%
#
# Case ID: 55
#   Mean Baseline:  28560.52
#   Mean Optimized: 21146.58
#   Mean Improvement: 25.96%
#   Median Baseline:  10514.41
#   Median Optimized: 9142.67
#   Median Improvement: 13.05%
#
# Case ID: 56
#   Mean Baseline:  35475.42
#   Mean Optimized: 7503.96
#   Mean Improvement: 78.85%
#   Median Baseline:  10917.95
#   Median Optimized: 7655.85
#   Median Improvement: 29.88%
#
# Case ID: 57
#   Mean Baseline:  74524.85
#   Mean Optimized: 33176.24
#   Mean Improvement: 55.48%
#   Median Baseline:  74290.93
#   Median Optimized: 8669.25
#   Median Improvement: 88.33%
#
# Case ID: 58
#   Mean Baseline:  49123.80
#   Mean Optimized: 56806.93
#   Mean Improvement: -15.64%
#   Median Baseline:  66872.22
#   Median Optimized: 68785.65
#   Median Improvement: -2.86%
#
# Case ID: 59
#   Mean Baseline:  56067.88
#   Mean Optimized: 67007.51
#   Mean Improvement: -19.51%
#   Median Baseline:  67604.79
#   Median Optimized: 66080.55
#   Median Improvement: 2.25%
#
# Case ID: 60
#   Mean Baseline:  61797.90
#   Mean Optimized: 67534.97
#   Mean Improvement: -9.28%
#   Median Baseline:  68064.56
#   Median Optimized: 66354.92
#   Median Improvement: 2.51%
#
# Case ID: 61
#   Mean Baseline:  68100.26
#   Mean Optimized: 62393.03
#   Mean Improvement: 8.38%
#   Median Baseline:  66991.62
#   Median Optimized: 67405.00
#   Median Improvement: -0.62%
#
# Case ID: 62
#   Mean Baseline:  68883.62
#   Mean Optimized: 68856.85
#   Mean Improvement: 0.04%
#   Median Baseline:  68855.14
#   Median Optimized: 68941.57
#   Median Improvement: -0.13%
#
# Case ID: 63
#   Mean Baseline:  12363.80
#   Mean Optimized: 11108.83
#   Mean Improvement: 10.15%
#   Median Baseline:  12526.75
#   Median Optimized: 10051.76
#   Median Improvement: 19.76%
#
# Case ID: 64
#   Mean Baseline:  10454.66
#   Mean Optimized: 11348.53
#   Mean Improvement: -8.55%
#   Median Baseline:  9703.98
#   Median Optimized: 10088.67
#   Median Improvement: -3.96%
#
# Case ID: 65
#   Mean Baseline:  12155.16
#   Mean Optimized: 18493.05
#   Mean Improvement: -52.14%
#   Median Baseline:  11161.30
#   Median Optimized: 11128.71
#   Median Improvement: 0.29%
#
# Case ID: 66
#   Mean Baseline:  17365.86
#   Mean Optimized: 10834.89
#   Mean Improvement: 37.61%
#   Median Baseline:  9172.57
#   Median Optimized: 9497.65
#   Median Improvement: -3.54%
#
# Case ID: 67
#   Mean Baseline:  9300.32
#   Mean Optimized: 17953.03
#   Mean Improvement: -93.04%
#   Median Baseline:  10094.20
#   Median Optimized: 11684.14
#   Median Improvement: -15.75%
#
# Case ID: 68
#   Mean Baseline:  32593.32
#   Mean Optimized: 16189.50
#   Mean Improvement: 50.33%
#   Median Baseline:  12372.94
#   Median Optimized: 9262.10
#   Median Improvement: 25.14%
#
# Case ID: 69
#   Mean Baseline:  37014.86
#   Mean Optimized: 15592.65
#   Mean Improvement: 57.87%
#   Median Baseline:  11034.50
#   Median Optimized: 8958.76
#   Median Improvement: 18.81%
#
# Case ID: 70
#   Mean Baseline:  17219.36
#   Mean Optimized: 21780.18
#   Mean Improvement: -26.49%
#   Median Baseline:  10122.40
#   Median Optimized: 9561.64
#   Median Improvement: 5.54%
#
# Case ID: 71
#   Mean Baseline:  27595.19
#   Mean Optimized: 28678.91
#   Mean Improvement: -3.93%
#   Median Baseline:  9815.53
#   Median Optimized: 9468.66
#   Median Improvement: 3.53%
#
# Case ID: 72
#   Mean Baseline:  27951.70
#   Mean Optimized: 27190.09
#   Mean Improvement: 2.72%
#   Median Baseline:  9569.79
#   Median Optimized: 9535.96
#   Median Improvement: 0.35%
#
# Case ID: 73
#   Mean Baseline:  52041.96
#   Mean Optimized: 38536.81
#   Mean Improvement: 25.95%
#   Median Baseline:  67693.52
#   Median Optimized: 38040.67
#   Median Improvement: 43.80%
#
# Case ID: 74
#   Mean Baseline:  63760.12
#   Mean Optimized: 51388.80
#   Mean Improvement: 19.40%
#   Median Baseline:  67825.62
#   Median Optimized: 68792.55
#   Median Improvement: -1.43%
#
# Case ID: 75
#   Mean Baseline:  58355.92
#   Mean Optimized: 62559.97
#   Mean Improvement: -7.20%
#   Median Baseline:  68390.94
#   Median Optimized: 69083.47
#   Median Improvement: -1.01%
#
# Case ID: 76
#   Mean Baseline:  69582.99
#   Mean Optimized: 66144.70
#   Mean Improvement: 4.94%
#   Median Baseline:  68258.97
#   Median Optimized: 65391.78
#   Median Improvement: 4.20%
#
# Case ID: 77
#   Mean Baseline:  67527.11
#   Mean Optimized: 66037.95
#   Mean Improvement: 2.21%
#   Median Baseline:  67397.54
#   Median Optimized: 65180.73
#   Median Improvement: 3.29%
#
# Case ID: 78
#   Mean Baseline:  66198.83
#   Mean Optimized: 67339.01
#   Mean Improvement: -1.72%
#   Median Baseline:  65351.89
#   Median Optimized: 65941.85
#   Median Improvement: -0.90%
#
# Case ID: 79
#   Mean Baseline:  20043.44
#   Mean Optimized: 9844.05
#   Mean Improvement: 50.89%
#   Median Baseline:  13027.37
#   Median Optimized: 9753.75
#   Median Improvement: 25.13%
#
# Case ID: 80
#   Mean Baseline:  10127.65
#   Mean Optimized: 10803.21
#   Mean Improvement: -6.67%
#   Median Baseline:  10333.75
#   Median Optimized: 10541.14
#   Median Improvement: -2.01%
#
# Case ID: 81
#   Mean Baseline:  11731.23
#   Mean Optimized: 8551.70
#   Mean Improvement: 27.10%
#   Median Baseline:  10687.78
#   Median Optimized: 7780.14
#   Median Improvement: 27.21%
#
# Case ID: 82
#   Mean Baseline:  18640.23
#   Mean Optimized: 9948.28
#   Mean Improvement: 46.63%
#   Median Baseline:  10854.41
#   Median Optimized: 9634.69
#   Median Improvement: 11.24%
#
# Case ID: 83
#   Mean Baseline:  17811.87
#   Mean Optimized: 9868.20
#   Mean Improvement: 44.60%
#   Median Baseline:  12011.50
#   Median Optimized: 8799.66
#   Median Improvement: 26.74%
#
# Case ID: 84
#   Mean Baseline:  15920.81
#   Mean Optimized: 10191.08
#   Mean Improvement: 35.99%
#   Median Baseline:  9012.81
#   Median Optimized: 9736.34
#   Median Improvement: -8.03%
#
# Case ID: 85
#   Mean Baseline:  15858.95
#   Mean Optimized: 10567.94
#   Mean Improvement: 33.36%
#   Median Baseline:  9567.91
#   Median Optimized: 9885.79
#   Median Improvement: -3.32%
#
# Case ID: 86
#   Mean Baseline:  16158.48
#   Mean Optimized: 15520.21
#   Mean Improvement: 3.95%
#   Median Baseline:  9771.02
#   Median Optimized: 9178.50
#   Median Improvement: 6.06%
#
# Case ID: 87
#   Mean Baseline:  34066.96
#   Mean Optimized: 14788.58
#   Mean Improvement: 56.59%
#   Median Baseline:  10215.96
#   Median Optimized: 8980.80
#   Median Improvement: 12.09%
#
# Case ID: 88
#   Mean Baseline:  33490.26
#   Mean Optimized: 20857.66
#   Mean Improvement: 37.72%
#   Median Baseline:  9588.51
#   Median Optimized: 10291.78
#   Median Improvement: -7.33%
#
# Case ID: 89
#   Mean Baseline:  33952.17
#   Mean Optimized: 38728.57
#   Mean Improvement: -14.07%
#   Median Baseline:  9262.10
#   Median Optimized: 37804.31
#   Median Improvement: -308.16%
#
# Case ID: 90
#   Mean Baseline:  45651.93
#   Mean Optimized: 65529.79
#   Mean Improvement: -43.54%
#   Median Baseline:  67213.17
#   Median Optimized: 72556.10
#   Median Improvement: -7.95%
#
# Case ID: 91
#   Mean Baseline:  62118.87
#   Mean Optimized: 68078.43
#   Mean Improvement: -9.59%
#   Median Baseline:  68018.09
#   Median Optimized: 67972.99
#   Median Improvement: 0.07%
#
# Case ID: 92
#   Mean Baseline:  67410.37
#   Mean Optimized: 67425.77
#   Mean Improvement: -0.02%
#   Median Baseline:  65405.68
#   Median Optimized: 66729.81
#   Median Improvement: -2.02%
#
# Case ID: 93
#   Mean Baseline:  67871.10
#   Mean Optimized: 69297.80
#   Mean Improvement: -2.10%
#   Median Baseline:  68026.04
#   Median Optimized: 67906.42
#   Median Improvement: 0.18%
#
# Case ID: 94
#   Mean Baseline:  68375.35
#   Mean Optimized: 70839.36
#   Mean Improvement: -3.60%
#   Median Baseline:  67086.43
#   Median Optimized: 67852.10
#   Median Improvement: -1.14%
#
# Case ID: 95
#   Mean Baseline:  11631.66
#   Mean Optimized: 10360.17
#   Mean Improvement: 10.93%
#   Median Baseline:  10471.80
#   Median Optimized: 9447.34
#   Median Improvement: 9.78%
#
# Case ID: 96
#   Mean Baseline:  10362.32
#   Mean Optimized: 9983.59
#   Mean Improvement: 3.65%
#   Median Baseline:  10181.98
#   Median Optimized: 9348.89
#   Median Improvement: 8.18%
#
# Case ID: 97
#   Mean Baseline:  9285.56
#   Mean Optimized: 10462.67
#   Mean Improvement: -12.68%
#   Median Baseline:  8186.96
#   Median Optimized: 10667.15
#   Median Improvement: -30.29%
#
# Case ID: 98
#   Mean Baseline:  10167.36
#   Mean Optimized: 11536.01
#   Mean Improvement: -13.46%
#   Median Baseline:  8739.58
#   Median Optimized: 10914.46
#   Median Improvement: -24.89%
#
# Case ID: 99
#   Mean Baseline:  34826.20
#   Mean Optimized: 11266.17
#   Mean Improvement: 67.65%
#   Median Baseline:  11711.67
#   Median Optimized: 10518.13
#   Median Improvement: 10.19%
#
# Case ID: 100
#   Mean Baseline:  9016.56
#   Mean Optimized: 83680.68
#   Mean Improvement: -828.08%
#   Median Baseline:  8991.36
#   Median Optimized: 12648.61
#   Median Improvement: -40.68%
#
# Case ID: 101
#   Mean Baseline:  10443.07
#   Mean Optimized: 9096.85
#   Mean Improvement: 12.89%
#   Median Baseline:  10021.08
#   Median Optimized: 9281.85
#   Median Improvement: 7.38%
#
# Case ID: 102
#   Mean Baseline:  82406.73
#   Mean Optimized: 33254.81
#   Mean Improvement: 59.65%
#   Median Baseline:  13033.80
#   Median Optimized: 9645.69
#   Median Improvement: 25.99%
#
# Case ID: 103
#   Mean Baseline:  56509.67
#   Mean Optimized: 80693.61
#   Mean Improvement: -42.80%
#   Median Baseline:  9524.60
#   Median Optimized: 9665.63
#   Median Improvement: -1.48%
#
# Case ID: 104
#   Mean Baseline:  102397.23
#   Mean Optimized: 128245.48
#   Mean Improvement: -25.24%
#   Median Baseline:  9550.55
#   Median Optimized: 126893.35
#   Median Improvement: -1228.65%
#
# Case ID: 105
#   Mean Baseline:  125694.93
#   Mean Optimized: 148910.31
#   Mean Improvement: -18.47%
#   Median Baseline:  125790.05
#   Median Optimized: 240541.33
#   Median Improvement: -91.22%
#
# Case ID: 106
#   Mean Baseline:  218115.13
#   Mean Optimized: 220477.40
#   Mean Improvement: -1.08%
#   Median Baseline:  239888.74
#   Median Optimized: 242320.19
#   Median Improvement: -1.01%
#
# Case ID: 107
#   Mean Baseline:  242178.21
#   Mean Optimized: 241114.43
#   Mean Improvement: 0.44%
#   Median Baseline:  242218.53
#   Median Optimized: 239243.34
#   Median Improvement: 1.23%
#
# Case ID: 108
#   Mean Baseline:  241121.97
#   Mean Optimized: 242768.78
#   Mean Improvement: -0.68%
#   Median Baseline:  238420.30
#   Median Optimized: 241097.87
#   Median Improvement: -1.12%
#
# Case ID: 109
#   Mean Baseline:  240156.43
#   Mean Optimized: 243495.22
#   Mean Improvement: -1.39%
#   Median Baseline:  239877.74
#   Median Optimized: 241967.24
#   Median Improvement: -0.87%
#
# Case ID: 110
#   Mean Baseline:  241341.62
#   Mean Optimized: 241796.12
#   Mean Improvement: -0.19%
#   Median Baseline:  239817.94
#   Median Optimized: 241221.21
#   Median Improvement: -0.59%
#
# Case ID: 111
#   Mean Baseline:  9955.95
#   Mean Optimized: 10517.72
#   Mean Improvement: -5.64%
#   Median Baseline:  10207.81
#   Median Optimized: 9774.77
#   Median Improvement: 4.24%
#
# Case ID: 112
#   Mean Baseline:  10813.36
#   Mean Optimized: 11900.76
#   Mean Improvement: -10.06%
#   Median Baseline:  11515.28
#   Median Optimized: 11630.49
#   Median Improvement: -1.00%
#
# Case ID: 113
#   Mean Baseline:  17030.04
#   Mean Optimized: 17941.34
#   Mean Improvement: -5.35%
#   Median Baseline:  9189.09
#   Median Optimized: 10385.59
#   Median Improvement: -13.02%
#
# Case ID: 114
#   Mean Baseline:  10357.88
#   Mean Optimized: 10382.80
#   Mean Improvement: -0.24%
#   Median Baseline:  10095.85
#   Median Optimized: 11065.57
#   Median Improvement: -9.61%
#
# Case ID: 115
#   Mean Baseline:  10197.32
#   Mean Optimized: 11813.23
#   Mean Improvement: -15.85%
#   Median Baseline:  9774.33
#   Median Optimized: 10073.51
#   Median Improvement: -3.06%
#
# Case ID: 116
#   Mean Baseline:  11170.42
#   Mean Optimized: 10674.42
#   Mean Improvement: 4.44%
#   Median Baseline:  10432.00
#   Median Optimized: 10879.62
#   Median Improvement: -4.29%
#
# Case ID: 117
#   Mean Baseline:  23829.00
#   Mean Optimized: 31358.91
#   Mean Improvement: -31.60%
#   Median Baseline:  11857.22
#   Median Optimized: 11504.65
#   Median Improvement: 2.97%
#
# Case ID: 118
#   Mean Baseline:  49655.88
#   Mean Optimized: 15866.82
#   Mean Improvement: 68.05%
#   Median Baseline:  74077.20
#   Median Optimized: 9081.54
#   Median Improvement: 87.74%
#
# Case ID: 119
#   Mean Baseline:  41655.29
#   Mean Optimized: 40456.54
#   Mean Improvement: 2.88%
#   Median Baseline:  40668.56
#   Median Optimized: 40344.37
#   Median Improvement: 0.80%
#
# Case ID: 120
#   Mean Baseline:  29017.39
#   Mean Optimized: 38943.43
#   Mean Improvement: -34.21%
#   Median Baseline:  10179.80
#   Median Optimized: 39101.47
#   Median Improvement: -284.11%
#
# Case ID: 121
#   Mean Baseline:  51513.41
#   Mean Optimized: 44714.64
#   Mean Improvement: 13.20%
#   Median Baseline:  68908.28
#   Median Optimized: 67553.30
#   Median Improvement: 1.97%
#
# Case ID: 122
#   Mean Baseline:  60469.52
#   Mean Optimized: 63472.30
#   Mean Improvement: -4.97%
#   Median Baseline:  71288.49
#   Median Optimized: 68108.44
#   Median Improvement: 4.46%
#
# Case ID: 123
#   Mean Baseline:  72752.30
#   Mean Optimized: 64790.17
#   Mean Improvement: 10.94%
#   Median Baseline:  72558.44
#   Median Optimized: 71262.36
#   Median Improvement: 1.79%
#
# Case ID: 124
#   Mean Baseline:  67892.05
#   Mean Optimized: 68485.07
#   Mean Improvement: -0.87%
#   Median Baseline:  68276.07
#   Median Optimized: 68526.05
#   Median Improvement: -0.37%
#
# Case ID: 125
#   Mean Baseline:  68327.90
#   Mean Optimized: 67265.55
#   Mean Improvement: 1.55%
#   Median Baseline:  67674.75
#   Median Optimized: 66132.25
#   Median Improvement: 2.28%
#
# Case ID: 126
#   Mean Baseline:  69332.75
#   Mean Optimized: 70558.26
#   Mean Improvement: -1.77%
#   Median Baseline:  69270.69
#   Median Optimized: 68137.90
#   Median Improvement: 1.64%
#
# Case ID: 127
#   Mean Baseline:  12801.78
#   Mean Optimized: 10958.45
#   Mean Improvement: 14.40%
#   Median Baseline:  10473.91
#   Median Optimized: 10345.98
#   Median Improvement: 1.22%
#
# Case ID: 128
#   Mean Baseline:  10679.37
#   Mean Optimized: 10315.27
#   Mean Improvement: 3.41%
#   Median Baseline:  11558.90
#   Median Optimized: 7934.92
#   Median Improvement: 31.35%
#
# Case ID: 129
#   Mean Baseline:  13577.03
#   Mean Optimized: 9324.93
#   Mean Improvement: 31.32%
#   Median Baseline:  13476.08
#   Median Optimized: 8707.71
#   Median Improvement: 35.38%
#
# Case ID: 130
#   Mean Baseline:  20202.17
#   Mean Optimized: 11111.78
#   Mean Improvement: 45.00%
#   Median Baseline:  10364.22
#   Median Optimized: 11242.57
#   Median Improvement: -8.47%
#
# Case ID: 131
#   Mean Baseline:  10557.75
#   Mean Optimized: 10417.13
#   Mean Improvement: 1.33%
#   Median Baseline:  10543.07
#   Median Optimized: 9442.86
#   Median Improvement: 10.44%
#
# Case ID: 132
#   Mean Baseline:  23659.84
#   Mean Optimized: 9241.71
#   Mean Improvement: 60.94%
#   Median Baseline:  11806.41
#   Median Optimized: 8944.04
#   Median Improvement: 24.24%
#
# Case ID: 133
#   Mean Baseline:  32277.13
#   Mean Optimized: 15399.83
#   Mean Improvement: 52.29%
#   Median Baseline:  12533.25
#   Median Optimized: 8699.60
#   Median Improvement: 30.59%
#
# Case ID: 134
#   Mean Baseline:  28634.35
#   Mean Optimized: 20996.04
#   Mean Improvement: 26.68%
#   Median Baseline:  11237.81
#   Median Optimized: 8556.44
#   Median Improvement: 23.86%
#
# Case ID: 135
#   Mean Baseline:  43033.29
#   Mean Optimized: 36732.63
#   Mean Improvement: 14.64%
#   Median Baseline:  42362.50
#   Median Optimized: 12124.91
#   Median Improvement: 71.38%
#
# Case ID: 136
#   Mean Baseline:  45534.17
#   Mean Optimized: 51992.86
#   Mean Improvement: -14.18%
#   Median Baseline:  69093.93
#   Median Optimized: 69700.40
#   Median Improvement: -0.88%
#
# Case ID: 137
#   Mean Baseline:  45212.01
#   Mean Optimized: 41014.74
#   Mean Improvement: 9.28%
#   Median Baseline:  68143.70
#   Median Optimized: 38637.73
#   Median Improvement: 43.30%
#
# Case ID: 138
#   Mean Baseline:  63776.92
#   Mean Optimized: 50496.85
#   Mean Improvement: 20.82%
#   Median Baseline:  69915.64
#   Median Optimized: 66300.00
#   Median Improvement: 5.17%
#
# Case ID: 139
#   Mean Baseline:  62231.23
#   Mean Optimized: 56717.74
#   Mean Improvement: 8.86%
#   Median Baseline:  67557.89
#   Median Optimized: 67400.04
#   Median Improvement: 0.23%
#
# Case ID: 140
#   Mean Baseline:  69432.97
#   Mean Optimized: 67566.00
#   Mean Improvement: 2.69%
#   Median Baseline:  70021.08
#   Median Optimized: 65992.51
#   Median Improvement: 5.75%
#
# Case ID: 141
#   Mean Baseline:  71158.32
#   Mean Optimized: 67179.47
#   Mean Improvement: 5.59%
#   Median Baseline:  68566.42
#   Median Optimized: 66224.64
#   Median Improvement: 3.42%
#
# Case ID: 142
#   Mean Baseline:  68198.38
#   Mean Optimized: 66675.47
#   Mean Improvement: 2.23%
#   Median Baseline:  68221.85
#   Median Optimized: 65335.70
#   Median Improvement: 4.23%
#
# Case ID: 143
#   Mean Baseline:  12729.75
#   Mean Optimized: 9901.13
#   Mean Improvement: 22.22%
#   Median Baseline:  13442.06
#   Median Optimized: 9270.55
#   Median Improvement: 31.03%
#
# Case ID: 144
#   Mean Baseline:  12478.30
#   Mean Optimized: 9176.84
#   Mean Improvement: 26.46%
#   Median Baseline:  11211.11
#   Median Optimized: 7854.25
#   Median Improvement: 29.94%
#
# Case ID: 145
#   Mean Baseline:  10219.89
#   Mean Optimized: 8977.35
#   Mean Improvement: 12.16%
#   Median Baseline:  10041.34
#   Median Optimized: 9073.61
#   Median Improvement: 9.64%
#
# Case ID: 146
#   Mean Baseline:  18056.72
#   Mean Optimized: 10479.72
#   Mean Improvement: 41.96%
#   Median Baseline:  10999.16
#   Median Optimized: 10131.12
#   Median Improvement: 7.89%
#
# Case ID: 147
#   Mean Baseline:  16818.69
#   Mean Optimized: 17012.08
#   Mean Improvement: -1.15%
#   Median Baseline:  8175.11
#   Median Optimized: 10450.01
#   Median Improvement: -27.83%
#
# Case ID: 148
#   Mean Baseline:  24056.15
#   Mean Optimized: 11458.98
#   Mean Improvement: 52.37%
#   Median Baseline:  10103.18
#   Median Optimized: 12150.45
#   Median Improvement: -20.26%
#
# Case ID: 149
#   Mean Baseline:  31451.33
#   Mean Optimized: 10958.13
#   Mean Improvement: 65.16%
#   Median Baseline:  11936.02
#   Median Optimized: 10414.72
#   Median Improvement: 12.75%
#
# Case ID: 150
#   Mean Baseline:  30137.10
#   Mean Optimized: 16752.10
#   Mean Improvement: 44.41%
#   Median Baseline:  12607.24
#   Median Optimized: 9146.97
#   Median Improvement: 27.45%
#
# Case ID: 151
#   Mean Baseline:  37524.14
#   Mean Optimized: 22641.57
#   Mean Improvement: 39.66%
#   Median Baseline:  12276.39
#   Median Optimized: 10482.83
#   Median Improvement: 14.61%
#
# Case ID: 152
#   Mean Baseline:  41616.40
#   Mean Optimized: 46899.57
#   Mean Improvement: -12.69%
#   Median Baseline:  40726.02
#   Median Optimized: 70676.56
#   Median Improvement: -73.54%
#
# Case ID: 153
#   Mean Baseline:  33931.44
#   Mean Optimized: 38482.86
#   Mean Improvement: -13.41%
#   Median Baseline:  8342.07
#   Median Optimized: 38745.43
#   Median Improvement: -364.46%
#
# Case ID: 154
#   Mean Baseline:  64329.10
#   Mean Optimized: 70019.39
#   Mean Improvement: -8.85%
#   Median Baseline:  69330.65
#   Median Optimized: 67700.67
#   Median Improvement: 2.35%
#
# Case ID: 155
#   Mean Baseline:  68117.13
#   Mean Optimized: 62611.96
#   Mean Improvement: 8.08%
#   Median Baseline:  67585.12
#   Median Optimized: 67875.53
#   Median Improvement: -0.43%
#
# Case ID: 156
#   Mean Baseline:  65424.46
#   Mean Optimized: 69004.33
#   Mean Improvement: -5.47%
#   Median Baseline:  70761.04
#   Median Optimized: 68106.22
#   Median Improvement: 3.75%
#
# Case ID: 157
#   Mean Baseline:  68894.61
#   Mean Optimized: 68331.21
#   Mean Improvement: 0.82%
#   Median Baseline:  68503.41
#   Median Optimized: 66928.30
#   Median Improvement: 2.30%
#
# Case ID: 158
#   Mean Baseline:  67941.51
#   Mean Optimized: 65860.51
#   Mean Improvement: 3.06%
#   Median Baseline:  68145.79
#   Median Optimized: 66027.70
#   Median Improvement: 3.11%
#
# Case ID: 159
#   Mean Baseline:  14052.06
#   Mean Optimized: 7877.31
#   Mean Improvement: 43.94%
#   Median Baseline:  14096.01
#   Median Optimized: 7644.22
#   Median Improvement: 45.77%
#
# Case ID: 160
#   Mean Baseline:  12511.73
#   Mean Optimized: 9679.66
#   Mean Improvement: 22.64%
#   Median Baseline:  11284.05
#   Median Optimized: 10387.98
#   Median Improvement: 7.94%
#
# Case ID: 161
#   Mean Baseline:  14308.65
#   Mean Optimized: 11217.91
#   Mean Improvement: 21.60%
#   Median Baseline:  13416.05
#   Median Optimized: 9930.94
#   Median Improvement: 25.98%
#
# Case ID: 162
#   Mean Baseline:  11712.32
#   Mean Optimized: 11311.86
#   Mean Improvement: 3.42%
#   Median Baseline:  12540.64
#   Median Optimized: 11673.68
#   Median Improvement: 6.91%
#
# Case ID: 163
#   Mean Baseline:  17737.04
#   Mean Optimized: 9264.72
#   Mean Improvement: 47.77%
#   Median Baseline:  11045.29
#   Median Optimized: 8989.91
#   Median Improvement: 18.61%
#
# Case ID: 164
#   Mean Baseline:  11573.96
#   Mean Optimized: 9107.62
#   Mean Improvement: 21.31%
#   Median Baseline:  10559.72
#   Median Optimized: 8582.37
#   Median Improvement: 18.73%
#
# Case ID: 165
#   Mean Baseline:  24219.05
#   Mean Optimized: 9613.31
#   Mean Improvement: 60.31%
#   Median Baseline:  12070.05
#   Median Optimized: 9575.29
#   Median Improvement: 20.67%
#
# Case ID: 166
#   Mean Baseline:  16208.21
#   Mean Optimized: 22601.91
#   Mean Improvement: -39.45%
#   Median Baseline:  9453.12
#   Median Optimized: 9966.70
#   Median Improvement: -5.43%
#
# Case ID: 167
#   Mean Baseline:  35466.02
#   Mean Optimized: 21857.58
#   Mean Improvement: 38.37%
#   Median Baseline:  11117.09
#   Median Optimized: 9473.36
#   Median Improvement: 14.79%
#
# Case ID: 168
#   Mean Baseline:  45597.40
#   Mean Optimized: 7882.51
#   Mean Improvement: 82.71%
#   Median Baseline:  68864.32
#   Median Optimized: 8764.40
#   Median Improvement: 87.27%
#
# Case ID: 169
#   Mean Baseline:  52176.34
#   Mean Optimized: 38238.98
#   Mean Improvement: 26.71%
#   Median Baseline:  69754.56
#   Median Optimized: 37959.20
#   Median Improvement: 45.58%
#
# Case ID: 170
#   Mean Baseline:  57443.61
#   Mean Optimized: 56784.66
#   Mean Improvement: 1.15%
#   Median Baseline:  68385.86
#   Median Optimized: 67890.64
#   Median Improvement: 0.72%
#
# Case ID: 171
#   Mean Baseline:  69804.72
#   Mean Optimized: 61743.05
#   Mean Improvement: 11.55%
#   Median Baseline:  69316.37
#   Median Optimized: 67626.62
#   Median Improvement: 2.44%
#
# Case ID: 172
#   Mean Baseline:  69078.73
#   Mean Optimized: 66897.01
#   Mean Improvement: 3.16%
#   Median Baseline:  68706.82
#   Median Optimized: 67243.41
#   Median Improvement: 2.13%
#
# Case ID: 173
#   Mean Baseline:  67597.09
#   Mean Optimized: 66833.96
#   Mean Improvement: 1.13%
#   Median Baseline:  68215.68
#   Median Optimized: 66732.46
#   Median Improvement: 2.17%
#
# Case ID: 174
#   Mean Baseline:  69050.08
#   Mean Optimized: 65917.23
#   Mean Improvement: 4.54%
#   Median Baseline:  68998.38
#   Median Optimized: 65363.35
#   Median Improvement: 5.27%
#
# Case ID: 175
#   Mean Baseline:  10366.41
#   Mean Optimized: 7838.77
#   Mean Improvement: 24.38%
#   Median Baseline:  9117.05
#   Median Optimized: 6790.65
#   Median Improvement: 25.52%
#
# Case ID: 176
#   Mean Baseline:  10640.23
#   Mean Optimized: 9091.32
#   Mean Improvement: 14.56%
#   Median Baseline:  9554.04
#   Median Optimized: 9282.36
#   Median Improvement: 2.84%
#
# Case ID: 177
#   Mean Baseline:  9298.86
#   Mean Optimized: 9058.28
#   Mean Improvement: 2.59%
#   Median Baseline:  8801.71
#   Median Optimized: 7750.22
#   Median Improvement: 11.95%
#
# Case ID: 178
#   Mean Baseline:  11438.06
#   Mean Optimized: 10531.51
#   Mean Improvement: 7.93%
#   Median Baseline:  11830.01
#   Median Optimized: 9099.11
#   Median Improvement: 23.08%
#
# Case ID: 179
#   Mean Baseline:  9091.93
#   Mean Optimized: 7524.09
#   Mean Improvement: 17.24%
#   Median Baseline:  8407.96
#   Median Optimized: 7634.55
#   Median Improvement: 9.20%
#
# Case ID: 180
#   Mean Baseline:  58560.47
#   Mean Optimized: 8430.35
#   Mean Improvement: 85.60%
#   Median Baseline:  12299.70
#   Median Optimized: 8311.40
#   Median Improvement: 32.43%
#
# Case ID: 181
#   Mean Baseline:  10294.73
#   Mean Optimized: 9198.01
#   Mean Improvement: 10.65%
#   Median Baseline:  9213.58
#   Median Optimized: 8039.26
#   Median Improvement: 12.75%
#
# Case ID: 182
#   Mean Baseline:  81727.06
#   Mean Optimized: 9057.19
#   Mean Improvement: 88.92%
#   Median Baseline:  13392.91
#   Median Optimized: 8389.95
#   Median Improvement: 37.36%
#
# Case ID: 183
#   Mean Baseline:  79421.04
#   Mean Optimized: 55534.77
#   Mean Improvement: 30.08%
#   Median Baseline:  9681.75
#   Median Optimized: 7867.49
#   Median Improvement: 18.74%
#
# Case ID: 184
#   Mean Baseline:  102092.48
#   Mean Optimized: 102971.88
#   Mean Improvement: -0.86%
#   Median Baseline:  9510.14
#   Median Optimized: 9015.31
#   Median Improvement: 5.20%
#
# Case ID: 185
#   Mean Baseline:  150370.23
#   Mean Optimized: 125328.26
#   Mean Improvement: 16.65%
#   Median Baseline:  240206.11
#   Median Optimized: 124842.45
#   Median Improvement: 48.03%
#
# Case ID: 186
#   Mean Baseline:  196389.61
#   Mean Optimized: 218962.67
#   Mean Improvement: -11.49%
#   Median Baseline:  240001.17
#   Median Optimized: 240984.76
#   Median Improvement: -0.41%
#
# Case ID: 187
#   Mean Baseline:  242039.85
#   Mean Optimized: 193891.51
#   Mean Improvement: 19.89%
#   Median Baseline:  240101.39
#   Median Optimized: 238204.58
#   Median Improvement: 0.79%
#
# Case ID: 188
#   Mean Baseline:  241833.71
#   Mean Optimized: 239435.72
#   Mean Improvement: 0.99%
#   Median Baseline:  241655.12
#   Median Optimized: 239103.75
#   Median Improvement: 1.06%
#
# Case ID: 189
#   Mean Baseline:  240899.82
#   Mean Optimized: 238979.33
#   Mean Improvement: 0.80%
#   Median Baseline:  239326.52
#   Median Optimized: 238402.13
#   Median Improvement: 0.39%
#
# Case ID: 190
#   Mean Baseline:  240836.06
#   Mean Optimized: 238852.33
#   Mean Improvement: 0.82%
#   Median Baseline:  240056.12
#   Median Optimized: 236994.66
#   Median Improvement: 1.28%
#
# Case ID: 191
#   Mean Baseline:  18418.53
#   Mean Optimized: 9785.59
#   Mean Improvement: 46.87%
#   Median Baseline:  10749.71
#   Median Optimized: 9436.44
#   Median Improvement: 12.22%
#
# Case ID: 192
#   Mean Baseline:  12467.81
#   Mean Optimized: 8428.50
#   Mean Improvement: 32.40%
#   Median Baseline:  11980.71
#   Median Optimized: 7547.70
#   Median Improvement: 37.00%
#
# Case ID: 193
#   Mean Baseline:  17958.73
#   Mean Optimized: 8170.57
#   Mean Improvement: 54.50%
#   Median Baseline:  10526.49
#   Median Optimized: 7688.57
#   Median Improvement: 26.96%
#
# Case ID: 194
#   Mean Baseline:  10933.37
#   Mean Optimized: 8343.80
#   Mean Improvement: 23.69%
#   Median Baseline:  10624.77
#   Median Optimized: 6988.30
#   Median Improvement: 34.23%
#
# Case ID: 195
#   Mean Baseline:  11830.43
#   Mean Optimized: 17298.95
#   Mean Improvement: -46.22%
#   Median Baseline:  12514.13
#   Median Optimized: 10676.47
#   Median Improvement: 14.68%
#
# Case ID: 196
#   Mean Baseline:  11624.23
#   Mean Optimized: 8756.45
#   Mean Improvement: 24.67%
#   Median Baseline:  10703.17
#   Median Optimized: 8350.20
#   Median Improvement: 21.98%
#
# Case ID: 197
#   Mean Baseline:  10791.96
#   Mean Optimized: 15487.07
#   Mean Improvement: -43.51%
#   Median Baseline:  10743.84
#   Median Optimized: 9017.66
#   Median Improvement: 16.07%
#
# Case ID: 198
#   Mean Baseline:  42605.45
#   Mean Optimized: 15440.63
#   Mean Improvement: 63.76%
#   Median Baseline:  43835.06
#   Median Optimized: 8647.33
#   Median Improvement: 80.27%
#
# Case ID: 199
#   Mean Baseline:  34663.62
#   Mean Optimized: 14660.50
#   Mean Improvement: 57.71%
#   Median Baseline:  12038.65
#   Median Optimized: 8325.12
#   Median Improvement: 30.85%
#
# ========================================
# Overall Mean Improvement:   6.77%
# Overall Median Improvement: 3.20%
# ========================================

# %%
c = 0
tc = 0
for k,v in case_improvements.items():
    if v < 0:
        print(k,v)
        c=c+1
    tc = tc + 1
print(f"Total problematic cases {c}")
print(f"Total cases {tc}")
# Out:
# (0, 2) -45.59035516573602
# (0, 4) -39.4519405967626
# (0, 7) -21.214556984761202
# (0, 10) -823.4129607199534
# (0, 13) -3.579961270101706
# (0, 14) -1.292399111331249
# (0, 15) -46.49591406230968
# (0, 18) -5.321857518263155
# (0, 25) -19.042201045538672
# (0, 28) -1.9740006841485285
# (0, 30) -0.8585997661139799
# (0, 33) -48.97791608379952
# (0, 35) -141.65820169175936
# (0, 36) -9.506355507970284
# (0, 37) -2.581617775836416
# (0, 38) -0.9138539372606906
# (0, 39) -8.214423508856633
# (0, 40) -51.198203111659666
# (0, 43) -9.435459719185408
# (0, 44) -6.051202712290529
# (0, 45) -5.813482279519691
# (0, 50) -38.084005184821216
# (0, 52) -5.932977627352541
# (0, 54) -53.15390593631609
# (0, 55) -2.6846648381810145
# (0, 58) -3.8456074871735644
# (0, 60) -3.6000309102029755
# (0, 61) -9.925303454148308
# (0, 62) -3.187495034244526
# (0, 66) -33.797682076976734
# (0, 67) -8.636727400924489
# (0, 74) -5.416529449848915
# (0, 75) -1322.8644599465872
# (0, 77) -14.151870450383738
# (0, 78) -2.5133138539500357
# (0, 80) -46.82906553858561
# (0, 81) -6.233999347121866
# (0, 83) -14.074037369191608
# (0, 84) -102.23064562229428
# (0, 85) -48.80198537239868
# (0, 86) -26.19667807012697
# (0, 88) -10.18704930611986
# (0, 89) -934.5588115015598
# (0, 90) -7.141645738432022
# (0, 91) -0.047137262634183434
# (0, 92) -2.77728962869912
# (0, 94) -1.553868217499541
# (0, 95) -75.4342377530157
# (0, 96) -5.354274849888393
# (0, 97) -166.5453674765835
# (0, 98) -118.37735922805554
# (0, 99) -0.27903282037929195
# (0, 105) -5326.545963145573
# (0, 106) -1.3823834367572732
# (0, 108) -0.5889036603694096
# (0, 109) -1.20478220942317
# (0, 110) -0.7769138803496342
# (0, 112) -90.13004621823875
# (0, 113) -59.97310781402499
# (0, 117) -476.2114451683271
# (0, 119) -1021.9934906020502
# (0, 121) -8.899088806914202
# (0, 122) -1028.1863924097472
# (0, 124) -10.672807296936417
# (0, 125) -15.33452437215375
# (0, 126) -2.9678077894570722
# (0, 127) -17.259899577206774
# (0, 128) -166.87986953308672
# (0, 130) -45.00704636301908
# (0, 137) -890.4710886794998
# (0, 138) -1.960360743253452
# (0, 143) -25.488220327630135
# (0, 145) -3.6310454735435176
# (0, 151) -27.745118135991966
# (0, 154) -1114.2949121644283
# (0, 166) -520.7781838946177
# (0, 167) -538.0693984931003
# (0, 169) -978.2292490962836
# (0, 172) -4.453912979377091
# (0, 177) -9.805525802663347
# (0, 178) -130.71209310271837
# (0, 180) -38.338145174412986
# (0, 181) -71.77006552814893
# (0, 183) -42.04381691675757
# (0, 184) -32.179783002434405
# (0, 185) -0.20793203490792017
# (0, 191) -68.91539229708545
# (0, 193) -60.86076246219141
# (0, 195) -20.1157648382053
# (1, 0) -2.780027715655627
# (1, 3) -2.61390511043852
# (1, 4) -90.23802098597336
# (1, 5) -88.63817850192083
# (1, 6) -73.27153387009272
# (1, 7) -626.5032184994831
# (1, 9) -4.529812428026344
# (1, 14) -2.106858940418403
# (1, 16) -14.093852027622722
# (1, 17) -46.51574022898016
# (1, 18) -49.72246689396276
# (1, 21) -2387.9199660257996
# (1, 22) -268.02916417345807
# (1, 25) -5.0901637972636795
# (1, 29) -0.21165984564952492
# (1, 32) -206.0525419022614
# (1, 33) -86.89842002575675
# (1, 38) -36.72032076885831
# (1, 39) -176.87074822504377
# (1, 40) -3.8334686412993486
# (1, 42) -978.4571987353488
# (1, 44) -7.819542000473407
# (1, 46) -5.115446020595723
# (1, 47) -30.355308669352336
# (1, 48) -5.302758172384502
# (1, 49) -25.485223584837218
# (1, 50) -58.291062238178284
# (1, 51) -43.61133136434829
# (1, 52) -47.70665809537708
# (1, 53) -877.9386242856193
# (1, 63) -3.432805213543144
# (1, 64) -57.676825588063515
# (1, 66) -6.912618894931367
# (1, 67) -23.325530953312704
# (1, 70) -1.6307663028923145
# (1, 72) -47.22460533915604
# (1, 73) -15.266645090472908
# (1, 74) -1.8075344154024664
# (1, 77) -2.8130935761854188
# (1, 80) -53.30157032651817
# (1, 84) -26.23216022182841
# (1, 90) -10.190972057782039
# (1, 93) -4.497784053259015
# (1, 94) -14.293477403854277
# (1, 97) -180.64821491915274
# (1, 99) -57.58011020891488
# (1, 100) -67.51693652728346
# (1, 101) -78.23791457674089
# (1, 103) -3234.1173968350176
# (1, 108) -2.230899468621821
# (1, 109) -0.18252998837129203
# (1, 111) -71.74358145355156
# (1, 112) -14.293460913330064
# (1, 113) -65.51779669571337
# (1, 114) -98.57370411684346
# (1, 117) -51.48799515255399
# (1, 119) -12.368724863011424
# (1, 124) -0.07090927016491973
# (1, 125) -2.2471845458837567
# (1, 126) -4.9388398145977686
# (1, 134) -484.95675808546474
# (1, 135) -502.1419062853844
# (1, 136) -659.164375512292
# (1, 138) -1426.2331149679812
# (1, 139) -19.984735527349194
# (1, 145) -10.332886919777035
# (1, 147) -63.3023901896658
# (1, 148) -30.52378811801317
# (1, 152) -0.7198726365741545
# (1, 153) -712.7317306203921
# (1, 154) -15.080905088950693
# (1, 155) -3.95621205822068
# (1, 157) -3.5194949545701286
# (1, 158) -1.3253389613284667
# (1, 160) -7.937449474125178
# (1, 162) -27.81858565852062
# (1, 163) -41.76499594475449
# (1, 166) -846.4494810982548
# (1, 167) -5.644774389224459
# (1, 170) -9.507233063137544
# (1, 176) -6.902231449790573
# (1, 178) -3.8199459632308606
# (1, 179) -1.5451739665281037
# (1, 199) -117.89437759010055
# (2, 0) -15.570914954767389
# (2, 3) -118.99779274492221
# (2, 4) -116.12851296499633
# (2, 6) -47.0926938993045
# (2, 7) -16.326572798464564
# (2, 9) -12.045453911868451
# (2, 17) -20.76325458857818
# (2, 20) -6.680600745267137
# (2, 24) -3.753760616344848
# (2, 28) -1.2355877102175494
# (2, 31) -3.142996908574389
# (2, 33) -73.11830177561093
# (2, 36) -870.7038824054795
# (2, 37) -69.47962228013986
# (2, 40) -10.73820524035881
# (2, 41) -647.2151631612353
# (2, 42) -0.020798541608866305
# (2, 45) -0.3960487039396111
# (2, 58) -900.9098208626394
# (2, 59) -1076.6488019977712
# (2, 61) -0.18117933377150142
# (2, 64) -90.80048732562945
# (2, 65) -190.83511367613855
# (2, 66) -6.197279720795388
# (2, 67) -9.536535415482831
# (2, 68) -112.38433468585775
# (2, 69) -49.166856362619576
# (2, 70) -56.80393082957007
# (2, 71) -19.094606053813443
# (2, 73) -5.917524029756032
# (2, 75) -1082.5421839571145
# (2, 77) -3.4237366392395394
# (2, 78) -6.533461106603664
# (2, 79) -3.3478562470223183
# (2, 82) -48.91848307151203
# (2, 83) -61.52239399139382
# (2, 84) -40.26226699640908
# (2, 88) -5.553606410029321
# (2, 89) -4.072158118318388
# (2, 92) -0.974250290500835
# (2, 93) -7.656217588710147
# (2, 95) -4.8221626272986
# (2, 97) -25.634609105414196
# (2, 98) -26.053896193304123
# (2, 99) -5.910522962610843
# (2, 100) -68.95581291536216
# (2, 101) -14.378730162896794
# (2, 102) -1741.6814914435556
# (2, 104) -2627.691589619262
# (2, 109) -1.0554772880003234
# (2, 111) -26.521833007413598
# (2, 112) -190.7211923480639
# (2, 114) -90.24536703571341
# (2, 115) -238.17010237643436
# (2, 116) -30.972913052471405
# (2, 118) -4.866483100638085
# (2, 120) -780.4153500402876
# (2, 121) -1026.588229415488
# (2, 122) -890.8622975195079
# (2, 123) -15.71066319507404
# (2, 124) -6.348539538505429
# (2, 125) -5.660316288916069
# (2, 126) -27.029224907547285
# (2, 127) -4.753754038303705
# (2, 128) -25.95038259884933
# (2, 129) -114.05789695055608
# (2, 130) -11.97858623771602
# (2, 133) -22.375480644713996
# (2, 147) -742.0445338875278
# (2, 148) -58.02753741410221
# (2, 149) -50.40346322026799
# (2, 150) -9.026136737360694
# (2, 152) -782.2786900569233
# (2, 153) -967.2964200421525
# (2, 154) -1.479329801117025
# (2, 156) -2.241658712503799
# (2, 157) -0.5906761485886945
# (2, 158) -12.74770895501644
# (2, 160) -26.624254904872352
# (2, 161) -69.4499001778482
# (2, 172) -7.030820450761786
# (2, 173) -6.305172771526111
# (2, 176) -222.4133506842596
# (2, 179) -38.306657973920444
# (2, 182) -5.772596131320211
# (2, 183) -2003.7318396658793
# (2, 184) -2.8628281988985695
# (2, 185) -0.4945702350213879
# (2, 186) -4.801993918899731
# (2, 187) -3.2351409829252944
# (2, 189) -1.0637100451679835
# (2, 190) -0.5925984822128405
# (2, 191) -23.91469650206391
# (2, 192) -44.97727727151769
# (2, 193) -15.685845025508039
# (2, 197) -4.05699203537935
# (3, 1) -110.14487071230434
# (3, 3) -228.32763269511497
# (3, 7) -17.333573774639717
# (3, 10) -6.842840296229366
# (3, 13) -10.594100466382928
# (3, 14) -8.75696800346394
# (3, 17) -7.10303700304962
# (3, 20) -70.0231091162051
# (3, 22) -41.20160064723526
# (3, 24) -43.35806662569321
# (3, 26) -1.0792011212881603
# (3, 28) -0.4316158769846547
# (3, 30) -0.9535520956318526
# (3, 31) -18.60363955181911
# (3, 39) -59.48524996155601
# (3, 40) -587.7201099884489
# (3, 44) -10.714441343233712
# (3, 46) -3.852500121490185
# (3, 47) -7.983073329121969
# (3, 48) -14.095742461167196
# (3, 49) -29.231141433836427
# (3, 50) -30.469752339601325
# (3, 51) -23.914596930074147
# (3, 52) -22.082496992547405
# (3, 58) -1076.0610971825295
# (3, 61) -4.48356097364698
# (3, 64) -7.821720352404912
# (3, 66) -34.15157448350041
# (3, 67) -1002.9611006628007
# (3, 69) -27.506017732362675
# (3, 71) -606.9960474166023
# (3, 72) -596.9198055873102
# (3, 73) -721.5225479194805
# (3, 74) -0.6177545938759126
# (3, 80) -40.992519023818126
# (3, 81) -2.3866526481055477
# (3, 86) -557.5549028280946
# (3, 90) -1444.3555346492908
# (3, 91) -7.249885089941238
# (3, 93) -0.033203636286487155
# (3, 96) -33.1419739596949
# (3, 103) -2.8778299211975447
# (3, 106) -2.5780224306780304
# (3, 113) -15.682819805984098
# (3, 117) -14.849260902376097
# (3, 121) -1.013693206140344
# (3, 122) -17.041599034452123
# (3, 123) -11.907095676597185
# (3, 126) -19.75215710106215
# (3, 128) -34.18198024089056
# (3, 130) -131.14530922390085
# (3, 131) -1.8506127471436369
# (3, 132) -13.881679829190437
# (3, 133) -671.079611898597
# (3, 134) -1111.726855362106
# (3, 135) -1064.989352949625
# (3, 136) -6.442647623050111
# (3, 137) -951.9654892242725
# (3, 140) -17.419678102649943
# (3, 144) -58.46157363725021
# (3, 147) -52.22784496060739
# (3, 148) -60.78611064423336
# (3, 149) -5.326474473068291
# (3, 150) -32.04088937381186
# (3, 153) -35.648148569284835
# (3, 154) -0.7025263108234863
# (3, 156) -2.8327951600917536
# (3, 157) -5.886541537204132
# (3, 159) -23.505129120580243
# (3, 162) -142.9555631649901
# (3, 173) -5.169083716748763
# (3, 178) -24.61122761830673
# (3, 186) -1.8455026833191583
# (3, 196) -41.71367023669414
# (3, 197) -21.02966197388344
# (4, 3) -56.54317049265527
# (4, 6) -1289.838914899748
# (4, 7) -881.6570900137442
# (4, 9) -3.3986790722521727
# (4, 14) -3.5889651433738026
# (4, 15) -109.85606099771348
# (4, 17) -4.821424596229196
# (4, 19) -62.51926159907653
# (4, 20) -0.06195743557262774
# (4, 21) -30.7220390219538
# (4, 25) -2640.809669076272
# (4, 26) -3162.7429765769275
# (4, 34) -49.1139469692848
# (4, 37) -22.842984486106477
# (4, 40) -543.1691201397254
# (4, 41) -13.118336345340861
# (4, 46) -3.7774337028967304
# (4, 48) -9.933067216973122
# (4, 50) -3.009173384799846
# (4, 51) -34.15825772770589
# (4, 61) -2.3812681796539565
# (4, 62) -9.841931525039973
# (4, 63) -31.10202568064925
# (4, 64) -8.364265163623688
# (4, 65) -19.713118107121467
# (4, 66) -129.75515958472167
# (4, 67) -69.55866150308427
# (4, 68) -461.64643897599274
# (4, 69) -614.2465149135381
# (4, 70) -505.20245501297677
# (4, 71) -788.5018361600289
# (4, 73) -776.2075699882683
# (4, 75) -0.19449242234769204
# (4, 78) -5.310519159688034
# (4, 79) -24.49968268717097
# (4, 81) -49.19429437486709
# (4, 85) -107.73276631780575
# (4, 90) -1316.8966559698442
# (4, 91) -1.109292142890096
# (4, 92) -8.242660696825405
# (4, 93) -13.215316376294375
# (4, 94) -23.335175180022546
# (4, 97) -22.627371606893224
# (4, 98) -24.765171387485214
# (4, 100) -65.89002180223825
# (4, 103) -2690.018118565
# (4, 104) -2552.064873154778
# (4, 105) -2882.378532134053
# (4, 106) -3718.0863237609833
# (4, 107) -0.13976375203203514
# (4, 108) -3.38679942982094
# (4, 109) -3.979583529226991
# (4, 110) -1.6609839735309946
# (4, 111) -39.73693911220387
# (4, 113) -15.742212139183534
# (4, 116) -14.258090270441159
# (4, 118) -48.19784967914886
# (4, 127) -132.85322455092648
# (4, 128) -8.745776990699525
# (4, 130) -8.540248607642965
# (4, 131) -67.39191850136734
# (4, 132) -37.79739972812134
# (4, 134) -31.62015995372414
# (4, 135) -542.5533134816328
# (4, 144) -0.2006589236580236
# (4, 147) -110.08053892563976
# (4, 149) -88.98485859285313
# (4, 152) -650.4197954273402
# (4, 154) -18.474612234875988
# (4, 155) -17.354268215175317
# (4, 156) -21.912369890375672
# (4, 158) -3.3680329447467425
# (4, 159) -62.20751541309609
# (4, 160) -60.32709580058874
# (4, 162) -10.208370166872474
# (4, 165) -40.30334925904631
# (4, 166) -90.29749182914436
# (4, 168) -72.01279748720731
# (4, 169) -0.4268180203382001
# (4, 176) -36.04454316233301
# (4, 179) -14.017485141055456
# (4, 188) -1.0949591236030736
# (4, 191) -0.2236614887425506
# (4, 194) -50.498593391084555
# (4, 195) -1141.895937931672
# (4, 197) -18.895439921841795
# (4, 198) -1190.4526245561467
# (4, 199) -2380.3463118389927
# (5, 0) -5.739317658493005
# (5, 1) -0.18186189273480746
# (5, 3) -58.840176349803706
# (5, 5) -418.15425035638026
# (5, 6) -28.25556909029199
# (5, 7) -1301.9387449752974
# (5, 8) -544.0954191910726
# (5, 9) -843.0244626640078
# (5, 10) -7.919367115006155
# (5, 11) -13.37641994794708
# (5, 13) -9.88294108823529
# (5, 15) -2315.939659333871
# (5, 17) -12.227002253494968
# (5, 18) -28.214270037521693
# (5, 19) -55.64428357725756
# (5, 20) -1575.021229552985
# (5, 21) -114.66734899079259
# (5, 22) -2658.0645470145405
# (5, 23) -3590.4499697479805
# (5, 25) -3121.276279057413
# (5, 26) -1.3862647514567286
# (5, 28) -3.795580080294716
# (5, 30) -2.9920863079290076
# (5, 40) -917.5458828852959
# (5, 41) -846.2992902249647
# (5, 42) -897.9244034241939
# (5, 44) -1616.8962550230074
# (5, 45) -7.12379989990532
# (5, 46) -3.575682107179424
# (5, 51) -4.965279388212024
# (5, 53) -28.15962257264046
# (5, 54) -34.101880679490606
# (5, 56) -202.72002871000265
# (5, 58) -1161.8934254929945
# (5, 59) -16.943079124769945
# (5, 60) -4.263595466037151
# (5, 61) -13.9657887195167
# (5, 63) -56.97182907685158
# (5, 64) -33.50884674308126
# (5, 66) -74.80042994025303
# (5, 69) -12.456627451936269
# (5, 71) -674.0339531190965
# (5, 72) -15.196196527617218
# (5, 73) -0.2050510680508651
# (5, 76) -0.7309383048453821
# (5, 77) -3.1243617785105116
# (5, 78) -4.665559944322207
# (5, 84) -9.22028327041084
# (5, 85) -51.19663849390598
# (5, 86) -11.662806146177466
# (5, 87) -6.340877288155772
# (5, 88) -774.5500080562977
# (5, 89) -691.6314177901908
# (5, 90) -862.0162240796491
# (5, 91) -7.166489700617289
# (5, 92) -8.96249429014882
# (5, 93) -4.721601747566669
# (5, 94) -8.04479767158414
# (5, 95) -164.21876468876383
# (5, 96) -145.3598585983323
# (5, 98) -33.37710351145928
# (5, 100) -2194.326698062416
# (5, 103) -3508.439577964081
# (5, 104) -4.537894776667399
# (5, 105) -5166.717539757381
# (5, 106) -4.548796885156907
# (5, 107) -1.5320916656854842
# (5, 108) -1.274061073047708
# (5, 109) -3.860893575297169
# (5, 110) -3.617149983071592
# (5, 111) -69.60650713727871
# (5, 112) -62.58735090058876
# (5, 113) -575.6720532039539
# (5, 114) -3.529677567334478
# (5, 115) -87.11193715814113
# (5, 116) -246.7061696878846
# (5, 117) -589.5881952197799
# (5, 120) -593.9689239053845
# (5, 121) -1633.7732899211353
# (5, 122) -2.541036928797548
# (5, 124) -1.0528750402631957
# (5, 132) -127.4271492088775
# (5, 135) -39.3872104598427
# (5, 136) -675.2758134822643
# (5, 138) -5.865737455549488
# (5, 139) -6.866358626067368
# (5, 141) -14.23982449462961
# (5, 144) -331.18557293415336
# (5, 145) -136.1305468624226
# (5, 146) -152.89758127224496
# (5, 147) -18.40583394501166
# (5, 149) -31.338134686511914
# (5, 150) -10.636982089194364
# (5, 152) -574.227837427264
# (5, 154) -2.708870642533947
# (5, 156) -2.90459265666155
# (5, 158) -2.937302642826187
# (5, 162) -4.541403687420232
# (5, 164) -84.18418167423431
# (5, 170) -805.0819737120015
# (5, 172) -0.0476912915017097
# (5, 175) -4.577258624672631
# (5, 177) -77.37603721395291
# (5, 178) -22.70657773464199
# (5, 179) -11.988559518541846
# (5, 181) -25.683287701329803
# (5, 183) -2427.5737682913295
# (5, 186) -2.8996628812212473
# (5, 189) -0.5331609473707823
# (5, 192) -40.43623978793976
# (5, 195) -2.5493555181574643
# (5, 196) -63.08305765085523
# (5, 197) -667.3373876832433
# (6, 0) -89.2007174616568
# (6, 1) -3.669770486601367
# (6, 3) -23.251987114587546
# (6, 4) -26.97386490732181
# (6, 6) -34.639910141244606
# (6, 9) -5.018776009803451
# (6, 12) -13.536090674372536
# (6, 20) -23.83333376571832
# (6, 23) -3.306576671016158
# (6, 24) -39.47579741707551
# (6, 25) -6308.438463524685
# (6, 27) -2.4555747655331714
# (6, 28) -0.7274154245351727
# (6, 29) -0.7811088661555191
# (6, 30) -1.4729022408733994
# (6, 31) -26.71340175599174
# (6, 32) -6.932869944379148
# (6, 34) -39.282971405012965
# (6, 40) -30.119157017072933
# (6, 41) -4.663201929722359
# (6, 42) -19.218587067228917
# (6, 43) -6.99722190332089
# (6, 44) -7.6673896123763186
# (6, 46) -83.58763523862997
# (6, 47) -14.388596022432464
# (6, 49) -41.36218755299946
# (6, 52) -8.54302917962528
# (6, 53) -8.16370272444294
# (6, 54) -89.24165460002585
# (6, 55) -644.363212422387
# (6, 62) -11.463117988472483
# (6, 63) -109.31535661714574
# (6, 64) -161.0093916961555
# (6, 67) -112.20829416431684
# (6, 68) -54.00611436326811
# (6, 70) -1299.3689206621134
# (6, 71) -94.16214951609186
# (6, 72) -21.784642830753416
# (6, 73) -0.6955675758134348
# (6, 74) -1449.5096952370825
# (6, 75) -0.3945834376258245
# (6, 76) -0.8036932914257672
# (6, 82) -111.2778953567267
# (6, 83) -191.40296388232215
# (6, 84) -44.03132667946812
# (6, 85) -263.6728563176392
# (6, 86) -23.35486654774945
# (6, 87) -854.6122677361388
# (6, 89) -5.7352642879811
# (6, 93) -4.034299192766953
# (6, 95) -15.998855381281754
# (6, 96) -41.76617726327099
# (6, 108) -1.882515877545939
# (6, 111) -15.914367446545855
# (6, 112) -21.39674683689183
# (6, 114) -60.74645693237682
# (6, 115) -96.47914759204394
# (6, 116) -41.63644063321007
# (6, 117) -607.7736330815003
# (6, 120) -1008.5168430379458
# (6, 125) -0.5845239737231003
# (6, 127) -43.9272483343703
# (6, 128) -40.57817835788286
# (6, 130) -42.165362143218374
# (6, 132) -32.086133837770376
# (6, 135) -44.37381646379104
# (6, 137) -2398.7913865075598
# (6, 140) -3.262399476188343
# (6, 141) -0.2308405722291663
# (6, 143) -28.661448027531012
# (6, 145) -45.04730457952545
# (6, 148) -66.52693537766655
# (6, 153) -0.3287412448605969
# (6, 155) -5.803931922793821
# (6, 157) -5.0971471544362155
# (6, 162) -35.724225254263395
# (6, 164) -65.70023274586526
# (6, 166) -83.98859299687489
# (6, 171) -5.0498771977728065
# (6, 175) -3.051823883147342
# (6, 177) -205.48393444685522
# (6, 183) -11.117875487387785
# (6, 184) -3245.273617032857
# (6, 185) -2615.423745899653
# (6, 196) -44.08199106131737
# (6, 197) -11.364809281970674
# (7, 0) -25.298411545172193
# (7, 3) -111.89860486166701
# (7, 4) -2.1390556963632443
# (7, 5) -676.3348461699259
# (7, 6) -43.11505599586439
# (7, 7) -40.77465613156357
# (7, 8) -735.8176721033323
# (7, 10) -7.676807022003896
# (7, 13) -8.406246361575231
# (7, 14) -23.022447545186946
# (7, 16) -184.71217938394778
# (7, 21) -7.518238441771172
# (7, 22) -11.80001339441544
# (7, 23) -14.430368245187353
# (7, 24) -2059.4269296053144
# (7, 26) -0.27566624623004443
# (7, 29) -1.1722203796152963
# (7, 30) -0.3008429899425009
# (7, 33) -40.102190616087185
# (7, 43) -4.917038681862761
# (7, 45) -2.9874907171613185
# (7, 48) -143.02358523825438
# (7, 51) -132.27416129801725
# (7, 52) -44.72079292630965
# (7, 53) -189.31436986754593
# (7, 58) -1.6209345367636443
# (7, 60) -19.309467855738152
# (7, 65) -29.7834598477657
# (7, 67) -80.05805750462216
# (7, 72) -55.26510853085826
# (7, 79) -140.68503361917445
# (7, 80) -36.23325629956401
# (7, 85) -54.99558183506645
# (7, 86) -45.86935891278142
# (7, 88) -50.667192527410506
# (7, 90) -1105.8394901586137
# (7, 91) -1089.8579742906686
# (7, 92) -8.750371896340146
# (7, 94) -32.00221098940322
# (7, 96) -15.693150758211827
# (7, 97) -75.13720004927335
# (7, 100) -3002.6428655391433
# (7, 102) -10.242901310738597
# (7, 113) -24.59581261748175
# (7, 115) -25.31579864778945
# (7, 117) -25.616124279996853
# (7, 119) -718.4507890196759
# (7, 120) -64.73941508357673
# (7, 121) -3.0969090643808532
# (7, 124) -3.136502857654247
# (7, 125) -2.339088785382089
# (7, 126) -3.740062011480591
# (7, 137) -7.308069549391133
# (7, 138) -4.804959932513965
# (7, 139) -1225.8505996273398
# (7, 140) -6.135399087606614
# (7, 142) -10.558095777167983
# (7, 147) -36.14892922147322
# (7, 151) -64.14670744996171
# (7, 157) -2.6367827765979848
# (7, 170) -8.435168367992492
# (7, 171) -4.35932106997554
# (7, 173) -4.3051855983064
# (7, 174) -0.9148034283561248
# (7, 175) -21.801520368928447
# (7, 180) -15.927748186198926
# (7, 181) -76.2779244865604
# (7, 183) -44.69006919522576
# (7, 186) -3182.817202432615
# (7, 189) -0.250616126338446
# (8, 2) -23.183245579953844
# (8, 3) -127.05861847358015
# (8, 4) -35.257137745752395
# (8, 5) -6.9091651064879755
# (8, 6) -29.59874856829341
# (8, 10) -7.766607509158173
# (8, 14) -0.7776229442505458
# (8, 22) -23.475971288308326
# (8, 23) -1965.2427267541689
# (8, 24) -42.66791209623547
# (8, 26) -3677.1645236640616
# (8, 29) -0.13662995208914216
# (8, 33) -22.21787552185822
# (8, 34) -191.2969366967648
# (8, 37) -22.782689957700462
# (8, 38) -1143.4117151707155
# (8, 45) -10.626742214815357
# (8, 47) -71.68832920979894
# (8, 61) -1.7281697972700367
# (8, 65) -818.3113033163702
# (8, 66) -3.3379211344257365
# (8, 67) -17.023286063905132
# (8, 71) -20.665067555493252
# (8, 74) -15.763356540373378
# (8, 78) -8.738718484566151
# (8, 80) -51.31594948278848
# (8, 82) -1.5603285104010052
# (8, 84) -68.82067475049075
# (8, 87) -11.928809816594104
# (8, 89) -21.231377173230957
# (8, 90) -4.471044743541323
# (8, 91) -6.632489937984487
# (8, 93) -3.871824361661438
# (8, 97) -6.055839779219363
# (8, 98) -62.054043313756935
# (8, 100) -3746.8980474454233
# (8, 101) -280.25722137891614
# (8, 103) -13.972181427941965
# (8, 104) -3728.3659857886073
# (8, 105) -67.56996261492849
# (8, 109) -5.421853412882427
# (8, 110) -0.7284984868451562
# (8, 113) -190.9922600680356
# (8, 115) -43.115367536227055
# (8, 119) -51.27181820472336
# (8, 120) -619.1653382764783
# (8, 124) -1.3835144674025603
# (8, 126) -4.343750799112278
# (8, 127) -88.23341075672218
# (8, 128) -34.555423188766724
# (8, 129) -11.769081578708136
# (8, 131) -119.46676658695034
# (8, 136) -869.4990889043735
# (8, 137) -0.48129643890045326
# (8, 141) -0.9109636943997986
# (8, 142) -14.410522147137458
# (8, 145) -7.164512636715413
# (8, 147) -59.09217235038937
# (8, 148) -8.72442917541158
# (8, 149) -45.43128784653565
# (8, 160) -15.372166112273552
# (8, 161) -8.036350223062485
# (8, 170) -30.581809913509243
# (8, 173) -2.482122449430115
# (8, 177) -103.60968049721966
# (8, 179) -14.872468941063802
# (8, 184) -2518.0451790984507
# (8, 186) -3684.5216506065135
# (8, 187) -0.5645048786451816
# (8, 189) -0.5742047514036276
# (8, 193) -45.137748068998135
# (8, 195) -86.33498954969947
# (9, 0) -15.139663124092534
# (9, 2) -77.15697451233108
# (9, 5) -62.28966889705697
# (9, 7) -5.647194599180357
# (9, 9) -620.3798089546398
# (9, 12) -14.615796542705864
# (9, 13) -1.4297918265732268
# (9, 14) -9.81193805075201
# (9, 16) -35.40949750858103
# (9, 18) -1.3617511391107517
# (9, 22) -18.20191797191697
# (9, 23) -126.418903405913
# (9, 24) -4988.443095184248
# (9, 25) -1.779252103092969
# (9, 26) -4201.03705615933
# (9, 27) -0.1570245913084067
# (9, 29) -1.9656450566342798
# (9, 30) -1.086617429575644
# (9, 33) -165.12596989739168
# (9, 36) -93.79471607129105
# (9, 38) -92.05450805516777
# (9, 43) -5.804890647221118
# (9, 44) -6.643855686555135
# (9, 45) -2.178194965575362
# (9, 47) -54.754978957930575
# (9, 48) -20.874562179559423
# (9, 50) -74.98947837593994
# (9, 51) -20.31192781313324
# (9, 56) -34.26986113774845
# (9, 59) -1415.400610570117
# (9, 60) -1652.637601683996
# (9, 62) -6.542901865721869
# (9, 65) -38.64505042255578
# (9, 72) -1372.6011745003798
# (9, 75) -11.677334010830819
# (9, 76) -7.095296118015419
# (9, 78) -4.929969046741672
# (9, 89) -29.841578205951436
# (9, 92) -0.003795950027965503
# (9, 99) -42.46656316609217
# (9, 100) -21.741565063541277
# (9, 104) -2697.32957933349
# (9, 105) -3046.208706448046
# (9, 106) -6.898871894126499
# (9, 107) -1.4330259549837372
# (9, 108) -6.963422594104197
# (9, 109) -3.4001994664915784
# (9, 110) -5.391167745845503
# (9, 114) -80.75623350089516
# (9, 115) -8.697533009861099
# (9, 124) -0.9753907683636079
# (9, 129) -24.924183048484405
# (9, 131) -177.16984707807885
# (9, 132) -51.931595704620456
# (9, 136) -1473.6413542948708
# (9, 139) -1.6251394419629472
# (9, 148) -31.318058008036786
# (9, 152) -610.3993747446549
# (9, 153) -931.8978525132385
# (9, 155) -5.383790691724047
# (9, 156) -1683.385441005778
# (9, 157) -16.334325969431514
# (9, 159) -8.025977640463006
# (9, 160) -13.56260324234603
# (9, 163) -128.3801794093656
# (9, 165) -6.033585781058997
# (9, 167) -587.4870492619932
# (9, 169) -24.181142361567673
# (9, 171) -10.712990555723657
# (9, 173) -2.8294053280791953
# (9, 174) -5.711921319718784
# (9, 178) -9.39605592859011
# (9, 184) -3807.977484106732
# (9, 187) -1.6333776218284235
# (9, 190) -2.059034492353513
# (9, 191) -7.32755629247725
# (9, 194) -20.73722205266442
# Total problematic cases 850
# Total cases 2000

# %%
log_name = 'LoanApp.csv'

base_path = os.path.join('..', '..', 'simulated_data', log_name)
baseline_dir_path = os.path.join(base_path, 'baseline')
optimized_dir_path = os.path.join(base_path, 'autonomous') # Updated path

# Check if directories exist before running
if not os.path.exists(baseline_dir_path) or not os.path.exists(optimized_dir_path):
    print(f"FATAL ERROR: Could not find directories.")
    print(f"Checked for: '{baseline_dir_path}'")
    print(f"Checked for: '{optimized_dir_path}'")
    print("Please ensure the CONFIG section is correct and you have run the simulations.")
else:
    print("--- Analysis 1: Comparing Costs on a Per-Log Basis ---")
    compare_costs_across_logs()
        
    print("\n\n--- Analysis 2: Comparing Aggregated Costs on a Per-Case Basis ---")
    compare_costs_across_cases()
# Out:
# --- Analysis 1: Comparing Costs on a Per-Log Basis ---
# Comparing costs for 10 simulation logs from 'LoanApp.csv'...
#
# --- Log 0 ---
#   Baseline Avg. Case Cost:  $1012.94
#   Optimized Avg. Case Cost: $1058.71
#   Cost Reduction: -4.52%
#
# --- Log 1 ---
#   Baseline Avg. Case Cost:  $1081.75
#   Optimized Avg. Case Cost: $1126.79
#   Cost Reduction: -4.16%
#
# --- Log 2 ---
#   Baseline Avg. Case Cost:  $968.88
#   Optimized Avg. Case Cost: $1058.36
#   Cost Reduction: -9.24%
#
# --- Log 3 ---
#   Baseline Avg. Case Cost:  $1199.75
#   Optimized Avg. Case Cost: $1105.98
#   Cost Reduction: 7.82%
#
# --- Log 4 ---
#   Baseline Avg. Case Cost:  $923.37
#   Optimized Avg. Case Cost: $1160.38
#   Cost Reduction: -25.67%
#
# --- Log 5 ---
#   Baseline Avg. Case Cost:  $1142.44
#   Optimized Avg. Case Cost: $1125.17
#   Cost Reduction: 1.51%
#
# --- Log 6 ---
#   Baseline Avg. Case Cost:  $1151.10
#   Optimized Avg. Case Cost: $989.97
#   Cost Reduction: 14.00%
#
# --- Log 7 ---
#   Baseline Avg. Case Cost:  $1049.25
#   Optimized Avg. Case Cost: $1105.21
#   Cost Reduction: -5.33%
#
# --- Log 8 ---
#   Baseline Avg. Case Cost:  $1049.49
#   Optimized Avg. Case Cost: $1033.77
#   Cost Reduction: 1.50%
#
# --- Log 9 ---
#   Baseline Avg. Case Cost:  $1008.60
#   Optimized Avg. Case Cost: $945.05
#   Cost Reduction: 6.30%
#
# ========================================
# Overall Average Cost Reduction: -1.78%
# ========================================
#
#
# --- Analysis 2: Comparing Aggregated Costs on a Per-Case Basis ---
# Case-by-case aggregated cost stats:
#
# Case ID: 0
#   Mean Baseline Cost:  $242.49
#   Mean Optimized Cost: $224.79
#   Mean Reduction: 7.30%
#   Median Baseline Cost:  $273.87
#   Median Optimized Cost: $216.40
#   Median Reduction: 20.98%
#
# Case ID: 1
#   Mean Baseline Cost:  $239.70
#   Mean Optimized Cost: $169.16
#   Mean Reduction: 29.43%
#   Median Baseline Cost:  $241.69
#   Median Optimized Cost: $137.82
#   Median Reduction: 42.98%
#
# Case ID: 2
#   Mean Baseline Cost:  $473.53
#   Mean Optimized Cost: $162.18
#   Mean Reduction: 65.75%
#   Median Baseline Cost:  $229.32
#   Median Optimized Cost: $155.90
#   Median Reduction: 32.02%
#
# Case ID: 3
#   Mean Baseline Cost:  $187.37
#   Mean Optimized Cost: $255.64
#   Mean Reduction: -36.44%
#   Median Baseline Cost:  $179.00
#   Median Optimized Cost: $240.10
#   Median Reduction: -34.14%
#
# Case ID: 4
#   Mean Baseline Cost:  $338.55
#   Mean Optimized Cost: $233.24
#   Mean Reduction: 31.11%
#   Median Baseline Cost:  $179.53
#   Median Optimized Cost: $232.17
#   Median Reduction: -29.32%
#
# Case ID: 5
#   Mean Baseline Cost:  $507.77
#   Mean Optimized Cost: $714.22
#   Mean Reduction: -40.66%
#   Median Baseline Cost:  $264.77
#   Median Optimized Cost: $201.99
#   Median Reduction: 23.71%
#
# Case ID: 6
#   Mean Baseline Cost:  $200.82
#   Mean Optimized Cost: $228.16
#   Mean Reduction: -13.62%
#   Median Baseline Cost:  $194.12
#   Median Optimized Cost: $227.61
#   Median Reduction: -17.25%
#
# Case ID: 7
#   Mean Baseline Cost:  $337.25
#   Mean Optimized Cost: $746.68
#   Mean Reduction: -121.41%
#   Median Baseline Cost:  $170.92
#   Median Optimized Cost: $179.72
#   Median Reduction: -5.15%
#
# Case ID: 8
#   Mean Baseline Cost:  $942.02
#   Mean Optimized Cost: $588.43
#   Mean Reduction: 37.54%
#   Median Baseline Cost:  $249.64
#   Median Optimized Cost: $171.70
#   Median Reduction: 31.22%
#
# Case ID: 9
#   Mean Baseline Cost:  $935.25
#   Mean Optimized Cost: $1256.07
#   Mean Reduction: -34.30%
#   Median Baseline Cost:  $247.80
#   Median Optimized Cost: $1666.38
#   Median Reduction: -572.46%
#
# Case ID: 10
#   Mean Baseline Cost:  $1586.86
#   Mean Optimized Cost: $1377.14
#   Mean Reduction: 13.22%
#   Median Baseline Cost:  $1898.26
#   Median Optimized Cost: $1715.99
#   Median Reduction: 9.60%
#
# Case ID: 11
#   Mean Baseline Cost:  $978.89
#   Mean Optimized Cost: $1406.40
#   Mean Reduction: -43.67%
#   Median Baseline Cost:  $985.66
#   Median Optimized Cost: $1651.16
#   Median Reduction: -67.52%
#
# Case ID: 12
#   Mean Baseline Cost:  $1050.28
#   Mean Optimized Cost: $1325.24
#   Mean Reduction: -26.18%
#   Median Baseline Cost:  $961.14
#   Median Optimized Cost: $1641.87
#   Median Reduction: -70.82%
#
# Case ID: 13
#   Mean Baseline Cost:  $1329.01
#   Mean Optimized Cost: $1182.79
#   Mean Reduction: 11.00%
#   Median Baseline Cost:  $1644.95
#   Median Optimized Cost: $1618.98
#   Median Reduction: 1.58%
#
# Case ID: 14
#   Mean Baseline Cost:  $952.65
#   Mean Optimized Cost: $1297.90
#   Mean Reduction: -36.24%
#   Median Baseline Cost:  $877.88
#   Median Optimized Cost: $1653.40
#   Median Reduction: -88.34%
#
# Case ID: 15
#   Mean Baseline Cost:  $263.69
#   Mean Optimized Cost: $203.93
#   Mean Reduction: 22.66%
#   Median Baseline Cost:  $300.79
#   Median Optimized Cost: $188.42
#   Median Reduction: 37.36%
#
# Case ID: 16
#   Mean Baseline Cost:  $222.52
#   Mean Optimized Cost: $180.59
#   Mean Reduction: 18.84%
#   Median Baseline Cost:  $234.00
#   Median Optimized Cost: $170.30
#   Median Reduction: 27.22%
#
# Case ID: 17
#   Mean Baseline Cost:  $262.90
#   Mean Optimized Cost: $212.85
#   Mean Reduction: 19.04%
#   Median Baseline Cost:  $252.10
#   Median Optimized Cost: $211.35
#   Median Reduction: 16.16%
#
# Case ID: 18
#   Mean Baseline Cost:  $1206.46
#   Mean Optimized Cost: $192.46
#   Mean Reduction: 84.05%
#   Median Baseline Cost:  $236.72
#   Median Optimized Cost: $192.06
#   Median Reduction: 18.87%
#
# Case ID: 19
#   Mean Baseline Cost:  $210.22
#   Mean Optimized Cost: $202.11
#   Mean Reduction: 3.86%
#   Median Baseline Cost:  $205.55
#   Median Optimized Cost: $181.00
#   Median Reduction: 11.95%
#
# Case ID: 20
#   Mean Baseline Cost:  $890.70
#   Mean Optimized Cost: $1188.20
#   Mean Reduction: -33.40%
#   Median Baseline Cost:  $181.64
#   Median Optimized Cost: $223.36
#   Median Reduction: -22.97%
#
# Case ID: 21
#   Mean Baseline Cost:  $2138.26
#   Mean Optimized Cost: $1190.69
#   Mean Reduction: 44.31%
#   Median Baseline Cost:  $192.29
#   Median Optimized Cost: $210.31
#   Median Reduction: -9.37%
#
# Case ID: 22
#   Mean Baseline Cost:  $1149.13
#   Mean Optimized Cost: $239.72
#   Mean Reduction: 79.14%
#   Median Baseline Cost:  $203.42
#   Median Optimized Cost: $207.84
#   Median Reduction: -2.17%
#
# Case ID: 23
#   Mean Baseline Cost:  $1481.22
#   Mean Optimized Cost: $1525.22
#   Mean Reduction: -2.97%
#   Median Baseline Cost:  $210.40
#   Median Optimized Cost: $180.17
#   Median Reduction: 14.37%
#
# Case ID: 24
#   Mean Baseline Cost:  $1438.33
#   Mean Optimized Cost: $3419.92
#   Mean Reduction: -137.77%
#   Median Baseline Cost:  $179.76
#   Median Optimized Cost: $241.39
#   Median Reduction: -34.29%
#
# Case ID: 25
#   Mean Baseline Cost:  $2909.06
#   Mean Optimized Cost: $3304.72
#   Mean Reduction: -13.60%
#   Median Baseline Cost:  $255.68
#   Median Optimized Cost: $213.98
#   Median Reduction: 16.31%
#
# Case ID: 26
#   Mean Baseline Cost:  $4609.07
#   Mean Optimized Cost: $6402.00
#   Mean Reduction: -38.90%
#   Median Baseline Cost:  $6152.08
#   Median Optimized Cost: $6314.13
#   Median Reduction: -2.63%
#
# Case ID: 27
#   Mean Baseline Cost:  $4476.27
#   Mean Optimized Cost: $5498.15
#   Mean Reduction: -22.83%
#   Median Baseline Cost:  $5963.01
#   Median Optimized Cost: $6235.59
#   Median Reduction: -4.57%
#
# Case ID: 28
#   Mean Baseline Cost:  $5730.21
#   Mean Optimized Cost: $5950.71
#   Mean Reduction: -3.85%
#   Median Baseline Cost:  $6717.97
#   Median Optimized Cost: $6102.79
#   Median Reduction: 9.16%
#
# Case ID: 29
#   Mean Baseline Cost:  $5029.40
#   Mean Optimized Cost: $6413.41
#   Mean Reduction: -27.52%
#   Median Baseline Cost:  $5937.87
#   Median Optimized Cost: $5999.41
#   Median Reduction: -1.04%
#
# Case ID: 30
#   Mean Baseline Cost:  $5500.52
#   Mean Optimized Cost: $6076.88
#   Mean Reduction: -10.48%
#   Median Baseline Cost:  $7111.97
#   Median Optimized Cost: $7010.67
#   Median Reduction: 1.42%
#
# Case ID: 31
#   Mean Baseline Cost:  $218.23
#   Mean Optimized Cost: $194.15
#   Mean Reduction: 11.03%
#   Median Baseline Cost:  $212.38
#   Median Optimized Cost: $188.63
#   Median Reduction: 11.18%
#
# Case ID: 32
#   Mean Baseline Cost:  $231.83
#   Mean Optimized Cost: $216.22
#   Mean Reduction: 6.73%
#   Median Baseline Cost:  $182.02
#   Median Optimized Cost: $234.45
#   Median Reduction: -28.81%
#
# Case ID: 33
#   Mean Baseline Cost:  $227.61
#   Mean Optimized Cost: $218.06
#   Mean Reduction: 4.20%
#   Median Baseline Cost:  $211.64
#   Median Optimized Cost: $222.49
#   Median Reduction: -5.13%
#
# Case ID: 34
#   Mean Baseline Cost:  $238.45
#   Mean Optimized Cost: $177.58
#   Mean Reduction: 25.53%
#   Median Baseline Cost:  $202.42
#   Median Optimized Cost: $183.07
#   Median Reduction: 9.56%
#
# Case ID: 35
#   Mean Baseline Cost:  $214.20
#   Mean Optimized Cost: $190.35
#   Mean Reduction: 11.13%
#   Median Baseline Cost:  $205.62
#   Median Optimized Cost: $174.16
#   Median Reduction: 15.30%
#
# Case ID: 36
#   Mean Baseline Cost:  $401.96
#   Mean Optimized Cost: $397.68
#   Mean Reduction: 1.06%
#   Median Baseline Cost:  $201.68
#   Median Optimized Cost: $209.31
#   Median Reduction: -3.79%
#
# Case ID: 37
#   Mean Baseline Cost:  $459.64
#   Mean Optimized Cost: $206.15
#   Mean Reduction: 55.15%
#   Median Baseline Cost:  $257.98
#   Median Optimized Cost: $179.94
#   Median Reduction: 30.25%
#
# Case ID: 38
#   Mean Baseline Cost:  $615.55
#   Mean Optimized Cost: $401.10
#   Mean Reduction: 34.84%
#   Median Baseline Cost:  $229.29
#   Median Optimized Cost: $186.76
#   Median Reduction: 18.55%
#
# Case ID: 39
#   Mean Baseline Cost:  $760.93
#   Mean Optimized Cost: $207.59
#   Mean Reduction: 72.72%
#   Median Baseline Cost:  $175.97
#   Median Optimized Cost: $194.77
#   Median Reduction: -10.68%
#
# Case ID: 40
#   Mean Baseline Cost:  $513.20
#   Mean Optimized Cost: $847.85
#   Mean Reduction: -65.21%
#   Median Baseline Cost:  $217.60
#   Median Optimized Cost: $276.85
#   Median Reduction: -27.23%
#
# Case ID: 41
#   Mean Baseline Cost:  $1543.89
#   Mean Optimized Cost: $1414.26
#   Mean Reduction: 8.40%
#   Median Baseline Cost:  $1846.62
#   Median Optimized Cost: $1830.48
#   Median Reduction: 0.87%
#
# Case ID: 42
#   Mean Baseline Cost:  $1525.75
#   Mean Optimized Cost: $1328.10
#   Mean Reduction: 12.95%
#   Median Baseline Cost:  $1729.98
#   Median Optimized Cost: $1728.53
#   Median Reduction: 0.08%
#
# Case ID: 43
#   Mean Baseline Cost:  $1713.34
#   Mean Optimized Cost: $1852.60
#   Mean Reduction: -8.13%
#   Median Baseline Cost:  $1695.20
#   Median Optimized Cost: $1911.72
#   Median Reduction: -12.77%
#
# Case ID: 44
#   Mean Baseline Cost:  $1547.64
#   Mean Optimized Cost: $1436.72
#   Mean Reduction: 7.17%
#   Median Baseline Cost:  $1911.42
#   Median Optimized Cost: $1675.89
#   Median Reduction: 12.32%
#
# Case ID: 45
#   Mean Baseline Cost:  $1153.52
#   Mean Optimized Cost: $968.00
#   Mean Reduction: 16.08%
#   Median Baseline Cost:  $1623.52
#   Median Optimized Cost: $944.36
#   Median Reduction: 41.83%
#
# Case ID: 46
#   Mean Baseline Cost:  $915.17
#   Mean Optimized Cost: $813.45
#   Mean Reduction: 11.11%
#   Median Baseline Cost:  $345.41
#   Median Optimized Cost: $242.70
#   Median Reduction: 29.74%
#
# Case ID: 47
#   Mean Baseline Cost:  $220.28
#   Mean Optimized Cost: $202.60
#   Mean Reduction: 8.02%
#   Median Baseline Cost:  $200.08
#   Median Optimized Cost: $191.69
#   Median Reduction: 4.19%
#
# Case ID: 48
#   Mean Baseline Cost:  $437.27
#   Mean Optimized Cost: $224.74
#   Mean Reduction: 48.60%
#   Median Baseline Cost:  $179.96
#   Median Optimized Cost: $216.19
#   Median Reduction: -20.13%
#
# Case ID: 49
#   Mean Baseline Cost:  $397.17
#   Mean Optimized Cost: $196.43
#   Mean Reduction: 50.54%
#   Median Baseline Cost:  $217.87
#   Median Optimized Cost: $170.14
#   Median Reduction: 21.91%
#
# Case ID: 50
#   Mean Baseline Cost:  $247.68
#   Mean Optimized Cost: $226.95
#   Mean Reduction: 8.37%
#   Median Baseline Cost:  $217.23
#   Median Optimized Cost: $210.93
#   Median Reduction: 2.90%
#
# Case ID: 51
#   Mean Baseline Cost:  $203.80
#   Mean Optimized Cost: $251.85
#   Mean Reduction: -23.57%
#   Median Baseline Cost:  $170.98
#   Median Optimized Cost: $255.66
#   Median Reduction: -49.52%
#
# Case ID: 52
#   Mean Baseline Cost:  $609.06
#   Mean Optimized Cost: $186.96
#   Mean Reduction: 69.30%
#   Median Baseline Cost:  $256.29
#   Median Optimized Cost: $164.92
#   Median Reduction: 35.65%
#
# Case ID: 53
#   Mean Baseline Cost:  $801.78
#   Mean Optimized Cost: $692.61
#   Mean Reduction: 13.62%
#   Median Baseline Cost:  $254.84
#   Median Optimized Cost: $192.20
#   Median Reduction: 24.58%
#
# Case ID: 54
#   Mean Baseline Cost:  $361.94
#   Mean Optimized Cost: $194.30
#   Mean Reduction: 46.32%
#   Median Baseline Cost:  $191.81
#   Median Optimized Cost: $216.41
#   Median Reduction: -12.83%
#
# Case ID: 55
#   Mean Baseline Cost:  $765.83
#   Mean Optimized Cost: $333.25
#   Mean Reduction: 56.48%
#   Median Baseline Cost:  $240.60
#   Median Optimized Cost: $196.15
#   Median Reduction: 18.48%
#
# Case ID: 56
#   Mean Baseline Cost:  $346.66
#   Mean Optimized Cost: $165.71
#   Mean Reduction: 52.20%
#   Median Baseline Cost:  $196.76
#   Median Optimized Cost: $162.50
#   Median Reduction: 17.42%
#
# Case ID: 57
#   Mean Baseline Cost:  $1459.60
#   Mean Optimized Cost: $887.07
#   Mean Reduction: 39.23%
#   Median Baseline Cost:  $1689.37
#   Median Optimized Cost: $212.58
#   Median Reduction: 87.42%
#
# Case ID: 58
#   Mean Baseline Cost:  $1413.52
#   Mean Optimized Cost: $1564.31
#   Mean Reduction: -10.67%
#   Median Baseline Cost:  $1825.43
#   Median Optimized Cost: $1749.44
#   Median Reduction: 4.16%
#
# Case ID: 59
#   Mean Baseline Cost:  $1036.48
#   Mean Optimized Cost: $1261.62
#   Mean Reduction: -21.72%
#   Median Baseline Cost:  $990.39
#   Median Optimized Cost: $1616.37
#   Median Reduction: -63.20%
#
# Case ID: 60
#   Mean Baseline Cost:  $755.29
#   Mean Optimized Cost: $1305.70
#   Mean Reduction: -72.87%
#   Median Baseline Cost:  $207.63
#   Median Optimized Cost: $1675.12
#   Median Reduction: -706.79%
#
# Case ID: 61
#   Mean Baseline Cost:  $1170.95
#   Mean Optimized Cost: $991.18
#   Mean Reduction: 15.35%
#   Median Baseline Cost:  $1579.04
#   Median Optimized Cost: $1017.22
#   Median Reduction: 35.58%
#
# Case ID: 62
#   Mean Baseline Cost:  $881.09
#   Mean Optimized Cost: $1262.52
#   Mean Reduction: -43.29%
#   Median Baseline Cost:  $342.84
#   Median Optimized Cost: $1843.10
#   Median Reduction: -437.60%
#
# Case ID: 63
#   Mean Baseline Cost:  $249.70
#   Mean Optimized Cost: $230.36
#   Mean Reduction: 7.75%
#   Median Baseline Cost:  $222.06
#   Median Optimized Cost: $189.59
#   Median Reduction: 14.62%
#
# Case ID: 64
#   Mean Baseline Cost:  $217.84
#   Mean Optimized Cost: $194.35
#   Mean Reduction: 10.78%
#   Median Baseline Cost:  $179.58
#   Median Optimized Cost: $189.43
#   Median Reduction: -5.49%
#
# Case ID: 65
#   Mean Baseline Cost:  $225.39
#   Mean Optimized Cost: $353.19
#   Mean Reduction: -56.70%
#   Median Baseline Cost:  $193.23
#   Median Optimized Cost: $242.95
#   Median Reduction: -25.74%
#
# Case ID: 66
#   Mean Baseline Cost:  $167.91
#   Mean Optimized Cost: $225.07
#   Mean Reduction: -34.04%
#   Median Baseline Cost:  $159.02
#   Median Optimized Cost: $226.86
#   Median Reduction: -42.66%
#
# Case ID: 67
#   Mean Baseline Cost:  $194.54
#   Mean Optimized Cost: $433.95
#   Mean Reduction: -123.06%
#   Median Baseline Cost:  $206.96
#   Median Optimized Cost: $259.89
#   Median Reduction: -25.57%
#
# Case ID: 68
#   Mean Baseline Cost:  $475.40
#   Mean Optimized Cost: $416.63
#   Mean Reduction: 12.36%
#   Median Baseline Cost:  $238.56
#   Median Optimized Cost: $151.43
#   Median Reduction: 36.52%
#
# Case ID: 69
#   Mean Baseline Cost:  $769.10
#   Mean Optimized Cost: $198.18
#   Mean Reduction: 74.23%
#   Median Baseline Cost:  $233.31
#   Median Optimized Cost: $200.16
#   Median Reduction: 14.21%
#
# Case ID: 70
#   Mean Baseline Cost:  $185.59
#   Mean Optimized Cost: $598.81
#   Mean Reduction: -222.65%
#   Median Baseline Cost:  $189.28
#   Median Optimized Cost: $209.30
#   Median Reduction: -10.58%
#
# Case ID: 71
#   Mean Baseline Cost:  $786.63
#   Mean Optimized Cost: $604.58
#   Mean Reduction: 23.14%
#   Median Baseline Cost:  $226.31
#   Median Optimized Cost: $198.86
#   Median Reduction: 12.13%
#
# Case ID: 72
#   Mean Baseline Cost:  $517.38
#   Mean Optimized Cost: $574.59
#   Mean Reduction: -11.06%
#   Median Baseline Cost:  $163.59
#   Median Optimized Cost: $176.26
#   Median Reduction: -7.75%
#
# Case ID: 73
#   Mean Baseline Cost:  $1311.49
#   Mean Optimized Cost: $803.80
#   Mean Reduction: 38.71%
#   Median Baseline Cost:  $1682.08
#   Median Optimized Cost: $164.59
#   Median Reduction: 90.22%
#
# Case ID: 74
#   Mean Baseline Cost:  $1494.69
#   Mean Optimized Cost: $1202.90
#   Mean Reduction: 19.52%
#   Median Baseline Cost:  $1792.19
#   Median Optimized Cost: $1740.62
#   Median Reduction: 2.88%
#
# Case ID: 75
#   Mean Baseline Cost:  $1336.92
#   Mean Optimized Cost: $1049.11
#   Mean Reduction: 21.53%
#   Median Baseline Cost:  $1863.87
#   Median Optimized Cost: $967.64
#   Median Reduction: 48.08%
#
# Case ID: 76
#   Mean Baseline Cost:  $1187.40
#   Mean Optimized Cost: $1635.97
#   Mean Reduction: -37.78%
#   Median Baseline Cost:  $1599.37
#   Median Optimized Cost: $1774.35
#   Median Reduction: -10.94%
#
# Case ID: 77
#   Mean Baseline Cost:  $1319.84
#   Mean Optimized Cost: $1326.72
#   Mean Reduction: -0.52%
#   Median Baseline Cost:  $1654.09
#   Median Optimized Cost: $1697.02
#   Median Reduction: -2.60%
#
# Case ID: 78
#   Mean Baseline Cost:  $1264.49
#   Mean Optimized Cost: $766.85
#   Mean Reduction: 39.35%
#   Median Baseline Cost:  $1553.47
#   Median Optimized Cost: $301.71
#   Median Reduction: 80.58%
#
# Case ID: 79
#   Mean Baseline Cost:  $373.72
#   Mean Optimized Cost: $200.48
#   Mean Reduction: 46.36%
#   Median Baseline Cost:  $237.11
#   Median Optimized Cost: $202.00
#   Median Reduction: 14.81%
#
# Case ID: 80
#   Mean Baseline Cost:  $192.19
#   Mean Optimized Cost: $231.09
#   Mean Reduction: -20.24%
#   Median Baseline Cost:  $159.28
#   Median Optimized Cost: $215.06
#   Median Reduction: -35.02%
#
# Case ID: 81
#   Mean Baseline Cost:  $253.82
#   Mean Optimized Cost: $191.15
#   Mean Reduction: 24.69%
#   Median Baseline Cost:  $261.60
#   Median Optimized Cost: $179.97
#   Median Reduction: 31.20%
#
# Case ID: 82
#   Mean Baseline Cost:  $223.72
#   Mean Optimized Cost: $202.43
#   Mean Reduction: 9.52%
#   Median Baseline Cost:  $186.54
#   Median Optimized Cost: $187.79
#   Median Reduction: -0.67%
#
# Case ID: 83
#   Mean Baseline Cost:  $320.81
#   Mean Optimized Cost: $198.50
#   Mean Reduction: 38.12%
#   Median Baseline Cost:  $147.85
#   Median Optimized Cost: $168.46
#   Median Reduction: -13.94%
#
# Case ID: 84
#   Mean Baseline Cost:  $368.42
#   Mean Optimized Cost: $209.68
#   Mean Reduction: 43.09%
#   Median Baseline Cost:  $192.80
#   Median Optimized Cost: $211.55
#   Median Reduction: -9.72%
#
# Case ID: 85
#   Mean Baseline Cost:  $402.75
#   Mean Optimized Cost: $203.00
#   Mean Reduction: 49.60%
#   Median Baseline Cost:  $240.92
#   Median Optimized Cost: $215.64
#   Median Reduction: 10.49%
#
# Case ID: 86
#   Mean Baseline Cost:  $399.21
#   Mean Optimized Cost: $352.65
#   Mean Reduction: 11.66%
#   Median Baseline Cost:  $224.20
#   Median Optimized Cost: $195.46
#   Median Reduction: 12.82%
#
# Case ID: 87
#   Mean Baseline Cost:  $702.69
#   Mean Optimized Cost: $350.39
#   Mean Reduction: 50.14%
#   Median Baseline Cost:  $249.41
#   Median Optimized Cost: $205.14
#   Median Reduction: 17.75%
#
# Case ID: 88
#   Mean Baseline Cost:  $1057.80
#   Mean Optimized Cost: $380.42
#   Mean Reduction: 64.04%
#   Median Baseline Cost:  $239.61
#   Median Optimized Cost: $230.04
#   Median Reduction: 4.00%
#
# Case ID: 89
#   Mean Baseline Cost:  $532.25
#   Mean Optimized Cost: $1013.00
#   Mean Reduction: -90.32%
#   Median Baseline Cost:  $222.68
#   Median Optimized Cost: $171.32
#   Median Reduction: 23.07%
#
# Case ID: 90
#   Mean Baseline Cost:  $848.03
#   Mean Optimized Cost: $1778.67
#   Mean Reduction: -109.74%
#   Median Baseline Cost:  $260.36
#   Median Optimized Cost: $1829.92
#   Median Reduction: -602.85%
#
# Case ID: 91
#   Mean Baseline Cost:  $1255.93
#   Mean Optimized Cost: $1629.71
#   Mean Reduction: -29.76%
#   Median Baseline Cost:  $1683.42
#   Median Optimized Cost: $1705.69
#   Median Reduction: -1.32%
#
# Case ID: 92
#   Mean Baseline Cost:  $1512.89
#   Mean Optimized Cost: $1352.44
#   Mean Reduction: 10.61%
#   Median Baseline Cost:  $1846.23
#   Median Optimized Cost: $1687.47
#   Median Reduction: 8.60%
#
# Case ID: 93
#   Mean Baseline Cost:  $1012.77
#   Mean Optimized Cost: $1477.15
#   Mean Reduction: -45.85%
#   Median Baseline Cost:  $986.60
#   Median Optimized Cost: $1700.74
#   Median Reduction: -72.38%
#
# Case ID: 94
#   Mean Baseline Cost:  $1004.52
#   Mean Optimized Cost: $1129.86
#   Mean Reduction: -12.48%
#   Median Baseline Cost:  $952.83
#   Median Optimized Cost: $1214.63
#   Median Reduction: -27.48%
#
# Case ID: 95
#   Mean Baseline Cost:  $214.51
#   Mean Optimized Cost: $213.10
#   Mean Reduction: 0.66%
#   Median Baseline Cost:  $210.22
#   Median Optimized Cost: $177.89
#   Median Reduction: 15.38%
#
# Case ID: 96
#   Mean Baseline Cost:  $243.00
#   Mean Optimized Cost: $211.89
#   Mean Reduction: 12.80%
#   Median Baseline Cost:  $248.43
#   Median Optimized Cost: $188.44
#   Median Reduction: 24.15%
#
# Case ID: 97
#   Mean Baseline Cost:  $173.15
#   Mean Optimized Cost: $233.87
#   Mean Reduction: -35.07%
#   Median Baseline Cost:  $182.06
#   Median Optimized Cost: $222.89
#   Median Reduction: -22.43%
#
# Case ID: 98
#   Mean Baseline Cost:  $200.15
#   Mean Optimized Cost: $218.01
#   Mean Reduction: -8.92%
#   Median Baseline Cost:  $198.12
#   Median Optimized Cost: $190.02
#   Median Reduction: 4.09%
#
# Case ID: 99
#   Mean Baseline Cost:  $930.55
#   Mean Optimized Cost: $183.73
#   Mean Reduction: 80.26%
#   Median Baseline Cost:  $221.64
#   Median Optimized Cost: $180.66
#   Median Reduction: 18.49%
#
# Case ID: 100
#   Mean Baseline Cost:  $175.91
#   Mean Optimized Cost: $859.85
#   Mean Reduction: -388.80%
#   Median Baseline Cost:  $150.02
#   Median Optimized Cost: $210.23
#   Median Reduction: -40.14%
#
# Case ID: 101
#   Mean Baseline Cost:  $197.06
#   Mean Optimized Cost: $189.76
#   Mean Reduction: 3.70%
#   Median Baseline Cost:  $201.93
#   Median Optimized Cost: $177.32
#   Median Reduction: 12.19%
#
# Case ID: 102
#   Mean Baseline Cost:  $1910.71
#   Mean Optimized Cost: $809.65
#   Mean Reduction: 57.63%
#   Median Baseline Cost:  $257.75
#   Median Optimized Cost: $216.68
#   Median Reduction: 15.94%
#
# Case ID: 103
#   Mean Baseline Cost:  $1502.43
#   Mean Optimized Cost: $2597.02
#   Mean Reduction: -72.85%
#   Median Baseline Cost:  $200.53
#   Median Optimized Cost: $226.63
#   Median Reduction: -13.02%
#
# Case ID: 104
#   Mean Baseline Cost:  $3038.40
#   Mean Optimized Cost: $2940.83
#   Mean Reduction: 3.21%
#   Median Baseline Cost:  $216.19
#   Median Optimized Cost: $241.12
#   Median Reduction: -11.53%
#
# Case ID: 105
#   Mean Baseline Cost:  $3469.40
#   Mean Optimized Cost: $4848.51
#   Mean Reduction: -39.75%
#   Median Baseline Cost:  $3070.35
#   Median Optimized Cost: $6596.65
#   Median Reduction: -114.85%
#
# Case ID: 106
#   Mean Baseline Cost:  $5746.50
#   Mean Optimized Cost: $5483.96
#   Mean Reduction: 4.57%
#   Median Baseline Cost:  $7051.07
#   Median Optimized Cost: $6817.14
#   Median Reduction: 3.32%
#
# Case ID: 107
#   Mean Baseline Cost:  $6057.36
#   Mean Optimized Cost: $5215.05
#   Mean Reduction: 13.91%
#   Median Baseline Cost:  $6471.43
#   Median Optimized Cost: $6020.33
#   Median Reduction: 6.97%
#
# Case ID: 108
#   Mean Baseline Cost:  $3190.84
#   Mean Optimized Cost: $5222.69
#   Mean Reduction: -63.68%
#   Median Baseline Cost:  $3167.20
#   Median Optimized Cost: $6018.51
#   Median Reduction: -90.03%
#
# Case ID: 109
#   Mean Baseline Cost:  $2743.07
#   Mean Optimized Cost: $4486.78
#   Mean Reduction: -63.57%
#   Median Baseline Cost:  $242.35
#   Median Optimized Cost: $5923.82
#   Median Reduction: -2344.34%
#
# Case ID: 110
#   Mean Baseline Cost:  $4691.87
#   Mean Optimized Cost: $3025.65
#   Mean Reduction: 35.51%
#   Median Baseline Cost:  $5851.70
#   Median Optimized Cost: $404.82
#   Median Reduction: 93.08%
#
# Case ID: 111
#   Mean Baseline Cost:  $235.95
#   Mean Optimized Cost: $199.61
#   Mean Reduction: 15.40%
#   Median Baseline Cost:  $244.62
#   Median Optimized Cost: $208.44
#   Median Reduction: 14.79%
#
# Case ID: 112
#   Mean Baseline Cost:  $249.85
#   Mean Optimized Cost: $190.45
#   Mean Reduction: 23.77%
#   Median Baseline Cost:  $256.06
#   Median Optimized Cost: $173.65
#   Median Reduction: 32.18%
#
# Case ID: 113
#   Mean Baseline Cost:  $365.99
#   Mean Optimized Cost: $178.70
#   Mean Reduction: 51.17%
#   Median Baseline Cost:  $199.91
#   Median Optimized Cost: $157.80
#   Median Reduction: 21.07%
#
# Case ID: 114
#   Mean Baseline Cost:  $217.04
#   Mean Optimized Cost: $236.42
#   Mean Reduction: -8.93%
#   Median Baseline Cost:  $190.53
#   Median Optimized Cost: $278.32
#   Median Reduction: -46.08%
#
# Case ID: 115
#   Mean Baseline Cost:  $244.67
#   Mean Optimized Cost: $205.89
#   Mean Reduction: 15.85%
#   Median Baseline Cost:  $256.15
#   Median Optimized Cost: $184.91
#   Median Reduction: 27.81%
#
# Case ID: 116
#   Mean Baseline Cost:  $219.09
#   Mean Optimized Cost: $230.14
#   Mean Reduction: -5.05%
#   Median Baseline Cost:  $209.50
#   Median Optimized Cost: $234.59
#   Median Reduction: -11.97%
#
# Case ID: 117
#   Mean Baseline Cost:  $640.29
#   Mean Optimized Cost: $780.88
#   Mean Reduction: -21.96%
#   Median Baseline Cost:  $234.99
#   Median Optimized Cost: $244.10
#   Median Reduction: -3.88%
#
# Case ID: 118
#   Mean Baseline Cost:  $898.41
#   Mean Optimized Cost: $191.46
#   Mean Reduction: 78.69%
#   Median Baseline Cost:  $219.85
#   Median Optimized Cost: $194.86
#   Median Reduction: 11.37%
#
# Case ID: 119
#   Mean Baseline Cost:  $750.41
#   Mean Optimized Cost: $850.32
#   Mean Reduction: -13.31%
#   Median Baseline Cost:  $243.48
#   Median Optimized Cost: $153.23
#   Median Reduction: 37.07%
#
# Case ID: 120
#   Mean Baseline Cost:  $584.79
#   Mean Optimized Cost: $1105.55
#   Mean Reduction: -89.05%
#   Median Baseline Cost:  $201.54
#   Median Optimized Cost: $1016.01
#   Median Reduction: -404.13%
#
# Case ID: 121
#   Mean Baseline Cost:  $1013.20
#   Mean Optimized Cost: $1239.35
#   Mean Reduction: -22.32%
#   Median Baseline Cost:  $965.12
#   Median Optimized Cost: $1600.34
#   Median Reduction: -65.82%
#
# Case ID: 122
#   Mean Baseline Cost:  $664.32
#   Mean Optimized Cost: $1405.33
#   Mean Reduction: -111.54%
#   Median Baseline Cost:  $306.07
#   Median Optimized Cost: $1752.34
#   Median Reduction: -472.53%
#
# Case ID: 123
#   Mean Baseline Cost:  $1040.95
#   Mean Optimized Cost: $1172.05
#   Mean Reduction: -12.59%
#   Median Baseline Cost:  $996.62
#   Median Optimized Cost: $1639.76
#   Median Reduction: -64.53%
#
# Case ID: 124
#   Mean Baseline Cost:  $1211.94
#   Mean Optimized Cost: $1555.24
#   Mean Reduction: -28.33%
#   Median Baseline Cost:  $1614.94
#   Median Optimized Cost: $1874.59
#   Median Reduction: -16.08%
#
# Case ID: 125
#   Mean Baseline Cost:  $936.31
#   Mean Optimized Cost: $1264.28
#   Mean Reduction: -35.03%
#   Median Baseline Cost:  $957.90
#   Median Optimized Cost: $1630.74
#   Median Reduction: -70.24%
#
# Case ID: 126
#   Mean Baseline Cost:  $884.46
#   Mean Optimized Cost: $802.86
#   Mean Reduction: 9.23%
#   Median Baseline Cost:  $445.76
#   Median Optimized Cost: $241.84
#   Median Reduction: 45.75%
#
# Case ID: 127
#   Mean Baseline Cost:  $229.75
#   Mean Optimized Cost: $222.49
#   Mean Reduction: 3.16%
#   Median Baseline Cost:  $232.46
#   Median Optimized Cost: $212.53
#   Median Reduction: 8.57%
#
# Case ID: 128
#   Mean Baseline Cost:  $170.30
#   Mean Optimized Cost: $224.05
#   Mean Reduction: -31.57%
#   Median Baseline Cost:  $166.81
#   Median Optimized Cost: $190.44
#   Median Reduction: -14.17%
#
# Case ID: 129
#   Mean Baseline Cost:  $259.11
#   Mean Optimized Cost: $193.52
#   Mean Reduction: 25.31%
#   Median Baseline Cost:  $226.26
#   Median Optimized Cost: $171.40
#   Median Reduction: 24.25%
#
# Case ID: 130
#   Mean Baseline Cost:  $235.65
#   Mean Optimized Cost: $217.38
#   Mean Reduction: 7.75%
#   Median Baseline Cost:  $232.74
#   Median Optimized Cost: $200.43
#   Median Reduction: 13.88%
#
# Case ID: 131
#   Mean Baseline Cost:  $219.59
#   Mean Optimized Cost: $194.12
#   Mean Reduction: 11.60%
#   Median Baseline Cost:  $221.61
#   Median Optimized Cost: $181.65
#   Median Reduction: 18.03%
#
# Case ID: 132
#   Mean Baseline Cost:  $511.96
#   Mean Optimized Cost: $159.22
#   Mean Reduction: 68.90%
#   Median Baseline Cost:  $208.18
#   Median Optimized Cost: $169.68
#   Median Reduction: 18.49%
#
# Case ID: 133
#   Mean Baseline Cost:  $517.81
#   Mean Optimized Cost: $194.62
#   Mean Reduction: 62.42%
#   Median Baseline Cost:  $212.57
#   Median Optimized Cost: $182.52
#   Median Reduction: 14.14%
#
# Case ID: 134
#   Mean Baseline Cost:  $754.26
#   Mean Optimized Cost: $565.37
#   Mean Reduction: 25.04%
#   Median Baseline Cost:  $271.42
#   Median Optimized Cost: $176.81
#   Median Reduction: 34.86%
#
# Case ID: 135
#   Mean Baseline Cost:  $708.22
#   Mean Optimized Cost: $903.78
#   Mean Reduction: -27.61%
#   Median Baseline Cost:  $211.72
#   Median Optimized Cost: $262.41
#   Median Reduction: -23.94%
#
# Case ID: 136
#   Mean Baseline Cost:  $1090.19
#   Mean Optimized Cost: $1678.79
#   Mean Reduction: -53.99%
#   Median Baseline Cost:  $985.62
#   Median Optimized Cost: $1954.71
#   Median Reduction: -98.32%
#
# Case ID: 137
#   Mean Baseline Cost:  $1066.95
#   Mean Optimized Cost: $925.44
#   Mean Reduction: 13.26%
#   Median Baseline Cost:  $1047.71
#   Median Optimized Cost: $216.14
#   Median Reduction: 79.37%
#
# Case ID: 138
#   Mean Baseline Cost:  $1657.18
#   Mean Optimized Cost: $1248.38
#   Mean Reduction: 24.67%
#   Median Baseline Cost:  $1722.65
#   Median Optimized Cost: $1021.06
#   Median Reduction: 40.73%
#
# Case ID: 139
#   Mean Baseline Cost:  $987.54
#   Mean Optimized Cost: $1691.09
#   Mean Reduction: -71.24%
#   Median Baseline Cost:  $319.71
#   Median Optimized Cost: $1971.62
#   Median Reduction: -516.68%
#
# Case ID: 140
#   Mean Baseline Cost:  $1204.71
#   Mean Optimized Cost: $1126.22
#   Mean Reduction: 6.52%
#   Median Baseline Cost:  $1615.79
#   Median Optimized Cost: $1647.45
#   Median Reduction: -1.96%
#
# Case ID: 141
#   Mean Baseline Cost:  $884.18
#   Mean Optimized Cost: $1455.25
#   Mean Reduction: -64.59%
#   Median Baseline Cost:  $184.27
#   Median Optimized Cost: $1653.77
#   Median Reduction: -797.46%
#
# Case ID: 142
#   Mean Baseline Cost:  $1139.80
#   Mean Optimized Cost: $911.49
#   Mean Reduction: 20.03%
#   Median Baseline Cost:  $1596.95
#   Median Optimized Cost: $903.69
#   Median Reduction: 43.41%
#
# Case ID: 143
#   Mean Baseline Cost:  $218.06
#   Mean Optimized Cost: $233.87
#   Mean Reduction: -7.25%
#   Median Baseline Cost:  $238.80
#   Median Optimized Cost: $236.21
#   Median Reduction: 1.08%
#
# Case ID: 144
#   Mean Baseline Cost:  $274.06
#   Mean Optimized Cost: $185.39
#   Mean Reduction: 32.35%
#   Median Baseline Cost:  $227.91
#   Median Optimized Cost: $165.94
#   Median Reduction: 27.19%
#
# Case ID: 145
#   Mean Baseline Cost:  $197.97
#   Mean Optimized Cost: $189.76
#   Mean Reduction: 4.15%
#   Median Baseline Cost:  $167.68
#   Median Optimized Cost: $209.03
#   Median Reduction: -24.66%
#
# Case ID: 146
#   Mean Baseline Cost:  $216.61
#   Mean Optimized Cost: $209.04
#   Mean Reduction: 3.49%
#   Median Baseline Cost:  $198.61
#   Median Optimized Cost: $186.53
#   Median Reduction: 6.09%
#
# Case ID: 147
#   Mean Baseline Cost:  $211.18
#   Mean Optimized Cost: $394.17
#   Mean Reduction: -86.65%
#   Median Baseline Cost:  $201.33
#   Median Optimized Cost: $171.79
#   Median Reduction: 14.67%
#
# Case ID: 148
#   Mean Baseline Cost:  $609.66
#   Mean Optimized Cost: $216.52
#   Mean Reduction: 64.49%
#   Median Baseline Cost:  $221.39
#   Median Optimized Cost: $232.47
#   Median Reduction: -5.01%
#
# Case ID: 149
#   Mean Baseline Cost:  $454.51
#   Mean Optimized Cost: $241.28
#   Mean Reduction: 46.91%
#   Median Baseline Cost:  $211.60
#   Median Optimized Cost: $201.57
#   Median Reduction: 4.74%
#
# Case ID: 150
#   Mean Baseline Cost:  $664.75
#   Mean Optimized Cost: $180.16
#   Mean Reduction: 72.90%
#   Median Baseline Cost:  $272.13
#   Median Optimized Cost: $184.98
#   Median Reduction: 32.02%
#
# Case ID: 151
#   Mean Baseline Cost:  $523.00
#   Mean Optimized Cost: $549.98
#   Mean Reduction: -5.16%
#   Median Baseline Cost:  $240.40
#   Median Optimized Cost: $218.82
#   Median Reduction: 8.98%
#
# Case ID: 152
#   Mean Baseline Cost:  $857.81
#   Mean Optimized Cost: $835.48
#   Mean Reduction: 2.60%
#   Median Baseline Cost:  $220.22
#   Median Optimized Cost: $227.42
#   Median Reduction: -3.27%
#
# Case ID: 153
#   Mean Baseline Cost:  $729.96
#   Mean Optimized Cost: $1065.64
#   Mean Reduction: -45.99%
#   Median Baseline Cost:  $204.84
#   Median Optimized Cost: $975.25
#   Median Reduction: -376.12%
#
# Case ID: 154
#   Mean Baseline Cost:  $1332.31
#   Mean Optimized Cost: $1844.54
#   Mean Reduction: -38.45%
#   Median Baseline Cost:  $1733.25
#   Median Optimized Cost: $1875.50
#   Median Reduction: -8.21%
#
# Case ID: 155
#   Mean Baseline Cost:  $1321.93
#   Mean Optimized Cost: $1182.16
#   Mean Reduction: 10.57%
#   Median Baseline Cost:  $1679.61
#   Median Optimized Cost: $1661.06
#   Median Reduction: 1.10%
#
# Case ID: 156
#   Mean Baseline Cost:  $906.37
#   Mean Optimized Cost: $1294.74
#   Mean Reduction: -42.85%
#   Median Baseline Cost:  $426.68
#   Median Optimized Cost: $1629.88
#   Median Reduction: -281.99%
#
# Case ID: 157
#   Mean Baseline Cost:  $1064.38
#   Mean Optimized Cost: $1137.77
#   Mean Reduction: -6.90%
#   Median Baseline Cost:  $1072.38
#   Median Optimized Cost: $1626.99
#   Median Reduction: -51.72%
#
# Case ID: 158
#   Mean Baseline Cost:  $1504.92
#   Mean Optimized Cost: $945.25
#   Mean Reduction: 37.19%
#   Median Baseline Cost:  $1771.54
#   Median Optimized Cost: $904.47
#   Median Reduction: 48.94%
#
# Case ID: 159
#   Mean Baseline Cost:  $268.54
#   Mean Optimized Cost: $163.57
#   Mean Reduction: 39.09%
#   Median Baseline Cost:  $229.57
#   Median Optimized Cost: $168.62
#   Median Reduction: 26.55%
#
# Case ID: 160
#   Mean Baseline Cost:  $222.29
#   Mean Optimized Cost: $210.65
#   Mean Reduction: 5.24%
#   Median Baseline Cost:  $242.14
#   Median Optimized Cost: $229.68
#   Median Reduction: 5.15%
#
# Case ID: 161
#   Mean Baseline Cost:  $222.15
#   Mean Optimized Cost: $258.61
#   Mean Reduction: -16.41%
#   Median Baseline Cost:  $239.47
#   Median Optimized Cost: $216.99
#   Median Reduction: 9.39%
#
# Case ID: 162
#   Mean Baseline Cost:  $237.32
#   Mean Optimized Cost: $215.94
#   Mean Reduction: 9.01%
#   Median Baseline Cost:  $224.08
#   Median Optimized Cost: $197.39
#   Median Reduction: 11.91%
#
# Case ID: 163
#   Mean Baseline Cost:  $394.92
#   Mean Optimized Cost: $209.30
#   Mean Reduction: 47.00%
#   Median Baseline Cost:  $232.55
#   Median Optimized Cost: $217.34
#   Median Reduction: 6.54%
#
# Case ID: 164
#   Mean Baseline Cost:  $237.22
#   Mean Optimized Cost: $163.09
#   Mean Reduction: 31.25%
#   Median Baseline Cost:  $219.10
#   Median Optimized Cost: $134.27
#   Median Reduction: 38.72%
#
# Case ID: 165
#   Mean Baseline Cost:  $643.62
#   Mean Optimized Cost: $193.99
#   Mean Reduction: 69.86%
#   Median Baseline Cost:  $252.73
#   Median Optimized Cost: $188.64
#   Median Reduction: 25.36%
#
# Case ID: 166
#   Mean Baseline Cost:  $371.70
#   Mean Optimized Cost: $557.07
#   Mean Reduction: -49.87%
#   Median Baseline Cost:  $188.10
#   Median Optimized Cost: $250.97
#   Median Reduction: -33.42%
#
# Case ID: 167
#   Mean Baseline Cost:  $1006.23
#   Mean Optimized Cost: $612.73
#   Mean Reduction: 39.11%
#   Median Baseline Cost:  $275.09
#   Median Optimized Cost: $207.27
#   Median Reduction: 24.66%
#
# Case ID: 168
#   Mean Baseline Cost:  $1446.63
#   Mean Optimized Cost: $177.41
#   Mean Reduction: 87.74%
#   Median Baseline Cost:  $1863.37
#   Median Optimized Cost: $174.65
#   Median Reduction: 90.63%
#
# Case ID: 169
#   Mean Baseline Cost:  $1465.95
#   Mean Optimized Cost: $1138.47
#   Mean Reduction: 22.34%
#   Median Baseline Cost:  $1826.22
#   Median Optimized Cost: $975.53
#   Median Reduction: 46.58%
#
# Case ID: 170
#   Mean Baseline Cost:  $1271.10
#   Mean Optimized Cost: $1629.35
#   Mean Reduction: -28.18%
#   Median Baseline Cost:  $1599.05
#   Median Optimized Cost: $1951.06
#   Median Reduction: -22.01%
#
# Case ID: 171
#   Mean Baseline Cost:  $914.72
#   Mean Optimized Cost: $1565.50
#   Mean Reduction: -71.15%
#   Median Baseline Cost:  $336.95
#   Median Optimized Cost: $1720.23
#   Median Reduction: -410.53%
#
# Case ID: 172
#   Mean Baseline Cost:  $1009.73
#   Mean Optimized Cost: $1185.21
#   Mean Reduction: -17.38%
#   Median Baseline Cost:  $936.30
#   Median Optimized Cost: $1653.90
#   Median Reduction: -76.64%
#
# Case ID: 173
#   Mean Baseline Cost:  $981.45
#   Mean Optimized Cost: $1412.44
#   Mean Reduction: -43.91%
#   Median Baseline Cost:  $984.33
#   Median Optimized Cost: $1613.23
#   Median Reduction: -63.89%
#
# Case ID: 174
#   Mean Baseline Cost:  $958.00
#   Mean Optimized Cost: $814.28
#   Mean Reduction: 15.00%
#   Median Baseline Cost:  $877.70
#   Median Optimized Cost: $258.86
#   Median Reduction: 70.51%
#
# Case ID: 175
#   Mean Baseline Cost:  $241.03
#   Mean Optimized Cost: $166.22
#   Mean Reduction: 31.04%
#   Median Baseline Cost:  $206.05
#   Median Optimized Cost: $148.65
#   Median Reduction: 27.86%
#
# Case ID: 176
#   Mean Baseline Cost:  $191.76
#   Mean Optimized Cost: $206.79
#   Mean Reduction: -7.84%
#   Median Baseline Cost:  $161.33
#   Median Optimized Cost: $208.60
#   Median Reduction: -29.30%
#
# Case ID: 177
#   Mean Baseline Cost:  $184.94
#   Mean Optimized Cost: $185.23
#   Mean Reduction: -0.16%
#   Median Baseline Cost:  $186.30
#   Median Optimized Cost: $181.33
#   Median Reduction: 2.67%
#
# Case ID: 178
#   Mean Baseline Cost:  $248.99
#   Mean Optimized Cost: $237.89
#   Mean Reduction: 4.46%
#   Median Baseline Cost:  $238.74
#   Median Optimized Cost: $209.38
#   Median Reduction: 12.30%
#
# Case ID: 179
#   Mean Baseline Cost:  $189.89
#   Mean Optimized Cost: $173.50
#   Mean Reduction: 8.63%
#   Median Baseline Cost:  $181.92
#   Median Optimized Cost: $153.81
#   Median Reduction: 15.45%
#
# Case ID: 180
#   Mean Baseline Cost:  $1575.26
#   Mean Optimized Cost: $183.58
#   Mean Reduction: 88.35%
#   Median Baseline Cost:  $260.65
#   Median Optimized Cost: $185.79
#   Median Reduction: 28.72%
#
# Case ID: 181
#   Mean Baseline Cost:  $231.10
#   Mean Optimized Cost: $174.38
#   Mean Reduction: 24.54%
#   Median Baseline Cost:  $226.50
#   Median Optimized Cost: $161.28
#   Median Reduction: 28.79%
#
# Case ID: 182
#   Mean Baseline Cost:  $2921.38
#   Mean Optimized Cost: $183.43
#   Mean Reduction: 93.72%
#   Median Baseline Cost:  $378.73
#   Median Optimized Cost: $167.93
#   Median Reduction: 55.66%
#
# Case ID: 183
#   Mean Baseline Cost:  $2543.67
#   Mean Optimized Cost: $1744.65
#   Mean Reduction: 31.41%
#   Median Baseline Cost:  $192.84
#   Median Optimized Cost: $187.30
#   Median Reduction: 2.87%
#
# Case ID: 184
#   Mean Baseline Cost:  $3556.67
#   Mean Optimized Cost: $2932.95
#   Mean Reduction: 17.54%
#   Median Baseline Cost:  $248.78
#   Median Optimized Cost: $176.36
#   Median Reduction: 29.11%
#
# Case ID: 185
#   Mean Baseline Cost:  $3235.38
#   Mean Optimized Cost: $3064.64
#   Mean Reduction: 5.28%
#   Median Baseline Cost:  $309.51
#   Median Optimized Cost: $194.94
#   Median Reduction: 37.01%
#
# Case ID: 186
#   Mean Baseline Cost:  $4500.94
#   Mean Optimized Cost: $5564.07
#   Mean Reduction: -23.62%
#   Median Baseline Cost:  $6458.96
#   Median Optimized Cost: $6892.06
#   Median Reduction: -6.71%
#
# Case ID: 187
#   Mean Baseline Cost:  $4762.29
#   Mean Optimized Cost: $4828.28
#   Mean Reduction: -1.39%
#   Median Baseline Cost:  $5978.69
#   Median Optimized Cost: $6584.66
#   Median Reduction: -10.14%
#
# Case ID: 188
#   Mean Baseline Cost:  $3347.48
#   Mean Optimized Cost: $4074.77
#   Mean Reduction: -21.73%
#   Median Baseline Cost:  $3071.53
#   Median Optimized Cost: $6121.15
#   Median Reduction: -99.29%
#
# Case ID: 189
#   Mean Baseline Cost:  $4515.59
#   Mean Optimized Cost: $5848.89
#   Mean Reduction: -29.53%
#   Median Baseline Cost:  $5921.55
#   Median Optimized Cost: $5946.34
#   Median Reduction: -0.42%
#
# Case ID: 190
#   Mean Baseline Cost:  $3338.83
#   Mean Optimized Cost: $5144.00
#   Mean Reduction: -54.07%
#   Median Baseline Cost:  $3107.56
#   Median Optimized Cost: $5905.88
#   Median Reduction: -90.05%
#
# Case ID: 191
#   Mean Baseline Cost:  $462.42
#   Mean Optimized Cost: $191.26
#   Mean Reduction: 58.64%
#   Median Baseline Cost:  $205.63
#   Median Optimized Cost: $203.44
#   Median Reduction: 1.06%
#
# Case ID: 192
#   Mean Baseline Cost:  $238.23
#   Mean Optimized Cost: $176.78
#   Mean Reduction: 25.79%
#   Median Baseline Cost:  $192.84
#   Median Optimized Cost: $135.93
#   Median Reduction: 29.51%
#
# Case ID: 193
#   Mean Baseline Cost:  $447.54
#   Mean Optimized Cost: $174.56
#   Mean Reduction: 60.99%
#   Median Baseline Cost:  $185.04
#   Median Optimized Cost: $152.79
#   Median Reduction: 17.43%
#
# Case ID: 194
#   Mean Baseline Cost:  $212.64
#   Mean Optimized Cost: $185.20
#   Mean Reduction: 12.90%
#   Median Baseline Cost:  $184.12
#   Median Optimized Cost: $175.79
#   Median Reduction: 4.52%
#
# Case ID: 195
#   Mean Baseline Cost:  $229.73
#   Mean Optimized Cost: $440.85
#   Mean Reduction: -91.90%
#   Median Baseline Cost:  $237.72
#   Median Optimized Cost: $249.91
#   Median Reduction: -5.13%
#
# Case ID: 196
#   Mean Baseline Cost:  $208.59
#   Mean Optimized Cost: $166.36
#   Mean Reduction: 20.25%
#   Median Baseline Cost:  $212.02
#   Median Optimized Cost: $158.88
#   Median Reduction: 25.06%
#
# Case ID: 197
#   Mean Baseline Cost:  $227.22
#   Mean Optimized Cost: $382.80
#   Mean Reduction: -68.47%
#   Median Baseline Cost:  $226.53
#   Median Optimized Cost: $200.84
#   Median Reduction: 11.34%
#
# Case ID: 198
#   Mean Baseline Cost:  $838.21
#   Mean Optimized Cost: $387.68
#   Mean Reduction: 53.75%
#   Median Baseline Cost:  $219.65
#   Median Optimized Cost: $177.19
#   Median Reduction: 19.33%
#
# Case ID: 199
#   Mean Baseline Cost:  $907.35
#   Mean Optimized Cost: $192.63
#   Mean Reduction: 78.77%
#   Median Baseline Cost:  $191.64
#   Median Optimized Cost: $203.53
#   Median Reduction: -6.21%
#
# ========================================
# Overall Mean Cost Reduction:   -0.16%
# Overall Median Cost Reduction: 4.18%
# ========================================

# %%
def calculate_total_wait_time(df: pd.DataFrame) -> float:
    """
    Calculates the total waiting time for all cases in a log file.

    Wait time is defined as the time between the end of the previous activity
    and the start of the current activity within the same case.

    Args:
        df (pd.DataFrame): The log DataFrame.

    Returns:
        float: The total waiting time in seconds for the entire log.
    """
    if df.empty:
        return 0.0

    # Ensure timestamp columns are in datetime format
    try:
        df['start_timestamp'] = pd.to_datetime(df['start_timestamp'], format='ISO8601')
        df['end_timestamp'] = pd.to_datetime(df['end_timestamp'], format='ISO8601')
    except Exception as e:
        print(f"  Warning: Could not parse timestamps. Error: {e}")
        return 0.0

    # Sort events to ensure correct chronological order within each case
    df = df.sort_values(by=['case_id', 'start_timestamp'])

    # Get the end time of the *previous* activity within the same case
    df['previous_end_timestamp'] = df.groupby('case_id')['end_timestamp'].shift(1)

    # The first activity in a case has no previous end time, so fill with its own start time
    df['previous_end_timestamp'].fillna(df['start_timestamp'], inplace=True)

    # Calculate wait time for each activity
    df['wait_time_seconds'] = (df['start_timestamp'] - df['previous_end_timestamp']).dt.total_seconds()
    
    # Ensure wait times are not negative (can happen with parallel activities)
    df['wait_time_seconds'] = df['wait_time_seconds'].clip(lower=0)
    
    # Return the sum of all wait times
    return df['wait_time_seconds'].sum()


# ==============================================================================
# --- NEW BENCHMARKING FUNCTION ---
# ==============================================================================

def compare_wait_times_across_logs(baseline_dir, optimized_dir, LOG_NAME):
    """
    Compares total wait times between baseline and optimized simulation logs.
    """
    print(f"Comparing total wait times for {LOG_NAME}...\n")
    all_improvements = []

    try:
        baseline_files = [f for f in os.listdir(baseline_dir) if f.startswith('simulated_log_')]
        num_simulations = len(baseline_files)
    except FileNotFoundError:
        print(f"Error: Baseline directory not found at {baseline_dir}")
        return

    for i in range(num_simulations):
        baseline_file = os.path.join(baseline_dir, f'simulated_log_{i}.csv')
        optimized_file = os.path.join(optimized_dir, f'simulated_log_{i}.csv')

        if not os.path.exists(baseline_file) or not os.path.exists(optimized_file):
            print(f"--- Log {i} ---\n  Could not compare due to missing file(s).\n")
            continue

        try:
            df_base = pd.read_csv(baseline_file)
            df_opt = pd.read_csv(optimized_file)
        except Exception as e:
            print(f"--- Log {i} ---\n  Error reading files: {e}\n")
            continue

        total_wait_base = calculate_total_wait_time(df_base)
        total_wait_opt = calculate_total_wait_time(df_opt)

        if total_wait_base > 0:
            # Improvement is a REDUCTION in wait time
            improvement_percent = ((total_wait_base - total_wait_opt) / total_wait_base) * 100
            all_improvements.append(improvement_percent)

            print(f"--- Log {i} ---")
            print(f"  Baseline Total Wait Time:  {total_wait_base / 3600:.2f} hours")
            print(f"  Optimized Total Wait Time: {total_wait_opt / 3600:.2f} hours")
            print(f"  Wait Time Reduction: {improvement_percent:.2f}%\n")
        else:
            print(f"--- Log {i} ---\n  Baseline wait time is zero, cannot calculate improvement.\n")

    if all_improvements:
        overall_avg_improvement = np.mean(all_improvements)
        print("="*40)
        print(f"Overall Average Wait Time Reduction: {overall_avg_improvement:.2f}%")
        print("="*40)

# ==============================================================================
# --- MAIN EXECUTION BLOCK ---
# ==============================================================================

# %%
# ==============================================================================
# --- HELPER FUNCTION ---
# ==============================================================================

def calculate_gini_coefficient(df: pd.DataFrame) -> float:
    """
    Calculates the Gini coefficient for resource workload in a log.
    A lower Gini coefficient indicates better load balancing.

    Args:
        df (pd.DataFrame): The log DataFrame.

    Returns:
        float: The Gini coefficient (between 0 and 1).
    """
    if df.empty or 'resource' not in df.columns:
        return 0.0

    # Calculate the total work duration for each resource
    try:
        df['start_timestamp'] = pd.to_datetime(df['start_timestamp'])
        df['end_timestamp'] = pd.to_datetime(df['end_timestamp'])
    except Exception:
        return 0.0 # Return neutral value if timestamps are invalid
        
    df['work_duration'] = (df['end_timestamp'] - df['start_timestamp']).dt.total_seconds()
    
    # Get total work per resource
    workload = df.groupby('resource')['work_duration'].sum()

    if workload.empty:
        return 0.0

    # Gini coefficient calculation
    # Based on the formula: G = (Σ (2i - n - 1) * x_i) / (n * Σ x_i)
    # where x is the sorted list of values, n is the count, and i is the rank.
    values = workload.sort_values().to_numpy()
    n = len(values)
    if n < 2:
        return 0.0 # Gini is 0 if there's only one resource
        
    i = np.arange(1, n + 1)
    numerator = np.sum((2 * i - n - 1) * values)
    denominator = n * np.sum(values)

    if denominator == 0:
        return 0.0

    return numerator / denominator


# ==============================================================================
# --- BENCHMARKING FUNCTIONS ---
# ==============================================================================

def compare_load_balancing_across_logs(baseline_dir, optimized_dir):
    """
    Compares the Gini coefficient for load balancing on a per-log basis.
    A lower Gini coefficient is better.
    """
    print(f"Comparing Load Balancing (Gini Coefficient) for {LOG_NAME}...\n")
    all_improvements = []

    try:
        baseline_files = [f for f in os.listdir(baseline_dir) if f.startswith('simulated_log_')]
        num_simulations = len(baseline_files)
    except FileNotFoundError:
        print(f"Error: Baseline directory not found at {baseline_dir}")
        return

    for i in range(num_simulations):
        baseline_file = os.path.join(baseline_dir, f'simulated_log_{i}.csv')
        optimized_file = os.path.join(optimized_dir, f'simulated_log_{i}.csv')

        if not os.path.exists(baseline_file) or not os.path.exists(optimized_file):
            print(f"--- Log {i} ---\n  Could not compare due to missing file(s).\n")
            continue

        try:
            df_base = pd.read_csv(baseline_file)
            df_opt = pd.read_csv(optimized_file)
        except Exception as e:
            print(f"--- Log {i} ---\n  Error reading files: {e}\n")
            continue

        gini_base = calculate_gini_coefficient(df_base)
        gini_opt = calculate_gini_coefficient(df_opt)

        if gini_base > 0:
            # Improvement is a REDUCTION in the Gini coefficient
            improvement_percent = ((gini_base - gini_opt) / gini_base) * 100
            all_improvements.append(improvement_percent)

            print(f"--- Log {i} ---")
            print(f"  Baseline Gini Coefficient:  {gini_base:.4f} (More unequal)")
            print(f"  Optimized Gini Coefficient: {gini_opt:.4f} (More equal)")
            print(f"  Load Balancing Improvement: {improvement_percent:.2f}%\n")
        else:
            print(f"--- Log {i} ---\n  Baseline Gini is zero, cannot calculate improvement.\n")

    if all_improvements:
        overall_avg_improvement = np.mean(all_improvements)
        print("="*50)
        print(f"Overall Average Improvement in Load Balancing: {overall_avg_improvement:.2f}%")
        print("="*50)


def compare_load_balancing_across_all_data(baseline_dir, optimized_dir):
    """
    Aggregates all logs and compares the overall Gini coefficient.
    This gives a single, stable measure of load balancing across the entire simulation set.
    """
    print(f"Comparing Overall Load Balancing by Aggregating All Logs...\n")
    
    # Load and concatenate all logs from each directory
    all_baseline_dfs = [pd.read_csv(os.path.join(baseline_dir, f)) for f in os.listdir(baseline_dir) if f.startswith('simulated_log_')]
    all_optimized_dfs = [pd.read_csv(os.path.join(optimized_dir, f)) for f in os.listdir(optimized_dir) if f.startswith('simulated_log_')]

    if not all_baseline_dfs or not all_optimized_dfs:
        print("Error: Could not load one or both sets of logs.")
        return

    # Create two massive DataFrames, one for baseline and one for optimized
    df_base_total = pd.concat(all_baseline_dfs, ignore_index=True)
    df_opt_total = pd.concat(all_optimized_dfs, ignore_index=True)

    # Calculate the Gini coefficient for the entire aggregated dataset
    gini_base_total = calculate_gini_coefficient(df_base_total)
    gini_opt_total = calculate_gini_coefficient(df_opt_total)

    if gini_base_total > 0:
        improvement_percent = ((gini_base_total - gini_opt_total) / gini_base_total) * 100
        
        print("--- Overall Aggregated Results ---")
        print(f"  Baseline Gini Coefficient (All Logs):  {gini_base_total:.4f}")
        print(f"  Optimized Gini Coefficient (All Logs): {gini_opt_total:.4f}")
        print(f"  Total Load Balancing Improvement: {improvement_percent:.2f}%\n")
    else:
        print("Could not calculate overall improvement as baseline Gini is zero.")


try:
    log_name = 'LoanApp.csv' 
    base_path = os.path.join('..', '..', 'simulated_data', log_name)
    baseline_dir_path = os.path.join(base_path, 'baseline')
    optimized_dir_path = os.path.join(base_path, 'autonomous')

    if not os.path.exists(baseline_dir_path) or not os.path.exists(optimized_dir_path):
        raise FileNotFoundError

    print("### Analysis 1: Per-Log Load Balancing Comparison ###\n")
    compare_load_balancing_across_logs(baseline_dir_path, optimized_dir_path)
        
    print("\n\n### Analysis 2: Overall Aggregated Load Balancing ###\n")
    compare_load_balancing_across_all_data(baseline_dir_path, optimized_dir_path)
except FileNotFoundError:
    print(f"FATAL ERROR: Could not find directories.")
    print(f"Checked for: '{baseline_dir_path}'")
    print(f"Checked for: '{optimized_dir_path}'")
    print("Please ensure the CONFIG section is correct and you have run the simulations.")
except Exception as e:
    print(f"An unexpected error occurred: {e}")
# Out:
# ### Analysis 1: Per-Log Load Balancing Comparison ###
#
# Comparing Load Balancing (Gini Coefficient) for LoanApp.csv...
#
# --- Log 0 ---
#   Baseline Gini is zero, cannot calculate improvement.
#
# --- Log 1 ---
#   Baseline Gini is zero, cannot calculate improvement.
#
# --- Log 2 ---
#   Baseline Gini is zero, cannot calculate improvement.
#
# --- Log 3 ---
#   Baseline Gini is zero, cannot calculate improvement.
#
# --- Log 4 ---
#   Baseline Gini is zero, cannot calculate improvement.
#
# --- Log 5 ---
#   Baseline Gini is zero, cannot calculate improvement.
#
# --- Log 6 ---
#   Baseline Gini is zero, cannot calculate improvement.
#
# --- Log 7 ---
#   Baseline Gini is zero, cannot calculate improvement.
#
# --- Log 8 ---
#   Baseline Gini is zero, cannot calculate improvement.
#
# --- Log 9 ---
#   Baseline Gini is zero, cannot calculate improvement.
#
#
#
# ### Analysis 2: Overall Aggregated Load Balancing ###
#
# Comparing Overall Load Balancing by Aggregating All Logs...
#
# Could not calculate overall improvement as baseline Gini is zero.

# %%
log_name = 'LoanApp.csv' 
base_path = os.path.join('..', '..', 'simulated_data', log_name)
baseline_dir_path = os.path.join(base_path, 'baseline')
optimized_dir_path = os.path.join(base_path, 'autonomous')

all_baseline_dfs = [pd.read_csv(os.path.join(baseline_dir_path, f)) for f in os.listdir(baseline_dir_path) if f.startswith('simulated_log_')]
all_optimized_dfs = [pd.read_csv(os.path.join(optimized_dir_path, f)) for f in os.listdir(optimized_dir_path) if f.startswith('simulated_log_')] 

for i in range(0,10):
    print(f"Log {i}")
    print(f"Baseline agents used: {all_baseline_dfs[i]['agent'].nunique()}")
    print(f"Optimized agents used: {all_optimized_dfs[i]['agent'].nunique()}")
    print()
# Out:
# Log 0
# Baseline agents used: 19
# Optimized agents used: 18
#
# Log 1
# Baseline agents used: 19
# Optimized agents used: 18
#
# Log 2
# Baseline agents used: 19
# Optimized agents used: 18
#
# Log 3
# Baseline agents used: 19
# Optimized agents used: 18
#
# Log 4
# Baseline agents used: 19
# Optimized agents used: 18
#
# Log 5
# Baseline agents used: 19
# Optimized agents used: 18
#
# Log 6
# Baseline agents used: 19
# Optimized agents used: 18
#
# Log 7
# Baseline agents used: 19
# Optimized agents used: 18
#
# Log 8
# Baseline agents used: 19
# Optimized agents used: 18
#
# Log 9
# Baseline agents used: 19
# Optimized agents used: 18

# %%
all_baseline_dfs[0]
# Out:
#       case_id  agent                         activity_name  \
# 0           0      0   Check application form completeness
# 1           1      1   Check application form completeness
# 2           0      2                             AML check
# 3           1      5  Return application back to applicant
# 4           2      4   Check application form completeness
# ...       ...    ...                                   ...
# 1491      199     13                      Assess loan risk
# 1492      198      0                    Reject application
# 1493      199     16                     Design loan offer
# 1494      199     17                    Approve loan offer
# 1495      199      9                   Approve application
#
#                           start_timestamp  \
# 0               2023-04-20 08:00:00+00:00
# 1               2023-04-20 08:30:00+00:00
# 2     2023-04-20 08:31:15.767146327+00:00
# 3     2023-04-20 08:39:04.998861004+00:00
# 4               2023-04-20 09:00:00+00:00
# ...                                   ...
# 1491  2023-05-09 08:18:07.242683294+00:00
# 1492  2023-05-08 14:15:20.135228054+00:00
# 1493  2023-05-09 08:38:07.242683294+00:00
# 1494  2023-05-09 08:50:11.867087651+00:00
# 1495  2023-05-09 09:10:11.867087651+00:00
#
#                             end_timestamp  TimeStep                 resource
# 0     2023-04-20 08:31:15.767146327+00:00         0             Clerk-000001
# 1     2023-04-20 08:39:04.998861004+00:00         1             Clerk-000002
# 2     2023-04-20 09:21:27.617434504+00:00         2  AML Investigator-000001
# 3     2023-04-20 08:44:04.998861004+00:00         3             Clerk-000004
# 4     2023-04-20 09:15:36.685940850+00:00         4             Clerk-000003
# ...                                   ...       ...                      ...
# 1491  2023-05-09 08:38:07.242683294+00:00      1606      Loan Officer-000002
# 1492  2023-05-08 14:25:20.135228054+00:00      1607             Clerk-000001
# 1493  2023-05-09 08:50:11.867087651+00:00      1608      Loan Officer-000004
# 1494  2023-05-09 09:10:11.867087651+00:00      1609    Senior Officer-000002
# 1495  2023-05-09 09:15:11.867087651+00:00      1610             Clerk-000006
#
# [1496 rows x 7 columns]

# %%
log_name = 'LoanApp.csv' 
base_path = os.path.join('..', '..', 'simulated_data', log_name)
baseline_dir_path = os.path.join(base_path, 'baseline')
optimized_dir_path = os.path.join(base_path, 'autonomous')


    
base_path = os.path.join('..', '..', 'simulated_data', log_name)
optimized_dir = os.path.join(base_path, 'autonomous')

    # Check if directories exist before running
if not os.path.exists(baseline_dir_path) or not os.path.exists(optimized_dir_path):
    print(f"FATAL ERROR: Could not find directories.")
    print(f"Checked for: '{baseline_dir_path}'")
    print(f"Checked for: '{optimized_dir_path}'")
    print("Please ensure the CONFIG section is correct and you have run the simulations.")
else:
    compare_wait_times_across_logs(baseline_dir_path, optimized_dir_path, 'LoanApp.csv')
# Out:
# Comparing total wait times for LoanApp.csv...
#
# --- Log 0 ---
#   Baseline Total Wait Time:  717.40 hours
#   Optimized Total Wait Time: 298.40 hours
#   Wait Time Reduction: 58.41%
#
# --- Log 1 ---
#   Baseline Total Wait Time:  818.01 hours
#   Optimized Total Wait Time: 362.38 hours
#   Wait Time Reduction: 55.70%
#
# --- Log 2 ---
#   Baseline Total Wait Time:  1012.35 hours
#   Optimized Total Wait Time: 794.54 hours
#   Wait Time Reduction: 21.52%
#
# --- Log 3 ---
#   Baseline Total Wait Time:  470.36 hours
#   Optimized Total Wait Time: 443.66 hours
#   Wait Time Reduction: 5.68%
#
# --- Log 4 ---
#   Baseline Total Wait Time:  601.06 hours
#   Optimized Total Wait Time: 507.20 hours
#   Wait Time Reduction: 15.62%
#
# --- Log 5 ---
#   Baseline Total Wait Time:  295.17 hours
#   Optimized Total Wait Time: 1112.60 hours
#   Wait Time Reduction: -276.93%
#
# --- Log 6 ---
#   Baseline Total Wait Time:  494.56 hours
#   Optimized Total Wait Time: 491.37 hours
#   Wait Time Reduction: 0.65%
#
# --- Log 7 ---
#   Baseline Total Wait Time:  899.53 hours
#   Optimized Total Wait Time: 345.65 hours
#   Wait Time Reduction: 61.57%
#
# --- Log 8 ---
#   Baseline Total Wait Time:  703.23 hours
#   Optimized Total Wait Time: 497.84 hours
#   Wait Time Reduction: 29.21%
#
# --- Log 9 ---
#   Baseline Total Wait Time:  545.85 hours
#   Optimized Total Wait Time: 701.95 hours
#   Wait Time Reduction: -28.60%
#
# ========================================
# Overall Average Wait Time Reduction: -5.72%
# ========================================
# /var/folders/x3/5rg2fq097snf05l9glzskh9r0000gn/T/ipykernel_2942/2274668689.py:32: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['previous_end_timestamp'].fillna(df['start_timestamp'], inplace=True)
# /var/folders/x3/5rg2fq097snf05l9glzskh9r0000gn/T/ipykernel_2942/2274668689.py:32: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['previous_end_timestamp'].fillna(df['start_timestamp'], inplace=True)
# /var/folders/x3/5rg2fq097snf05l9glzskh9r0000gn/T/ipykernel_2942/2274668689.py:32: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['previous_end_timestamp'].fillna(df['start_timestamp'], inplace=True)
# /var/folders/x3/5rg2fq097snf05l9glzskh9r0000gn/T/ipykernel_2942/2274668689.py:32: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['previous_end_timestamp'].fillna(df['start_timestamp'], inplace=True)
# /var/folders/x3/5rg2fq097snf05l9glzskh9r0000gn/T/ipykernel_2942/2274668689.py:32: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['previous_end_timestamp'].fillna(df['start_timestamp'], inplace=True)
# /var/folders/x3/5rg2fq097snf05l9glzskh9r0000gn/T/ipykernel_2942/2274668689.py:32: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['previous_end_timestamp'].fillna(df['start_timestamp'], inplace=True)
# /var/folders/x3/5rg2fq097snf05l9glzskh9r0000gn/T/ipykernel_2942/2274668689.py:32: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['previous_end_timestamp'].fillna(df['start_timestamp'], inplace=True)
# /var/folders/x3/5rg2fq097snf05l9glzskh9r0000gn/T/ipykernel_2942/2274668689.py:32: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['previous_end_timestamp'].fillna(df['start_timestamp'], inplace=True)
# /var/folders/x3/5rg2fq097snf05l9glzskh9r0000gn/T/ipykernel_2942/2274668689.py:32: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['previous_end_timestamp'].fillna(df['start_timestamp'], inplace=True)
# /var/folders/x3/5rg2fq097snf05l9glzskh9r0000gn/T/ipykernel_2942/2274668689.py:32: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['previous_end_timestamp'].fillna(df['start_timestamp'], inplace=True)
# /var/folders/x3/5rg2fq097snf05l9glzskh9r0000gn/T/ipykernel_2942/2274668689.py:32: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['previous_end_timestamp'].fillna(df['start_timestamp'], inplace=True)
# /var/folders/x3/5rg2fq097snf05l9glzskh9r0000gn/T/ipykernel_2942/2274668689.py:32: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['previous_end_timestamp'].fillna(df['start_timestamp'], inplace=True)
# /var/folders/x3/5rg2fq097snf05l9glzskh9r0000gn/T/ipykernel_2942/2274668689.py:32: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['previous_end_timestamp'].fillna(df['start_timestamp'], inplace=True)
# /var/folders/x3/5rg2fq097snf05l9glzskh9r0000gn/T/ipykernel_2942/2274668689.py:32: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['previous_end_timestamp'].fillna(df['start_timestamp'], inplace=True)
# /var/folders/x3/5rg2fq097snf05l9glzskh9r0000gn/T/ipykernel_2942/2274668689.py:32: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['previous_end_timestamp'].fillna(df['start_timestamp'], inplace=True)
# /var/folders/x3/5rg2fq097snf05l9glzskh9r0000gn/T/ipykernel_2942/2274668689.py:32: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['previous_end_timestamp'].fillna(df['start_timestamp'], inplace=True)
# /var/folders/x3/5rg2fq097snf05l9glzskh9r0000gn/T/ipykernel_2942/2274668689.py:32: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['previous_end_timestamp'].fillna(df['start_timestamp'], inplace=True)
# /var/folders/x3/5rg2fq097snf05l9glzskh9r0000gn/T/ipykernel_2942/2274668689.py:32: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['previous_end_timestamp'].fillna(df['start_timestamp'], inplace=True)
# /var/folders/x3/5rg2fq097snf05l9glzskh9r0000gn/T/ipykernel_2942/2274668689.py:32: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['previous_end_timestamp'].fillna(df['start_timestamp'], inplace=True)
# /var/folders/x3/5rg2fq097snf05l9glzskh9r0000gn/T/ipykernel_2942/2274668689.py:32: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['previous_end_timestamp'].fillna(df['start_timestamp'], inplace=True)

# %%
log_name = 'LoanApp.csv' 
    
base_path = os.path.join('..', '..', 'simulated_data', log_name)
optimized_dir = os.path.join(base_path, 'autonomous')


optimized_logs= []
for i in range(10):
    optimized_file = os.path.join(optimized_dir, f'simulated_log_{i}.csv')
    optimized_df = pd.read_csv(optimized_file)
    optimized_logs.append(optimized_df)

baseline_dir = os.path.join(base_path, 'baseline')


baseline_logs= []
for i in range(10):
    baseline_file = os.path.join(baseline_dir, f'simulated_log_{i}.csv')
    baseline_df = pd.read_csv(baseline_file)
    baseline_logs.append(baseline_df)

# %%
optimized_logs_0_cost = add_activity_cost_column(optimized_logs[0], AGENT_COSTS)
baseline_logs_0_cost = add_activity_cost_column(baseline_logs[0], AGENT_COSTS)

# %%
optimized_logs_0_cost[optimized_logs_0_cost['case_id']==50]
# Out:
#      case_id  agent                        activity_name  \
# 346       50      9  Check application form completeness
# 348       50      3                    Appraise property
# 352       50      0                 Check credit history
# 357       50      7                            AML check
# 363       50     13                     Assess loan risk
# 368       50     13                    Design loan offer
# 378       50     14                   Approve loan offer
# 385       50     10                   Cancel application
#
#                         start_timestamp                       end_timestamp  \
# 346           2023-04-25 09:00:00+00:00 2023-04-25 09:03:54.726464335+00:00
# 348 2023-04-25 09:03:54.726464335+00:00 2023-04-25 09:25:32.309296008+00:00
# 352 2023-04-25 09:25:32.309296008+00:00 2023-04-25 09:26:02.540782713+00:00
# 357 2023-04-25 09:26:02.540782713+00:00 2023-04-25 09:39:15.453701600+00:00
# 363 2023-04-25 09:39:15.453701600+00:00 2023-04-25 09:59:15.453701600+00:00
# 368 2023-04-25 09:59:15.453701600+00:00 2023-04-25 10:03:54.191550507+00:00
# 378 2023-04-25 10:03:54.191550507+00:00 2023-04-25 10:23:54.191550507+00:00
# 385 2023-04-25 10:23:54.191550507+00:00 2023-04-25 10:28:54.191550507+00:00
#
#      TimeStep                 resource  duration_seconds  cost_per_hour  \
# 346       384             Clerk-000006        234.726464             90
# 348       386         Appraiser-000001       1297.582832             90
# 352       390             Clerk-000001         30.231487             30
# 357       395  AML Investigator-000002        792.912919            110
# 363       401      Loan Officer-000002       1200.000000             95
# 368       406      Loan Officer-000002        278.737849             95
# 378       416    Senior Officer-000001       1200.000000            150
# 385       423             Clerk-000007        300.000000             30
#
#      activity_cost
# 346       5.868162
# 348      32.439571
# 352       0.251929
# 357      24.227895
# 363      31.666667
# 368       7.355582
# 378      50.000000
# 385       2.500000

# %%
baseline_logs_0_cost[baseline_logs_0_cost['case_id']==194]
# Out:
#       case_id  agent                        activity_name  \
# 1429      194      4  Check application form completeness
# 1432      194      7                            AML check
# 1438      194      0                 Check credit history
# 1443      194      6                    Appraise property
# 1453      194     11                     Assess loan risk
# 1457      194     13                    Design loan offer
# 1460      194     17                   Approve loan offer
# 1465      194      1                  Approve application
#
#                          start_timestamp                       end_timestamp  \
# 1429           2023-05-08 09:00:00+00:00 2023-05-08 09:02:46.537850782+00:00
# 1432 2023-05-08 09:02:46.537850782+00:00 2023-05-08 09:04:51.624568721+00:00
# 1438 2023-05-08 09:04:51.624568721+00:00 2023-05-08 09:25:23.351810765+00:00
# 1443 2023-05-08 10:11:34.354388136+00:00 2023-05-08 11:09:57.530088552+00:00
# 1453 2023-05-08 11:09:57.530088552+00:00 2023-05-08 11:29:57.530088552+00:00
# 1457 2023-05-08 11:29:57.530088552+00:00 2023-05-08 11:30:28.916392668+00:00
# 1460 2023-05-08 11:30:28.916392668+00:00 2023-05-08 11:50:28.916392668+00:00
# 1465 2023-05-08 11:50:28.916392668+00:00 2023-05-08 11:55:28.916392668+00:00
#
#       TimeStep                 resource  duration_seconds  cost_per_hour  \
# 1429      1512             Clerk-000003        166.537851             60
# 1432      1515  AML Investigator-000002        125.086718            110
# 1438      1521             Clerk-000001       1231.727242             30
# 1443      1526         Appraiser-000002       3503.175700             90
# 1453      1536      Loan Officer-000001       1200.000000             95
# 1457      1540      Loan Officer-000002         31.386304             95
# 1460      1544    Senior Officer-000002       1200.000000            150
# 1465      1551             Clerk-000002        300.000000             30
#
#       activity_cost
# 1429       2.775631
# 1432       3.822094
# 1438      10.264394
# 1443      87.579393
# 1453      31.666667
# 1457       0.828250
# 1460      50.000000
# 1465       2.500000

# %%
baseline_logs_0_cost[baseline_logs_0_cost['resource']=='Clerk-000001']
# Out:
#       case_id  agent                        activity_name  \
# 0           0      0  Check application form completeness
# 18          4      0                 Check credit history
# 24          5      0                 Check credit history
# 42          7      0                 Check credit history
# 44          4      0                   Reject application
# ...       ...    ...                                  ...
# 1423      193      0  Check application form completeness
# 1438      194      0                 Check credit history
# 1441      195      0                 Check credit history
# 1455      192      0                   Reject application
# 1482      196      0                  Approve application
#
#                          start_timestamp                       end_timestamp  \
# 0              2023-04-20 08:00:00+00:00 2023-04-20 08:43:37.614829726+00:00
# 18   2023-04-20 10:02:09.387286291+00:00 2023-04-20 10:08:41.646032284+00:00
# 24   2023-04-20 10:55:01.152356712+00:00 2023-04-20 11:16:40.415409532+00:00
# 42   2023-04-20 12:24:53.147598732+00:00 2023-04-20 12:41:42.314751443+00:00
# 44   2023-04-20 11:09:12.020939566+00:00 2023-04-20 11:19:12.020939566+00:00
# ...                                  ...                                 ...
# 1423           2023-05-08 08:30:00+00:00 2023-05-08 08:33:58.925055555+00:00
# 1438 2023-05-08 09:04:51.624568721+00:00 2023-05-08 09:25:23.351810765+00:00
# 1441 2023-05-08 10:04:03.163355210+00:00 2023-05-08 10:51:55.303721034+00:00
# 1455 2023-05-08 12:21:48.645351867+00:00 2023-05-08 12:31:48.645351867+00:00
# 1482 2023-05-08 14:06:00.352159140+00:00 2023-05-08 14:11:00.352159140+00:00
#
#       TimeStep      resource  duration_seconds  cost_per_hour  activity_cost
# 0            0  Clerk-000001       2617.614830             30      21.813457
# 18          18  Clerk-000001        392.258746             30       3.268823
# 24          24  Clerk-000001       1299.263053             30      10.827192
# 42          42  Clerk-000001       1009.167153             30       8.409726
# 44          44  Clerk-000001        600.000000             30       5.000000
# ...        ...           ...               ...            ...            ...
# 1423      1506  Clerk-000001        238.925056             30       1.991042
# 1438      1521  Clerk-000001       1231.727242             30      10.264394
# 1441      1524  Clerk-000001       2872.140366             30      23.934503
# 1455      1538  Clerk-000001        600.000000             30       5.000000
# 1482      1570  Clerk-000001        300.000000             30       2.500000
#
# [84 rows x 10 columns]

# %%
baseline_logs_0_cost[baseline_logs_0_cost['resource']=='Clerk-000002']
# Out:
#       case_id  agent                        activity_name  \
# 1           1      1  Check application form completeness
# 12          2      1                 Check credit history
# 32          7      1  Check application form completeness
# 66         12      1  Check application form completeness
# 85         16      1  Check application form completeness
# ...       ...    ...                                  ...
# 1407      191      1                 Check credit history
# 1421      188      1                   Reject application
# 1440      196      1  Check application form completeness
# 1449      193      1                  Approve application
# 1465      194      1                  Approve application
#
#                          start_timestamp                       end_timestamp  \
# 1              2023-04-20 08:30:00+00:00 2023-04-20 08:55:49.298830341+00:00
# 12   2023-04-20 09:33:32.006788136+00:00 2023-04-20 09:44:39.466867740+00:00
# 32             2023-04-20 11:30:00+00:00 2023-04-20 11:42:44.909816420+00:00
# 66             2023-04-20 14:00:00+00:00 2023-04-20 14:20:28.951480734+00:00
# 85             2023-04-21 08:00:00+00:00 2023-04-21 08:08:50.980187505+00:00
# ...                                  ...                                 ...
# 1407 2023-05-08 07:45:22.644238317+00:00 2023-05-08 07:58:54.831447354+00:00
# 1421 2023-05-08 08:14:58.688161850+00:00 2023-05-08 08:24:58.688161850+00:00
# 1440           2023-05-08 10:00:00+00:00 2023-05-08 10:05:48.257170446+00:00
# 1449 2023-05-08 09:58:14.365056257+00:00 2023-05-08 10:03:14.365056257+00:00
# 1465 2023-05-08 11:50:28.916392668+00:00 2023-05-08 11:55:28.916392668+00:00
#
#       TimeStep      resource  duration_seconds  cost_per_hour  activity_cost
# 1            1  Clerk-000002       1549.298830             30      12.910824
# 12          12  Clerk-000002        667.460080             30       5.562167
# 32          32  Clerk-000002        764.909816             30       6.374248
# 66          66  Clerk-000002       1228.951481             30      10.241262
# 85          85  Clerk-000002        530.980188             30       4.424835
# ...        ...           ...               ...            ...            ...
# 1407      1489  Clerk-000002        812.187209             30       6.768227
# 1421      1504  Clerk-000002        600.000000             30       5.000000
# 1440      1523  Clerk-000002        348.257170             30       2.902143
# 1449      1532  Clerk-000002        300.000000             30       2.500000
# 1465      1551  Clerk-000002        300.000000             30       2.500000
#
# [80 rows x 10 columns]

# %%
baseline_logs_0_cost[baseline_logs_0_cost['resource']=='Clerk-000003']
# Out:
#       case_id  agent                        activity_name  \
# 4           0      4                 Check credit history
# 13          3      4                 Check credit history
# 31          6      4                 Check credit history
# 56         10      4                 Check credit history
# 62          8      4                   Reject application
# ...       ...    ...                                  ...
# 1365      184      4                 Check credit history
# 1398      191      4  Check application form completeness
# 1403      184      4                  Approve application
# 1429      194      4  Check application form completeness
# 1452      198      4  Check application form completeness
#
#                          start_timestamp                       end_timestamp  \
# 4    2023-04-20 08:59:03.365612694+00:00 2023-04-20 09:35:30.082000453+00:00
# 13   2023-04-20 09:33:38.514312029+00:00 2023-04-20 10:26:15.079206372+00:00
# 31   2023-04-20 11:17:30.059813396+00:00 2023-04-20 11:30:42.615563646+00:00
# 56   2023-04-20 13:02:51.964511128+00:00 2023-04-20 13:11:48.704326890+00:00
# 62   2023-04-20 13:12:48.746063072+00:00 2023-04-20 13:22:48.746063072+00:00
# ...                                  ...                                 ...
# 1365 2023-05-05 12:46:56.162499494+00:00 2023-05-05 12:50:31.211560972+00:00
# 1398           2023-05-08 07:30:00+00:00 2023-05-08 07:39:25.752899560+00:00
# 1403 2023-05-05 13:36:38.559937620+00:00 2023-05-05 13:41:38.559937620+00:00
# 1429           2023-05-08 09:00:00+00:00 2023-05-08 09:02:46.537850782+00:00
# 1452           2023-05-08 11:00:00+00:00 2023-05-08 11:05:36.452634738+00:00
#
#       TimeStep      resource  duration_seconds  cost_per_hour  activity_cost
# 4            4  Clerk-000003       2186.716388             60      36.445273
# 13          13  Clerk-000003       3156.564894             60      52.609415
# 31          31  Clerk-000003        792.555750             60      13.209263
# 56          56  Clerk-000003        536.739816             60       8.945664
# 62          62  Clerk-000003        600.000000             60      10.000000
# ...        ...           ...               ...            ...            ...
# 1365      1443  Clerk-000003        215.049061             60       3.584151
# 1398      1478  Clerk-000003        565.752900             60       9.429215
# 1403      1484  Clerk-000003        300.000000             60       5.000000
# 1429      1512  Clerk-000003        166.537851             60       2.775631
# 1452      1535  Clerk-000003        336.452635             60       5.607544
#
# [78 rows x 10 columns]
