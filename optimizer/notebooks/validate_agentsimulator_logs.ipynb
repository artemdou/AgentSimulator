# %%
import pandas as pd
import os
import numpy as np

# %%
def calculate_average_cycle_time(file_path):
    """
    Reads a simulation log and calculates the average cycle time per case.
    """
    try:
        df = pd.read_csv(file_path)
    except FileNotFoundError:
        print(f"Warning: File not found at {file_path}")
        return None

    if df.empty:
        print(f"Warning: File is empty at {file_path}")
        return None

    # Ensure timestamp columns are in datetime format
    df['start_timestamp'] = pd.to_datetime(df['start_timestamp'], format='ISO8601', errors='coerce')
    df['end_timestamp'] = pd.to_datetime(df['end_timestamp'], format='ISO8601', errors='coerce')

    # Group by case_id to find the start of the first activity and end of the last
    case_times = df.groupby('case_id').agg(
        case_start=('start_timestamp', 'min'),
        case_end=('end_timestamp', 'max')
    )

    # Calculate cycle time for each case
    case_times['cycle_time'] = case_times['case_end'] - case_times['case_start']
    
    # Return the average cycle time for the entire log
    return case_times['cycle_time'].mean()

def calculate_case_cycle_times(df):
    """Returns a dictionary of {case_id: cycle_time} from the log."""
    df['start_timestamp'] = pd.to_datetime(df['start_timestamp'], format='ISO8601', errors='coerce')
    df['end_timestamp'] = pd.to_datetime(df['end_timestamp'], format='ISO8601', errors='coerce')

    case_times = {}
    for case_id, group in df.groupby('case_id'):
        start = group['start_timestamp'].min()
        end = group['end_timestamp'].max()
        if pd.notna(start) and pd.notna(end):
            case_times[case_id] = (end - start).total_seconds()
    return case_times

# %%
def comparison_across_logs():
    """
    Compares cycle times between baseline and optimized simulation logs.
    Returns overall improvements and a dict of case-level improvements.
    """
    log_name = 'LoanApp.csv' 
    
    base_path = os.path.join('..', '..', 'simulated_data', log_name)
    baseline_dir = os.path.join(base_path, 'baseline')
    optimized_dir = os.path.join(base_path, 'autonomous')

    if not os.path.exists(baseline_dir) or not os.path.exists(optimized_dir):
        print(f"Error: Make sure both '{baseline_dir}' and '{optimized_dir}' exist.")
        return

    try:
        num_simulations = len([f for f in os.listdir(baseline_dir) if f.startswith('simulated_log_')])
    except FileNotFoundError:
        print(f"Error: Baseline directory not found at {baseline_dir}")
        return
        
    print(f"Comparing {num_simulations} simulation logs from '{log_name}'...\n")

    all_improvements = []
    case_improvements = {}

    for i in range(num_simulations):
        baseline_file = os.path.join(baseline_dir, f'simulated_log_{i}.csv')
        optimized_file = os.path.join(optimized_dir, f'simulated_log_{i}.csv')

        if not os.path.exists(baseline_file) or not os.path.exists(optimized_file):
            print(f"--- Log {i} ---\n  Could not compare due to missing file(s).\n")
            continue

        try:
            df_base = pd.read_csv(baseline_file)
            df_opt = pd.read_csv(optimized_file)
        except Exception as e:
            print(f"--- Log {i} ---\n  Error reading files: {e}\n")
            continue

        baseline_cases = calculate_case_cycle_times(df_base)
        optimized_cases = calculate_case_cycle_times(df_opt)

        per_log_improvements = []
        for case_id in baseline_cases:
            if case_id in optimized_cases and baseline_cases[case_id] > 0:
                improvement = ((baseline_cases[case_id] - optimized_cases[case_id]) / baseline_cases[case_id]) * 100
                per_log_improvements.append(improvement)
                case_improvements[(i, case_id)] = improvement  # (log_number, case_id) => improvement

        if per_log_improvements:
            avg_baseline_time = np.mean(list(baseline_cases.values()))
            avg_optimized_time = np.mean(list(optimized_cases.values()))
            improvement_percent = ((avg_baseline_time - avg_optimized_time) / avg_baseline_time) * 100
            all_improvements.append(improvement_percent)

            print(f"--- Log {i} ---")
            print(f"  Baseline Avg. Cycle Time:  {avg_baseline_time}")
            print(f"  Optimized Avg. Cycle Time: {avg_optimized_time}")
            print(f"  Improvement: {improvement_percent:.2f}%\n")
        else:
            print(f"--- Log {i} ---\n  No valid case matches found.\n")

    if all_improvements:
        overall_avg_improvement = np.mean(all_improvements)
        print("="*40)
        print(f"Overall Average Improvement: {overall_avg_improvement:.2f}%")
        print("="*40)

    return all_improvements, case_improvements

# %%
def compararison_across_cases():
    """
    Aggregates and compares mean and median cycle times per case_id across all logs.
    Prints per-case statistics and overall average/median improvement.
    """
    log_name = 'LoanApp.csv'

    base_path = os.path.join('..', '..', 'simulated_data', log_name)
    baseline_dir = os.path.join(base_path, 'baseline')
    optimized_dir = os.path.join(base_path, 'autonomous')

    if not os.path.exists(baseline_dir) or not os.path.exists(optimized_dir):
        print(f"Error: Make sure both '{baseline_dir}' and '{optimized_dir}' exist.")
        return

    try:
        num_simulations = len([f for f in os.listdir(baseline_dir) if f.startswith('simulated_log_')])
    except FileNotFoundError:
        print(f"Error: Baseline directory not found at {baseline_dir}")
        return

    # Collect case times across all logs
    all_baseline = {}
    all_optimized = {}

    for i in range(num_simulations):
        baseline_file = os.path.join(baseline_dir, f'simulated_log_{i}.csv')
        optimized_file = os.path.join(optimized_dir, f'simulated_log_{i}.csv')

        if not os.path.exists(baseline_file) or not os.path.exists(optimized_file):
            continue

        try:
            df_base = pd.read_csv(baseline_file)
            df_opt = pd.read_csv(optimized_file)
        except:
            continue

        baseline_cases = calculate_case_cycle_times(df_base)
        optimized_cases = calculate_case_cycle_times(df_opt)

        for case_id, time in baseline_cases.items():
            all_baseline.setdefault(case_id, []).append(time)

        for case_id, time in optimized_cases.items():
            all_optimized.setdefault(case_id, []).append(time)

    # Now compare
    common_cases = set(all_baseline.keys()) & set(all_optimized.keys())

    print("Case-by-case aggregated stats:\n")

    mean_improvements = []
    median_improvements = []

    for case_id in sorted(common_cases):
        baseline_times = all_baseline[case_id]
        optimized_times = all_optimized[case_id]

        if not baseline_times or not optimized_times:
            continue

        mean_base = np.mean(baseline_times)
        mean_opt = np.mean(optimized_times)
        median_base = np.median(baseline_times)
        median_opt = np.median(optimized_times)

        if mean_base > 0:
            mean_improvement = ((mean_base - mean_opt) / mean_base) * 100
            mean_improvements.append(mean_improvement)
        else:
            mean_improvement = 0

        if median_base > 0:
            median_improvement = ((median_base - median_opt) / median_base) * 100
            median_improvements.append(median_improvement)
        else:
            median_improvement = 0

        print(f"Case ID: {case_id}")
        print(f"  Mean Baseline:  {mean_base:.2f}")
        print(f"  Mean Optimized: {mean_opt:.2f}")
        print(f"  Mean Improvement: {mean_improvement:.2f}%")
        print(f"  Median Baseline:  {median_base:.2f}")
        print(f"  Median Optimized: {median_opt:.2f}")
        print(f"  Median Improvement: {median_improvement:.2f}%\n")

    # Print overall stats
    if mean_improvements:
        overall_mean_improvement = np.mean(mean_improvements)
        overall_median_improvement = np.median(median_improvements)

        print("="*40)
        print(f"Overall Mean Improvement:   {overall_mean_improvement:.2f}%")
        print(f"Overall Median Improvement: {overall_median_improvement:.2f}%")
        print("="*40)

# %%
# --- CONFIGURATION ---
# Define the cost per hour for each resource.
# The script will assign a cost of 0 to any resource not listed here.
AGENT_COSTS = {
    "Clerk-000006": 90,
    "Clerk-000001": 30,
    "Applicant-000001": 0,
    "Clerk-000007": 30,
    "Clerk-000004": 90,
    "Clerk-000003": 60,
    "Clerk-000008": 30,
    "Senior Officer-000002": 150,
    "Appraiser-000002": 90,
    "AML Investigator-000002": 110,
    "Appraiser-000001": 90,
    "Loan Officer-000002": 95,
    "AML Investigator-000001": 110,
    "Loan Officer-000001": 95,
    "Loan Officer-000004": 105,
    "Clerk-000002": 30,
    "Loan Officer-000003": 105,
    "Senior Officer-000001": 150,
    "Clerk-000005": 90
    }


def calculate_case_costs(df: pd.DataFrame, agent_costs: dict) -> dict:
    """
    Reads a simulation log DataFrame and calculates the total agent cost for each case.
    
    Args:
        df: The log DataFrame.
        agent_costs: A dictionary mapping resource names to their cost per hour.

    Returns:
        A dictionary mapping each case_id to its total cost.
    """
    if df.empty:
        return {}
    
    # Ensure timestamp columns are in datetime format
    df['start_timestamp'] = pd.to_datetime(df['start_timestamp'], format='ISO8601', errors='coerce')
    df['end_timestamp'] = pd.to_datetime(df['end_timestamp'], format='ISO8601', errors='coerce')

    # Calculate the duration of each task in seconds
    df['duration_seconds'] = (df['end_timestamp'] - df['start_timestamp']).dt.total_seconds()

    # Map the cost per hour to each event, defaulting to 0 if not found
    df['cost_per_hour'] = df['resource'].map(agent_costs).fillna(0)

    # Calculate the cost for each individual task
    df['task_cost'] = (df['duration_seconds'] / 3600) * df['cost_per_hour']

    # Group by case_id and sum the costs to get the total cost per case
    case_total_costs = df.groupby('case_id')['task_cost'].sum()

    return case_total_costs.to_dict()


def compare_costs_across_logs():
    """
    Compares total agent costs between baseline and optimized simulation logs on a per-log basis.
    """
    log_name = 'LoanApp.csv' 
    
    # Adjust this path to match your project structure
    base_path = os.path.join('..', '..', 'simulated_data', log_name)
    baseline_dir = os.path.join(base_path, 'baseline')
    optimized_dir = os.path.join(base_path, 'autonomous') # Updated to point to your optimized logs

    if not os.path.exists(baseline_dir) or not os.path.exists(optimized_dir):
        print(f"Error: Make sure both '{baseline_dir}' and '{optimized_dir}' exist.")
        return

    try:
        num_simulations = len([f for f in os.listdir(baseline_dir) if f.startswith('simulated_log_')])
    except FileNotFoundError:
        print(f"Error: Baseline directory not found at {baseline_dir}")
        return
        
    print(f"Comparing costs for {num_simulations} simulation logs from '{log_name}'...\n")

    all_improvements = []

    for i in range(num_simulations):
        baseline_file = os.path.join(baseline_dir, f'simulated_log_{i}.csv')
        optimized_file = os.path.join(optimized_dir, f'simulated_log_{i}.csv')

        if not os.path.exists(baseline_file) or not os.path.exists(optimized_file):
            print(f"--- Log {i} ---\n  Could not compare due to missing file(s).\n")
            continue

        try:
            df_base = pd.read_csv(baseline_file)
            df_opt = pd.read_csv(optimized_file)
        except Exception as e:
            print(f"--- Log {i} ---\n  Error reading files: {e}\n")
            continue

        baseline_costs = calculate_case_costs(df_base, AGENT_COSTS)
        optimized_costs = calculate_case_costs(df_opt, AGENT_COSTS)
        
        # Filter for cases present in both logs
        common_case_ids = set(baseline_costs.keys()) & set(optimized_costs.keys())
        
        if not common_case_ids:
            print(f"--- Log {i} ---\n  No common cases found to compare.\n")
            continue

        avg_baseline_cost = np.mean([baseline_costs[cid] for cid in common_case_ids])
        avg_optimized_cost = np.mean([optimized_costs[cid] for cid in common_case_ids])
        
        if avg_baseline_cost > 0:
            improvement_percent = ((avg_baseline_cost - avg_optimized_cost) / avg_baseline_cost) * 100
            all_improvements.append(improvement_percent)

            print(f"--- Log {i} ---")
            print(f"  Baseline Avg. Case Cost:  ${avg_baseline_cost:.2f}")
            print(f"  Optimized Avg. Case Cost: ${avg_optimized_cost:.2f}")
            print(f"  Cost Reduction: {improvement_percent:.2f}%\n")
        else:
            print(f"--- Log {i} ---\n  Baseline cost is zero, cannot calculate improvement.\n")

    if all_improvements:
        overall_avg_improvement = np.mean(all_improvements)
        print("="*40)
        print(f"Overall Average Cost Reduction: {overall_avg_improvement:.2f}%")
        print("="*40)


def compare_costs_across_cases():
    """
    Aggregates and compares mean and median costs per case_id across all logs.
    """
    log_name = 'LoanApp.csv'

    base_path = os.path.join('..', '..', 'simulated_data', log_name)
    baseline_dir = os.path.join(base_path, 'baseline')
    optimized_dir = os.path.join(base_path, 'autonomous') # Updated path

    if not os.path.exists(baseline_dir) or not os.path.exists(optimized_dir):
        print(f"Error: Make sure both '{baseline_dir}' and '{optimized_dir}' exist.")
        return

    try:
        num_simulations = len([f for f in os.listdir(baseline_dir) if f.startswith('simulated_log_')])
    except FileNotFoundError:
        print(f"Error: Baseline directory not found at {baseline_dir}")
        return

    # Collect case costs across all logs
    all_baseline_costs = {}
    all_optimized_costs = {}

    for i in range(num_simulations):
        baseline_file = os.path.join(baseline_dir, f'simulated_log_{i}.csv')
        optimized_file = os.path.join(optimized_dir, f'simulated_log_{i}.csv')

        if not os.path.exists(baseline_file) or not os.path.exists(optimized_file): continue
        try:
            df_base = pd.read_csv(baseline_file)
            df_opt = pd.read_csv(optimized_file)
        except: continue

        baseline_cases = calculate_case_costs(df_base, AGENT_COSTS)
        optimized_cases = calculate_case_costs(df_opt, AGENT_COSTS)

        for case_id, cost in baseline_cases.items(): all_baseline_costs.setdefault(case_id, []).append(cost)
        for case_id, cost in optimized_cases.items(): all_optimized_costs.setdefault(case_id, []).append(cost)

    common_cases = set(all_baseline_costs.keys()) & set(all_optimized_costs.keys())
    print("Case-by-case aggregated cost stats:\n")

    mean_improvements = []
    median_improvements = []

    for case_id in sorted(common_cases):
        baseline_costs = all_baseline_costs[case_id]
        optimized_costs = all_optimized_costs[case_id]

        if not baseline_costs or not optimized_costs: continue

        mean_base = np.mean(baseline_costs)
        mean_opt = np.mean(optimized_costs)
        median_base = np.median(baseline_costs)
        median_opt = np.median(optimized_costs)

        mean_improvement = ((mean_base - mean_opt) / mean_base) * 100 if mean_base > 0 else 0
        median_improvement = ((median_base - median_opt) / median_base) * 100 if median_base > 0 else 0
        mean_improvements.append(mean_improvement)
        median_improvements.append(median_improvement)

        print(f"Case ID: {case_id}")
        print(f"  Mean Baseline Cost:  ${mean_base:.2f}")
        print(f"  Mean Optimized Cost: ${mean_opt:.2f}")
        print(f"  Mean Reduction: {mean_improvement:.2f}%")
        print(f"  Median Baseline Cost:  ${median_base:.2f}")
        print(f"  Median Optimized Cost: ${median_opt:.2f}")
        print(f"  Median Reduction: {median_improvement:.2f}%\n")

    if mean_improvements:
        overall_mean_improvement = np.mean(mean_improvements)
        overall_median_improvement = np.median(median_improvements)

        print("="*40)
        print(f"Overall Mean Cost Reduction:   {overall_mean_improvement:.2f}%")
        print(f"Overall Median Cost Reduction: {overall_median_improvement:.2f}%")
        print("="*40)

# %%
def add_activity_cost_column(logs_df: pd.DataFrame, agent_costs: dict) -> pd.DataFrame:
    """
    Enriches a log DataFrame with activity-level cost information.

    This function calculates the cost of each individual activity based on its
    duration and the hourly rate of the resource who performed it.

    Args:
        logs_df (pd.DataFrame): 
            The input DataFrame of simulation logs. It must contain the columns:
            'start_timestamp', 'end_timestamp', and 'resource'.
        
        agent_costs (dict): 
            A dictionary mapping resource names (str) to their cost per hour (float/int).

    Returns:
        pd.DataFrame: 
            A new DataFrame containing all original columns plus a new 
            'activity_cost' column. Returns an empty DataFrame if the input is empty.
    """
    if logs_df.empty:
        return logs_df.copy()

    # Create a copy to avoid modifying the original DataFrame in place
    df = logs_df.copy()

    # 1. Ensure timestamp columns are proper datetime objects
    df['start_timestamp'] = pd.to_datetime(df['start_timestamp'], format='ISO8601')
    df['end_timestamp'] = pd.to_datetime(df['end_timestamp'], format='ISO8601')

    # 2. Calculate the duration of each task in seconds
    df['duration_seconds'] = (df['end_timestamp'] - df['start_timestamp']).dt.total_seconds()

    # 3. Map the agent's cost per hour to each event row.
    #    .map() is a highly efficient way to do this.
    #    .fillna(0) ensures that any resource not in our agent_costs dict gets a cost of 0.
    df['cost_per_hour'] = df['resource'].map(agent_costs).fillna(0)

    # 4. Calculate the final cost for each activity
    #    (Duration in seconds / 3600 seconds per hour) * cost per hour
    df['activity_cost'] = (df['duration_seconds'] / 3600) * df['cost_per_hour']
    
    # Optional: You can drop the intermediate columns if you want a cleaner output
    # df = df.drop(columns=['duration_seconds', 'cost_per_hour'])

    return df

# %%
log_improvements, case_improvements = comparison_across_logs()
# Out:
# Comparing 10 simulation logs from 'LoanApp.csv'...
#
# --- Log 0 ---
#   Baseline Avg. Cycle Time:  50275.163768165
#   Optimized Avg. Cycle Time: 43427.0523623
#   Improvement: 13.62%
#
# --- Log 1 ---
#   Baseline Avg. Cycle Time:  56348.631561815
#   Optimized Avg. Cycle Time: 49905.426406850005
#   Improvement: 11.43%
#
# --- Log 2 ---
#   Baseline Avg. Cycle Time:  54611.17538516499
#   Optimized Avg. Cycle Time: 52692.46970421501
#   Improvement: 3.51%
#
# --- Log 3 ---
#   Baseline Avg. Cycle Time:  52161.806842785
#   Optimized Avg. Cycle Time: 42229.66258994
#   Improvement: 19.04%
#
# --- Log 4 ---
#   Baseline Avg. Cycle Time:  47820.89159405001
#   Optimized Avg. Cycle Time: 40377.819716100006
#   Improvement: 15.56%
#
# --- Log 5 ---
#   Baseline Avg. Cycle Time:  47887.91980021
#   Optimized Avg. Cycle Time: 44609.299664130005
#   Improvement: 6.85%
#
# --- Log 6 ---
#   Baseline Avg. Cycle Time:  52402.908601805
#   Optimized Avg. Cycle Time: 40825.293545205
#   Improvement: 22.09%
#
# --- Log 7 ---
#   Baseline Avg. Cycle Time:  55972.741497740004
#   Optimized Avg. Cycle Time: 47139.90670413001
#   Improvement: 15.78%
#
# --- Log 8 ---
#   Baseline Avg. Cycle Time:  53739.924323885
#   Optimized Avg. Cycle Time: 48851.16692117499
#   Improvement: 9.10%
#
# --- Log 9 ---
#   Baseline Avg. Cycle Time:  47826.745340024994
#   Optimized Avg. Cycle Time: 45039.63617412999
#   Improvement: 5.83%
#
# ========================================
# Overall Average Improvement: 12.28%
# ========================================

# %%
compararison_across_cases()
# Out:
# Case-by-case aggregated stats:
#
# Case ID: 0
#   Mean Baseline:  9998.62
#   Mean Optimized: 8483.26
#   Mean Improvement: 15.16%
#   Median Baseline:  10295.61
#   Median Optimized: 7013.87
#   Median Improvement: 31.88%
#
# Case ID: 1
#   Mean Baseline:  10671.63
#   Mean Optimized: 8095.43
#   Mean Improvement: 24.14%
#   Median Baseline:  10751.04
#   Median Optimized: 8767.87
#   Median Improvement: 18.45%
#
# Case ID: 2
#   Mean Baseline:  16381.52
#   Mean Optimized: 9270.70
#   Mean Improvement: 43.41%
#   Median Baseline:  9643.76
#   Median Optimized: 9625.00
#   Median Improvement: 0.19%
#
# Case ID: 3
#   Mean Baseline:  7699.71
#   Mean Optimized: 11331.30
#   Mean Improvement: -47.17%
#   Median Baseline:  7950.31
#   Median Optimized: 10946.50
#   Median Improvement: -37.69%
#
# Case ID: 4
#   Mean Baseline:  16440.36
#   Mean Optimized: 10652.72
#   Mean Improvement: 35.20%
#   Median Baseline:  9095.94
#   Median Optimized: 9059.36
#   Median Improvement: 0.40%
#
# Case ID: 5
#   Mean Baseline:  17603.60
#   Mean Optimized: 9578.14
#   Mean Improvement: 45.59%
#   Median Baseline:  11132.85
#   Median Optimized: 10395.52
#   Median Improvement: 6.62%
#
# Case ID: 6
#   Mean Baseline:  9059.38
#   Mean Optimized: 8863.69
#   Mean Improvement: 2.16%
#   Median Baseline:  9497.48
#   Median Optimized: 8739.48
#   Median Improvement: 7.98%
#
# Case ID: 7
#   Mean Baseline:  14456.38
#   Mean Optimized: 15519.45
#   Mean Improvement: -7.35%
#   Median Baseline:  7701.82
#   Median Optimized: 7547.25
#   Median Improvement: 2.01%
#
# Case ID: 8
#   Mean Baseline:  33949.35
#   Mean Optimized: 28469.12
#   Mean Improvement: 16.14%
#   Median Baseline:  10995.64
#   Median Optimized: 9412.88
#   Median Improvement: 14.39%
#
# Case ID: 9
#   Mean Baseline:  39220.14
#   Mean Optimized: 31676.73
#   Mean Improvement: 19.23%
#   Median Baseline:  38219.92
#   Median Optimized: 7699.47
#   Median Improvement: 79.85%
#
# Case ID: 10
#   Mean Baseline:  57864.71
#   Mean Optimized: 56680.86
#   Mean Improvement: 2.05%
#   Median Baseline:  69587.06
#   Median Optimized: 67777.04
#   Median Improvement: 2.60%
#
# Case ID: 11
#   Mean Baseline:  70400.43
#   Mean Optimized: 53718.10
#   Mean Improvement: 23.70%
#   Median Baseline:  70552.02
#   Median Optimized: 65031.22
#   Median Improvement: 7.83%
#
# Case ID: 12
#   Mean Baseline:  72315.85
#   Mean Optimized: 67139.44
#   Mean Improvement: 7.16%
#   Median Baseline:  72424.09
#   Median Optimized: 67122.31
#   Median Improvement: 7.32%
#
# Case ID: 13
#   Mean Baseline:  67510.08
#   Mean Optimized: 65614.54
#   Mean Improvement: 2.81%
#   Median Baseline:  67285.97
#   Median Optimized: 65007.94
#   Median Improvement: 3.39%
#
# Case ID: 14
#   Mean Baseline:  68432.22
#   Mean Optimized: 67255.45
#   Mean Improvement: 1.72%
#   Median Baseline:  68231.58
#   Median Optimized: 67656.17
#   Median Improvement: 0.84%
#
# Case ID: 15
#   Mean Baseline:  12935.46
#   Mean Optimized: 8562.29
#   Mean Improvement: 33.81%
#   Median Baseline:  13001.73
#   Median Optimized: 8052.79
#   Median Improvement: 38.06%
#
# Case ID: 16
#   Mean Baseline:  10785.92
#   Mean Optimized: 9688.21
#   Mean Improvement: 10.18%
#   Median Baseline:  10809.25
#   Median Optimized: 9378.24
#   Median Improvement: 13.24%
#
# Case ID: 17
#   Mean Baseline:  11906.67
#   Mean Optimized: 9055.26
#   Mean Improvement: 23.95%
#   Median Baseline:  11912.29
#   Median Optimized: 8259.41
#   Median Improvement: 30.66%
#
# Case ID: 18
#   Mean Baseline:  36148.76
#   Mean Optimized: 10757.78
#   Mean Improvement: 70.24%
#   Median Baseline:  12565.74
#   Median Optimized: 11898.95
#   Median Improvement: 5.31%
#
# Case ID: 19
#   Mean Baseline:  9651.06
#   Mean Optimized: 10833.62
#   Mean Improvement: -12.25%
#   Median Baseline:  8035.20
#   Median Optimized: 11062.16
#   Median Improvement: -37.67%
#
# Case ID: 20
#   Mean Baseline:  35211.63
#   Mean Optimized: 34041.35
#   Mean Improvement: 3.32%
#   Median Baseline:  12254.58
#   Median Optimized: 9956.77
#   Median Improvement: 18.75%
#
# Case ID: 21
#   Mean Baseline:  57230.03
#   Mean Optimized: 9016.08
#   Mean Improvement: 84.25%
#   Median Baseline:  10249.65
#   Median Optimized: 8447.65
#   Median Improvement: 17.58%
#
# Case ID: 22
#   Mean Baseline:  32927.77
#   Mean Optimized: 32748.26
#   Mean Improvement: 0.55%
#   Median Baseline:  9150.34
#   Median Optimized: 9327.28
#   Median Improvement: -1.93%
#
# Case ID: 23
#   Mean Baseline:  79583.02
#   Mean Optimized: 8909.51
#   Mean Improvement: 88.80%
#   Median Baseline:  10031.52
#   Median Optimized: 8538.11
#   Median Improvement: 14.89%
#
# Case ID: 24
#   Mean Baseline:  104571.30
#   Mean Optimized: 78887.29
#   Mean Improvement: 24.56%
#   Median Baseline:  10114.67
#   Median Optimized: 10262.67
#   Median Improvement: -1.46%
#
# Case ID: 25
#   Mean Baseline:  148667.51
#   Mean Optimized: 150709.01
#   Mean Improvement: -1.37%
#   Median Baseline:  240767.42
#   Median Optimized: 242962.21
#   Median Improvement: -0.91%
#
# Case ID: 26
#   Mean Baseline:  148004.79
#   Mean Optimized: 100606.19
#   Mean Improvement: 32.03%
#   Median Baseline:  238711.60
#   Median Optimized: 7613.40
#   Median Improvement: 96.81%
#
# Case ID: 27
#   Mean Baseline:  241258.48
#   Mean Optimized: 239184.19
#   Mean Improvement: 0.86%
#   Median Baseline:  240683.71
#   Median Optimized: 237938.82
#   Median Improvement: 1.14%
#
# Case ID: 28
#   Mean Baseline:  240892.81
#   Mean Optimized: 240844.00
#   Mean Improvement: 0.02%
#   Median Baseline:  240052.19
#   Median Optimized: 241128.87
#   Median Improvement: -0.45%
#
# Case ID: 29
#   Mean Baseline:  239391.45
#   Mean Optimized: 239007.64
#   Mean Improvement: 0.16%
#   Median Baseline:  238999.02
#   Median Optimized: 238158.86
#   Median Improvement: 0.35%
#
# Case ID: 30
#   Mean Baseline:  237069.05
#   Mean Optimized: 239779.65
#   Mean Improvement: -1.14%
#   Median Baseline:  237445.17
#   Median Optimized: 238806.05
#   Median Improvement: -0.57%
#
# Case ID: 31
#   Mean Baseline:  11709.99
#   Mean Optimized: 10873.03
#   Mean Improvement: 7.15%
#   Median Baseline:  10906.64
#   Median Optimized: 12243.01
#   Median Improvement: -12.25%
#
# Case ID: 32
#   Mean Baseline:  12390.13
#   Mean Optimized: 11012.08
#   Mean Improvement: 11.12%
#   Median Baseline:  13222.57
#   Median Optimized: 10634.81
#   Median Improvement: 19.57%
#
# Case ID: 33
#   Mean Baseline:  10385.24
#   Mean Optimized: 16481.87
#   Mean Improvement: -58.70%
#   Median Baseline:  9246.84
#   Median Optimized: 8996.42
#   Median Improvement: 2.71%
#
# Case ID: 34
#   Mean Baseline:  12125.74
#   Mean Optimized: 23334.44
#   Mean Improvement: -92.44%
#   Median Baseline:  13770.14
#   Median Optimized: 10036.63
#   Median Improvement: 27.11%
#
# Case ID: 35
#   Mean Baseline:  10250.95
#   Mean Optimized: 9448.65
#   Mean Improvement: 7.83%
#   Median Baseline:  10299.78
#   Median Optimized: 9489.83
#   Median Improvement: 7.86%
#
# Case ID: 36
#   Mean Baseline:  18327.12
#   Mean Optimized: 15688.83
#   Mean Improvement: 14.40%
#   Median Baseline:  12365.49
#   Median Optimized: 9558.01
#   Median Improvement: 22.70%
#
# Case ID: 37
#   Mean Baseline:  16927.54
#   Mean Optimized: 16264.60
#   Mean Improvement: 3.92%
#   Median Baseline:  10569.06
#   Median Optimized: 9957.25
#   Median Improvement: 5.79%
#
# Case ID: 38
#   Mean Baseline:  22277.61
#   Mean Optimized: 8883.63
#   Mean Improvement: 60.12%
#   Median Baseline:  10075.51
#   Median Optimized: 9465.49
#   Median Improvement: 6.05%
#
# Case ID: 39
#   Mean Baseline:  33794.81
#   Mean Optimized: 15234.37
#   Mean Improvement: 54.92%
#   Median Baseline:  11883.22
#   Median Optimized: 8961.28
#   Median Improvement: 24.59%
#
# Case ID: 40
#   Mean Baseline:  27719.60
#   Mean Optimized: 27393.81
#   Mean Improvement: 1.18%
#   Median Baseline:  10196.55
#   Median Optimized: 8548.50
#   Median Improvement: 16.16%
#
# Case ID: 41
#   Mean Baseline:  58971.98
#   Mean Optimized: 65978.17
#   Mean Improvement: -11.88%
#   Median Baseline:  68346.97
#   Median Optimized: 70192.06
#   Median Improvement: -2.70%
#
# Case ID: 42
#   Mean Baseline:  55941.52
#   Mean Optimized: 49125.96
#   Mean Improvement: 12.18%
#   Median Baseline:  66637.27
#   Median Optimized: 66141.55
#   Median Improvement: 0.74%
#
# Case ID: 43
#   Mean Baseline:  77513.77
#   Mean Optimized: 67799.25
#   Mean Improvement: 12.53%
#   Median Baseline:  67439.10
#   Median Optimized: 67320.14
#   Median Improvement: 0.18%
#
# Case ID: 44
#   Mean Baseline:  61524.38
#   Mean Optimized: 68039.33
#   Mean Improvement: -10.59%
#   Median Baseline:  65055.71
#   Median Optimized: 66851.92
#   Median Improvement: -2.76%
#
# Case ID: 45
#   Mean Baseline:  66687.94
#   Mean Optimized: 65464.54
#   Mean Improvement: 1.83%
#   Median Baseline:  66560.22
#   Median Optimized: 65674.50
#   Median Improvement: 1.33%
#
# Case ID: 46
#   Mean Baseline:  77448.53
#   Mean Optimized: 66318.94
#   Mean Improvement: 14.37%
#   Median Baseline:  67638.54
#   Median Optimized: 66156.80
#   Median Improvement: 2.19%
#
# Case ID: 47
#   Mean Baseline:  10087.03
#   Mean Optimized: 8893.94
#   Mean Improvement: 11.83%
#   Median Baseline:  9901.01
#   Median Optimized: 9010.02
#   Median Improvement: 9.00%
#
# Case ID: 48
#   Mean Baseline:  16611.92
#   Mean Optimized: 10569.17
#   Mean Improvement: 36.38%
#   Median Baseline:  9309.39
#   Median Optimized: 9136.64
#   Median Improvement: 1.86%
#
# Case ID: 49
#   Mean Baseline:  19868.55
#   Mean Optimized: 8419.38
#   Mean Improvement: 57.62%
#   Median Baseline:  11726.64
#   Median Optimized: 8525.84
#   Median Improvement: 27.30%
#
# Case ID: 50
#   Mean Baseline:  11096.05
#   Mean Optimized: 8318.26
#   Mean Improvement: 25.03%
#   Median Baseline:  10033.81
#   Median Optimized: 8530.65
#   Median Improvement: 14.98%
#
# Case ID: 51
#   Mean Baseline:  11441.79
#   Mean Optimized: 9511.43
#   Mean Improvement: 16.87%
#   Median Baseline:  10652.49
#   Median Optimized: 9709.53
#   Median Improvement: 8.85%
#
# Case ID: 52
#   Mean Baseline:  33240.39
#   Mean Optimized: 9619.35
#   Mean Improvement: 71.06%
#   Median Baseline:  11667.70
#   Median Optimized: 10542.21
#   Median Improvement: 9.65%
#
# Case ID: 53
#   Mean Baseline:  30009.18
#   Mean Optimized: 15415.68
#   Mean Improvement: 48.63%
#   Median Baseline:  13581.15
#   Median Optimized: 10452.29
#   Median Improvement: 23.04%
#
# Case ID: 54
#   Mean Baseline:  23671.48
#   Mean Optimized: 15517.69
#   Mean Improvement: 34.45%
#   Median Baseline:  11290.21
#   Median Optimized: 8624.07
#   Median Improvement: 23.61%
#
# Case ID: 55
#   Mean Baseline:  28560.52
#   Mean Optimized: 21894.83
#   Mean Improvement: 23.34%
#   Median Baseline:  10514.41
#   Median Optimized: 9812.31
#   Median Improvement: 6.68%
#
# Case ID: 56
#   Mean Baseline:  35475.42
#   Mean Optimized: 27097.52
#   Mean Improvement: 23.62%
#   Median Baseline:  10917.95
#   Median Optimized: 9053.34
#   Median Improvement: 17.08%
#
# Case ID: 57
#   Mean Baseline:  74524.85
#   Mean Optimized: 38168.49
#   Mean Improvement: 48.78%
#   Median Baseline:  74290.93
#   Median Optimized: 37711.05
#   Median Improvement: 49.24%
#
# Case ID: 58
#   Mean Baseline:  49123.80
#   Mean Optimized: 49645.80
#   Mean Improvement: -1.06%
#   Median Baseline:  66872.22
#   Median Optimized: 65962.49
#   Median Improvement: 1.36%
#
# Case ID: 59
#   Mean Baseline:  56067.88
#   Mean Optimized: 55938.00
#   Mean Improvement: 0.23%
#   Median Baseline:  67604.79
#   Median Optimized: 67781.53
#   Median Improvement: -0.26%
#
# Case ID: 60
#   Mean Baseline:  61797.90
#   Mean Optimized: 68286.70
#   Mean Improvement: -10.50%
#   Median Baseline:  68064.56
#   Median Optimized: 68030.89
#   Median Improvement: 0.05%
#
# Case ID: 61
#   Mean Baseline:  68100.26
#   Mean Optimized: 66171.21
#   Mean Improvement: 2.83%
#   Median Baseline:  66991.62
#   Median Optimized: 65940.15
#   Median Improvement: 1.57%
#
# Case ID: 62
#   Mean Baseline:  68883.62
#   Mean Optimized: 66551.97
#   Mean Improvement: 3.38%
#   Median Baseline:  68855.14
#   Median Optimized: 65031.91
#   Median Improvement: 5.55%
#
# Case ID: 63
#   Mean Baseline:  12363.80
#   Mean Optimized: 10117.04
#   Mean Improvement: 18.17%
#   Median Baseline:  12526.75
#   Median Optimized: 10155.76
#   Median Improvement: 18.93%
#
# Case ID: 64
#   Mean Baseline:  10454.66
#   Mean Optimized: 8172.12
#   Mean Improvement: 21.83%
#   Median Baseline:  9703.98
#   Median Optimized: 7594.10
#   Median Improvement: 21.74%
#
# Case ID: 65
#   Mean Baseline:  12155.16
#   Mean Optimized: 8951.26
#   Mean Improvement: 26.36%
#   Median Baseline:  11161.30
#   Median Optimized: 9179.39
#   Median Improvement: 17.76%
#
# Case ID: 66
#   Mean Baseline:  17365.86
#   Mean Optimized: 10109.99
#   Mean Improvement: 41.78%
#   Median Baseline:  9172.57
#   Median Optimized: 9438.64
#   Median Improvement: -2.90%
#
# Case ID: 67
#   Mean Baseline:  9300.32
#   Mean Optimized: 9265.11
#   Mean Improvement: 0.38%
#   Median Baseline:  10094.20
#   Median Optimized: 10064.11
#   Median Improvement: 0.30%
#
# Case ID: 68
#   Mean Baseline:  32593.32
#   Mean Optimized: 10904.91
#   Mean Improvement: 66.54%
#   Median Baseline:  12372.94
#   Median Optimized: 9659.18
#   Median Improvement: 21.93%
#
# Case ID: 69
#   Mean Baseline:  37014.86
#   Mean Optimized: 7055.85
#   Mean Improvement: 80.94%
#   Median Baseline:  11034.50
#   Median Optimized: 6760.24
#   Median Improvement: 38.74%
#
# Case ID: 70
#   Mean Baseline:  17219.36
#   Mean Optimized: 21953.83
#   Mean Improvement: -27.50%
#   Median Baseline:  10122.40
#   Median Optimized: 9578.90
#   Median Improvement: 5.37%
#
# Case ID: 71
#   Mean Baseline:  27595.19
#   Mean Optimized: 7569.07
#   Mean Improvement: 72.57%
#   Median Baseline:  9815.53
#   Median Optimized: 6829.18
#   Median Improvement: 30.42%
#
# Case ID: 72
#   Mean Baseline:  27951.70
#   Mean Optimized: 39460.67
#   Mean Improvement: -41.17%
#   Median Baseline:  9569.79
#   Median Optimized: 39699.10
#   Median Improvement: -314.84%
#
# Case ID: 73
#   Mean Baseline:  52041.96
#   Mean Optimized: 44981.62
#   Mean Improvement: 13.57%
#   Median Baseline:  67693.52
#   Median Optimized: 67773.66
#   Median Improvement: -0.12%
#
# Case ID: 74
#   Mean Baseline:  63760.12
#   Mean Optimized: 62196.02
#   Mean Improvement: 2.45%
#   Median Baseline:  67825.62
#   Median Optimized: 67594.36
#   Median Improvement: 0.34%
#
# Case ID: 75
#   Mean Baseline:  58355.92
#   Mean Optimized: 54045.95
#   Mean Improvement: 7.39%
#   Median Baseline:  68390.94
#   Median Optimized: 65569.17
#   Median Improvement: 4.13%
#
# Case ID: 76
#   Mean Baseline:  69582.99
#   Mean Optimized: 64858.55
#   Mean Improvement: 6.79%
#   Median Baseline:  68258.97
#   Median Optimized: 65085.97
#   Median Improvement: 4.65%
#
# Case ID: 77
#   Mean Baseline:  67527.11
#   Mean Optimized: 66214.30
#   Mean Improvement: 1.94%
#   Median Baseline:  67397.54
#   Median Optimized: 66804.32
#   Median Improvement: 0.88%
#
# Case ID: 78
#   Mean Baseline:  66198.83
#   Mean Optimized: 67523.07
#   Mean Improvement: -2.00%
#   Median Baseline:  65351.89
#   Median Optimized: 66156.38
#   Median Improvement: -1.23%
#
# Case ID: 79
#   Mean Baseline:  20043.44
#   Mean Optimized: 8376.88
#   Mean Improvement: 58.21%
#   Median Baseline:  13027.37
#   Median Optimized: 8203.31
#   Median Improvement: 37.03%
#
# Case ID: 80
#   Mean Baseline:  10127.65
#   Mean Optimized: 10016.69
#   Mean Improvement: 1.10%
#   Median Baseline:  10333.75
#   Median Optimized: 8728.69
#   Median Improvement: 15.53%
#
# Case ID: 81
#   Mean Baseline:  11731.23
#   Mean Optimized: 10659.14
#   Mean Improvement: 9.14%
#   Median Baseline:  10687.78
#   Median Optimized: 10286.57
#   Median Improvement: 3.75%
#
# Case ID: 82
#   Mean Baseline:  18640.23
#   Mean Optimized: 9034.99
#   Mean Improvement: 51.53%
#   Median Baseline:  10854.41
#   Median Optimized: 8022.85
#   Median Improvement: 26.09%
#
# Case ID: 83
#   Mean Baseline:  17811.87
#   Mean Optimized: 9926.34
#   Mean Improvement: 44.27%
#   Median Baseline:  12011.50
#   Median Optimized: 10089.89
#   Median Improvement: 16.00%
#
# Case ID: 84
#   Mean Baseline:  15920.81
#   Mean Optimized: 8673.49
#   Mean Improvement: 45.52%
#   Median Baseline:  9012.81
#   Median Optimized: 7354.04
#   Median Improvement: 18.40%
#
# Case ID: 85
#   Mean Baseline:  15858.95
#   Mean Optimized: 8227.58
#   Mean Improvement: 48.12%
#   Median Baseline:  9567.91
#   Median Optimized: 9101.43
#   Median Improvement: 4.88%
#
# Case ID: 86
#   Mean Baseline:  16158.48
#   Mean Optimized: 8777.34
#   Mean Improvement: 45.68%
#   Median Baseline:  9771.02
#   Median Optimized: 8566.81
#   Median Improvement: 12.32%
#
# Case ID: 87
#   Mean Baseline:  34066.96
#   Mean Optimized: 27781.04
#   Mean Improvement: 18.45%
#   Median Baseline:  10215.96
#   Median Optimized: 7598.08
#   Median Improvement: 25.63%
#
# Case ID: 88
#   Mean Baseline:  33490.26
#   Mean Optimized: 13426.13
#   Mean Improvement: 59.91%
#   Median Baseline:  9588.51
#   Median Optimized: 7275.41
#   Median Improvement: 24.12%
#
# Case ID: 89
#   Mean Baseline:  33952.17
#   Mean Optimized: 45509.12
#   Mean Improvement: -34.04%
#   Median Baseline:  9262.10
#   Median Optimized: 68527.05
#   Median Improvement: -639.87%
#
# Case ID: 90
#   Mean Baseline:  45651.93
#   Mean Optimized: 49741.42
#   Mean Improvement: -8.96%
#   Median Baseline:  67213.17
#   Median Optimized: 68026.91
#   Median Improvement: -1.21%
#
# Case ID: 91
#   Mean Baseline:  62118.87
#   Mean Optimized: 67460.66
#   Mean Improvement: -8.60%
#   Median Baseline:  68018.09
#   Median Optimized: 67543.73
#   Median Improvement: 0.70%
#
# Case ID: 92
#   Mean Baseline:  67410.37
#   Mean Optimized: 65792.94
#   Mean Improvement: 2.40%
#   Median Baseline:  65405.68
#   Median Optimized: 65524.25
#   Median Improvement: -0.18%
#
# Case ID: 93
#   Mean Baseline:  67871.10
#   Mean Optimized: 66920.10
#   Mean Improvement: 1.40%
#   Median Baseline:  68026.04
#   Median Optimized: 66184.53
#   Median Improvement: 2.71%
#
# Case ID: 94
#   Mean Baseline:  68375.35
#   Mean Optimized: 67000.81
#   Mean Improvement: 2.01%
#   Median Baseline:  67086.43
#   Median Optimized: 65110.56
#   Median Improvement: 2.95%
#
# Case ID: 95
#   Mean Baseline:  11631.66
#   Mean Optimized: 9760.48
#   Mean Improvement: 16.09%
#   Median Baseline:  10471.80
#   Median Optimized: 9327.44
#   Median Improvement: 10.93%
#
# Case ID: 96
#   Mean Baseline:  10362.32
#   Mean Optimized: 9300.01
#   Mean Improvement: 10.25%
#   Median Baseline:  10181.98
#   Median Optimized: 8986.17
#   Median Improvement: 11.74%
#
# Case ID: 97
#   Mean Baseline:  9285.56
#   Mean Optimized: 9712.10
#   Mean Improvement: -4.59%
#   Median Baseline:  8186.96
#   Median Optimized: 9308.64
#   Median Improvement: -13.70%
#
# Case ID: 98
#   Mean Baseline:  10167.36
#   Mean Optimized: 9159.71
#   Mean Improvement: 9.91%
#   Median Baseline:  8739.58
#   Median Optimized: 9452.04
#   Median Improvement: -8.15%
#
# Case ID: 99
#   Mean Baseline:  34826.20
#   Mean Optimized: 8497.17
#   Mean Improvement: 75.60%
#   Median Baseline:  11711.67
#   Median Optimized: 7443.97
#   Median Improvement: 36.44%
#
# Case ID: 100
#   Mean Baseline:  9016.56
#   Mean Optimized: 10172.73
#   Mean Improvement: -12.82%
#   Median Baseline:  8991.36
#   Median Optimized: 9681.83
#   Median Improvement: -7.68%
#
# Case ID: 101
#   Mean Baseline:  10443.07
#   Mean Optimized: 58237.89
#   Mean Improvement: -457.67%
#   Median Baseline:  10021.08
#   Median Optimized: 11249.12
#   Median Improvement: -12.25%
#
# Case ID: 102
#   Mean Baseline:  82406.73
#   Mean Optimized: 32702.25
#   Mean Improvement: 60.32%
#   Median Baseline:  13033.80
#   Median Optimized: 9103.61
#   Median Improvement: 30.15%
#
# Case ID: 103
#   Mean Baseline:  56509.67
#   Mean Optimized: 104372.88
#   Mean Improvement: -84.70%
#   Median Baseline:  9524.60
#   Median Optimized: 11019.22
#   Median Improvement: -15.69%
#
# Case ID: 104
#   Mean Baseline:  102397.23
#   Mean Optimized: 103142.40
#   Mean Improvement: -0.73%
#   Median Baseline:  9550.55
#   Median Optimized: 9214.19
#   Median Improvement: 3.52%
#
# Case ID: 105
#   Mean Baseline:  125694.93
#   Mean Optimized: 101248.05
#   Mean Improvement: 19.45%
#   Median Baseline:  125790.05
#   Median Optimized: 8990.23
#   Median Improvement: 92.85%
#
# Case ID: 106
#   Mean Baseline:  218115.13
#   Mean Optimized: 171605.94
#   Mean Improvement: 21.32%
#   Median Baseline:  239888.74
#   Median Optimized: 240035.63
#   Median Improvement: -0.06%
#
# Case ID: 107
#   Mean Baseline:  242178.21
#   Mean Optimized: 216661.83
#   Mean Improvement: 10.54%
#   Median Baseline:  242218.53
#   Median Optimized: 240021.58
#   Median Improvement: 0.91%
#
# Case ID: 108
#   Mean Baseline:  241121.97
#   Mean Optimized: 239437.99
#   Mean Improvement: 0.70%
#   Median Baseline:  238420.30
#   Median Optimized: 238536.32
#   Median Improvement: -0.05%
#
# Case ID: 109
#   Mean Baseline:  240156.43
#   Mean Optimized: 239842.34
#   Mean Improvement: 0.13%
#   Median Baseline:  239877.74
#   Median Optimized: 238915.85
#   Median Improvement: 0.40%
#
# Case ID: 110
#   Mean Baseline:  241341.62
#   Mean Optimized: 241439.06
#   Mean Improvement: -0.04%
#   Median Baseline:  239817.94
#   Median Optimized: 240017.31
#   Median Improvement: -0.08%
#
# Case ID: 111
#   Mean Baseline:  9955.95
#   Mean Optimized: 11433.35
#   Mean Improvement: -14.84%
#   Median Baseline:  10207.81
#   Median Optimized: 10301.34
#   Median Improvement: -0.92%
#
# Case ID: 112
#   Mean Baseline:  10813.36
#   Mean Optimized: 10861.19
#   Mean Improvement: -0.44%
#   Median Baseline:  11515.28
#   Median Optimized: 10312.05
#   Median Improvement: 10.45%
#
# Case ID: 113
#   Mean Baseline:  17030.04
#   Mean Optimized: 9916.05
#   Mean Improvement: 41.77%
#   Median Baseline:  9189.09
#   Median Optimized: 8258.61
#   Median Improvement: 10.13%
#
# Case ID: 114
#   Mean Baseline:  10357.88
#   Mean Optimized: 9301.16
#   Mean Improvement: 10.20%
#   Median Baseline:  10095.85
#   Median Optimized: 8145.28
#   Median Improvement: 19.32%
#
# Case ID: 115
#   Mean Baseline:  10197.32
#   Mean Optimized: 17030.41
#   Mean Improvement: -67.01%
#   Median Baseline:  9774.33
#   Median Optimized: 10567.55
#   Median Improvement: -8.12%
#
# Case ID: 116
#   Mean Baseline:  11170.42
#   Mean Optimized: 9105.23
#   Mean Improvement: 18.49%
#   Median Baseline:  10432.00
#   Median Optimized: 8074.59
#   Median Improvement: 22.60%
#
# Case ID: 117
#   Mean Baseline:  23829.00
#   Mean Optimized: 17941.55
#   Mean Improvement: 24.71%
#   Median Baseline:  11857.22
#   Median Optimized: 11396.61
#   Median Improvement: 3.88%
#
# Case ID: 118
#   Mean Baseline:  49655.88
#   Mean Optimized: 9727.44
#   Mean Improvement: 80.41%
#   Median Baseline:  74077.20
#   Median Optimized: 9705.27
#   Median Improvement: 86.90%
#
# Case ID: 119
#   Mean Baseline:  41655.29
#   Mean Optimized: 23533.08
#   Mean Improvement: 43.51%
#   Median Baseline:  40668.56
#   Median Optimized: 9435.73
#   Median Improvement: 76.80%
#
# Case ID: 120
#   Mean Baseline:  29017.39
#   Mean Optimized: 21491.02
#   Mean Improvement: 25.94%
#   Median Baseline:  10179.80
#   Median Optimized: 9478.39
#   Median Improvement: 6.89%
#
# Case ID: 121
#   Mean Baseline:  51513.41
#   Mean Optimized: 58602.23
#   Mean Improvement: -13.76%
#   Median Baseline:  68908.28
#   Median Optimized: 68029.87
#   Median Improvement: 1.27%
#
# Case ID: 122
#   Mean Baseline:  60469.52
#   Mean Optimized: 49850.80
#   Mean Improvement: 17.56%
#   Median Baseline:  71288.49
#   Median Optimized: 65936.15
#   Median Improvement: 7.51%
#
# Case ID: 123
#   Mean Baseline:  72752.30
#   Mean Optimized: 61516.79
#   Mean Improvement: 15.44%
#   Median Baseline:  72558.44
#   Median Optimized: 66566.71
#   Median Improvement: 8.26%
#
# Case ID: 124
#   Mean Baseline:  67892.05
#   Mean Optimized: 67198.83
#   Mean Improvement: 1.02%
#   Median Baseline:  68276.07
#   Median Optimized: 66173.39
#   Median Improvement: 3.08%
#
# Case ID: 125
#   Mean Baseline:  68327.90
#   Mean Optimized: 66501.16
#   Mean Improvement: 2.67%
#   Median Baseline:  67674.75
#   Median Optimized: 64682.87
#   Median Improvement: 4.42%
#
# Case ID: 126
#   Mean Baseline:  69332.75
#   Mean Optimized: 67799.36
#   Mean Improvement: 2.21%
#   Median Baseline:  69270.69
#   Median Optimized: 66883.67
#   Median Improvement: 3.45%
#
# Case ID: 127
#   Mean Baseline:  12801.78
#   Mean Optimized: 17265.39
#   Mean Improvement: -34.87%
#   Median Baseline:  10473.91
#   Median Optimized: 9490.97
#   Median Improvement: 9.38%
#
# Case ID: 128
#   Mean Baseline:  10679.37
#   Mean Optimized: 11077.84
#   Mean Improvement: -3.73%
#   Median Baseline:  11558.90
#   Median Optimized: 9960.62
#   Median Improvement: 13.83%
#
# Case ID: 129
#   Mean Baseline:  13577.03
#   Mean Optimized: 9865.59
#   Mean Improvement: 27.34%
#   Median Baseline:  13476.08
#   Median Optimized: 7870.39
#   Median Improvement: 41.60%
#
# Case ID: 130
#   Mean Baseline:  20202.17
#   Mean Optimized: 9706.84
#   Mean Improvement: 51.95%
#   Median Baseline:  10364.22
#   Median Optimized: 9816.55
#   Median Improvement: 5.28%
#
# Case ID: 131
#   Mean Baseline:  10557.75
#   Mean Optimized: 9088.69
#   Mean Improvement: 13.91%
#   Median Baseline:  10543.07
#   Median Optimized: 9126.97
#   Median Improvement: 13.43%
#
# Case ID: 132
#   Mean Baseline:  23659.84
#   Mean Optimized: 10120.79
#   Mean Improvement: 57.22%
#   Median Baseline:  11806.41
#   Median Optimized: 10428.14
#   Median Improvement: 11.67%
#
# Case ID: 133
#   Mean Baseline:  32277.13
#   Mean Optimized: 9573.44
#   Mean Improvement: 70.34%
#   Median Baseline:  12533.25
#   Median Optimized: 10350.20
#   Median Improvement: 17.42%
#
# Case ID: 134
#   Mean Baseline:  28634.35
#   Mean Optimized: 8536.02
#   Mean Improvement: 70.19%
#   Median Baseline:  11237.81
#   Median Optimized: 7971.67
#   Median Improvement: 29.06%
#
# Case ID: 135
#   Mean Baseline:  43033.29
#   Mean Optimized: 21648.23
#   Mean Improvement: 49.69%
#   Median Baseline:  42362.50
#   Median Optimized: 9992.14
#   Median Improvement: 76.41%
#
# Case ID: 136
#   Mean Baseline:  45534.17
#   Mean Optimized: 32328.98
#   Mean Improvement: 29.00%
#   Median Baseline:  69093.93
#   Median Optimized: 8025.49
#   Median Improvement: 88.38%
#
# Case ID: 137
#   Mean Baseline:  45212.01
#   Mean Optimized: 31463.30
#   Mean Improvement: 30.41%
#   Median Baseline:  68143.70
#   Median Optimized: 7894.52
#   Median Improvement: 88.41%
#
# Case ID: 138
#   Mean Baseline:  63776.92
#   Mean Optimized: 49968.42
#   Mean Improvement: 21.65%
#   Median Baseline:  69915.64
#   Median Optimized: 67218.18
#   Median Improvement: 3.86%
#
# Case ID: 139
#   Mean Baseline:  62231.23
#   Mean Optimized: 62194.61
#   Mean Improvement: 0.06%
#   Median Baseline:  67557.89
#   Median Optimized: 68136.25
#   Median Improvement: -0.86%
#
# Case ID: 140
#   Mean Baseline:  69432.97
#   Mean Optimized: 61238.01
#   Mean Improvement: 11.80%
#   Median Baseline:  70021.08
#   Median Optimized: 67251.55
#   Median Improvement: 3.96%
#
# Case ID: 141
#   Mean Baseline:  71158.32
#   Mean Optimized: 66906.74
#   Mean Improvement: 5.97%
#   Median Baseline:  68566.42
#   Median Optimized: 66269.67
#   Median Improvement: 3.35%
#
# Case ID: 142
#   Mean Baseline:  68198.38
#   Mean Optimized: 64415.68
#   Mean Improvement: 5.55%
#   Median Baseline:  68221.85
#   Median Optimized: 63766.06
#   Median Improvement: 6.53%
#
# Case ID: 143
#   Mean Baseline:  12729.75
#   Mean Optimized: 10955.10
#   Mean Improvement: 13.94%
#   Median Baseline:  13442.06
#   Median Optimized: 9795.92
#   Median Improvement: 27.12%
#
# Case ID: 144
#   Mean Baseline:  12478.30
#   Mean Optimized: 12494.63
#   Mean Improvement: -0.13%
#   Median Baseline:  11211.11
#   Median Optimized: 12731.36
#   Median Improvement: -13.56%
#
# Case ID: 145
#   Mean Baseline:  10219.89
#   Mean Optimized: 10716.39
#   Mean Improvement: -4.86%
#   Median Baseline:  10041.34
#   Median Optimized: 10352.58
#   Median Improvement: -3.10%
#
# Case ID: 146
#   Mean Baseline:  18056.72
#   Mean Optimized: 18259.51
#   Mean Improvement: -1.12%
#   Median Baseline:  10999.16
#   Median Optimized: 11532.63
#   Median Improvement: -4.85%
#
# Case ID: 147
#   Mean Baseline:  16818.69
#   Mean Optimized: 11572.05
#   Mean Improvement: 31.20%
#   Median Baseline:  8175.11
#   Median Optimized: 10167.01
#   Median Improvement: -24.37%
#
# Case ID: 148
#   Mean Baseline:  24056.15
#   Mean Optimized: 10119.48
#   Mean Improvement: 57.93%
#   Median Baseline:  10103.18
#   Median Optimized: 10112.79
#   Median Improvement: -0.10%
#
# Case ID: 149
#   Mean Baseline:  31451.33
#   Mean Optimized: 16417.74
#   Mean Improvement: 47.80%
#   Median Baseline:  11936.02
#   Median Optimized: 10190.89
#   Median Improvement: 14.62%
#
# Case ID: 150
#   Mean Baseline:  30137.10
#   Mean Optimized: 21625.81
#   Mean Improvement: 28.24%
#   Median Baseline:  12607.24
#   Median Optimized: 8790.15
#   Median Improvement: 30.28%
#
# Case ID: 151
#   Mean Baseline:  37524.14
#   Mean Optimized: 22144.30
#   Mean Improvement: 40.99%
#   Median Baseline:  12276.39
#   Median Optimized: 10173.52
#   Median Improvement: 17.13%
#
# Case ID: 152
#   Mean Baseline:  41616.40
#   Mean Optimized: 27613.98
#   Mean Improvement: 33.65%
#   Median Baseline:  40726.02
#   Median Optimized: 10101.72
#   Median Improvement: 75.20%
#
# Case ID: 153
#   Mean Baseline:  33931.44
#   Mean Optimized: 33074.70
#   Mean Improvement: 2.52%
#   Median Baseline:  8342.07
#   Median Optimized: 8989.97
#   Median Improvement: -7.77%
#
# Case ID: 154
#   Mean Baseline:  64329.10
#   Mean Optimized: 51093.51
#   Mean Improvement: 20.57%
#   Median Baseline:  69330.65
#   Median Optimized: 67566.62
#   Median Improvement: 2.54%
#
# Case ID: 155
#   Mean Baseline:  68117.13
#   Mean Optimized: 62063.50
#   Mean Improvement: 8.89%
#   Median Baseline:  67585.12
#   Median Optimized: 67572.96
#   Median Improvement: 0.02%
#
# Case ID: 156
#   Mean Baseline:  65424.46
#   Mean Optimized: 67997.13
#   Mean Improvement: -3.93%
#   Median Baseline:  70761.04
#   Median Optimized: 68413.45
#   Median Improvement: 3.32%
#
# Case ID: 157
#   Mean Baseline:  68894.61
#   Mean Optimized: 67449.46
#   Mean Improvement: 2.10%
#   Median Baseline:  68503.41
#   Median Optimized: 65815.19
#   Median Improvement: 3.92%
#
# Case ID: 158
#   Mean Baseline:  67941.51
#   Mean Optimized: 67593.36
#   Mean Improvement: 0.51%
#   Median Baseline:  68145.79
#   Median Optimized: 68692.40
#   Median Improvement: -0.80%
#
# Case ID: 159
#   Mean Baseline:  14052.06
#   Mean Optimized: 10540.36
#   Mean Improvement: 24.99%
#   Median Baseline:  14096.01
#   Median Optimized: 8577.40
#   Median Improvement: 39.15%
#
# Case ID: 160
#   Mean Baseline:  12511.73
#   Mean Optimized: 9901.42
#   Mean Improvement: 20.86%
#   Median Baseline:  11284.05
#   Median Optimized: 8684.10
#   Median Improvement: 23.04%
#
# Case ID: 161
#   Mean Baseline:  14308.65
#   Mean Optimized: 9959.91
#   Mean Improvement: 30.39%
#   Median Baseline:  13416.05
#   Median Optimized: 9668.52
#   Median Improvement: 27.93%
#
# Case ID: 162
#   Mean Baseline:  11712.32
#   Mean Optimized: 17164.25
#   Mean Improvement: -46.55%
#   Median Baseline:  12540.64
#   Median Optimized: 9378.74
#   Median Improvement: 25.21%
#
# Case ID: 163
#   Mean Baseline:  17737.04
#   Mean Optimized: 10615.68
#   Mean Improvement: 40.15%
#   Median Baseline:  11045.29
#   Median Optimized: 9922.72
#   Median Improvement: 10.16%
#
# Case ID: 164
#   Mean Baseline:  11573.96
#   Mean Optimized: 10685.14
#   Mean Improvement: 7.68%
#   Median Baseline:  10559.72
#   Median Optimized: 10442.62
#   Median Improvement: 1.11%
#
# Case ID: 165
#   Mean Baseline:  24219.05
#   Mean Optimized: 10096.33
#   Mean Improvement: 58.31%
#   Median Baseline:  12070.05
#   Median Optimized: 9792.38
#   Median Improvement: 18.87%
#
# Case ID: 166
#   Mean Baseline:  16208.21
#   Mean Optimized: 9926.15
#   Mean Improvement: 38.76%
#   Median Baseline:  9453.12
#   Median Optimized: 10052.40
#   Median Improvement: -6.34%
#
# Case ID: 167
#   Mean Baseline:  35466.02
#   Mean Optimized: 21051.94
#   Mean Improvement: 40.64%
#   Median Baseline:  11117.09
#   Median Optimized: 9125.93
#   Median Improvement: 17.91%
#
# Case ID: 168
#   Mean Baseline:  45597.40
#   Mean Optimized: 47665.31
#   Mean Improvement: -4.54%
#   Median Baseline:  68864.32
#   Median Optimized: 70375.68
#   Median Improvement: -2.19%
#
# Case ID: 169
#   Mean Baseline:  52176.34
#   Mean Optimized: 39799.05
#   Mean Improvement: 23.72%
#   Median Baseline:  69754.56
#   Median Optimized: 38263.56
#   Median Improvement: 45.15%
#
# Case ID: 170
#   Mean Baseline:  57443.61
#   Mean Optimized: 64719.55
#   Mean Improvement: -12.67%
#   Median Baseline:  68385.86
#   Median Optimized: 70597.73
#   Median Improvement: -3.23%
#
# Case ID: 171
#   Mean Baseline:  69804.72
#   Mean Optimized: 61762.66
#   Mean Improvement: 11.52%
#   Median Baseline:  69316.37
#   Median Optimized: 67257.42
#   Median Improvement: 2.97%
#
# Case ID: 172
#   Mean Baseline:  69078.73
#   Mean Optimized: 68321.09
#   Mean Improvement: 1.10%
#   Median Baseline:  68706.82
#   Median Optimized: 68829.37
#   Median Improvement: -0.18%
#
# Case ID: 173
#   Mean Baseline:  67597.09
#   Mean Optimized: 66784.21
#   Mean Improvement: 1.20%
#   Median Baseline:  68215.68
#   Median Optimized: 66639.57
#   Median Improvement: 2.31%
#
# Case ID: 174
#   Mean Baseline:  69050.08
#   Mean Optimized: 67926.68
#   Mean Improvement: 1.63%
#   Median Baseline:  68998.38
#   Median Optimized: 67607.92
#   Median Improvement: 2.02%
#
# Case ID: 175
#   Mean Baseline:  10366.41
#   Mean Optimized: 10951.84
#   Mean Improvement: -5.65%
#   Median Baseline:  9117.05
#   Median Optimized: 11179.20
#   Median Improvement: -22.62%
#
# Case ID: 176
#   Mean Baseline:  10640.23
#   Mean Optimized: 9991.42
#   Mean Improvement: 6.10%
#   Median Baseline:  9554.04
#   Median Optimized: 9069.17
#   Median Improvement: 5.07%
#
# Case ID: 177
#   Mean Baseline:  9298.86
#   Mean Optimized: 35271.54
#   Mean Improvement: -279.31%
#   Median Baseline:  8801.71
#   Median Optimized: 10478.18
#   Median Improvement: -19.05%
#
# Case ID: 178
#   Mean Baseline:  11438.06
#   Mean Optimized: 10475.83
#   Mean Improvement: 8.41%
#   Median Baseline:  11830.01
#   Median Optimized: 11416.00
#   Median Improvement: 3.50%
#
# Case ID: 179
#   Mean Baseline:  9091.93
#   Mean Optimized: 9001.60
#   Mean Improvement: 0.99%
#   Median Baseline:  8407.96
#   Median Optimized: 8798.79
#   Median Improvement: -4.65%
#
# Case ID: 180
#   Mean Baseline:  58560.47
#   Mean Optimized: 10073.62
#   Mean Improvement: 82.80%
#   Median Baseline:  12299.70
#   Median Optimized: 10109.14
#   Median Improvement: 17.81%
#
# Case ID: 181
#   Mean Baseline:  10294.73
#   Mean Optimized: 35436.67
#   Mean Improvement: -244.22%
#   Median Baseline:  9213.58
#   Median Optimized: 12565.16
#   Median Improvement: -36.38%
#
# Case ID: 182
#   Mean Baseline:  81727.06
#   Mean Optimized: 33940.66
#   Mean Improvement: 58.47%
#   Median Baseline:  13392.91
#   Median Optimized: 9818.13
#   Median Improvement: 26.69%
#
# Case ID: 183
#   Mean Baseline:  79421.04
#   Mean Optimized: 33090.29
#   Mean Improvement: 58.34%
#   Median Baseline:  9681.75
#   Median Optimized: 10038.45
#   Median Improvement: -3.68%
#
# Case ID: 184
#   Mean Baseline:  102092.48
#   Mean Optimized: 125271.46
#   Mean Improvement: -22.70%
#   Median Baseline:  9510.14
#   Median Optimized: 125554.64
#   Median Improvement: -1220.22%
#
# Case ID: 185
#   Mean Baseline:  150370.23
#   Mean Optimized: 125014.58
#   Mean Improvement: 16.86%
#   Median Baseline:  240206.11
#   Median Optimized: 124999.82
#   Median Improvement: 47.96%
#
# Case ID: 186
#   Mean Baseline:  196389.61
#   Mean Optimized: 170101.56
#   Mean Improvement: 13.39%
#   Median Baseline:  240001.17
#   Median Optimized: 238425.99
#   Median Improvement: 0.66%
#
# Case ID: 187
#   Mean Baseline:  242039.85
#   Mean Optimized: 240274.22
#   Mean Improvement: 0.73%
#   Median Baseline:  240101.39
#   Median Optimized: 240028.44
#   Median Improvement: 0.03%
#
# Case ID: 188
#   Mean Baseline:  241833.71
#   Mean Optimized: 238700.94
#   Mean Improvement: 1.30%
#   Median Baseline:  241655.12
#   Median Optimized: 239066.47
#   Median Improvement: 1.07%
#
# Case ID: 189
#   Mean Baseline:  240899.82
#   Mean Optimized: 239147.24
#   Mean Improvement: 0.73%
#   Median Baseline:  239326.52
#   Median Optimized: 237980.61
#   Median Improvement: 0.56%
#
# Case ID: 190
#   Mean Baseline:  240836.06
#   Mean Optimized: 239552.65
#   Mean Improvement: 0.53%
#   Median Baseline:  240056.12
#   Median Optimized: 239691.30
#   Median Improvement: 0.15%
#
# Case ID: 191
#   Mean Baseline:  18418.53
#   Mean Optimized: 8549.54
#   Mean Improvement: 53.58%
#   Median Baseline:  10749.71
#   Median Optimized: 8241.89
#   Median Improvement: 23.33%
#
# Case ID: 192
#   Mean Baseline:  12467.81
#   Mean Optimized: 7517.98
#   Mean Improvement: 39.70%
#   Median Baseline:  11980.71
#   Median Optimized: 7401.40
#   Median Improvement: 38.22%
#
# Case ID: 193
#   Mean Baseline:  17958.73
#   Mean Optimized: 7606.51
#   Mean Improvement: 57.64%
#   Median Baseline:  10526.49
#   Median Optimized: 7003.20
#   Median Improvement: 33.47%
#
# Case ID: 194
#   Mean Baseline:  10933.37
#   Mean Optimized: 9523.85
#   Mean Improvement: 12.89%
#   Median Baseline:  10624.77
#   Median Optimized: 9673.49
#   Median Improvement: 8.95%
#
# Case ID: 195
#   Mean Baseline:  11830.43
#   Mean Optimized: 9323.76
#   Mean Improvement: 21.19%
#   Median Baseline:  12514.13
#   Median Optimized: 9154.78
#   Median Improvement: 26.84%
#
# Case ID: 196
#   Mean Baseline:  11624.23
#   Mean Optimized: 9395.29
#   Mean Improvement: 19.17%
#   Median Baseline:  10703.17
#   Median Optimized: 8547.16
#   Median Improvement: 20.14%
#
# Case ID: 197
#   Mean Baseline:  10791.96
#   Mean Optimized: 11344.90
#   Mean Improvement: -5.12%
#   Median Baseline:  10743.84
#   Median Optimized: 12316.22
#   Median Improvement: -14.64%
#
# Case ID: 198
#   Mean Baseline:  42605.45
#   Mean Optimized: 8872.56
#   Mean Improvement: 79.18%
#   Median Baseline:  43835.06
#   Median Optimized: 9306.78
#   Median Improvement: 78.77%
#
# Case ID: 199
#   Mean Baseline:  34663.62
#   Mean Optimized: 9868.49
#   Mean Improvement: 71.53%
#   Median Baseline:  12038.65
#   Median Optimized: 10726.82
#   Median Improvement: 10.90%
#
# ========================================
# Overall Mean Improvement:   12.04%
# Overall Median Improvement: 5.18%
# ========================================

# %%
c = 0
tc = 0
for k,v in case_improvements.items():
    if v < 0:
        print(k,v)
        c=c+1
    tc = tc + 1
print(f"Total problematic cases {c}")
print(f"Total cases {tc}")
# Out:
# (0, 2) -73.65859282472478
# (0, 3) -62.06380556591306
# (0, 4) -142.5238444640616
# (0, 5) -15.329876726745914
# (0, 6) -7.67842260803399
# (0, 7) -72.86502450509045
# (0, 8) -1361.7046349748225
# (0, 9) -928.8152319692738
# (0, 10) -828.8260879481094
# (0, 14) -1.0727054522686137
# (0, 16) -39.48146639294299
# (0, 18) -27.032818005075
# (0, 25) -3883.459463336321
# (0, 27) -2.3447385475862816
# (0, 28) -5.348311957905844
# (0, 30) -1.2028895094878982
# (0, 31) -45.50651214112711
# (0, 35) -32.48100682026206
# (0, 40) -17.269655896066396
# (0, 41) -0.13627231416419627
# (0, 43) -1.2410814784860942
# (0, 44) -1.626849973281382
# (0, 45) -1.1380447285674773
# (0, 49) -84.82406179363919
# (0, 52) -37.99676633659143
# (0, 54) -1154.1733505557484
# (0, 56) -0.8779382459129762
# (0, 58) -1.5567402795402223
# (0, 59) -10.597193839604161
# (0, 60) -4.594865102244207
# (0, 61) -1.564688468829277
# (0, 64) -18.78575087700633
# (0, 66) -47.47788741849631
# (0, 74) -3.7873173560858215
# (0, 75) -1288.7697844881159
# (0, 78) -0.7640885540243437
# (0, 80) -4.238622500657513
# (0, 81) -81.89725221702064
# (0, 84) -3.3000642051110827
# (0, 85) -5.167472675175095
# (0, 86) -3.210974589764956
# (0, 89) -35.83424743111467
# (0, 92) -3.746388489157229
# (0, 93) -0.7900075181253577
# (0, 97) -175.22136793161062
# (0, 100) -13.3170167407522
# (0, 101) -17.728263460632075
# (0, 102) -11.122148769148328
# (0, 103) -3.6325032354404505
# (0, 104) -2418.4866027432145
# (0, 105) -99.40497447659176
# (0, 107) -2.0053631340640634
# (0, 108) -0.142027820187938
# (0, 109) -1.233194712204012
# (0, 110) -0.5553077467156357
# (0, 111) -51.74205661955593
# (0, 112) -119.70802598521331
# (0, 113) -136.9221728703631
# (0, 119) -74.03071761875128
# (0, 121) -1009.740481710936
# (0, 122) -6.975232824261739
# (0, 124) -5.1364256256322935
# (0, 127) -24.196897942534132
# (0, 128) -159.7341187942722
# (0, 130) -18.125369453523124
# (0, 136) -1.5204952395130382
# (0, 137) -0.563754108967134
# (0, 138) -5.087216341006733
# (0, 141) -11.498770138532223
# (0, 143) -31.490456381977676
# (0, 144) -52.26597062466646
# (0, 145) -1.4573283064247367
# (0, 146) -122.01808916373882
# (0, 147) -14.236543030663828
# (0, 150) -445.37192601811
# (0, 151) -0.6409530120981396
# (0, 154) -1151.2228887146753
# (0, 164) -24.302039065610998
# (0, 168) -588.3455311238991
# (0, 169) -12.021702970810743
# (0, 172) -7.787981463063678
# (0, 176) -54.61337645367404
# (0, 178) -32.01815805126039
# (0, 180) -44.445375588307975
# (0, 181) -30.423715589257235
# (0, 183) -48.336925113496
# (0, 188) -0.09418460959867915
# (0, 191) -17.900054342773096
# (0, 193) -20.663702572648134
# (1, 0) -27.92139361990297
# (1, 3) -48.44677499098028
# (1, 4) -9.979791743864705
# (1, 5) -31.3094393889094
# (1, 6) -8.74723868365938
# (1, 14) -3.1176535435655626
# (1, 16) -31.270461810860994
# (1, 18) -85.50137085444737
# (1, 19) -77.21847792650944
# (1, 20) -44.190764200482704
# (1, 21) -36.828488787302256
# (1, 22) -241.99659115072643
# (1, 25) -3.141260032752908
# (1, 30) -1.4775019924129926
# (1, 31) -16.416922991865622
# (1, 32) -216.0764089258958
# (1, 33) -817.2457982407707
# (1, 34) -450.97092304206103
# (1, 37) -11.57661203379879
# (1, 38) -51.90554889251878
# (1, 39) -119.78777741134243
# (1, 40) -679.7479720183115
# (1, 42) -1085.2768565505844
# (1, 44) -3.8641182541466894
# (1, 46) -1.0283745075277226
# (1, 47) -42.74603402980213
# (1, 48) -129.32495587256793
# (1, 50) -11.377157239049582
# (1, 51) -4.424872918914465
# (1, 52) -20.784355906350562
# (1, 55) -5.997543250247988
# (1, 57) -3.658418265020534
# (1, 59) -1.7452440440042076
# (1, 60) -1.9316198487831184
# (1, 61) -6.995538066569239
# (1, 63) -61.15355792099664
# (1, 65) -36.7743118879721
# (1, 67) -33.757390619389184
# (1, 72) -920.229467387847
# (1, 73) -914.3712787250154
# (1, 77) -3.135040961526426
# (1, 80) -4.307261176998888
# (1, 84) -18.169731216571254
# (1, 85) -10.090719868735574
# (1, 89) -0.3284090481295998
# (1, 90) -3.529588322586764
# (1, 94) -1.3809689555535072
# (1, 95) -63.900129627129644
# (1, 97) -82.52397372807364
# (1, 98) -19.940644859605637
# (1, 100) -21.675245174568914
# (1, 103) -41.02941923817433
# (1, 108) -0.26972285370681787
# (1, 111) -111.51011393148681
# (1, 113) -191.5762176450221
# (1, 114) -11.346524993823127
# (1, 117) -25.392012143751657
# (1, 124) -3.472486777930324
# (1, 127) -6.407867002045808
# (1, 128) -16.994999527320505
# (1, 137) -692.079325120601
# (1, 138) -1293.3935176381904
# (1, 139) -1.3152698982857525
# (1, 140) -10.090774378853592
# (1, 143) -6.509033250516448
# (1, 144) -38.60928403365728
# (1, 146) -601.1361524758836
# (1, 147) -77.09895429303052
# (1, 148) -33.166601400138966
# (1, 149) -39.64628934371199
# (1, 150) -8.734003683908806
# (1, 153) -2.9209014144050536
# (1, 155) -1.7339499034521737
# (1, 158) -1.467649090210393
# (1, 163) -100.29345605345638
# (1, 164) -80.8134835261482
# (1, 165) -75.75794953942923
# (1, 166) -12.46338715382569
# (1, 168) -6.850676907890121
# (1, 169) -13.811214416596837
# (1, 170) -4.277863428950232
# (1, 175) -78.2624233731036
# (1, 176) -42.22928701648464
# (1, 177) -31.40950891030777
# (1, 178) -72.59458562435654
# (1, 179) -83.63939637035145
# (1, 181) -1853.3360269298348
# (1, 185) -2686.266708821005
# (1, 190) -0.3990714478117288
# (1, 198) -14.975547763806036
# (1, 199) -26.157148832389403
# (2, 2) -69.73850739245248
# (2, 3) -65.20102256688901
# (2, 4) -8.565408282165722
# (2, 6) -83.58155541560076
# (2, 7) -14.197570480400087
# (2, 9) -963.1783258682693
# (2, 12) -0.6520689817075349
# (2, 14) -1.8496420951812964
# (2, 17) -9.445458755193142
# (2, 22) -31.65622355553867
# (2, 24) -23.31109627273572
# (2, 28) -1.824008524318011
# (2, 30) -0.8332362170627805
# (2, 31) -120.38546842867078
# (2, 32) -45.49811496163806
# (2, 33) -149.17336068517596
# (2, 34) -393.1598542279369
# (2, 35) -8.877379894239096
# (2, 36) -900.5593168648955
# (2, 37) -790.5570543133796
# (2, 39) -0.6480253457194218
# (2, 40) -2.731681329234823
# (2, 41) -874.1709770819261
# (2, 42) -1.4560053696825686
# (2, 44) -7.746943538131365
# (2, 48) -83.82169769280756
# (2, 51) -8.339953137604258
# (2, 52) -51.9391391752295
# (2, 56) -533.6704039507263
# (2, 58) -857.2551054808691
# (2, 59) -1054.1510283091675
# (2, 62) -4.584633462507385
# (2, 64) -10.089219730668985
# (2, 65) -85.48462396324271
# (2, 68) -5.420401707783722
# (2, 70) -20.710889665304894
# (2, 72) -530.5817172212417
# (2, 77) -4.440986105769926
# (2, 78) -8.22902614532221
# (2, 80) -28.88151808825807
# (2, 82) -6.699696016257471
# (2, 83) -67.24219377149463
# (2, 84) -7.956113429387898
# (2, 85) -4.579092018553841
# (2, 93) -0.44189926392183104
# (2, 97) -30.321472338590855
# (2, 100) -140.04295605045394
# (2, 101) -2424.0073371770395
# (2, 102) -1697.0811590888231
# (2, 104) -2637.1239574310375
# (2, 111) -34.290977072173796
# (2, 112) -39.43241461316211
# (2, 114) -27.220970221060238
# (2, 115) -169.21352332506575
# (2, 116) -67.38983480333994
# (2, 120) -800.1991527000869
# (2, 121) -28.402685149864364
# (2, 126) -4.46814378452852
# (2, 129) -43.57548207562117
# (2, 133) -33.500198362265145
# (2, 145) -19.56006221122176
# (2, 146) -7.6249820984936285
# (2, 147) -12.145650688463135
# (2, 148) -24.13285064850719
# (2, 149) -11.562476103835289
# (2, 152) -27.44764300015172
# (2, 153) -18.68802113933966
# (2, 158) -6.517405488378884
# (2, 165) -26.78016320402112
# (2, 168) -8.396358498862762
# (2, 170) -9.163564538006426
# (2, 172) -10.617215568682303
# (2, 173) -6.200502898290347
# (2, 176) -158.78969958078898
# (2, 177) -1685.7600198093405
# (2, 181) -63.52290639230276
# (2, 182) -2110.6595097750424
# (2, 186) -1.4187708732088535
# (2, 187) -0.9298070171982684
# (2, 188) -1.3099478722364082
# (2, 189) -1.0518799127430383
# (2, 190) -0.1475524254667321
# (2, 193) -33.238254580361634
# (2, 197) -98.05153956378112
# (2, 199) -11.77556019633806
# (3, 0) -48.0385501503263
# (3, 3) -142.66039160456518
# (3, 12) -0.9574931615926975
# (3, 13) -9.436443665804271
# (3, 14) -3.3885099955907583
# (3, 17) -7.399950565720667
# (3, 19) -65.13800476803253
# (3, 20) -44.9620416416606
# (3, 22) -3.403087685125423
# (3, 23) -10.949043173242497
# (3, 24) -4.66261919739208
# (3, 27) -1.877615115740745
# (3, 28) -0.11532336643182138
# (3, 29) -0.9647982147456451
# (3, 30) -1.7672690880418906
# (3, 31) -19.884542220616574
# (3, 33) -5.729030576524281
# (3, 35) -11.340235341481785
# (3, 39) -98.32573990601043
# (3, 40) -6.744096119515583
# (3, 44) -11.537145713982543
# (3, 46) -9.191499793732302
# (3, 48) -28.583764885631446
# (3, 50) -12.663731277087804
# (3, 54) -48.22757472105479
# (3, 55) -641.238262777786
# (3, 58) -996.0178537822331
# (3, 61) -4.304274275368548
# (3, 64) -10.939153697921673
# (3, 66) -37.30496145377587
# (3, 69) -2.640530963676653
# (3, 70) -4.105422227632428
# (3, 72) -606.9365885417855
# (3, 73) -723.3884576783004
# (3, 74) -5.058947463039868
# (3, 77) -10.285447313801596
# (3, 79) -7.611650396898129
# (3, 82) -6.378853160406697
# (3, 90) -1270.229380136638
# (3, 93) -2.093489697664269
# (3, 96) -42.025963168508326
# (3, 97) -41.59228930158859
# (3, 98) -2.675060274638015
# (3, 104) -61.87712095809711
# (3, 106) -0.8278230400423492
# (3, 107) -0.354948896479717
# (3, 113) -14.222410858420165
# (3, 118) -23.9627454079929
# (3, 119) -54.529327411086534
# (3, 122) -0.3422566238604086
# (3, 123) -1.2018292601527327
# (3, 125) -1.9885476923188996
# (3, 129) -8.273524745770441
# (3, 130) -25.935404732493406
# (3, 133) -15.463570930865114
# (3, 134) -21.03703528988238
# (3, 144) -27.158165794353383
# (3, 150) -10.249933186681142
# (3, 153) -936.0850347741107
# (3, 154) -18.620716221269053
# (3, 155) -6.922937722849438
# (3, 157) -2.8585724933619447
# (3, 159) -4.379305819448756
# (3, 160) -12.915136939694227
# (3, 162) -148.95029939088502
# (3, 166) -9.425228086286197
# (3, 168) -1183.8408552690817
# (3, 173) -2.441519056762795
# (3, 175) -65.11938410801388
# (3, 176) -27.937169486031006
# (3, 177) -42.86009585939472
# (3, 179) -15.162725349059384
# (3, 181) -94.81646547990775
# (3, 186) -0.018240594323964115
# (3, 187) -0.13926926284352
# (3, 190) -0.6261525782578305
# (3, 192) -6.017573354989347
# (3, 196) -0.21168977894156019
# (3, 197) -18.40013632295153
# (3, 198) -24.489926707537432
# (3, 199) -23.747335094986074
# (4, 3) -95.16392576642343
# (4, 6) -58.99039096892983
# (4, 8) -5.316264024320464
# (4, 10) -779.5428732307172
# (4, 14) -7.414669056047897
# (4, 15) -289.28845485379907
# (4, 19) -24.79235789425624
# (4, 21) -57.64569173072979
# (4, 28) -0.9756211523485109
# (4, 30) -1.7936694684169763
# (4, 34) -49.36730930216869
# (4, 37) -14.704075628418472
# (4, 41) -11.94739707678273
# (4, 42) -2.242654195140255
# (4, 43) -3.20368845239594
# (4, 44) -9.107378889349057
# (4, 46) -0.10771297258250093
# (4, 48) -18.50790394730174
# (4, 55) -19.565003355515813
# (4, 62) -4.415453540984833
# (4, 66) -14.88571845454609
# (4, 67) -30.68752597265783
# (4, 73) -5.221946501712362
# (4, 78) -9.770051384831547
# (4, 80) -9.34664201276189
# (4, 86) -7.825953995904035
# (4, 89) -644.8582975645974
# (4, 90) -1290.849092144506
# (4, 91) -2.0346901496772833
# (4, 92) -5.4716699555555515
# (4, 93) -0.19211936673820423
# (4, 94) -26.22194625784206
# (4, 96) -2.0991427839388526
# (4, 97) -56.75747420203435
# (4, 103) -2784.7138259542858
# (4, 105) -12.47633959580094
# (4, 106) -3731.5418381733343
# (4, 108) -1.2284482081211068
# (4, 110) -2.389570403476264
# (4, 111) -32.06117940236566
# (4, 113) -0.5413939256341532
# (4, 114) -113.47263932415046
# (4, 115) -4.5379860554432225
# (4, 117) -23.42172150910226
# (4, 118) -93.37848045383554
# (4, 129) -30.791658113928595
# (4, 131) -41.55588432541633
# (4, 132) -57.608018290743225
# (4, 133) -9.392883548357842
# (4, 141) -4.040223263730955
# (4, 143) -32.182770041325284
# (4, 144) -120.26243538741493
# (4, 145) -49.38241765504866
# (4, 146) -92.00329609625513
# (4, 147) -52.752763831263714
# (4, 148) -5.39671264790832
# (4, 150) -479.845803307619
# (4, 151) -10.035802517808811
# (4, 153) -806.717310199403
# (4, 154) -5.462144147815313
# (4, 155) -10.277309442694744
# (4, 156) -8.984466127416347
# (4, 158) -9.931952340925369
# (4, 159) -12.26598717819662
# (4, 160) -33.19189899644089
# (4, 163) -0.24899235162078645
# (4, 165) -10.680743788447938
# (4, 166) -84.07089120531491
# (4, 168) -47.49785273915969
# (4, 178) -7.572592536136293
# (4, 182) -8.499656498525335
# (4, 187) -1.8949011300824037
# (4, 188) -1.3509487690809288
# (4, 190) -0.0688161564680695
# (4, 191) -2.4786549368124056
# (4, 193) -49.18494151336941
# (4, 194) -37.430558655799835
# (4, 195) -35.40178769535485
# (4, 198) -10.336157881989234
# (4, 199) -291.94808024353654
# (5, 3) -49.96054889932536
# (5, 7) -39.03447938306601
# (5, 10) -4.317017608256022
# (5, 13) -2.999518799019605
# (5, 18) -30.123356967632237
# (5, 25) -3171.3756655453453
# (5, 35) -9.32050561413837
# (5, 37) -12.669166616998195
# (5, 38) -10.133549691422196
# (5, 39) -34.304096541683606
# (5, 40) -32.24657735582594
# (5, 41) -800.9404102874464
# (5, 42) -875.2081572678691
# (5, 44) -1549.1217847513924
# (5, 45) -1.2014806146890904
# (5, 48) -3.253204066517505
# (5, 51) -18.940758598838904
# (5, 54) -24.711369481353877
# (5, 56) -111.54794890495279
# (5, 58) -1115.7167728069917
# (5, 59) -5.723281692246196
# (5, 60) -17.096866412261395
# (5, 61) -4.145837093745051
# (5, 63) -138.82753878013173
# (5, 64) -81.36389150896466
# (5, 66) -17.105895543085
# (5, 70) -26.738006907314098
# (5, 72) -1000.6479250694699
# (5, 73) -6.380328179566369
# (5, 76) -4.670871852446612
# (5, 77) -7.640253235082463
# (5, 78) -13.614848226998284
# (5, 82) -41.87702832504351
# (5, 85) -118.3598131601548
# (5, 86) -86.82408305020576
# (5, 87) -685.7516543375189
# (5, 89) -659.6074481843971
# (5, 90) -813.9023169503575
# (5, 91) -1.9456005385802402
# (5, 93) -3.40913428478186
# (5, 95) -65.72830453302002
# (5, 96) -20.93848745261247
# (5, 99) -12.02940003925636
# (5, 100) -20.36184193367073
# (5, 101) -2035.3627506168784
# (5, 103) -5.815094056255116
# (5, 105) -5029.477942230387
# (5, 110) -1.1098303668666545
# (5, 111) -52.307200268969154
# (5, 114) -6.060492900059254
# (5, 115) -225.9115640691166
# (5, 116) -111.0606563441149
# (5, 117) -4.014724548222018
# (5, 119) -2.576058924360641
# (5, 120) -10.226836019907386
# (5, 121) -1813.4728416389898
# (5, 130) -68.62246860152212
# (5, 132) -170.3843631308583
# (5, 134) -38.93221482328388
# (5, 135) -63.38880825416331
# (5, 136) -694.1823890397889
# (5, 138) -5.047777014566234
# (5, 139) -7.293469113095889
# (5, 141) -3.903917316168956
# (5, 142) -1.9669630976040693
# (5, 144) -393.5939938443804
# (5, 145) -107.86063023507542
# (5, 146) -47.678259363933265
# (5, 147) -100.46327952551168
# (5, 148) -25.03176505876822
# (5, 149) -740.5010352757569
# (5, 150) -9.024166339966262
# (5, 154) -1.6577210678732988
# (5, 156) -6.135358161198161
# (5, 164) -16.62808051752755
# (5, 167) -5.118454266092781
# (5, 172) -3.6751683246882374
# (5, 177) -75.53240881264584
# (5, 179) -74.27310699117899
# (5, 180) -115.37996267216232
# (5, 189) -0.21255162985091158
# (5, 197) -44.36663699480839
# (6, 3) -5.238851489167552
# (6, 4) -66.32009086183167
# (6, 8) -2.2415170336153922
# (6, 12) -0.36152785334315013
# (6, 24) -42.222026182761795
# (6, 25) -0.607876570868012
# (6, 26) -3149.2054583537297
# (6, 28) -0.8122140977904104
# (6, 35) -17.1626448876596
# (6, 36) -15.200303229023454
# (6, 37) -17.5196678922575
# (6, 38) -9.446274913085734
# (6, 41) -2.7317587037281097
# (6, 42) -3.7465084997757545
# (6, 43) -3.9959736489095543
# (6, 44) -0.6004987434700815
# (6, 54) -120.35924001377303
# (6, 55) -629.4173834639937
# (6, 56) -12.688431369686565
# (6, 58) -11.734988987497003
# (6, 63) -149.5458473644392
# (6, 67) -103.41299698988806
# (6, 68) -39.12375083190887
# (6, 70) -6.080502466284651
# (6, 71) -30.68931355084977
# (6, 72) -13.225057976246626
# (6, 74) -60.31470004871282
# (6, 76) -2.0326650976348155
# (6, 80) -3.876666550522613
# (6, 81) -4.151464208134971
# (6, 83) -57.95712265466919
# (6, 85) -3.427726592992063
# (6, 93) -2.479068027064924
# (6, 95) -138.42445573509872
# (6, 108) -1.4731129530262017
# (6, 110) -0.6048830623288787
# (6, 111) -75.96517590230438
# (6, 112) -21.5435293359454
# (6, 114) -26.447212812843198
# (6, 115) -16.91336566551186
# (6, 121) -18.54645784161294
# (6, 125) -12.533855363171392
# (6, 126) -17.120435030310258
# (6, 127) -1529.3005943405285
# (6, 128) -328.13990317130003
# (6, 130) -5.208778504709054
# (6, 131) -42.16996211901879
# (6, 132) -137.9779285946553
# (6, 134) -67.79835181209552
# (6, 135) -64.6557658027373
# (6, 137) -2296.1703677628325
# (6, 139) -3.7171962868216966
# (6, 140) -5.109784504702497
# (6, 141) -0.8289645374742199
# (6, 143) -5.816316255566358
# (6, 147) -86.1772220712129
# (6, 157) -0.5565928254010517
# (6, 166) -45.83938464022948
# (6, 175) -53.12419362026856
# (6, 176) -99.35503534603694
# (6, 177) -258.1969085365135
# (6, 178) -1.9339023686756398
# (6, 182) -62.52277521983574
# (6, 183) -2426.771003779655
# (6, 184) -17.04713876773405
# (6, 185) -1.9594243745445141
# (6, 191) -1.5553575786218405
# (6, 197) -49.90117166597101
# (7, 4) -12.249715670216418
# (7, 10) -0.19919286480806148
# (7, 13) -10.469925019311097
# (7, 14) -5.38787928643485
# (7, 22) -22.152655300948688
# (7, 25) -1.3223881311288659
# (7, 30) -0.04120219646777991
# (7, 35) -5.6679796148055415
# (7, 40) -0.9495203973483844
# (7, 43) -5.694404002179148
# (7, 44) -4.381660747929271
# (7, 45) -10.465883250630418
# (7, 47) -16.239484537222012
# (7, 48) -36.05052334082672
# (7, 51) -78.08005737628939
# (7, 52) -3.188930071703952
# (7, 53) -2051.1102034094383
# (7, 60) -9.97768510709487
# (7, 66) -25.277637238951456
# (7, 67) -80.15665314495335
# (7, 68) -7.762601825359935
# (7, 70) -470.181615806546
# (7, 72) -31.067074997785603
# (7, 85) -57.26405458256999
# (7, 88) -55.75835458777736
# (7, 91) -1148.6646956186773
# (7, 96) -6.189196245214594
# (7, 97) -73.95920446247848
# (7, 99) -21.823512843907686
# (7, 100) -39.74570505092041
# (7, 102) -41.22350469328222
# (7, 103) -2200.7449637982295
# (7, 104) -2.162844491200308
# (7, 106) -0.5991951460482856
# (7, 108) -0.8240334473454316
# (7, 109) -1.7513465879238441
# (7, 112) -15.286719430608114
# (7, 115) -11.164489280795408
# (7, 117) -12.849183624139817
# (7, 118) -75.75728520086345
# (7, 120) -1280.3946281456574
# (7, 121) -2.5822294857666432
# (7, 132) -44.45742355902648
# (7, 136) -0.6776819805840247
# (7, 137) -2.518159666024097
# (7, 139) -1187.7338084452294
# (7, 140) -2.7748210742183126
# (7, 145) -8.895291924968435
# (7, 147) -31.703892844899627
# (7, 151) -840.7369241449335
# (7, 152) -1.916465563815269
# (7, 155) -1.6863929112860436
# (7, 157) -9.24809612753597
# (7, 158) -2.8323988876048145
# (7, 167) -31.78513265732746
# (7, 170) -15.717285586761948
# (7, 171) -2.3993833091843766
# (7, 174) -20.406326047242967
# (7, 175) -3.2435287561218975
# (7, 177) -10.956685432984711
# (7, 179) -41.64266672787574
# (7, 180) -7.165378147500591
# (7, 181) -212.83897870967024
# (7, 183) -63.51450756978533
# (7, 184) -1.412205651095062
# (7, 185) -0.3676152649357981
# (7, 186) -3162.2046885572504
# (7, 187) -0.12124028835871158
# (7, 194) -25.950356078267152
# (7, 195) -79.20080100379023
# (8, 0) -48.654429992343886
# (8, 2) -118.33663255171368
# (8, 3) -276.00885270504887
# (8, 4) -149.9228112127032
# (8, 5) -27.462765553503232
# (8, 6) -39.96064117241801
# (8, 7) -13.132099043471952
# (8, 8) -692.3294373550149
# (8, 10) -1.0179984916620664
# (8, 11) -9.936392331208353
# (8, 17) -1.0022356110436397
# (8, 18) -19.964248322223227
# (8, 19) -96.59672583800659
# (8, 22) -2677.4851443656935
# (8, 23) -6.269837245987022
# (8, 24) -3372.9203139398114
# (8, 25) -6.8479165895780705
# (8, 26) -21.678989435943123
# (8, 29) -2.7533587228997662
# (8, 31) -20.29821277037715
# (8, 32) -19.40984120685959
# (8, 34) -154.55860167467168
# (8, 38) -12.70637614831658
# (8, 45) -1.9700267222135581
# (8, 47) -26.22888272527853
# (8, 70) -625.162601111542
# (8, 71) -41.55446975105174
# (8, 73) -0.3040007903367447
# (8, 79) -14.770638420237
# (8, 80) -72.46481118275018
# (8, 83) -38.93099317322253
# (8, 84) -81.74902725527457
# (8, 86) -13.756160706160149
# (8, 87) -868.3937592207883
# (8, 89) -931.1717899815243
# (8, 90) -0.31801989859791235
# (8, 91) -10.783881863565888
# (8, 92) -6.221003181472405
# (8, 94) -8.87554129783889
# (8, 95) -33.59337751824826
# (8, 98) -28.2059103520512
# (8, 99) -32.68108299827585
# (8, 100) -4.237334808370454
# (8, 101) -283.1261782782612
# (8, 103) -40.527607469338776
# (8, 104) -13.62786747956252
# (8, 105) -4636.387926180621
# (8, 106) -2.0579028520989273
# (8, 107) -0.43331948001655823
# (8, 109) -3.3304907034738402
# (8, 110) -6.107010433337246
# (8, 112) -56.78669738014912
# (8, 113) -31.95970617119519
# (8, 115) -604.718925854281
# (8, 117) -6.131908389479206
# (8, 119) -1712.8972534058598
# (8, 120) -11.035554705838333
# (8, 124) -6.360407599350099
# (8, 126) -15.024908188932566
# (8, 127) -71.87032953907267
# (8, 128) -301.54142401944165
# (8, 129) -56.94888583908851
# (8, 131) -147.67608791257015
# (8, 138) -2.5999242359113666
# (8, 147) -43.450430755972164
# (8, 149) -25.066870321624222
# (8, 157) -5.871306522242416
# (8, 158) -6.769569919304569
# (8, 159) -19.651127834431243
# (8, 160) -56.60445979277189
# (8, 161) -29.94909331687859
# (8, 162) -25.322170329848028
# (8, 163) -39.98535868651292
# (8, 164) -3.3876033731265007
# (8, 165) -2.337117849204783
# (8, 166) -55.602751489653876
# (8, 167) -559.1473214764048
# (8, 169) -1.7350961538875869
# (8, 170) -1193.0251389405628
# (8, 171) -6.006823191300323
# (8, 173) -1.563750597153107
# (8, 174) -15.238252342273753
# (8, 177) -92.84379390559297
# (8, 182) -0.45764943322311424
# (8, 184) -2544.8534887200144
# (8, 189) -2.2883651182140543
# (8, 191) -3.696541644682738
# (8, 193) -17.28058515328711
# (8, 195) -8.312941906885195
# (8, 197) -8.422861532619981
# (9, 2) -122.95592447874306
# (9, 7) -27.60339637899473
# (9, 8) -31.20688946320125
# (9, 11) -0.9754885110321406
# (9, 12) -3.3886950233922177
# (9, 16) -30.134252253781995
# (9, 18) -34.48419824399328
# (9, 19) -135.47310443724078
# (9, 20) -3.0743126722483085
# (9, 23) -45.43251797113
# (9, 24) -4911.8026921281835
# (9, 26) -11.440835668769523
# (9, 29) -2.5228350403724282
# (9, 30) -5.557556188305363
# (9, 32) -17.127813836296504
# (9, 33) -163.19438342761723
# (9, 34) -28.69705585193114
# (9, 36) -122.47700586245304
# (9, 38) -0.5421731195295969
# (9, 39) -28.151946781496704
# (9, 41) -3.0263141218795986
# (9, 44) -2.0173099591718997
# (9, 47) -58.92665419500358
# (9, 48) -41.27588173804069
# (9, 51) -51.19320906495823
# (9, 56) -36.10502718384486
# (9, 59) -1551.3291410160248
# (9, 60) -1754.7665075597579
# (9, 62) -18.36103630721199
# (9, 72) -87.00108428420297
# (9, 74) -0.6576678684342327
# (9, 75) -4.01148242620406
# (9, 76) -1.9598525756990732
# (9, 78) -6.480763180363643
# (9, 81) -87.94920134401667
# (9, 83) -63.100379665963914
# (9, 87) -1290.716495064585
# (9, 89) -34.18998961477275
# (9, 94) -1.4202611613610454
# (9, 99) -46.99976345045972
# (9, 101) -0.36859668160254555
# (9, 103) -2212.468572660552
# (9, 104) -2612.751754882547
# (9, 105) -9.660002041861375
# (9, 108) -2.1766093270547877
# (9, 109) -2.518945534497895
# (9, 110) -1.4830129094115474
# (9, 114) -77.25804449163323
# (9, 124) -0.8355700614174615
# (9, 126) -4.408078136263638
# (9, 129) -21.779036038969767
# (9, 131) -28.1127050766868
# (9, 132) -129.91098680014397
# (9, 136) -45.666605647040214
# (9, 143) -28.601236082478305
# (9, 144) -84.5882841795518
# (9, 149) -4.048555821549676
# (9, 151) -7.489970362582577
# (9, 156) -1695.6659886011955
# (9, 157) -3.6280200531892124
# (9, 162) -447.82293859527533
# (9, 166) -64.12736668403912
# (9, 167) -582.1042724471693
# (9, 168) -12.46149931521433
# (9, 169) -1189.0877928826687
# (9, 170) -9.308020667027822
# (9, 173) -13.303936966628093
# (9, 174) -7.441955991654855
# (9, 175) -32.506823909602005
# (9, 178) -43.19310391877468
# (9, 180) -1.8207407961818456
# (9, 182) -1.6248499306689812
# (9, 183) -68.79637840931625
# (9, 184) -3740.350651034558
# (9, 185) -3907.1499287526963
# (9, 189) -0.10638365611155338
# (9, 194) -15.685175417047631
# (9, 197) -1.4488971438600533
# Total problematic cases 814
# Total cases 2000

# %%
log_name = 'LoanApp.csv'

base_path = os.path.join('..', '..', 'simulated_data', log_name)
baseline_dir_path = os.path.join(base_path, 'baseline')
optimized_dir_path = os.path.join(base_path, 'autonomous') # Updated path

# Check if directories exist before running
if not os.path.exists(baseline_dir_path) or not os.path.exists(optimized_dir_path):
    print(f"FATAL ERROR: Could not find directories.")
    print(f"Checked for: '{baseline_dir_path}'")
    print(f"Checked for: '{optimized_dir_path}'")
    print("Please ensure the CONFIG section is correct and you have run the simulations.")
else:
    print("--- Analysis 1: Comparing Costs on a Per-Log Basis ---")
    compare_costs_across_logs()
        
    print("\n\n--- Analysis 2: Comparing Aggregated Costs on a Per-Case Basis ---")
    compare_costs_across_cases()
# Out:
# --- Analysis 1: Comparing Costs on a Per-Log Basis ---
# Comparing costs for 10 simulation logs from 'LoanApp.csv'...
#
# --- Log 0 ---
#   Baseline Avg. Case Cost:  $1012.94
#   Optimized Avg. Case Cost: $905.42
#   Cost Reduction: 10.61%
#
# --- Log 1 ---
#   Baseline Avg. Case Cost:  $1081.75
#   Optimized Avg. Case Cost: $1125.23
#   Cost Reduction: -4.02%
#
# --- Log 2 ---
#   Baseline Avg. Case Cost:  $968.88
#   Optimized Avg. Case Cost: $1205.72
#   Cost Reduction: -24.44%
#
# --- Log 3 ---
#   Baseline Avg. Case Cost:  $1199.75
#   Optimized Avg. Case Cost: $1072.75
#   Cost Reduction: 10.59%
#
# --- Log 4 ---
#   Baseline Avg. Case Cost:  $923.37
#   Optimized Avg. Case Cost: $958.81
#   Cost Reduction: -3.84%
#
# --- Log 5 ---
#   Baseline Avg. Case Cost:  $1142.44
#   Optimized Avg. Case Cost: $1060.85
#   Cost Reduction: 7.14%
#
# --- Log 6 ---
#   Baseline Avg. Case Cost:  $1151.10
#   Optimized Avg. Case Cost: $985.40
#   Cost Reduction: 14.39%
#
# --- Log 7 ---
#   Baseline Avg. Case Cost:  $1049.25
#   Optimized Avg. Case Cost: $1093.84
#   Cost Reduction: -4.25%
#
# --- Log 8 ---
#   Baseline Avg. Case Cost:  $1049.49
#   Optimized Avg. Case Cost: $992.03
#   Cost Reduction: 5.48%
#
# --- Log 9 ---
#   Baseline Avg. Case Cost:  $1008.60
#   Optimized Avg. Case Cost: $1071.05
#   Cost Reduction: -6.19%
#
# ========================================
# Overall Average Cost Reduction: 0.55%
# ========================================
#
#
# --- Analysis 2: Comparing Aggregated Costs on a Per-Case Basis ---
# Case-by-case aggregated cost stats:
#
# Case ID: 0
#   Mean Baseline Cost:  $242.49
#   Mean Optimized Cost: $159.46
#   Mean Reduction: 34.24%
#   Median Baseline Cost:  $273.87
#   Median Optimized Cost: $130.94
#   Median Reduction: 52.19%
#
# Case ID: 1
#   Mean Baseline Cost:  $239.70
#   Mean Optimized Cost: $159.31
#   Mean Reduction: 33.54%
#   Median Baseline Cost:  $241.69
#   Median Optimized Cost: $146.89
#   Median Reduction: 39.22%
#
# Case ID: 2
#   Mean Baseline Cost:  $473.53
#   Mean Optimized Cost: $223.72
#   Mean Reduction: 52.75%
#   Median Baseline Cost:  $229.32
#   Median Optimized Cost: $216.42
#   Median Reduction: 5.63%
#
# Case ID: 3
#   Mean Baseline Cost:  $187.37
#   Mean Optimized Cost: $267.38
#   Mean Reduction: -42.71%
#   Median Baseline Cost:  $179.00
#   Median Optimized Cost: $225.21
#   Median Reduction: -25.82%
#
# Case ID: 4
#   Mean Baseline Cost:  $338.55
#   Mean Optimized Cost: $245.25
#   Mean Reduction: 27.56%
#   Median Baseline Cost:  $179.53
#   Median Optimized Cost: $222.39
#   Median Reduction: -23.87%
#
# Case ID: 5
#   Mean Baseline Cost:  $507.77
#   Mean Optimized Cost: $221.91
#   Mean Reduction: 56.30%
#   Median Baseline Cost:  $264.77
#   Median Optimized Cost: $243.00
#   Median Reduction: 8.22%
#
# Case ID: 6
#   Mean Baseline Cost:  $200.82
#   Mean Optimized Cost: $174.26
#   Mean Reduction: 13.22%
#   Median Baseline Cost:  $194.12
#   Median Optimized Cost: $179.24
#   Median Reduction: 7.67%
#
# Case ID: 7
#   Mean Baseline Cost:  $337.25
#   Mean Optimized Cost: $160.68
#   Mean Reduction: 52.35%
#   Median Baseline Cost:  $170.92
#   Median Optimized Cost: $151.74
#   Median Reduction: 11.22%
#
# Case ID: 8
#   Mean Baseline Cost:  $942.02
#   Mean Optimized Cost: $516.36
#   Mean Reduction: 45.19%
#   Median Baseline Cost:  $249.64
#   Median Optimized Cost: $190.70
#   Median Reduction: 23.61%
#
# Case ID: 9
#   Mean Baseline Cost:  $935.25
#   Mean Optimized Cost: $1009.77
#   Mean Reduction: -7.97%
#   Median Baseline Cost:  $247.80
#   Median Optimized Cost: $198.86
#   Median Reduction: 19.75%
#
# Case ID: 10
#   Mean Baseline Cost:  $1586.86
#   Mean Optimized Cost: $1409.96
#   Mean Reduction: 11.15%
#   Median Baseline Cost:  $1898.26
#   Median Optimized Cost: $1694.42
#   Median Reduction: 10.74%
#
# Case ID: 11
#   Mean Baseline Cost:  $978.89
#   Mean Optimized Cost: $1452.52
#   Mean Reduction: -48.38%
#   Median Baseline Cost:  $985.66
#   Median Optimized Cost: $1758.32
#   Median Reduction: -78.39%
#
# Case ID: 12
#   Mean Baseline Cost:  $1050.28
#   Mean Optimized Cost: $1944.70
#   Mean Reduction: -85.16%
#   Median Baseline Cost:  $961.14
#   Median Optimized Cost: $1929.79
#   Median Reduction: -100.78%
#
# Case ID: 13
#   Mean Baseline Cost:  $1329.01
#   Mean Optimized Cost: $1623.73
#   Mean Reduction: -22.18%
#   Median Baseline Cost:  $1644.95
#   Median Optimized Cost: $1754.60
#   Median Reduction: -6.67%
#
# Case ID: 14
#   Mean Baseline Cost:  $952.65
#   Mean Optimized Cost: $1331.84
#   Mean Reduction: -39.80%
#   Median Baseline Cost:  $877.88
#   Median Optimized Cost: $1629.94
#   Median Reduction: -85.67%
#
# Case ID: 15
#   Mean Baseline Cost:  $263.69
#   Mean Optimized Cost: $184.64
#   Mean Reduction: 29.98%
#   Median Baseline Cost:  $300.79
#   Median Optimized Cost: $169.34
#   Median Reduction: 43.70%
#
# Case ID: 16
#   Mean Baseline Cost:  $222.52
#   Mean Optimized Cost: $220.65
#   Mean Reduction: 0.84%
#   Median Baseline Cost:  $234.00
#   Median Optimized Cost: $197.27
#   Median Reduction: 15.70%
#
# Case ID: 17
#   Mean Baseline Cost:  $262.90
#   Mean Optimized Cost: $191.97
#   Mean Reduction: 26.98%
#   Median Baseline Cost:  $252.10
#   Median Optimized Cost: $182.40
#   Median Reduction: 27.65%
#
# Case ID: 18
#   Mean Baseline Cost:  $1206.46
#   Mean Optimized Cost: $245.37
#   Mean Reduction: 79.66%
#   Median Baseline Cost:  $236.72
#   Median Optimized Cost: $194.05
#   Median Reduction: 18.03%
#
# Case ID: 19
#   Mean Baseline Cost:  $210.22
#   Mean Optimized Cost: $232.54
#   Mean Reduction: -10.61%
#   Median Baseline Cost:  $205.55
#   Median Optimized Cost: $265.69
#   Median Reduction: -29.26%
#
# Case ID: 20
#   Mean Baseline Cost:  $890.70
#   Mean Optimized Cost: $203.95
#   Mean Reduction: 77.10%
#   Median Baseline Cost:  $181.64
#   Median Optimized Cost: $210.92
#   Median Reduction: -16.12%
#
# Case ID: 21
#   Mean Baseline Cost:  $2138.26
#   Mean Optimized Cost: $192.22
#   Mean Reduction: 91.01%
#   Median Baseline Cost:  $192.29
#   Median Optimized Cost: $169.27
#   Median Reduction: 11.97%
#
# Case ID: 22
#   Mean Baseline Cost:  $1149.13
#   Mean Optimized Cost: $893.80
#   Mean Reduction: 22.22%
#   Median Baseline Cost:  $203.42
#   Median Optimized Cost: $175.63
#   Median Reduction: 13.66%
#
# Case ID: 23
#   Mean Baseline Cost:  $1481.22
#   Mean Optimized Cost: $192.69
#   Mean Reduction: 86.99%
#   Median Baseline Cost:  $210.40
#   Median Optimized Cost: $199.52
#   Median Reduction: 5.17%
#
# Case ID: 24
#   Mean Baseline Cost:  $1438.33
#   Mean Optimized Cost: $2737.32
#   Mean Reduction: -90.31%
#   Median Baseline Cost:  $179.76
#   Median Optimized Cost: $244.45
#   Median Reduction: -35.99%
#
# Case ID: 25
#   Mean Baseline Cost:  $2909.06
#   Mean Optimized Cost: $3376.13
#   Mean Reduction: -16.06%
#   Median Baseline Cost:  $255.68
#   Median Optimized Cost: $3036.45
#   Median Reduction: -1087.59%
#
# Case ID: 26
#   Mean Baseline Cost:  $4609.07
#   Mean Optimized Cost: $2037.41
#   Mean Reduction: 55.80%
#   Median Baseline Cost:  $6152.08
#   Median Optimized Cost: $131.58
#   Median Reduction: 97.86%
#
# Case ID: 27
#   Mean Baseline Cost:  $4476.27
#   Mean Optimized Cost: $6343.46
#   Mean Reduction: -41.71%
#   Median Baseline Cost:  $5963.01
#   Median Optimized Cost: $6099.03
#   Median Reduction: -2.28%
#
# Case ID: 28
#   Mean Baseline Cost:  $5730.21
#   Mean Optimized Cost: $6532.00
#   Mean Reduction: -13.99%
#   Median Baseline Cost:  $6717.97
#   Median Optimized Cost: $7188.84
#   Median Reduction: -7.01%
#
# Case ID: 29
#   Mean Baseline Cost:  $5029.40
#   Mean Optimized Cost: $5172.62
#   Mean Reduction: -2.85%
#   Median Baseline Cost:  $5937.87
#   Median Optimized Cost: $5946.58
#   Median Reduction: -0.15%
#
# Case ID: 30
#   Mean Baseline Cost:  $5500.52
#   Mean Optimized Cost: $5166.15
#   Mean Reduction: 6.08%
#   Median Baseline Cost:  $7111.97
#   Median Optimized Cost: $5947.65
#   Median Reduction: 16.37%
#
# Case ID: 31
#   Mean Baseline Cost:  $218.23
#   Mean Optimized Cost: $240.62
#   Mean Reduction: -10.26%
#   Median Baseline Cost:  $212.38
#   Median Optimized Cost: $245.41
#   Median Reduction: -15.55%
#
# Case ID: 32
#   Mean Baseline Cost:  $231.83
#   Mean Optimized Cost: $245.59
#   Mean Reduction: -5.94%
#   Median Baseline Cost:  $182.02
#   Median Optimized Cost: $251.79
#   Median Reduction: -38.33%
#
# Case ID: 33
#   Mean Baseline Cost:  $227.61
#   Mean Optimized Cost: $354.49
#   Mean Reduction: -55.74%
#   Median Baseline Cost:  $211.64
#   Median Optimized Cost: $202.44
#   Median Reduction: 4.35%
#
# Case ID: 34
#   Mean Baseline Cost:  $238.45
#   Mean Optimized Cost: $638.31
#   Mean Reduction: -167.69%
#   Median Baseline Cost:  $202.42
#   Median Optimized Cost: $181.65
#   Median Reduction: 10.26%
#
# Case ID: 35
#   Mean Baseline Cost:  $214.20
#   Mean Optimized Cost: $191.21
#   Mean Reduction: 10.73%
#   Median Baseline Cost:  $205.62
#   Median Optimized Cost: $214.05
#   Median Reduction: -4.10%
#
# Case ID: 36
#   Mean Baseline Cost:  $401.96
#   Mean Optimized Cost: $356.25
#   Mean Reduction: 11.37%
#   Median Baseline Cost:  $201.68
#   Median Optimized Cost: $194.90
#   Median Reduction: 3.36%
#
# Case ID: 37
#   Mean Baseline Cost:  $459.64
#   Mean Optimized Cost: $177.44
#   Mean Reduction: 61.39%
#   Median Baseline Cost:  $257.98
#   Median Optimized Cost: $161.90
#   Median Reduction: 37.24%
#
# Case ID: 38
#   Mean Baseline Cost:  $615.55
#   Mean Optimized Cost: $193.95
#   Mean Reduction: 68.49%
#   Median Baseline Cost:  $229.29
#   Median Optimized Cost: $175.11
#   Median Reduction: 23.63%
#
# Case ID: 39
#   Mean Baseline Cost:  $760.93
#   Mean Optimized Cost: $356.44
#   Mean Reduction: 53.16%
#   Median Baseline Cost:  $175.97
#   Median Optimized Cost: $188.88
#   Median Reduction: -7.34%
#
# Case ID: 40
#   Mean Baseline Cost:  $513.20
#   Mean Optimized Cost: $470.86
#   Mean Reduction: 8.25%
#   Median Baseline Cost:  $217.60
#   Median Optimized Cost: $187.33
#   Median Reduction: 13.91%
#
# Case ID: 41
#   Mean Baseline Cost:  $1543.89
#   Mean Optimized Cost: $1750.73
#   Mean Reduction: -13.40%
#   Median Baseline Cost:  $1846.62
#   Median Optimized Cost: $1861.15
#   Median Reduction: -0.79%
#
# Case ID: 42
#   Mean Baseline Cost:  $1525.75
#   Mean Optimized Cost: $1337.00
#   Mean Reduction: 12.37%
#   Median Baseline Cost:  $1729.98
#   Median Optimized Cost: $1806.20
#   Median Reduction: -4.41%
#
# Case ID: 43
#   Mean Baseline Cost:  $1713.34
#   Mean Optimized Cost: $1248.78
#   Mean Reduction: 27.11%
#   Median Baseline Cost:  $1695.20
#   Median Optimized Cost: $1632.94
#   Median Reduction: 3.67%
#
# Case ID: 44
#   Mean Baseline Cost:  $1547.64
#   Mean Optimized Cost: $1297.54
#   Mean Reduction: 16.16%
#   Median Baseline Cost:  $1911.42
#   Median Optimized Cost: $1669.63
#   Median Reduction: 12.65%
#
# Case ID: 45
#   Mean Baseline Cost:  $1153.52
#   Mean Optimized Cost: $1596.52
#   Mean Reduction: -38.40%
#   Median Baseline Cost:  $1623.52
#   Median Optimized Cost: $1731.14
#   Median Reduction: -6.63%
#
# Case ID: 46
#   Mean Baseline Cost:  $915.17
#   Mean Optimized Cost: $1222.44
#   Mean Reduction: -33.57%
#   Median Baseline Cost:  $345.41
#   Median Optimized Cost: $1727.45
#   Median Reduction: -400.12%
#
# Case ID: 47
#   Mean Baseline Cost:  $220.28
#   Mean Optimized Cost: $195.14
#   Mean Reduction: 11.41%
#   Median Baseline Cost:  $200.08
#   Median Optimized Cost: $218.78
#   Median Reduction: -9.35%
#
# Case ID: 48
#   Mean Baseline Cost:  $437.27
#   Mean Optimized Cost: $218.77
#   Mean Reduction: 49.97%
#   Median Baseline Cost:  $179.96
#   Median Optimized Cost: $195.68
#   Median Reduction: -8.73%
#
# Case ID: 49
#   Mean Baseline Cost:  $397.17
#   Mean Optimized Cost: $193.30
#   Mean Reduction: 51.33%
#   Median Baseline Cost:  $217.87
#   Median Optimized Cost: $191.59
#   Median Reduction: 12.06%
#
# Case ID: 50
#   Mean Baseline Cost:  $247.68
#   Mean Optimized Cost: $185.12
#   Mean Reduction: 25.26%
#   Median Baseline Cost:  $217.23
#   Median Optimized Cost: $168.00
#   Median Reduction: 22.66%
#
# Case ID: 51
#   Mean Baseline Cost:  $203.80
#   Mean Optimized Cost: $214.12
#   Mean Reduction: -5.07%
#   Median Baseline Cost:  $170.98
#   Median Optimized Cost: $218.73
#   Median Reduction: -27.93%
#
# Case ID: 52
#   Mean Baseline Cost:  $609.06
#   Mean Optimized Cost: $210.29
#   Mean Reduction: 65.47%
#   Median Baseline Cost:  $256.29
#   Median Optimized Cost: $210.65
#   Median Reduction: 17.81%
#
# Case ID: 53
#   Mean Baseline Cost:  $801.78
#   Mean Optimized Cost: $367.80
#   Mean Reduction: 54.13%
#   Median Baseline Cost:  $254.84
#   Median Optimized Cost: $226.42
#   Median Reduction: 11.15%
#
# Case ID: 54
#   Mean Baseline Cost:  $361.94
#   Mean Optimized Cost: $422.86
#   Mean Reduction: -16.83%
#   Median Baseline Cost:  $191.81
#   Median Optimized Cost: $196.17
#   Median Reduction: -2.27%
#
# Case ID: 55
#   Mean Baseline Cost:  $765.83
#   Mean Optimized Cost: $515.28
#   Mean Reduction: 32.72%
#   Median Baseline Cost:  $240.60
#   Median Optimized Cost: $219.01
#   Median Reduction: 8.97%
#
# Case ID: 56
#   Mean Baseline Cost:  $346.66
#   Mean Optimized Cost: $604.52
#   Mean Reduction: -74.38%
#   Median Baseline Cost:  $196.76
#   Median Optimized Cost: $193.41
#   Median Reduction: 1.70%
#
# Case ID: 57
#   Mean Baseline Cost:  $1459.60
#   Mean Optimized Cost: $1046.99
#   Mean Reduction: 28.27%
#   Median Baseline Cost:  $1689.37
#   Median Optimized Cost: $848.22
#   Median Reduction: 49.79%
#
# Case ID: 58
#   Mean Baseline Cost:  $1413.52
#   Mean Optimized Cost: $1357.31
#   Mean Reduction: 3.98%
#   Median Baseline Cost:  $1825.43
#   Median Optimized Cost: $1689.29
#   Median Reduction: 7.46%
#
# Case ID: 59
#   Mean Baseline Cost:  $1036.48
#   Mean Optimized Cost: $1374.87
#   Mean Reduction: -32.65%
#   Median Baseline Cost:  $990.39
#   Median Optimized Cost: $1673.01
#   Median Reduction: -68.92%
#
# Case ID: 60
#   Mean Baseline Cost:  $755.29
#   Mean Optimized Cost: $1465.09
#   Mean Reduction: -93.98%
#   Median Baseline Cost:  $207.63
#   Median Optimized Cost: $1646.78
#   Median Reduction: -693.14%
#
# Case ID: 61
#   Mean Baseline Cost:  $1170.95
#   Mean Optimized Cost: $1382.68
#   Mean Reduction: -18.08%
#   Median Baseline Cost:  $1579.04
#   Median Optimized Cost: $1620.04
#   Median Reduction: -2.60%
#
# Case ID: 62
#   Mean Baseline Cost:  $881.09
#   Mean Optimized Cost: $1313.64
#   Mean Reduction: -49.09%
#   Median Baseline Cost:  $342.84
#   Median Optimized Cost: $1731.82
#   Median Reduction: -405.14%
#
# Case ID: 63
#   Mean Baseline Cost:  $249.70
#   Mean Optimized Cost: $221.29
#   Mean Reduction: 11.38%
#   Median Baseline Cost:  $222.06
#   Median Optimized Cost: $201.26
#   Median Reduction: 9.37%
#
# Case ID: 64
#   Mean Baseline Cost:  $217.84
#   Mean Optimized Cost: $189.79
#   Mean Reduction: 12.88%
#   Median Baseline Cost:  $179.58
#   Median Optimized Cost: $198.90
#   Median Reduction: -10.76%
#
# Case ID: 65
#   Mean Baseline Cost:  $225.39
#   Mean Optimized Cost: $216.59
#   Mean Reduction: 3.91%
#   Median Baseline Cost:  $193.23
#   Median Optimized Cost: $214.61
#   Median Reduction: -11.07%
#
# Case ID: 66
#   Mean Baseline Cost:  $167.91
#   Mean Optimized Cost: $226.93
#   Mean Reduction: -35.15%
#   Median Baseline Cost:  $159.02
#   Median Optimized Cost: $222.88
#   Median Reduction: -40.16%
#
# Case ID: 67
#   Mean Baseline Cost:  $194.54
#   Mean Optimized Cost: $185.64
#   Mean Reduction: 4.58%
#   Median Baseline Cost:  $206.96
#   Median Optimized Cost: $191.73
#   Median Reduction: 7.36%
#
# Case ID: 68
#   Mean Baseline Cost:  $475.40
#   Mean Optimized Cost: $242.94
#   Mean Reduction: 48.90%
#   Median Baseline Cost:  $238.56
#   Median Optimized Cost: $235.99
#   Median Reduction: 1.08%
#
# Case ID: 69
#   Mean Baseline Cost:  $769.10
#   Mean Optimized Cost: $161.27
#   Mean Reduction: 79.03%
#   Median Baseline Cost:  $233.31
#   Median Optimized Cost: $167.61
#   Median Reduction: 28.16%
#
# Case ID: 70
#   Mean Baseline Cost:  $185.59
#   Mean Optimized Cost: $611.49
#   Mean Reduction: -229.49%
#   Median Baseline Cost:  $189.28
#   Median Optimized Cost: $236.30
#   Median Reduction: -24.85%
#
# Case ID: 71
#   Mean Baseline Cost:  $786.63
#   Mean Optimized Cost: $191.88
#   Mean Reduction: 75.61%
#   Median Baseline Cost:  $226.31
#   Median Optimized Cost: $161.12
#   Median Reduction: 28.81%
#
# Case ID: 72
#   Mean Baseline Cost:  $517.38
#   Mean Optimized Cost: $1056.94
#   Mean Reduction: -104.29%
#   Median Baseline Cost:  $163.59
#   Median Optimized Cost: $969.56
#   Median Reduction: -492.68%
#
# Case ID: 73
#   Mean Baseline Cost:  $1311.49
#   Mean Optimized Cost: $1272.19
#   Mean Reduction: 3.00%
#   Median Baseline Cost:  $1682.08
#   Median Optimized Cost: $1715.40
#   Median Reduction: -1.98%
#
# Case ID: 74
#   Mean Baseline Cost:  $1494.69
#   Mean Optimized Cost: $1816.90
#   Mean Reduction: -21.56%
#   Median Baseline Cost:  $1792.19
#   Median Optimized Cost: $1849.78
#   Median Reduction: -3.21%
#
# Case ID: 75
#   Mean Baseline Cost:  $1336.92
#   Mean Optimized Cost: $1446.80
#   Mean Reduction: -8.22%
#   Median Baseline Cost:  $1863.87
#   Median Optimized Cost: $1689.83
#   Median Reduction: 9.34%
#
# Case ID: 76
#   Mean Baseline Cost:  $1187.40
#   Mean Optimized Cost: $1498.54
#   Mean Reduction: -26.20%
#   Median Baseline Cost:  $1599.37
#   Median Optimized Cost: $1648.18
#   Median Reduction: -3.05%
#
# Case ID: 77
#   Mean Baseline Cost:  $1319.84
#   Mean Optimized Cost: $1212.32
#   Mean Reduction: 8.15%
#   Median Baseline Cost:  $1654.09
#   Median Optimized Cost: $1715.29
#   Median Reduction: -3.70%
#
# Case ID: 78
#   Mean Baseline Cost:  $1264.49
#   Mean Optimized Cost: $975.22
#   Mean Reduction: 22.88%
#   Median Baseline Cost:  $1553.47
#   Median Optimized Cost: $955.10
#   Median Reduction: 38.52%
#
# Case ID: 79
#   Mean Baseline Cost:  $373.72
#   Mean Optimized Cost: $189.78
#   Mean Reduction: 49.22%
#   Median Baseline Cost:  $237.11
#   Median Optimized Cost: $187.66
#   Median Reduction: 20.85%
#
# Case ID: 80
#   Mean Baseline Cost:  $192.19
#   Mean Optimized Cost: $202.46
#   Mean Reduction: -5.35%
#   Median Baseline Cost:  $159.28
#   Median Optimized Cost: $196.20
#   Median Reduction: -23.18%
#
# Case ID: 81
#   Mean Baseline Cost:  $253.82
#   Mean Optimized Cost: $214.69
#   Mean Reduction: 15.42%
#   Median Baseline Cost:  $261.60
#   Median Optimized Cost: $165.04
#   Median Reduction: 36.91%
#
# Case ID: 82
#   Mean Baseline Cost:  $223.72
#   Mean Optimized Cost: $212.04
#   Mean Reduction: 5.22%
#   Median Baseline Cost:  $186.54
#   Median Optimized Cost: $196.26
#   Median Reduction: -5.21%
#
# Case ID: 83
#   Mean Baseline Cost:  $320.81
#   Mean Optimized Cost: $182.50
#   Mean Reduction: 43.11%
#   Median Baseline Cost:  $147.85
#   Median Optimized Cost: $169.37
#   Median Reduction: -14.56%
#
# Case ID: 84
#   Mean Baseline Cost:  $368.42
#   Mean Optimized Cost: $193.82
#   Mean Reduction: 47.39%
#   Median Baseline Cost:  $192.80
#   Median Optimized Cost: $180.66
#   Median Reduction: 6.30%
#
# Case ID: 85
#   Mean Baseline Cost:  $402.75
#   Mean Optimized Cost: $183.87
#   Mean Reduction: 54.35%
#   Median Baseline Cost:  $240.92
#   Median Optimized Cost: $199.19
#   Median Reduction: 17.32%
#
# Case ID: 86
#   Mean Baseline Cost:  $399.21
#   Mean Optimized Cost: $191.12
#   Mean Reduction: 52.13%
#   Median Baseline Cost:  $224.20
#   Median Optimized Cost: $186.20
#   Median Reduction: 16.95%
#
# Case ID: 87
#   Mean Baseline Cost:  $702.69
#   Mean Optimized Cost: $630.60
#   Mean Reduction: 10.26%
#   Median Baseline Cost:  $249.41
#   Median Optimized Cost: $183.84
#   Median Reduction: 26.29%
#
# Case ID: 88
#   Mean Baseline Cost:  $1057.80
#   Mean Optimized Cost: $323.68
#   Mean Reduction: 69.40%
#   Median Baseline Cost:  $239.61
#   Median Optimized Cost: $170.99
#   Median Reduction: 28.64%
#
# Case ID: 89
#   Mean Baseline Cost:  $532.25
#   Mean Optimized Cost: $960.72
#   Mean Reduction: -80.50%
#   Median Baseline Cost:  $222.68
#   Median Optimized Cost: $896.63
#   Median Reduction: -302.65%
#
# Case ID: 90
#   Mean Baseline Cost:  $848.03
#   Mean Optimized Cost: $1081.34
#   Mean Reduction: -27.51%
#   Median Baseline Cost:  $260.36
#   Median Optimized Cost: $917.98
#   Median Reduction: -252.59%
#
# Case ID: 91
#   Mean Baseline Cost:  $1255.93
#   Mean Optimized Cost: $1660.87
#   Mean Reduction: -32.24%
#   Median Baseline Cost:  $1683.42
#   Median Optimized Cost: $1650.78
#   Median Reduction: 1.94%
#
# Case ID: 92
#   Mean Baseline Cost:  $1512.89
#   Mean Optimized Cost: $1465.70
#   Mean Reduction: 3.12%
#   Median Baseline Cost:  $1846.23
#   Median Optimized Cost: $1665.78
#   Median Reduction: 9.77%
#
# Case ID: 93
#   Mean Baseline Cost:  $1012.77
#   Mean Optimized Cost: $1529.13
#   Mean Reduction: -50.98%
#   Median Baseline Cost:  $986.60
#   Median Optimized Cost: $1807.80
#   Median Reduction: -83.24%
#
# Case ID: 94
#   Mean Baseline Cost:  $1004.52
#   Mean Optimized Cost: $920.60
#   Mean Reduction: 8.35%
#   Median Baseline Cost:  $952.83
#   Median Optimized Cost: $983.45
#   Median Reduction: -3.21%
#
# Case ID: 95
#   Mean Baseline Cost:  $214.51
#   Mean Optimized Cost: $208.45
#   Mean Reduction: 2.82%
#   Median Baseline Cost:  $210.22
#   Median Optimized Cost: $194.73
#   Median Reduction: 7.37%
#
# Case ID: 96
#   Mean Baseline Cost:  $243.00
#   Mean Optimized Cost: $213.71
#   Mean Reduction: 12.05%
#   Median Baseline Cost:  $248.43
#   Median Optimized Cost: $207.11
#   Median Reduction: 16.63%
#
# Case ID: 97
#   Mean Baseline Cost:  $173.15
#   Mean Optimized Cost: $236.08
#   Mean Reduction: -36.34%
#   Median Baseline Cost:  $182.06
#   Median Optimized Cost: $221.21
#   Median Reduction: -21.50%
#
# Case ID: 98
#   Mean Baseline Cost:  $200.15
#   Mean Optimized Cost: $177.10
#   Mean Reduction: 11.52%
#   Median Baseline Cost:  $198.12
#   Median Optimized Cost: $190.98
#   Median Reduction: 3.61%
#
# Case ID: 99
#   Mean Baseline Cost:  $930.55
#   Mean Optimized Cost: $162.43
#   Mean Reduction: 82.55%
#   Median Baseline Cost:  $221.64
#   Median Optimized Cost: $143.61
#   Median Reduction: 35.21%
#
# Case ID: 100
#   Mean Baseline Cost:  $175.91
#   Mean Optimized Cost: $235.95
#   Mean Reduction: -34.13%
#   Median Baseline Cost:  $150.02
#   Median Optimized Cost: $217.24
#   Median Reduction: -44.81%
#
# Case ID: 101
#   Mean Baseline Cost:  $197.06
#   Mean Optimized Cost: $1777.22
#   Mean Reduction: -801.89%
#   Median Baseline Cost:  $201.93
#   Median Optimized Cost: $242.68
#   Median Reduction: -20.18%
#
# Case ID: 102
#   Mean Baseline Cost:  $1910.71
#   Mean Optimized Cost: $1165.85
#   Mean Reduction: 38.98%
#   Median Baseline Cost:  $257.75
#   Median Optimized Cost: $190.33
#   Median Reduction: 26.16%
#
# Case ID: 103
#   Mean Baseline Cost:  $1502.43
#   Mean Optimized Cost: $2184.56
#   Mean Reduction: -45.40%
#   Median Baseline Cost:  $200.53
#   Median Optimized Cost: $272.32
#   Median Reduction: -35.80%
#
# Case ID: 104
#   Mean Baseline Cost:  $3038.40
#   Mean Optimized Cost: $1748.10
#   Mean Reduction: 42.47%
#   Median Baseline Cost:  $216.19
#   Median Optimized Cost: $186.28
#   Median Reduction: 13.83%
#
# Case ID: 105
#   Mean Baseline Cost:  $3469.40
#   Mean Optimized Cost: $2773.41
#   Mean Reduction: 20.06%
#   Median Baseline Cost:  $3070.35
#   Median Optimized Cost: $229.32
#   Median Reduction: 92.53%
#
# Case ID: 106
#   Mean Baseline Cost:  $5746.50
#   Mean Optimized Cost: $5194.43
#   Mean Reduction: 9.61%
#   Median Baseline Cost:  $7051.07
#   Median Optimized Cost: $6734.79
#   Median Reduction: 4.49%
#
# Case ID: 107
#   Mean Baseline Cost:  $6057.36
#   Mean Optimized Cost: $4865.55
#   Mean Reduction: 19.68%
#   Median Baseline Cost:  $6471.43
#   Median Optimized Cost: $6077.33
#   Median Reduction: 6.09%
#
# Case ID: 108
#   Mean Baseline Cost:  $3190.84
#   Mean Optimized Cost: $5851.48
#   Mean Reduction: -83.38%
#   Median Baseline Cost:  $3167.20
#   Median Optimized Cost: $5998.71
#   Median Reduction: -89.40%
#
# Case ID: 109
#   Mean Baseline Cost:  $2743.07
#   Mean Optimized Cost: $5972.40
#   Mean Reduction: -117.73%
#   Median Baseline Cost:  $242.35
#   Median Optimized Cost: $6523.29
#   Median Reduction: -2591.70%
#
# Case ID: 110
#   Mean Baseline Cost:  $4691.87
#   Mean Optimized Cost: $4132.17
#   Mean Reduction: 11.93%
#   Median Baseline Cost:  $5851.70
#   Median Optimized Cost: $5852.39
#   Median Reduction: -0.01%
#
# Case ID: 111
#   Mean Baseline Cost:  $235.95
#   Mean Optimized Cost: $268.25
#   Mean Reduction: -13.69%
#   Median Baseline Cost:  $244.62
#   Median Optimized Cost: $226.36
#   Median Reduction: 7.47%
#
# Case ID: 112
#   Mean Baseline Cost:  $249.85
#   Mean Optimized Cost: $195.23
#   Mean Reduction: 21.86%
#   Median Baseline Cost:  $256.06
#   Median Optimized Cost: $202.53
#   Median Reduction: 20.90%
#
# Case ID: 113
#   Mean Baseline Cost:  $365.99
#   Mean Optimized Cost: $212.60
#   Mean Reduction: 41.91%
#   Median Baseline Cost:  $199.91
#   Median Optimized Cost: $176.97
#   Median Reduction: 11.47%
#
# Case ID: 114
#   Mean Baseline Cost:  $217.04
#   Mean Optimized Cost: $200.29
#   Mean Reduction: 7.71%
#   Median Baseline Cost:  $190.53
#   Median Optimized Cost: $200.25
#   Median Reduction: -5.10%
#
# Case ID: 115
#   Mean Baseline Cost:  $244.67
#   Mean Optimized Cost: $393.26
#   Mean Reduction: -60.73%
#   Median Baseline Cost:  $256.15
#   Median Optimized Cost: $238.68
#   Median Reduction: 6.82%
#
# Case ID: 116
#   Mean Baseline Cost:  $219.09
#   Mean Optimized Cost: $194.14
#   Mean Reduction: 11.39%
#   Median Baseline Cost:  $209.50
#   Median Optimized Cost: $172.41
#   Median Reduction: 17.70%
#
# Case ID: 117
#   Mean Baseline Cost:  $640.29
#   Mean Optimized Cost: $386.92
#   Mean Reduction: 39.57%
#   Median Baseline Cost:  $234.99
#   Median Optimized Cost: $204.81
#   Median Reduction: 12.84%
#
# Case ID: 118
#   Mean Baseline Cost:  $898.41
#   Mean Optimized Cost: $185.64
#   Mean Reduction: 79.34%
#   Median Baseline Cost:  $219.85
#   Median Optimized Cost: $205.94
#   Median Reduction: 6.33%
#
# Case ID: 119
#   Mean Baseline Cost:  $750.41
#   Mean Optimized Cost: $609.07
#   Mean Reduction: 18.84%
#   Median Baseline Cost:  $243.48
#   Median Optimized Cost: $200.18
#   Median Reduction: 17.78%
#
# Case ID: 120
#   Mean Baseline Cost:  $584.79
#   Mean Optimized Cost: $586.12
#   Mean Reduction: -0.23%
#   Median Baseline Cost:  $201.54
#   Median Optimized Cost: $206.43
#   Median Reduction: -2.42%
#
# Case ID: 121
#   Mean Baseline Cost:  $1013.20
#   Mean Optimized Cost: $1618.63
#   Mean Reduction: -59.75%
#   Median Baseline Cost:  $965.12
#   Median Optimized Cost: $1724.95
#   Median Reduction: -78.73%
#
# Case ID: 122
#   Mean Baseline Cost:  $664.32
#   Mean Optimized Cost: $1384.39
#   Mean Reduction: -108.39%
#   Median Baseline Cost:  $306.07
#   Median Optimized Cost: $1716.29
#   Median Reduction: -460.75%
#
# Case ID: 123
#   Mean Baseline Cost:  $1040.95
#   Mean Optimized Cost: $1567.52
#   Mean Reduction: -50.58%
#   Median Baseline Cost:  $996.62
#   Median Optimized Cost: $1785.64
#   Median Reduction: -79.17%
#
# Case ID: 124
#   Mean Baseline Cost:  $1211.94
#   Mean Optimized Cost: $1625.03
#   Mean Reduction: -34.09%
#   Median Baseline Cost:  $1614.94
#   Median Optimized Cost: $1705.14
#   Median Reduction: -5.58%
#
# Case ID: 125
#   Mean Baseline Cost:  $936.31
#   Mean Optimized Cost: $1629.80
#   Mean Reduction: -74.07%
#   Median Baseline Cost:  $957.90
#   Median Optimized Cost: $1743.25
#   Median Reduction: -81.99%
#
# Case ID: 126
#   Mean Baseline Cost:  $884.46
#   Mean Optimized Cost: $1145.06
#   Mean Reduction: -29.46%
#   Median Baseline Cost:  $445.76
#   Median Optimized Cost: $1594.11
#   Median Reduction: -257.62%
#
# Case ID: 127
#   Mean Baseline Cost:  $229.75
#   Mean Optimized Cost: $456.21
#   Mean Reduction: -98.57%
#   Median Baseline Cost:  $232.46
#   Median Optimized Cost: $183.93
#   Median Reduction: 20.88%
#
# Case ID: 128
#   Mean Baseline Cost:  $170.30
#   Mean Optimized Cost: $218.81
#   Mean Reduction: -28.49%
#   Median Baseline Cost:  $166.81
#   Median Optimized Cost: $191.81
#   Median Reduction: -14.99%
#
# Case ID: 129
#   Mean Baseline Cost:  $259.11
#   Mean Optimized Cost: $232.71
#   Mean Reduction: 10.19%
#   Median Baseline Cost:  $226.26
#   Median Optimized Cost: $187.35
#   Median Reduction: 17.20%
#
# Case ID: 130
#   Mean Baseline Cost:  $235.65
#   Mean Optimized Cost: $201.85
#   Mean Reduction: 14.34%
#   Median Baseline Cost:  $232.74
#   Median Optimized Cost: $187.53
#   Median Reduction: 19.42%
#
# Case ID: 131
#   Mean Baseline Cost:  $219.59
#   Mean Optimized Cost: $191.85
#   Mean Reduction: 12.63%
#   Median Baseline Cost:  $221.61
#   Median Optimized Cost: $200.21
#   Median Reduction: 9.66%
#
# Case ID: 132
#   Mean Baseline Cost:  $511.96
#   Mean Optimized Cost: $198.48
#   Mean Reduction: 61.23%
#   Median Baseline Cost:  $208.18
#   Median Optimized Cost: $184.28
#   Median Reduction: 11.48%
#
# Case ID: 133
#   Mean Baseline Cost:  $517.81
#   Mean Optimized Cost: $188.42
#   Mean Reduction: 63.61%
#   Median Baseline Cost:  $212.57
#   Median Optimized Cost: $175.66
#   Median Reduction: 17.36%
#
# Case ID: 134
#   Mean Baseline Cost:  $754.26
#   Mean Optimized Cost: $178.55
#   Mean Reduction: 76.33%
#   Median Baseline Cost:  $271.42
#   Median Optimized Cost: $149.19
#   Median Reduction: 45.03%
#
# Case ID: 135
#   Mean Baseline Cost:  $708.22
#   Mean Optimized Cost: $541.46
#   Mean Reduction: 23.55%
#   Median Baseline Cost:  $211.72
#   Median Optimized Cost: $217.73
#   Median Reduction: -2.84%
#
# Case ID: 136
#   Mean Baseline Cost:  $1090.19
#   Mean Optimized Cost: $905.41
#   Mean Reduction: 16.95%
#   Median Baseline Cost:  $985.62
#   Median Optimized Cost: $206.91
#   Median Reduction: 79.01%
#
# Case ID: 137
#   Mean Baseline Cost:  $1066.95
#   Mean Optimized Cost: $995.32
#   Mean Reduction: 6.71%
#   Median Baseline Cost:  $1047.71
#   Median Optimized Cost: $206.30
#   Median Reduction: 80.31%
#
# Case ID: 138
#   Mean Baseline Cost:  $1657.18
#   Mean Optimized Cost: $1287.52
#   Mean Reduction: 22.31%
#   Median Baseline Cost:  $1722.65
#   Median Optimized Cost: $1784.13
#   Median Reduction: -3.57%
#
# Case ID: 139
#   Mean Baseline Cost:  $987.54
#   Mean Optimized Cost: $1194.24
#   Mean Reduction: -20.93%
#   Median Baseline Cost:  $319.71
#   Median Optimized Cost: $1688.42
#   Median Reduction: -428.10%
#
# Case ID: 140
#   Mean Baseline Cost:  $1204.71
#   Mean Optimized Cost: $1239.84
#   Mean Reduction: -2.92%
#   Median Baseline Cost:  $1615.79
#   Median Optimized Cost: $1657.42
#   Median Reduction: -2.58%
#
# Case ID: 141
#   Mean Baseline Cost:  $884.18
#   Mean Optimized Cost: $1635.32
#   Mean Reduction: -84.95%
#   Median Baseline Cost:  $184.27
#   Median Optimized Cost: $1746.12
#   Median Reduction: -847.58%
#
# Case ID: 142
#   Mean Baseline Cost:  $1139.80
#   Mean Optimized Cost: $1105.27
#   Mean Reduction: 3.03%
#   Median Baseline Cost:  $1596.95
#   Median Optimized Cost: $1564.59
#   Median Reduction: 2.03%
#
# Case ID: 143
#   Mean Baseline Cost:  $218.06
#   Mean Optimized Cost: $231.09
#   Mean Reduction: -5.98%
#   Median Baseline Cost:  $238.80
#   Median Optimized Cost: $222.94
#   Median Reduction: 6.64%
#
# Case ID: 144
#   Mean Baseline Cost:  $274.06
#   Mean Optimized Cost: $273.68
#   Mean Reduction: 0.14%
#   Median Baseline Cost:  $227.91
#   Median Optimized Cost: $269.05
#   Median Reduction: -18.05%
#
# Case ID: 145
#   Mean Baseline Cost:  $197.97
#   Mean Optimized Cost: $210.96
#   Mean Reduction: -6.56%
#   Median Baseline Cost:  $167.68
#   Median Optimized Cost: $199.20
#   Median Reduction: -18.80%
#
# Case ID: 146
#   Mean Baseline Cost:  $216.61
#   Mean Optimized Cost: $437.38
#   Mean Reduction: -101.92%
#   Median Baseline Cost:  $198.61
#   Median Optimized Cost: $162.79
#   Median Reduction: 18.04%
#
# Case ID: 147
#   Mean Baseline Cost:  $211.18
#   Mean Optimized Cost: $235.79
#   Mean Reduction: -11.65%
#   Median Baseline Cost:  $201.33
#   Median Optimized Cost: $201.17
#   Median Reduction: 0.08%
#
# Case ID: 148
#   Mean Baseline Cost:  $609.66
#   Mean Optimized Cost: $190.94
#   Mean Reduction: 68.68%
#   Median Baseline Cost:  $221.39
#   Median Optimized Cost: $212.58
#   Median Reduction: 3.98%
#
# Case ID: 149
#   Mean Baseline Cost:  $454.51
#   Mean Optimized Cost: $493.71
#   Mean Reduction: -8.62%
#   Median Baseline Cost:  $211.60
#   Median Optimized Cost: $207.38
#   Median Reduction: 2.00%
#
# Case ID: 150
#   Mean Baseline Cost:  $664.75
#   Mean Optimized Cost: $509.54
#   Mean Reduction: 23.35%
#   Median Baseline Cost:  $272.13
#   Median Optimized Cost: $195.75
#   Median Reduction: 28.07%
#
# Case ID: 151
#   Mean Baseline Cost:  $523.00
#   Mean Optimized Cost: $640.57
#   Mean Reduction: -22.48%
#   Median Baseline Cost:  $240.40
#   Median Optimized Cost: $240.18
#   Median Reduction: 0.09%
#
# Case ID: 152
#   Mean Baseline Cost:  $857.81
#   Mean Optimized Cost: $338.37
#   Mean Reduction: 60.55%
#   Median Baseline Cost:  $220.22
#   Median Optimized Cost: $202.77
#   Median Reduction: 7.92%
#
# Case ID: 153
#   Mean Baseline Cost:  $729.96
#   Mean Optimized Cost: $965.93
#   Mean Reduction: -32.33%
#   Median Baseline Cost:  $204.84
#   Median Optimized Cost: $185.48
#   Median Reduction: 9.45%
#
# Case ID: 154
#   Mean Baseline Cost:  $1332.31
#   Mean Optimized Cost: $1234.94
#   Mean Reduction: 7.31%
#   Median Baseline Cost:  $1733.25
#   Median Optimized Cost: $1772.60
#   Median Reduction: -2.27%
#
# Case ID: 155
#   Mean Baseline Cost:  $1321.93
#   Mean Optimized Cost: $1375.37
#   Mean Reduction: -4.04%
#   Median Baseline Cost:  $1679.61
#   Median Optimized Cost: $1639.90
#   Median Reduction: 2.36%
#
# Case ID: 156
#   Mean Baseline Cost:  $906.37
#   Mean Optimized Cost: $1637.43
#   Mean Reduction: -80.66%
#   Median Baseline Cost:  $426.68
#   Median Optimized Cost: $1716.56
#   Median Reduction: -302.31%
#
# Case ID: 157
#   Mean Baseline Cost:  $1064.38
#   Mean Optimized Cost: $1503.87
#   Mean Reduction: -41.29%
#   Median Baseline Cost:  $1072.38
#   Median Optimized Cost: $1774.33
#   Median Reduction: -65.46%
#
# Case ID: 158
#   Mean Baseline Cost:  $1504.92
#   Mean Optimized Cost: $1025.13
#   Mean Reduction: 31.88%
#   Median Baseline Cost:  $1771.54
#   Median Optimized Cost: $957.92
#   Median Reduction: 45.93%
#
# Case ID: 159
#   Mean Baseline Cost:  $268.54
#   Mean Optimized Cost: $201.88
#   Mean Reduction: 24.82%
#   Median Baseline Cost:  $229.57
#   Median Optimized Cost: $190.10
#   Median Reduction: 17.19%
#
# Case ID: 160
#   Mean Baseline Cost:  $222.29
#   Mean Optimized Cost: $188.81
#   Mean Reduction: 15.06%
#   Median Baseline Cost:  $242.14
#   Median Optimized Cost: $198.27
#   Median Reduction: 18.12%
#
# Case ID: 161
#   Mean Baseline Cost:  $222.15
#   Mean Optimized Cost: $232.82
#   Mean Reduction: -4.80%
#   Median Baseline Cost:  $239.47
#   Median Optimized Cost: $217.95
#   Median Reduction: 8.98%
#
# Case ID: 162
#   Mean Baseline Cost:  $237.32
#   Mean Optimized Cost: $416.10
#   Mean Reduction: -75.33%
#   Median Baseline Cost:  $224.08
#   Median Optimized Cost: $236.29
#   Median Reduction: -5.45%
#
# Case ID: 163
#   Mean Baseline Cost:  $394.92
#   Mean Optimized Cost: $237.97
#   Mean Reduction: 39.74%
#   Median Baseline Cost:  $232.55
#   Median Optimized Cost: $218.82
#   Median Reduction: 5.90%
#
# Case ID: 164
#   Mean Baseline Cost:  $237.22
#   Mean Optimized Cost: $221.43
#   Mean Reduction: 6.65%
#   Median Baseline Cost:  $219.10
#   Median Optimized Cost: $199.97
#   Median Reduction: 8.73%
#
# Case ID: 165
#   Mean Baseline Cost:  $643.62
#   Mean Optimized Cost: $228.64
#   Mean Reduction: 64.48%
#   Median Baseline Cost:  $252.73
#   Median Optimized Cost: $227.33
#   Median Reduction: 10.05%
#
# Case ID: 166
#   Mean Baseline Cost:  $371.70
#   Mean Optimized Cost: $196.91
#   Mean Reduction: 47.02%
#   Median Baseline Cost:  $188.10
#   Median Optimized Cost: $197.94
#   Median Reduction: -5.23%
#
# Case ID: 167
#   Mean Baseline Cost:  $1006.23
#   Mean Optimized Cost: $529.80
#   Mean Reduction: 47.35%
#   Median Baseline Cost:  $275.09
#   Median Optimized Cost: $220.53
#   Median Reduction: 19.84%
#
# Case ID: 168
#   Mean Baseline Cost:  $1446.63
#   Mean Optimized Cost: $916.06
#   Mean Reduction: 36.68%
#   Median Baseline Cost:  $1863.37
#   Median Optimized Cost: $212.47
#   Median Reduction: 88.60%
#
# Case ID: 169
#   Mean Baseline Cost:  $1465.95
#   Mean Optimized Cost: $651.78
#   Mean Reduction: 55.54%
#   Median Baseline Cost:  $1826.22
#   Median Optimized Cost: $201.05
#   Median Reduction: 88.99%
#
# Case ID: 170
#   Mean Baseline Cost:  $1271.10
#   Mean Optimized Cost: $1682.08
#   Mean Reduction: -32.33%
#   Median Baseline Cost:  $1599.05
#   Median Optimized Cost: $1943.86
#   Median Reduction: -21.56%
#
# Case ID: 171
#   Mean Baseline Cost:  $914.72
#   Mean Optimized Cost: $1433.62
#   Mean Reduction: -56.73%
#   Median Baseline Cost:  $336.95
#   Median Optimized Cost: $1674.21
#   Median Reduction: -396.88%
#
# Case ID: 172
#   Mean Baseline Cost:  $1009.73
#   Mean Optimized Cost: $1036.76
#   Mean Reduction: -2.68%
#   Median Baseline Cost:  $936.30
#   Median Optimized Cost: $944.83
#   Median Reduction: -0.91%
#
# Case ID: 173
#   Mean Baseline Cost:  $981.45
#   Mean Optimized Cost: $1326.76
#   Mean Reduction: -35.18%
#   Median Baseline Cost:  $984.33
#   Median Optimized Cost: $1663.56
#   Median Reduction: -69.00%
#
# Case ID: 174
#   Mean Baseline Cost:  $958.00
#   Mean Optimized Cost: $1068.66
#   Mean Reduction: -11.55%
#   Median Baseline Cost:  $877.70
#   Median Optimized Cost: $1430.46
#   Median Reduction: -62.98%
#
# Case ID: 175
#   Mean Baseline Cost:  $241.03
#   Mean Optimized Cost: $237.38
#   Mean Reduction: 1.51%
#   Median Baseline Cost:  $206.05
#   Median Optimized Cost: $210.39
#   Median Reduction: -2.11%
#
# Case ID: 176
#   Mean Baseline Cost:  $191.76
#   Mean Optimized Cost: $199.69
#   Mean Reduction: -4.14%
#   Median Baseline Cost:  $161.33
#   Median Optimized Cost: $185.59
#   Median Reduction: -15.04%
#
# Case ID: 177
#   Mean Baseline Cost:  $184.94
#   Mean Optimized Cost: $842.02
#   Mean Reduction: -355.30%
#   Median Baseline Cost:  $186.30
#   Median Optimized Cost: $217.91
#   Median Reduction: -16.97%
#
# Case ID: 178
#   Mean Baseline Cost:  $248.99
#   Mean Optimized Cost: $197.50
#   Mean Reduction: 20.68%
#   Median Baseline Cost:  $238.74
#   Median Optimized Cost: $201.59
#   Median Reduction: 15.56%
#
# Case ID: 179
#   Mean Baseline Cost:  $189.89
#   Mean Optimized Cost: $188.49
#   Mean Reduction: 0.74%
#   Median Baseline Cost:  $181.92
#   Median Optimized Cost: $195.75
#   Median Reduction: -7.60%
#
# Case ID: 180
#   Mean Baseline Cost:  $1575.26
#   Mean Optimized Cost: $213.74
#   Mean Reduction: 86.43%
#   Median Baseline Cost:  $260.65
#   Median Optimized Cost: $230.34
#   Median Reduction: 11.63%
#
# Case ID: 181
#   Mean Baseline Cost:  $231.10
#   Mean Optimized Cost: $913.45
#   Mean Reduction: -295.26%
#   Median Baseline Cost:  $226.50
#   Median Optimized Cost: $260.01
#   Median Reduction: -14.80%
#
# Case ID: 182
#   Mean Baseline Cost:  $2921.38
#   Mean Optimized Cost: $839.32
#   Mean Reduction: 71.27%
#   Median Baseline Cost:  $378.73
#   Median Optimized Cost: $218.15
#   Median Reduction: 42.40%
#
# Case ID: 183
#   Mean Baseline Cost:  $2543.67
#   Mean Optimized Cost: $919.13
#   Mean Reduction: 63.87%
#   Median Baseline Cost:  $192.84
#   Median Optimized Cost: $226.90
#   Median Reduction: -17.66%
#
# Case ID: 184
#   Mean Baseline Cost:  $3556.67
#   Mean Optimized Cost: $3779.43
#   Mean Reduction: -6.26%
#   Median Baseline Cost:  $248.78
#   Median Optimized Cost: $210.62
#   Median Reduction: 15.34%
#
# Case ID: 185
#   Mean Baseline Cost:  $3235.38
#   Mean Optimized Cost: $3094.91
#   Mean Reduction: 4.34%
#   Median Baseline Cost:  $309.51
#   Median Optimized Cost: $209.63
#   Median Reduction: 32.27%
#
# Case ID: 186
#   Mean Baseline Cost:  $4500.94
#   Mean Optimized Cost: $4076.36
#   Mean Reduction: 9.43%
#   Median Baseline Cost:  $6458.96
#   Median Optimized Cost: $3234.41
#   Median Reduction: 49.92%
#
# Case ID: 187
#   Mean Baseline Cost:  $4762.29
#   Mean Optimized Cost: $6755.14
#   Mean Reduction: -41.85%
#   Median Baseline Cost:  $5978.69
#   Median Optimized Cost: $7226.33
#   Median Reduction: -20.87%
#
# Case ID: 188
#   Mean Baseline Cost:  $3347.48
#   Mean Optimized Cost: $5173.68
#   Mean Reduction: -54.55%
#   Median Baseline Cost:  $3071.53
#   Median Optimized Cost: $6005.63
#   Median Reduction: -95.53%
#
# Case ID: 189
#   Mean Baseline Cost:  $4515.59
#   Mean Optimized Cost: $5890.23
#   Mean Reduction: -30.44%
#   Median Baseline Cost:  $5921.55
#   Median Optimized Cost: $5925.70
#   Median Reduction: -0.07%
#
# Case ID: 190
#   Mean Baseline Cost:  $3338.83
#   Mean Optimized Cost: $3308.21
#   Mean Reduction: 0.92%
#   Median Baseline Cost:  $3107.56
#   Median Optimized Cost: $3028.23
#   Median Reduction: 2.55%
#
# Case ID: 191
#   Mean Baseline Cost:  $462.42
#   Mean Optimized Cost: $187.89
#   Mean Reduction: 59.37%
#   Median Baseline Cost:  $205.63
#   Median Optimized Cost: $158.91
#   Median Reduction: 22.72%
#
# Case ID: 192
#   Mean Baseline Cost:  $238.23
#   Mean Optimized Cost: $166.15
#   Mean Reduction: 30.26%
#   Median Baseline Cost:  $192.84
#   Median Optimized Cost: $168.87
#   Median Reduction: 12.43%
#
# Case ID: 193
#   Mean Baseline Cost:  $447.54
#   Mean Optimized Cost: $171.87
#   Mean Reduction: 61.60%
#   Median Baseline Cost:  $185.04
#   Median Optimized Cost: $165.52
#   Median Reduction: 10.55%
#
# Case ID: 194
#   Mean Baseline Cost:  $212.64
#   Mean Optimized Cost: $206.07
#   Mean Reduction: 3.09%
#   Median Baseline Cost:  $184.12
#   Median Optimized Cost: $213.89
#   Median Reduction: -16.17%
#
# Case ID: 195
#   Mean Baseline Cost:  $229.73
#   Mean Optimized Cost: $203.48
#   Mean Reduction: 11.42%
#   Median Baseline Cost:  $237.72
#   Median Optimized Cost: $217.96
#   Median Reduction: 8.31%
#
# Case ID: 196
#   Mean Baseline Cost:  $208.59
#   Mean Optimized Cost: $213.44
#   Mean Reduction: -2.32%
#   Median Baseline Cost:  $212.02
#   Median Optimized Cost: $198.24
#   Median Reduction: 6.50%
#
# Case ID: 197
#   Mean Baseline Cost:  $227.22
#   Mean Optimized Cost: $245.03
#   Mean Reduction: -7.84%
#   Median Baseline Cost:  $226.53
#   Median Optimized Cost: $232.62
#   Median Reduction: -2.69%
#
# Case ID: 198
#   Mean Baseline Cost:  $838.21
#   Mean Optimized Cost: $203.23
#   Mean Reduction: 75.75%
#   Median Baseline Cost:  $219.65
#   Median Optimized Cost: $207.08
#   Median Reduction: 5.72%
#
# Case ID: 199
#   Mean Baseline Cost:  $907.35
#   Mean Optimized Cost: $210.03
#   Mean Reduction: 76.85%
#   Median Baseline Cost:  $191.64
#   Median Optimized Cost: $211.20
#   Median Reduction: -10.21%
#
# ========================================
# Overall Mean Cost Reduction:   -4.32%
# Overall Median Cost Reduction: 3.48%
# ========================================

# %%
def calculate_total_wait_time(df: pd.DataFrame) -> float:
    """
    Calculates the total waiting time for all cases in a log file.

    Wait time is defined as the time between the end of the previous activity
    and the start of the current activity within the same case.

    Args:
        df (pd.DataFrame): The log DataFrame.

    Returns:
        float: The total waiting time in seconds for the entire log.
    """
    if df.empty:
        return 0.0

    # Ensure timestamp columns are in datetime format
    try:
        df['start_timestamp'] = pd.to_datetime(df['start_timestamp'], format='ISO8601')
        df['end_timestamp'] = pd.to_datetime(df['end_timestamp'], format='ISO8601')
    except Exception as e:
        print(f"  Warning: Could not parse timestamps. Error: {e}")
        return 0.0

    # Sort events to ensure correct chronological order within each case
    df = df.sort_values(by=['case_id', 'start_timestamp'])

    # Get the end time of the *previous* activity within the same case
    df['previous_end_timestamp'] = df.groupby('case_id')['end_timestamp'].shift(1)

    # The first activity in a case has no previous end time, so fill with its own start time
    df['previous_end_timestamp'].fillna(df['start_timestamp'], inplace=True)

    # Calculate wait time for each activity
    df['wait_time_seconds'] = (df['start_timestamp'] - df['previous_end_timestamp']).dt.total_seconds()
    
    # Ensure wait times are not negative (can happen with parallel activities)
    df['wait_time_seconds'] = df['wait_time_seconds'].clip(lower=0)
    
    # Return the sum of all wait times
    return df['wait_time_seconds'].sum()


# ==============================================================================
# --- NEW BENCHMARKING FUNCTION ---
# ==============================================================================

def compare_wait_times_across_logs(baseline_dir, optimized_dir, LOG_NAME):
    """
    Compares total wait times between baseline and optimized simulation logs.
    """
    print(f"Comparing total wait times for {LOG_NAME}...\n")
    all_improvements = []

    try:
        baseline_files = [f for f in os.listdir(baseline_dir) if f.startswith('simulated_log_')]
        num_simulations = len(baseline_files)
    except FileNotFoundError:
        print(f"Error: Baseline directory not found at {baseline_dir}")
        return

    for i in range(num_simulations):
        baseline_file = os.path.join(baseline_dir, f'simulated_log_{i}.csv')
        optimized_file = os.path.join(optimized_dir, f'simulated_log_{i}.csv')

        if not os.path.exists(baseline_file) or not os.path.exists(optimized_file):
            print(f"--- Log {i} ---\n  Could not compare due to missing file(s).\n")
            continue

        try:
            df_base = pd.read_csv(baseline_file)
            df_opt = pd.read_csv(optimized_file)
        except Exception as e:
            print(f"--- Log {i} ---\n  Error reading files: {e}\n")
            continue

        total_wait_base = calculate_total_wait_time(df_base)
        total_wait_opt = calculate_total_wait_time(df_opt)

        if total_wait_base > 0:
            # Improvement is a REDUCTION in wait time
            improvement_percent = ((total_wait_base - total_wait_opt) / total_wait_base) * 100
            all_improvements.append(improvement_percent)

            print(f"--- Log {i} ---")
            print(f"  Baseline Total Wait Time:  {total_wait_base / 3600:.2f} hours")
            print(f"  Optimized Total Wait Time: {total_wait_opt / 3600:.2f} hours")
            print(f"  Wait Time Reduction: {improvement_percent:.2f}%\n")
        else:
            print(f"--- Log {i} ---\n  Baseline wait time is zero, cannot calculate improvement.\n")

    if all_improvements:
        overall_avg_improvement = np.mean(all_improvements)
        print("="*40)
        print(f"Overall Average Wait Time Reduction: {overall_avg_improvement:.2f}%")
        print("="*40)

# ==============================================================================
# --- MAIN EXECUTION BLOCK ---
# ==============================================================================

# %%
log_name = 'LoanApp.csv' 
base_path = os.path.join('..', '..', 'simulated_data', log_name)
baseline_dir_path = os.path.join(base_path, 'baseline')
optimized_dir_path = os.path.join(base_path, 'autonomous')


    
base_path = os.path.join('..', '..', 'simulated_data', log_name)
optimized_dir = os.path.join(base_path, 'autonomous')

    # Check if directories exist before running
if not os.path.exists(baseline_dir_path) or not os.path.exists(optimized_dir_path):
    print(f"FATAL ERROR: Could not find directories.")
    print(f"Checked for: '{baseline_dir_path}'")
    print(f"Checked for: '{optimized_dir_path}'")
    print("Please ensure the CONFIG section is correct and you have run the simulations.")
else:
    compare_wait_times_across_logs(baseline_dir_path, optimized_dir_path, 'LoanApp.csv')
# Out:
# Comparing total wait times for LoanApp.csv...
#
# --- Log 0 ---
#   Baseline Total Wait Time:  717.40 hours
#   Optimized Total Wait Time: 563.02 hours
#   Wait Time Reduction: 21.52%
#
# --- Log 1 ---
#   Baseline Total Wait Time:  818.01 hours
#   Optimized Total Wait Time: 579.25 hours
#   Wait Time Reduction: 29.19%
#
# --- Log 2 ---
#   Baseline Total Wait Time:  1012.35 hours
#   Optimized Total Wait Time: 536.74 hours
#   Wait Time Reduction: 46.98%
#
# --- Log 3 ---
#   Baseline Total Wait Time:  470.36 hours
#   Optimized Total Wait Time: 212.50 hours
#   Wait Time Reduction: 54.82%
#
# --- Log 4 ---
#   Baseline Total Wait Time:  601.06 hours
#   Optimized Total Wait Time: 355.53 hours
#   Wait Time Reduction: 40.85%
#
# --- Log 5 ---
#   Baseline Total Wait Time:  295.17 hours
#   Optimized Total Wait Time: 288.36 hours
#   Wait Time Reduction: 2.31%
#
# --- Log 6 ---
#   Baseline Total Wait Time:  494.56 hours
#   Optimized Total Wait Time: 308.85 hours
#   Wait Time Reduction: 37.55%
#
# --- Log 7 ---
#   Baseline Total Wait Time:  899.53 hours
#   Optimized Total Wait Time: 422.31 hours
#   Wait Time Reduction: 53.05%
#
# --- Log 8 ---
#   Baseline Total Wait Time:  703.23 hours
#   Optimized Total Wait Time: 654.26 hours
#   Wait Time Reduction: 6.96%
#
# --- Log 9 ---
#   Baseline Total Wait Time:  545.85 hours
#   Optimized Total Wait Time: 449.57 hours
#   Wait Time Reduction: 17.64%
#
# ========================================
# Overall Average Wait Time Reduction: 31.09%
# ========================================
# /var/folders/x3/5rg2fq097snf05l9glzskh9r0000gn/T/ipykernel_65817/2274668689.py:32: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['previous_end_timestamp'].fillna(df['start_timestamp'], inplace=True)
# /var/folders/x3/5rg2fq097snf05l9glzskh9r0000gn/T/ipykernel_65817/2274668689.py:32: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['previous_end_timestamp'].fillna(df['start_timestamp'], inplace=True)
# /var/folders/x3/5rg2fq097snf05l9glzskh9r0000gn/T/ipykernel_65817/2274668689.py:32: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['previous_end_timestamp'].fillna(df['start_timestamp'], inplace=True)
# /var/folders/x3/5rg2fq097snf05l9glzskh9r0000gn/T/ipykernel_65817/2274668689.py:32: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['previous_end_timestamp'].fillna(df['start_timestamp'], inplace=True)
# /var/folders/x3/5rg2fq097snf05l9glzskh9r0000gn/T/ipykernel_65817/2274668689.py:32: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['previous_end_timestamp'].fillna(df['start_timestamp'], inplace=True)
# /var/folders/x3/5rg2fq097snf05l9glzskh9r0000gn/T/ipykernel_65817/2274668689.py:32: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['previous_end_timestamp'].fillna(df['start_timestamp'], inplace=True)
# /var/folders/x3/5rg2fq097snf05l9glzskh9r0000gn/T/ipykernel_65817/2274668689.py:32: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['previous_end_timestamp'].fillna(df['start_timestamp'], inplace=True)
# /var/folders/x3/5rg2fq097snf05l9glzskh9r0000gn/T/ipykernel_65817/2274668689.py:32: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['previous_end_timestamp'].fillna(df['start_timestamp'], inplace=True)
# /var/folders/x3/5rg2fq097snf05l9glzskh9r0000gn/T/ipykernel_65817/2274668689.py:32: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['previous_end_timestamp'].fillna(df['start_timestamp'], inplace=True)
# /var/folders/x3/5rg2fq097snf05l9glzskh9r0000gn/T/ipykernel_65817/2274668689.py:32: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['previous_end_timestamp'].fillna(df['start_timestamp'], inplace=True)
# /var/folders/x3/5rg2fq097snf05l9glzskh9r0000gn/T/ipykernel_65817/2274668689.py:32: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['previous_end_timestamp'].fillna(df['start_timestamp'], inplace=True)
# /var/folders/x3/5rg2fq097snf05l9glzskh9r0000gn/T/ipykernel_65817/2274668689.py:32: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['previous_end_timestamp'].fillna(df['start_timestamp'], inplace=True)
# /var/folders/x3/5rg2fq097snf05l9glzskh9r0000gn/T/ipykernel_65817/2274668689.py:32: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['previous_end_timestamp'].fillna(df['start_timestamp'], inplace=True)
# /var/folders/x3/5rg2fq097snf05l9glzskh9r0000gn/T/ipykernel_65817/2274668689.py:32: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['previous_end_timestamp'].fillna(df['start_timestamp'], inplace=True)
# /var/folders/x3/5rg2fq097snf05l9glzskh9r0000gn/T/ipykernel_65817/2274668689.py:32: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['previous_end_timestamp'].fillna(df['start_timestamp'], inplace=True)
# /var/folders/x3/5rg2fq097snf05l9glzskh9r0000gn/T/ipykernel_65817/2274668689.py:32: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['previous_end_timestamp'].fillna(df['start_timestamp'], inplace=True)
# /var/folders/x3/5rg2fq097snf05l9glzskh9r0000gn/T/ipykernel_65817/2274668689.py:32: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['previous_end_timestamp'].fillna(df['start_timestamp'], inplace=True)
# /var/folders/x3/5rg2fq097snf05l9glzskh9r0000gn/T/ipykernel_65817/2274668689.py:32: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['previous_end_timestamp'].fillna(df['start_timestamp'], inplace=True)
# /var/folders/x3/5rg2fq097snf05l9glzskh9r0000gn/T/ipykernel_65817/2274668689.py:32: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['previous_end_timestamp'].fillna(df['start_timestamp'], inplace=True)
# /var/folders/x3/5rg2fq097snf05l9glzskh9r0000gn/T/ipykernel_65817/2274668689.py:32: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['previous_end_timestamp'].fillna(df['start_timestamp'], inplace=True)

# %%
log_name = 'LoanApp.csv' 
    
base_path = os.path.join('..', '..', 'simulated_data', log_name)
optimized_dir = os.path.join(base_path, 'autonomous')


optimized_logs= []
for i in range(10):
    optimized_file = os.path.join(optimized_dir, f'simulated_log_{i}.csv')
    optimized_df = pd.read_csv(optimized_file)
    optimized_logs.append(optimized_df)

baseline_dir = os.path.join(base_path, 'baseline')


baseline_logs= []
for i in range(10):
    baseline_file = os.path.join(baseline_dir, f'simulated_log_{i}.csv')
    baseline_df = pd.read_csv(baseline_file)
    baseline_logs.append(baseline_df)

# %%
optimized_logs_0_cost = add_activity_cost_column(optimized_logs[0], AGENT_COSTS)
baseline_logs_0_cost = add_activity_cost_column(baseline_logs[0], AGENT_COSTS)

# %%
optimized_logs_0_cost[optimized_logs_0_cost['case_id']==50]
# Out:
#      case_id  agent                        activity_name  \
# 346       50      9  Check application form completeness
# 348       50      3                    Appraise property
# 352       50      0                 Check credit history
# 357       50      7                            AML check
# 363       50     13                     Assess loan risk
# 368       50     13                    Design loan offer
# 378       50     14                   Approve loan offer
# 385       50     10                   Cancel application
#
#                         start_timestamp                       end_timestamp  \
# 346           2023-04-25 09:00:00+00:00 2023-04-25 09:03:54.726464335+00:00
# 348 2023-04-25 09:03:54.726464335+00:00 2023-04-25 09:25:32.309296008+00:00
# 352 2023-04-25 09:25:32.309296008+00:00 2023-04-25 09:26:02.540782713+00:00
# 357 2023-04-25 09:26:02.540782713+00:00 2023-04-25 09:39:15.453701600+00:00
# 363 2023-04-25 09:39:15.453701600+00:00 2023-04-25 09:59:15.453701600+00:00
# 368 2023-04-25 09:59:15.453701600+00:00 2023-04-25 10:03:54.191550507+00:00
# 378 2023-04-25 10:03:54.191550507+00:00 2023-04-25 10:23:54.191550507+00:00
# 385 2023-04-25 10:23:54.191550507+00:00 2023-04-25 10:28:54.191550507+00:00
#
#      TimeStep                 resource  duration_seconds  cost_per_hour  \
# 346       384             Clerk-000006        234.726464             90
# 348       386         Appraiser-000001       1297.582832             90
# 352       390             Clerk-000001         30.231487             30
# 357       395  AML Investigator-000002        792.912919            110
# 363       401      Loan Officer-000002       1200.000000             95
# 368       406      Loan Officer-000002        278.737849             95
# 378       416    Senior Officer-000001       1200.000000            150
# 385       423             Clerk-000007        300.000000             30
#
#      activity_cost
# 346       5.868162
# 348      32.439571
# 352       0.251929
# 357      24.227895
# 363      31.666667
# 368       7.355582
# 378      50.000000
# 385       2.500000

# %%
baseline_logs_0_cost[baseline_logs_0_cost['case_id']==194]
# Out:
#       case_id  agent                        activity_name  \
# 1429      194      4  Check application form completeness
# 1432      194      7                            AML check
# 1438      194      0                 Check credit history
# 1443      194      6                    Appraise property
# 1453      194     11                     Assess loan risk
# 1457      194     13                    Design loan offer
# 1460      194     17                   Approve loan offer
# 1465      194      1                  Approve application
#
#                          start_timestamp                       end_timestamp  \
# 1429           2023-05-08 09:00:00+00:00 2023-05-08 09:02:46.537850782+00:00
# 1432 2023-05-08 09:02:46.537850782+00:00 2023-05-08 09:04:51.624568721+00:00
# 1438 2023-05-08 09:04:51.624568721+00:00 2023-05-08 09:25:23.351810765+00:00
# 1443 2023-05-08 10:11:34.354388136+00:00 2023-05-08 11:09:57.530088552+00:00
# 1453 2023-05-08 11:09:57.530088552+00:00 2023-05-08 11:29:57.530088552+00:00
# 1457 2023-05-08 11:29:57.530088552+00:00 2023-05-08 11:30:28.916392668+00:00
# 1460 2023-05-08 11:30:28.916392668+00:00 2023-05-08 11:50:28.916392668+00:00
# 1465 2023-05-08 11:50:28.916392668+00:00 2023-05-08 11:55:28.916392668+00:00
#
#       TimeStep                 resource  duration_seconds  cost_per_hour  \
# 1429      1512             Clerk-000003        166.537851             60
# 1432      1515  AML Investigator-000002        125.086718            110
# 1438      1521             Clerk-000001       1231.727242             30
# 1443      1526         Appraiser-000002       3503.175700             90
# 1453      1536      Loan Officer-000001       1200.000000             95
# 1457      1540      Loan Officer-000002         31.386304             95
# 1460      1544    Senior Officer-000002       1200.000000            150
# 1465      1551             Clerk-000002        300.000000             30
#
#       activity_cost
# 1429       2.775631
# 1432       3.822094
# 1438      10.264394
# 1443      87.579393
# 1453      31.666667
# 1457       0.828250
# 1460      50.000000
# 1465       2.500000
